# %% [markdown]
# # ⚡ Párhuzamos ügynök munkafolyamatok a GitHub Modellekkel (Python)
#
# ## 📋 Haladó párhuzamos feldolgozás bemutató
#
# Ez a jegyzetfüzet **egyidejű munkafolyamatmintákat** mutat be a Microsoft Agent Framework használatával. Megtanulod, hogyan építs magasan párhuzamos, nagy teljesítményű munkafolyamatokat, ahol több MI ügynök egyszerre működik, jelentősen javítva az áteresztőképességet és lehetővé téve összetett, több szálon futó üzleti folyamatokat.
#
# ## 🎯 Tanulási célok
#
# ### 🚀 **Az egyidejű feldolgozás alapjai**
# - **Ügynökök párhuzamos futtatása**: Több ügynök egyidejű futtatása a maximális hatékonyságért
# - **Munkafolyamat koordináció**: Egyidejű műveletek összehangolása az adatkonzisztencia megtartásával
# - **Teljesítményoptimalizálás**: Jelentős gyorsulás párhuzamos feldolgozással
# - **Erőforrás-kezelés**: Az MI modell erőforrásainak hatékony kihasználása egyidejű műveletek alatt
#
# ### 🏗️ **Haladó párhuzamos minták**
# - **Fork-Join feldolgozás**: Munka felosztása több ügynökre és eredmények egyesítése
# - **Csővezér párhuzamosság**: Átfedő végrehajtási lépések a folyamatos áteresztőképességért
# - **Terheléselosztás**: Munkamegosztás egyenletesen a rendelkezésre álló ügynök erőforrások között
# - **Szinkronizációs pontok**: Egyidejű ügynökök összehangolása a kritikus munkafolyamat-fázisokban
#
# ### 🏢 **Vállalati párhuzamos alkalmazások**
# - **Nagy volumenű dokumentumfeldolgozás**: Több dokumentum egyidejű feldolgozása
# - **Valós idejű tartalomelemzés**: Bejövő adatfolyamok egyidejű elemzése
# - **Csomagfeldolgozás optimalizálás**: Maximális áteresztőképesség nagy léptékű műveleteknél
# - **Multimodális elemzés**: Különböző tartalomtípusok (szöveg, képek, adatok) párhuzamos feldolgozása
#
# ## ⚙️ Előfeltételek és beállítás
#
# ### 📦 **Szükséges függőségek**
#
# Telepítsd az Agent Frameworköt egyidejű munkafolyamatok támogatásával:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Modellek konfigurációja**
#
# **Környezet beállítása (.env fájl):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Egyidejű feldolgozási megfontolások:**
# - **Korlátozások**: Figyeld a GitHub Modellek API sebességkorlátját egyidejű kérések esetén
# - **Erőforrás használat**: Vedd figyelembe a memória- és CPU-használatot több párhuzamos ügynöknél
# - **Hibakezelés**: Robust hibakezelést valósíts meg párhuzamos műveleteknél
#
# ### 🏗️ **Egyidejű munkafolyamat architektúra**
#
# ```mermaid
# graph TD
#     A[Munkafolyamat Indítása] --> B[Párhuzamos Végrehajtás]
#     B --> C[Ügynök Csoport 1]
#     B --> D[Ügynök Csoport 2]
#     B --> E[Ügynök Csoport 3]
#     C --> F[Eredmény Összegzés]
#     D --> F
#     E --> F
#     F --> G[Végső Kimenet]
#
#     H[GitHub Modellek API] --> C
#     H --> D
#     H --> E
# ```
#
# **Fő előnyök:**
# - **⚡ Teljesítmény**: Jelentős gyorsulás párhuzamos végrehajtással
# - **📈 Skálázhatóság**: Nagyobb terhelések kezelése arányos időnövekedés nélkül
# - **🔄 Hatékonyság**: Jobb kihasználása a rendelkezésre álló számítási erőforrásoknak
# - **🎯 Áteresztőképesség**: Több munka feldolgozása ugyanannyi idő alatt
#
# ## 🎨 **Párhuzamos munkafolyamat tervezési minták**
#
# ### 🔍 **Kutatási és elemzési csővezeték**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Adatfeldolgozó munkafolyamat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Tartalomkészítő csővezeték**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Többfázisú feldolgozás**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Vállalati teljesítmény előnyök**
#
# ### ⚡ **Áteresztőképesség optimalizálás**
# - **Párhuzamos végrehajtás**: Több ügynök egyidejű munkája
# - **Erőforrás kihasználás**: A rendelkezésre álló MI modell kapacitás maximális kihasználása
# - **Időcsökkentés**: Jelentős csökkenés az összes feldolgozási időben
# - **Skálázható architektúra**: Szükség esetén könnyen bővíthető további párhuzamos ügynökökkel
#
# ### 🛡️ **Megbízhatóság és rugalmasság**
# - **Hibatűrés**: Egyedi ügynökhibák nem állítják le az egész munkafolyamatot
# - **Hiba izoláció**: Egy párhuzamos ág problémái nem befolyásolják a többit
# - **Zökkenőmentes lecsengés**: A rendszer működik még csökkentett ügynökkapacitás mellett is
# - **Helyreállítási mechanizmusok**: Automatikus újrapróbálkozás és hibakezelés a sikertelen műveleteknél
#
# ### 📊 **Megfigyelés és átláthatóság**
# - **Egyidejű végrehajtás nyomon követése**: Minden párhuzamos művelet előrehaladásának figyelése
# - **Teljesítménymutatók**: Gyorsulás és hatékonyságnövekedés mérése
# - **Erőforrás-használat elemzés**: A párhuzamos ügynök allokáció optimalizálása
# - **Fékek azonosítása**: Teljesítménybeli szűk keresztmetszetek feltárása és megoldása
#
# Készítsünk nagy teljesítményű, párhuzamos MI munkafolyamatokat! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Jogi nyilatkozat**:
# Ez a dokumentum az AI fordítási szolgáltatás, a [Co-op Translator](https://github.com/Azure/co-op-translator) segítségével készült. Bár az pontosságra törekszünk, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti dokumentum az anyanyelvén tekintendő hiteles forrásnak. Fontos információk esetén professzionális emberi fordítást javasolunk. Nem vállalunk felelősséget semmilyen félreértésért vagy téves értelmezésért, amely ebből a fordításból ered.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
