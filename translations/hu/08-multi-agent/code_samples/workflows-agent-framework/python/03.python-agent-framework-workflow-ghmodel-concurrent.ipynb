# %% [markdown]
# # ⚡ Egyidejű Ügynök Munkafolyamatok a Microsoft Foundry-val (Python)
#
# ## 📋 Fejlett Párhuzamos Feldolgozási Bemutató
#
# Ez a jegyzetfüzet **egyidejű munkafolyamat-mintákat** mutat be a Microsoft Agent Framework segítségével. Megtanulhatod, hogyan lehet nagy teljesítményű, párhuzamos feldolgozási munkafolyamatokat építeni, ahol több MI ügynök egyszerre hajtódik végre, jelentősen javítva a feldolgozási sebességet és lehetővé téve fejlett, többszálú üzleti folyamatokat.
#
# > **Áttérés megjegyzés:** Ez a minta korábban a GitHub Modellekre hivatkozott. A GitHub Modellek elavultak (2026 júliusában megszűnnek), ezért most a **Microsoft Foundry**-t használja a `FoundryChatClient`-en keresztül, amely az Azure OpenAI **Responses API**-t célozza.
#
# ## 🎯 Tanulási Célok
#
# ### 🚀 **Egyidejű Feldolgozás Alapjai**
# - **Párhuzamos Ügynök Végrehajtás**: Több ügynök egyidejű futtatása a maximális hatékonyság érdekében
# - **Munkafolyamat Orkesztráció**: Egyidejű műveletek koordinálása az adatkonzisztencia megőrzése mellett
# - **Teljesítmény-optimalizáció**: Jelentős gyorsulás elérése párhuzamos feldolgozással
# - **Erőforrás-kezelés**: AI modell erőforrásainak hatékony kihasználása az egyidejű műveleteknél
#
# ### 🏗️ **Fejlett Egyidejűségi Minták**
# - **Fork-Join Feldolgozás**: Munka felosztása több ügynökre és az eredmények egyesítése
# - **Folyamatpárhuzamúság**: Végrehajtási szakaszok átfedése a folyamatos áteresztőképesség érdekében
# - **Terhelés Egyensúlyozás**: Munka egyenletes elosztása a rendelkezésre álló ügynök erőforrások között
# - **Szinkronizációs Pontok**: Egyidejű ügynökök koordinálása kritikus munkafolyamat szakaszokban
#
# ### 🏢 **Vállalati Egyidejű Alkalmazások**
# - **Nagy Volumenű Dokumentumfeldolgozás**: Több dokumentum egyidejű feldolgozása
# - **Valós Idejű Tartalomelemzés**: Bejövő adatfolyamok egyidejű elemzése
# - **Batch Feldolgozás Optimalizáció**: Maximális áteresztőképesség nagy léptékű műveleteknél
# - **Többmodalitás Elemzés**: Különböző tartalomtípusok párhuzamos feldolgozása (szöveg, képek, adatok)
#
# ## ⚙️ Előfeltételek és Beállítás
#
# ### 📦 **Szükséges Függőségek**
#
# Telepítsd az Agent Framework-öt egyidejű munkafolyamat képességekkel:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Konfiguráció**
#
# Jelentkezz be az Azure CLI-vel (`az login`), hogy az `AzureCliCredential` hitelesíthessen, majd állítsd be a Microsoft Foundry projekt részleteit.
#
# **Környezeti beállítás (.env fájl):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Egyidejű feldolgozási megfontolások:**
# - **Sebességkorlátok**: Figyeld az Azure OpenAI sebességkorlátokat az egyidejű kérésekhez
# - **Erőforrás Használat**: Figyelembe véve a memória- és CPU-felhasználást több egyidejű ügynöknél
# - **Hibakezelés**: Robusztus hibakezelés megvalósítása párhuzamos műveletekhez
#
# ### 🏗️ **Egyidejű Munkafolyamat Architektúra**
#
# ```mermaid
# graph TD
#     A[Munkafolyamat indítása] --> B[Egyidejű végrehajtás]
#     B --> C[Ügynökcsoport 1]
#     B --> D[Ügynökcsoport 2]
#     B --> E[Ügynökcsoport 3]
#     C --> F[Eredmények összesítése]
#     D --> F
#     E --> F
#     F --> G[Végső kimenet]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Főbb Előnyök:**
# - **⚡ Teljesítmény**: Jelentős gyorsulás párhuzamos végrehajtással
# - **📈 Skálázhatóság**: Növekvő munkaterhelések kezelése arányos időnövekedés nélkül
# - **🔄 Hatékonyság**: A rendelkezésre álló számítási erőforrások jobb kihasználása
# - **🎯 Áteresztőképesség**: Több munka feldolgozása azonos idő alatt
#
# ## 🎨 **Egyidejű Munkafolyamat Tervezési Minták**
#
# ### 🔍 **Kutatás és Elemzés Folyamata**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Adatfeldolgozó Munkafolyamat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Tartalomkészítő Folyamat**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Többfázisú Feldolgozás**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Vállalati Teljesítmény Előnyök**
#
# ### ⚡ **Áteresztőképesség Optimalizáció**
# - **Párhuzamos Végrehajtás**: Több ügynök dolgozik egyszerre
# - **Erőforrás Kihasználás**: A rendelkezésre álló MI modell kapacitás maximális kihasználása
# - **Időcsökkentés**: Jelentős csökkenés az összfogási időben
# - **Skálázható Architektúra**: Új egyidejű ügynökök könnyű hozzáadása szükség esetén
#
# ### 🛡️ **Megbízhatóság és Rugalmasság**
# - **Hibatűrés**: Egyedi ügynök hibák nem állítják le az egész munkafolyamatot
# - **Hiba Izoláció**: Egy egyidejű ági probléma nem befolyásolja a többit
# - **Zsályázatos Romlás**: A rendszer működik még csökkentett ügynöki kapacitás mellett is
# - **Helyreállítási Mechanizmusok**: Automatikus újrapróbálkozás és hibakezelés sikertelen műveleteknél
#
# ### 📊 **Monitoring és Megfigyelhetőség**
# - **Egyidejű Végrehajtási Nyomonkövetés**: Az összes párhuzamos művelet előrehaladásának követése
# - **Teljesítménymutatók**: Gyorsulás és hatékonyság mérés
# - **Erőforrás Használat Elemzés**: Az egyidejű ügynök allokáció optimalizálása
# - **Szűk keresztmetszetek Azonosítása**: Teljesítménykorlátok felderítése és megoldása
#
# Építsünk nagy teljesítményű egyidejű MI munkafolyamatokat! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Jogi nyilatkozat**:
# Ez a dokumentum az AI fordítási szolgáltatás, a [Co-op Translator](https://github.com/Azure/co-op-translator) segítségével készült. Bár az pontosságra törekszünk, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti dokumentum az anyanyelvén tekintendő hiteles forrásnak. Fontos információk esetén professzionális emberi fordítást javasolunk. Nem vállalunk felelősséget semmilyen félreértésért vagy téves értelmezésért, amely ebből a fordításból ered.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
