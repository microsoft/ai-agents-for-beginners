# %% [markdown]
# # 🔄 Základní pracovní postupy agentů s Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Návod na orchestraci pracovních postupů
#
# Tento notebook ukazuje, jak vytvářet sofistikované **pracovní postupy agentů** pomocí Microsoft Agent Framework pro .NET a Azure OpenAI (Responses API). Naučíte se vytvářet více-krokové obchodní procesy, ve kterých AI agenti spolupracují na dokončení složitých úkolů prostřednictvím strukturovaných vzorů orchestrací.
#
# ## 🎯 Cíle učení
#
# ### 🏗️ **Základy architektury pracovních postupů**
# - **Workflow Builder**: Navrhněte a orchestrujte složité více-krokové AI procesy
# - **Koordinace agentů**: Koordinujte více specializovaných agentů v rámci pracovních postupů
# - **Azure OpenAI (Responses API)**: Využijte Azure OpenAI Responses API v pracovních postupech
# - **Vizualizace pracovních postupů**: Vytvářejte a zobrazujte struktury pracovních postupů pro lepší pochopení
#
# ### 🔄 **Vzorové vzory orchestrací**
# - **Sekvenční zpracování**: Řetězte více úkolů agentů v logickém pořadí
# - **Správa stavu**: Udržujte kontext a tok dat mezi fázemi pracovního postupu
# - **Zpracování chyb**: Implementujte robustní obnovení po chybách a odolnost pracovních postupů
# - **Optimalizace výkonu**: Navrhujte efektivní pracovní postupy pro rozsáhlé podnikové operace
#
# ### 🏢 **Podnikové aplikace pracovních postupů**
# - **Automatizace obchodních procesů**: Automatizujte složité organizační pracovní postupy
# - **Výrobní proces obsahu**: Redakční pracovní postupy s kontrolami a schvalováním
# - **Automatizace zákaznického servisu**: Více-krokové řešení zákaznických dotazů
# - **Pracovní postupy zpracování dat**: ETL pracovní postupy s AI poháněnou transformací
#
# ## ⚙️ Požadavky a nastavení
#
# ### 📦 **Požadované balíčky NuGet**
#
# Tato ukázka pracovního postupu využívá několik klíčových .NET balíčků:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Konfigurace Azure OpenAI**
#
# **Nastavení prostředí (.env soubor):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Přístup k Azure OpenAI:**
# 1. Vytvořte zdroj Azure OpenAI na portálu Azure
# 2. Nasadťe model (například `gpt-5-mini`) a zaznamenejte název nasazení
# 3. Přihlaste se pomocí `az login` a nastavte proměnné prostředí, jak je uvedeno výše
#
# ### 🏗️ **Přehled architektury pracovních postupů**
#
# ```mermaid
# graph TD
#     A[Tvůrce pracovních postupů] --> B[Registr agentů]
#     B --> C[Motor vykonávání pracovních postupů]
#     C --> D[Agent 1: Generátor obsahu
#     C --> E[Agent 2: Recenzent obsahu
#     D --> F[Výsledky pracovních postupů]
#     E --> F
#     G[Azure OpenAI (API odpovědí)] --> D
#     G --> E
# ```
#
# **Klíčové komponenty:**
# - **WorkflowBuilder**: Hlavní orchestrátor pro navrhování pracovních postupů
# - **AIAgent**: Jednotliví specializovaní agenti s konkrétními schopnostmi
# - **Azure OpenAI Client**: Integrace Azure OpenAI Responses API
# - **Execution Context**: Správa stavu a toku dat mezi fázemi pracovního postupu
#
# ## 🎨 **Vzorové vzory návrhu podnikových pracovních postupů**
#
# ### 📝 **Výrobní pracovní postup obsahu**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Pipeline zpracování dokumentů**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Pracovní postup Business Intelligence**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Automatizace zákaznického servisu**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Podnikové přínosy**
#
# ### 🎯 **Spolehlivost a škálovatelnost**
# - **Deterministické provádění**: Konzistentní, opakovatelný výsledek pracovních postupů
# - **Obnova po chybách**: Elegantní řešení selhání v jakékoli fázi pracovního postupu
# - **Sledování výkonu**: Sledování metrik provádění a možností optimalizace
# - **Správa zdrojů**: Efektivní přidělení a využití zdrojů AI modelů
#
# ### 🔒 **Bezpečnost a shoda**
# - **Bezpečná autentifikace**: Microsoft Entra ID autentifikace pomocí `az login` (AzureCliCredential)
# - **Auditní stopy**: Kompletní záznamy provádění pracovních postupů a rozhodovacích bodů
# - **Řízení přístupu**: Granulární oprávnění k provádění a monitorování pracovních postupů
# - **Ochrana dat**: Bezpečné zpracování citlivých informací v rámci pracovních postupů
#
# ### 📊 **Pozorovatelnost a správa**
# - **Vizualizace pracovních postupů**: Jasná reprezentace toků procesů a závislostí
# - **Sledování provádění**: Sledování průběhu a výkonu pracovních postupů v reálném čase
# - **Hlásení chyb**: Detailní analýza chyb a možnosti ladění
# - **Analytika výkonu**: Metriky pro optimalizaci a plánování kapacit
#
# Postavme váš první AI pracovní postup připravený pro podnik! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Prohlášení o omezení odpovědnosti**:
# Tento dokument byl přeložen pomocí AI překladatelské služby [Co-op Translator](https://github.com/Azure/co-op-translator). Přestože usilujeme o co největší přesnost, mějte prosím na paměti, že automatizované překlady mohou obsahovat chyby nebo nepřesnosti. Originální dokument v jeho mateřském jazyce by měl být považován za autoritativní zdroj. Pro kritické informace se doporučuje profesionální lidský překlad. Nejsme odpovědní za jakékoli nedorozumění nebo nesprávné interpretace vzniklé použitím tohoto překladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
