# %% [markdown]
# # 🔄 Základní pracovní postupy agentů s modely GitHub (Python)
#
# ## 📋 Výukový kurz orchestrací pracovních postupů
#
# Tento notebook představuje výkonné možnosti **Workflow Builder** v Microsoft Agent Framework. Naučte se vytvářet sofistikované, vícekrokové pracovní postupy agentů, které zvládnou komplexní obchodní procesy a koordinují více AI operací bez problémů.
#
# ## 🎯 Výukové cíle
#
# ### 🏗️ **Architektura pracovního postupu**
# - **Workflow Builder**: Navrhování a orchestraci složitých vícekrokových procesů
# - **Provedení založené na událostech**: Zpracování událostí pracovního postupu a přechodů stavů
# - **Vizuální návrh pracovních postupů**: Vytváření a vizualizace struktur pracovních postupů
# - **Integrace modelů GitHub**: Využití AI modelů v kontextu pracovních postupů
#
# ### 🔄 **Orchestraci procesů**
# - **Sekvenční operace**: Řetězení více úkolů agenta v logickém pořadí
# - **Podmíněná logika**: Implementace rozhodovacích bodů a větvení pracovních postupů
# - **Zpracování chyb**: Robustní zotavení z chyb a odolnost pracovních postupů
# - **Správa stavů**: Sledování a řízení stavu provádění pracovních postupů
#
# ### 📊 **Vzorové pracovní postupy pro podniky**
# - **Automatizace obchodních procesů**: Automatizace složitých organizačních pracovních postupů
# - **Koordinace více agentů**: Koordinace více specializovaných agentů
# - **Škálovatelné provádění**: Navrhování pracovních postupů pro podnikové operace v měřítku
# - **Monitorování a pozorovatelnost**: Sledování výkonu pracovních postupů a výsledků
#
# ## ⚙️ Požadavky a nastavení
#
# ### 📦 **Potřebné závislosti**
#
# Nainstalujte Agent Framework s možnostmi pracovních postupů:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Konfigurace modelů GitHub**
#
# **Nastavení prostředí (soubor .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Použití v podnicích**
#
# **Příklady obchodních procesů:**
# - **Zavedení zákazníka**: Vícekrokové ověřovací a nastavovací pracovní postupy
# - **Obsahový řetězec**: Automatizovaná tvorba, kontrola a publikování obsahu
# - **Zpracování dat**: ETL pracovní postupy s AI řízenou transformací
# - **Zajištění kvality**: Automatizované testování a validační procesy
#
# **Výhody pracovních postupů:**
# - 🎯 **Spolehlivost**: Deterministické provádění s obnovou po chybě
# - 📈 **Škálovatelnost**: Zvládnutí automatizace procesů ve velkém rozsahu
# - 🔍 **Pozorovatelnost**: Kompletní auditní stopy a monitorování
# - 🔧 **Udržovatelnost**: Vizuální návrh a modulární komponenty
#
# ## 🎨 Vzory návrhu pracovních postupů
#
# ### Základní struktura pracovního postupu
# ```mermaid
# graph TD
#     A[Start] --> B[Úkol agenta 1]
#     B --> C{Rozhodovací bod}
#     C -->|Úspěch| D[Úkol agenta 2]
#     C -->|Selhání| E[Obsluha chyb]
#     D --> F[Konec]
#     E --> F
# ```
#
# **Klíčové komponenty:**
# - **WorkflowBuilder**: Hlavní orchestrace
# - **WorkflowEvent**: Zpracování událostí a komunikace
# - **WorkflowViz**: Vizuální reprezentace pracovního postupu a ladění
#
# Postavme váš první inteligentní pracovní postup! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()

# %%
# Configure the Azure AI Foundry provider with keyless authentication
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = await provider.create_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = await provider.create_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Prohlášení o omezení odpovědnosti**:
# Tento dokument byl přeložen pomocí AI překladatelské služby [Co-op Translator](https://github.com/Azure/co-op-translator). Přestože usilujeme o co největší přesnost, mějte prosím na paměti, že automatizované překlady mohou obsahovat chyby nebo nepřesnosti. Originální dokument v jeho mateřském jazyce by měl být považován za autoritativní zdroj. Pro kritické informace se doporučuje profesionální lidský překlad. Nejsme odpovědní za jakékoli nedorozumění nebo nesprávné interpretace vzniklé použitím tohoto překladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
