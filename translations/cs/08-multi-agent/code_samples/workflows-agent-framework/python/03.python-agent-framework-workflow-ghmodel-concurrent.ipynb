# %% [markdown]
# # ⚡ Současné pracovní postupy agentů s GitHub modely (Python)
#
# ## 📋 Pokročilý návod na paralelní zpracování
#
# Tento notebook demonstruje **vzory současných pracovních postupů** pomocí Microsoft Agent Framework. Naučíte se, jak vytvářet vysoce výkonné pracovní postupy paralelního zpracování, kde více AI agentů pracuje současně, což dramaticky zlepšuje propustnost a umožňuje sofistikované vícevláknové podnikové procesy.
#
# ## 🎯 Výukové cíle
#
# ### 🚀 **Základy současného zpracování**
# - **Paralelní spouštění agentů**: Spouštění více agentů současně pro maximální efektivitu
# - **Orchestraci pracovních postupů**: Koordinace současných operací při zachování konzistence dat
# - **Optimalizace výkonu**: Dosáhnout významného zrychlení díky paralelnímu zpracování
# - **Správa zdrojů**: Efektivní využití zdrojů AI modelů napříč současnými operacemi
#
# ### 🏗️ **Pokročilé vzory současnosti**
# - **Fork-Join zpracování**: Rozdělení práce mezi více agentů a sloučení výsledků
# - **Pipeline paralelismus**: Překrývající se fáze provádění pro nepřetržitou propustnost
# - **Vyvažování zátěže**: Rovnoměrné rozdělení práce mezi dostupné agentní zdroje
# - **Synchronizační body**: Koordinace současných agentů v kritických fázích pracovního postupu
#
# ### 🏢 **Podnikové aplikace současnosti**
# - **Zpracování velkého objemu dokumentů**: Současné zpracování více dokumentů
# - **Analýza obsahu v reálném čase**: Současná analýza příchozích datových toků
# - **Optimalizace dávkového zpracování**: Maximalizace propustnosti pro rozsáhlé operace
# - **Multi-modální analýza**: Paralelní zpracování různých typů obsahu (text, obrázky, data)
#
# ## ⚙️ Požadavky a nastavení
#
# ### 📦 **Požadované závislosti**
#
# Nainstalujte Agent Framework s podporou současných pracovních postupů:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Konfigurace GitHub modelů**
#
# **Nastavení prostředí (.env soubor):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Úvahy o současném zpracování:**
# - **Limity rychlosti**: Sledujte limity rychlosti API GitHub modelů pro současné požadavky
# - **Využití zdrojů**: Zohledněte paměť a CPU při více současných agentech
# - **Zpracování chyb**: Implementujte robustní zotavení chyb pro paralelní operace
#
# ### 🏗️ **Architektura současných pracovních postupů**
#
# ```mermaid
# graph TD
#     A[Zahájení pracovního postupu] --> B[Souběžné provádění]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Agregace výsledků]
#     D --> F
#     E --> F
#     F --> G[Konečný výstup]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Hlavní přínosy:**
# - **⚡ Výkon**: Významné zrychlení díky paralelnímu běhu
# - **📈 Škálovatelnost**: Zvládnutí zvýšených pracovních zátěží bez úměrného prodloužení doby
# - **🔄 Efektivita**: Lepší využití dostupných výpočetních zdrojů
# - **🎯 Propustnost**: Zpracování více práce ve stejném čase
#
# ## 🎨 **Vzory návrhu současných pracovních postupů**
#
# ### 🔍 **Výzkumný a analytický pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Pracovní postup zpracování dat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline tvorby obsahu**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Vícefázové zpracování**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Podnikové výhody výkonu**
#
# ### ⚡ **Optimalizace propustnosti**
# - **Paralelní provádění**: Více agentů pracujících současně
# - **Využití zdrojů**: Maximální efektivita dostupné kapacity AI modelů
# - **Zkrácení času**: Výrazné zkrácení celkové doby zpracování
# - **Škálovatelná architektura**: Snadné přidání dalších současných agentů podle potřeby
#
# ### 🛡️ **Spolehlivost a odolnost**
# - **Odolnost vůči chybám**: Selhání jednotlivých agentů nezastaví celý pracovní postup
# - **Izolace chyb**: Problémy v jedné současné větvi neovlivní ostatní
# - **Graceful degradation**: Systém pokračuje v provozu i se sníženou kapacitou agentů
# - **Mechanismy zotavení**: Automatické opakování a zpracování chyb u neúspěšných operací
#
# ### 📊 **Monitorování a pozorovatelnost**
# - **Sledování současného běhu**: Monitorování průběhu všech paralelních operací
# - **Metody výkonu**: Měření zrychlení a zisků efektivity
# - **Analýza využití zdrojů**: Optimalizace přidělení současných agentů
# - **Identifikace úzkých míst**: Nájsť a vyřešit výkonové omezení
#
# Pojďme vytvářet vysoce výkonné současné AI pracovní postupy! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Prohlášení o omezení odpovědnosti**:
# Tento dokument byl přeložen pomocí AI překladatelské služby [Co-op Translator](https://github.com/Azure/co-op-translator). Přestože usilujeme o co největší přesnost, mějte prosím na paměti, že automatizované překlady mohou obsahovat chyby nebo nepřesnosti. Originální dokument v jeho mateřském jazyce by měl být považován za autoritativní zdroj. Pro kritické informace se doporučuje profesionální lidský překlad. Nejsme odpovědní za jakékoli nedorozumění nebo nesprávné interpretace vzniklé použitím tohoto překladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
