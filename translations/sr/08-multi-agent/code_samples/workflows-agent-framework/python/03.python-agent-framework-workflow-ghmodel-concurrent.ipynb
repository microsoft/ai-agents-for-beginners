# %% [markdown]
# # ⚡ Конкурентни токови рада агената са GitHub моделима (Python)
#
# ## 📋 Напредни туторијал паралелне обраде
#
# Овај нотебоок демонстрира **образце конкурентних токова рада** користећи Microsoft Agent Framework. Научићете како да изградите високо перформантне, паралелне токове рада у којима више AI агената извршавају задатке истовремено, драматично побољшавајући пропусност и омогућавајући софистициране вишеслојне пословне процесе.
#
# ## 🎯 Циљеви учења
#
# ### 🚀 **Основе конкурентне обраде**
# - **Паралелно извршавање агената**: Покрените више агената истовремено за максималну ефикасност
# - **Оркестрација токова рада**: Координирајте конкурентне операције уз одржавање конзистентности података
# - **Оптимизација перформанси**: Остварите значајно убрзање кроз паралелну обраду
# - **Управљање ресурсима**: Ефикасно користите ресурсе AI модела у конкурентним операцијама
#
# ### 🏗️ **Напредни образци конкурентности**
# - **Fork-Join обрада**: Поделите рад на више агената и спојите резултате
# - **Паралелизам у пипелинама**: Преклапање извршавања фаза за континуирану пропусност
# - **Баланс оптерећења**: Равномерна расподела посла између расположивих ресурса агената
# - **Синхронизациони моменти**: Координација конкурентних агената у критичним фазама тока рада
#
# ### 🏢 **Корпоративне конкурентне апликације**
# - **Обрада докумената великог обима**: Обрада више докумената истовремено
# - **Анализа садржаја у реалном времену**: Конкурентна анализа долазних токова података
# - **Оптимизација пакетне обраде**: Максимизирање пропусности за операције великог обима
# - **Вишемодална анализа**: Паралелна обрада различитих типова садржаја (текст, слике, подаци)
#
# ## ⚙️ Захтеви и подешавање
#
# ### 📦 **Потребне зависности**
#
# Инсталирајте Agent Framework са могућностима конкурентних токова рада:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Конфигурација GitHub модела**
#
# **Подешавање окружења (.env фајл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Разматрања за конкурентну обраду:**
# - **Ограничења брзине**: Пратите ограничења API позива GitHub модела за конкурентне захтеве
# - **Коришћење ресурса**: Узмите у обзир употребу меморије и CPU са више истовремених агената
# - **Руковање грешкама**: Имплементирајте робусно опорављање од грешака за паралелне операције
#
# ### 🏗️ **Архитектура конкурентних токова рада**
#
# ```mermaid
# graph TD
#     A[Почетак радног тока] --> B[Паралелно извршавање]
#     B --> C[Пул агената 1]
#     B --> D[Пул агената 2]
#     B --> E[Пул агената 3]
#     C --> F[Аграгција резултата]
#     D --> F
#     E --> F
#     F --> G[Коначни резултат]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Кључне предности:**
# - **⚡ Перформансе**: Значајно убрзање кроз паралелно извршавање
# - **📈 Скалирање**: Обрада повећаног оптерећења без пропорционалног повећања времена
# - **🔄 Ефикасност**: Боље коришћење расположивих рачунарских ресурса
# - **🎯 Пропусност**: Обрада више посла у истом временском периоду
#
# ## 🎨 **Образци дизајна конкурентних токова рада**
#
# ### 🔍 **Пипелин за истраживање и анализу**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Ток обраде података**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Пипелин за креирање садржаја**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Вишестепена обрада**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Корпоративне предности перформанси**
#
# ### ⚡ **Оптимизација пропусности**
# - **Паралелно извршавање**: Више агената ради истовремено
# - **Коришћење ресурса**: Максимална ефикасност доступног капацитета AI модела
# - **Смањење времена**: Значајно смањење укупног времена обраде
# - **Скалирајућа архитектура**: Лако додавање више конкурентних агената по потреби
#
# ### 🛡️ **Поузданост и отпорност**
# - **Отпорност на грешке**: Неуспеси појединачних агената не заустављају цео ток рада
# - **Изолација грешака**: Проблеми у једној конкурентној гранци не утичу на друге
# - **Грациозно деградирање**: Систем наставља са радом чак и уз смањени капацитет агената
# - **Механизми опоравка**: Аутоматско поновно покретање и руковање грешкама за неуспеле операције
#
# ### 📊 **Праћење и посматрање**
# - **Праћење извршавања истовремено**: Контрола напретка свих паралелних операција
# - **Метрике перформанси**: Мерење убрзања и добитака у ефикасности
# - **Аналитика коришћења ресурса**: Оптимизација доделе конкурентних агената
# - **Идентификација узрока кочења**: Проналажење и решавање ограничења перформанси
#
# Хајде да изградимо високо перформантне конкурентне AI токове рада! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Изјава о одрицању одговорности**:
# Овај документ је преведен коришћењем услуге за аутоматски превод [Co-op Translator](https://github.com/Azure/co-op-translator). Иако тежимо тачности, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитативним извором. За критичне информације препоручује се професионални људски превод. Нисмо одговорни за било каква неспоразума или погрешна тумачења која произилазе из коришћења овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
