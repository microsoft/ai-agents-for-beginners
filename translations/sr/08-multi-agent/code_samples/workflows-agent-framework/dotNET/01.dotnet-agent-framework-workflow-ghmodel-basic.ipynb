# %% [markdown]
# # 🔄 Основни агенцијски токови рада са Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Туторијал о оркестрацији токова рада
#
# Овај бележник показује како направити софистициране **агенцијске токове рада** користећи Microsoft Agent Framework за .NET и Azure OpenAI (Responses API). Научићете како да креирате пословне процесе са више корака у којима AI агенти сарађују да би обавили сложене задатке кроз структуриране обрасце оркестрације.
#
# ## 🎯 Циљеви учења
#
# ### 🏗️ **Основе архитектуре токова рада**
# - **Workflow Builder**: Дизајнирање и оркестрација сложених вишестепених AI процеса
# - **Усклађивање агената**: Координација више специјализованих агената унутар токова рада
# - **Azure OpenAI (Responses API)**: Коришћење Azure OpenAI Responses API у токовима рада
# - **Визуелни дизајн токова рада**: Креирање и визуелизација структура токова рада за боље разумевање
#
# ### 🔄 **Обрасци оркестрације процеса**
# - **Секвенцијална обрада**: Ланац више агенцијских задатака у логичном редоследу
# - **Управљање стањем**: Одржавање контекста и протока података кроз фазе тока рада
# - **Руковање грешкама**: Имплементација робусног опоравка од грешака и отпорности тока рада
# - **Оптимизација перформанси**: Дизајн ефикасних токова рада за пословне операције великог обима
#
# ### 🏢 **Пословне апликације токова рада**
# - **Аутоматизација пословних процеса**: Аутоматизација сложених организационих токова рада
# - **Цевовод производње садржаја**: Уређивачки токови рада са фазама прегледа и одобрења
# - **Аутоматизација корисничке службе**: Решавање корисничких упита у више корака
# - **Токови рада за обраду података**: ETL токови рада са AI-подржаном трансформацијом
#
# ## ⚙️ Захтеви и подешавања
#
# ### 📦 **Потребни NuGet пакети**
#
# За демонстрацију тока рада користи се неколико кључних .NET пакета:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Конфигурација Azure OpenAI**
#
# **Подешавање окружења (датотека .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Приступ Azure OpenAI:**
# 1. Направите Azure OpenAI ресурс у Azure порталу
# 2. Деплојтујте модел (на пример, `gpt-5-mini`) и запишите име деплоја
# 3. Пријавите се помоћу `az login` и конфигуришите променљиве окружења као што је горе приказано
#
# ### 🏗️ **Преглед архитектуре тока рада**
#
# ```mermaid
# graph TD
#     A[Креатор радних токова] --> B[Регистар агената]
#     B --> C[Енгин за извршавање радних токова]
#     C --> D[Agent 1: Генератор садржаја
#     C --> E[Agent 2: Рецензент садржаја
#     D --> F[Резултати радних токова]
#     E --> F
#     G[Azure OpenAI (Responses API)] --> D
#     G --> E
# ```
#
# **Кључне компоненте:**
# - **WorkflowBuilder**: Главни механизам оркестрације за дизајн токова рада
# - **AIAgent**: Појединачни специјализовани агенти са специфичним способностима
# - **Azure OpenAI Client**: Интеграција Azure OpenAI Responses API
# - **Execution Context**: Управљање стањем и протоком података између фаза тока рада
#
# ## 🎨 **Обрасци дизајна пословних токова рада**
#
# ### 📝 **Ток производње садржаја**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Цевовод за обраду докумената**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Ток пословне интелигенције**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Аутоматизација корисничке службе**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Пословне користи**
#
# ### 🎯 **Поузданост и скалабилност**
# - **Детерминистичко извршавање**: Конзистентни, понављиви резултати тока рада
# - **Опоравак од грешака**: Грациозно руковођење грешкама на било којој фази тока рада
# - **Мониторинг перформанси**: Праћење метрика извршења и могућности оптимизације
# - **Управљање ресурсима**: Ефикасна алокација и коришћење ресурса AI модела
#
# ### 🔒 **Безбедност и усаглашеност**
# - **Сигурна аутентификација**: Microsoft Entra ID аутентификација путем `az login` (AzureCliCredential)
# - **Аудит трагови**: Потпуна евиденција извршења тока рада и тачака одлуке
# - **Контрола приступа**: Грануларна права за извршавање и праћење тока рада
# - **Приватност података**: Сигурно руковање осетљивим информацијама кроз целе токове рада
#
# ### 📊 **Посматрање и управљање**
# - **Визуелни дизајн токова рада**: Јасна репрезентација токова процеса и зависности
# - **Праћење извршења**: Праћење напретка тока рада и перформанси у реалном времену
# - **Извештавање о грешкама**: Детаљна анализа грешака и могућности отклањања грешака
# - **Аналитика перформанси**: Метрике за оптимизацију и планирање капацитета
#
# Хајде да направимо ваш први пословно спреман AI ток рада! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Изјава о одрицању одговорности**:
# Овај документ је преведен коришћењем услуге за аутоматски превод [Co-op Translator](https://github.com/Azure/co-op-translator). Иако тежимо тачности, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитативним извором. За критичне информације препоручује се професионални људски превод. Нисмо одговорни за било каква неспоразума или погрешна тумачења која произилазе из коришћења овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
