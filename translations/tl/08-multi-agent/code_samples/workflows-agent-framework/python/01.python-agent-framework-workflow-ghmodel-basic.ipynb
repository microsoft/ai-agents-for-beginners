# %% [markdown]
# # 🔄 Mga Pangunahing Daloy ng Trabaho ng Ahente gamit ang mga Modelo ng GitHub (Python)
#
# ## 📋 Tutorial sa Orkestrasyon ng Daloy ng Trabaho
#
# Ipinapakilala sa notebook na ito ang makapangyarihang mga kakayahan ng **Workflow Builder** ng Microsoft Agent Framework. Matutunan kung paano gumawa ng sopistikadong, multi-step na daloy ng trabaho ng ahente na kayang humawak ng kumplikadong mga proseso ng negosyo at mag-coordinate ng maraming operasyon ng AI nang maayos.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🏗️ **Arkitektura ng Daloy ng Trabaho**
# - **Workflow Builder**: Disenyo at orkestrasyon ng mga kumplikadong multi-step na proseso
# - **Event-Driven Execution**: Pamamahala ng mga kaganapan sa daloy ng trabaho at mga paglipat ng estado
# - **Visual Workflow Design**: Lumikha at magpakita ng mga istruktura ng daloy ng trabaho
# - **GitHub Models Integration**: Pagsasamantala sa mga modelo ng AI sa loob ng mga konteksto ng daloy ng trabaho
#
# ### 🔄 **Orkestrasyon ng Proseso**
# - **Sequential Operations**: Pagkakadena ng maraming mga gawain ng ahente sa lohikal na pagkakasunud-sunod
# - **Conditional Logic**: Pagpapatupad ng mga puntong desisyon at pagsanga ng mga daloy ng trabaho
# - **Error Handling**: Matatag na pag-recover sa mga error at katatagan ng daloy ng trabaho
# - **State Management**: Pagsubaybay at pamamahala ng estado ng pagpapatupad ng daloy ng trabaho
#
# ### 📊 **Mga Pattern ng Daloy ng Trabaho sa Enterprise**
# - **Business Process Automation**: Awtomatikong pagproseso ng kumplikadong mga daloy ng trabaho ng organisasyon
# - **Multi-Agent Coordination**: Pagsasaayos ng maraming espesyalistang ahente
# - **Scalable Execution**: Disenyo ng mga daloy ng trabaho para sa enterprise-scale na mga operasyon
# - **Monitoring & Observability**: Pagsubaybay ng performance at mga kinalabasan ng daloy ng trabaho
#
# ## ⚙️ Mga Kinakailangan & Setup
#
# ### 📦 **Mga Kinakailangang Dependency**
#
# I-install ang Agent Framework na may mga kakayahan sa workflow:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Pag-configure ng mga Modelo ng GitHub**
#
# **Setup ng Kapaligiran (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Mga Gamit sa Enterprise**
#
# **Mga Halimbawa ng Proseso ng Negosyo:**
# - **Customer Onboarding**: Multi-step na beripikasyon at mga daloy ng pagsasaayos
# - **Content Pipeline**: Automated na paglikha, pag-review, at pag-publish ng nilalaman
# - **Data Processing**: ETL na mga daloy ng trabaho na may AI-powered na transformasyon
# - **Quality Assurance**: Automated na pagsubok at validation na mga proseso
#
# **Mga Benepisyo ng Workflow:**
# - 🎯 **Reliability**: Deterministic na pagpapatupad na may pag-recover sa error
# - 📈 **Scalability**: Kakayahang humawak ng high-volume na pag-aautomat ng proseso
# - 🔍 **Observability**: Kumpletong audit trails at pagsubaybay
# - 🔧 **Maintainability**: Visual na disenyo at modular na mga bahagi
#
# ## 🎨 Mga Pattern ng Disenyo ng Daloy ng Trabaho
#
# ### Pangunahing Istruktura ng Daloy ng Trabaho
# ```mermaid
# graph TD
#     A[Magsimula] --> B[Gawain ng Ahente 1]
#     B --> C{Puntong Pangdesisyon}
#     C -->|Tagumpay| D[Gawain ng Ahente 2]
#     C -->|Kabiguan| E[Tagapamahala ng Error]
#     D --> F[Wakas]
#     E --> F
# ```
#
# **Pangunahing Mga Bahagi:**
# - **WorkflowBuilder**: Pangunahing makina ng orkestrasyon
# - **WorkflowEvent**: Pamamahala ng mga kaganapan at komunikasyon
# - **WorkflowViz**: Visual na representasyon ng daloy ng trabaho at debugging
#
# Tayo na't bumuo ng iyong unang intelligent na daloy ng trabaho! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()

# %%
# Configure the Azure AI Foundry provider with keyless authentication
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = await provider.create_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = await provider.create_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
