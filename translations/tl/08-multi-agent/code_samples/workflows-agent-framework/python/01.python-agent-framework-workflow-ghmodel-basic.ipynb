# %% [markdown]
# # 🔄 Pangunahing Daloy ng Trabaho ng Ahente gamit ang GitHub Models (Python)
#
# ## 📋 Tutorial sa Workflow Orchestration
#
# Ipinakikilala ng notebook na ito ang makapangyarihang **Workflow Builder** na kakayahan ng Microsoft Agent Framework. Matutunan kung paano gumawa ng sopistikadong, multi-step na daloy ng trabaho ng ahente na maaaring hawakan ang komplikadong proseso ng negosyo at magkordinasyon ng maraming operasyon ng AI nang maayos.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🏗️ **Arkitektura ng Workflow**
# - **Workflow Builder**: Disenyo at pamahalaan ang mga komplikadong multi-step na proseso
# - **Event-Driven Execution**: Pamahalaan ang mga event ng workflow at mga state transition
# - **Visual Workflow Design**: Gumawa at biswal na ipakita ang mga estruktura ng workflow
# - **GitHub Models Integration**: Gamitin ang mga modelo ng AI sa loob ng mga konteksto ng workflow
#
# ### 🔄 **Pag-oorganisa ng Proseso**
# - **Sequential Operations**: Magkadena ng maraming gawain ng ahente sa lohikal na pagkakasunod
# - **Conditional Logic**: Ipatupad ang mga punto ng desisyon at mga branching workflow
# - **Error Handling**: Matatag na pagbawi sa mga error at katatagan ng workflow
# - **State Management**: Subaybayan at pamahalaan ang estado ng pagpapatupad ng workflow
#
# ### 📊 **Mga Pattern ng Enterprise Workflow**
# - **Business Process Automation**: I-automate ang mga komplikadong workflow ng organisasyon
# - **Multi-Agent Coordination**: Mag-kordinasyon ng maraming espesyalisadong ahente
# - **Scalable Execution**: Disenyo ng mga workflow para sa operasyon sa antas enterprise
# - **Monitoring & Observability**: Subaybayan ang performance at mga resulta ng workflow
#
# ## ⚙️ Mga Kailangan at Setup
#
# ### 📦 **Kinakailangang Mga Dependensya**
#
# I-install ang Agent Framework na may mga kakayahan sa workflow:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Pagsasaayos ng Kapaligiran (file na .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Mga Gamit sa Enterprise**
#
# **Mga Halimbawa ng Proseso ng Negosyo:**
# - **Customer Onboarding**: Multi-step na beripikasyon at setup na workflow
# - **Content Pipeline**: Automated na paglikha, pagsusuri, at pag-publish ng nilalaman
# - **Data Processing**: ETL na mga workflow na may AI-powered na transformasyon
# - **Quality Assurance**: Automated na pagsusuri at mga proseso ng beripikasyon
#
# **Mga Benepisyo ng Workflow:**
# - 🎯 **Reliability**: Deterministikong pagpapatupad na may pagbawi sa error
# - 📈 **Scalability**: Kaya ang automation ng proseso ng malalaking volume
# - 🔍 **Observability**: Kumpletong audit trail at pagmamanman
# - 🔧 **Maintainability**: Biswal na disenyo at mga modular na bahagi
#
# ## 🎨 Mga Pattern sa Disenyo ng Workflow
#
# ### Pangunahing Estruktura ng Workflow
# ```mermaid
# graph TD
#     A[Simula] --> B[Gawain ng Ahente 1]
#     B --> C{Punto ng Desisyon}
#     C -->|Tagumpay| D[Gawain ng Ahente 2]
#     C -->|Kabiguan| E[Tagapamahala ng Error]
#     D --> F[Wakas]
#     E --> F
# ```
#
# **Pangunahing Mga Bahagi:**
# - **WorkflowBuilder**: Pangunahing makina ng orchestration
# - **WorkflowEvent**: Pag-handle ng mga event at komunikasyon
# - **WorkflowViz**: Biswal na representasyon ng workflow at debugging
#
# Gawin natin ang iyong unang matalinong workflow! 🚀

# %%
! pip install agent-framework-core -U

# %%
# 🔄 Import Workflow and Agent Framework Components
# Core components for building sophisticated agent workflows

from agent_framework.openai import OpenAIChatClient    # 🤖 GitHub Models client integration
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz  # 🏗️ Workflow orchestration tools

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()

# %%
# 🔗 Initialize GitHub Models Chat Client for Workflow Operations
# Create the AI client that will power agents within our workflow
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # 🌐 GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # 🔑 Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # 🎯 Selected AI model
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent   = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

front_desk_agent = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(front_desk_agent).add_edge(front_desk_agent, reviewer_agent).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
result =''
async for event in workflow.run_stream('I would like to go to Paris.'):
    if isinstance(event, DatabaseEvent):
        print(f"{event}")
    if isinstance(event, WorkflowEvent):
        result += str(event.data)
        # print(f"Workflow output: {event.data}")

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
