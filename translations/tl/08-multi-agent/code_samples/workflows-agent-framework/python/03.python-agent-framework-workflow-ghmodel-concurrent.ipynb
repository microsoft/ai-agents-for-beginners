# %% [markdown]
# # ⚡ Mga Kasabay-sabay na Workflow ng Ahente gamit ang Microsoft Foundry (Python)
#
# ## 📋 Advanced na Tutorial sa Parallel Processing
#
# Ipinapakita ng notebook na ito ang **mga kasabay-sabay na pattern ng workflow** gamit ang Microsoft Agent Framework. Matututuhan mong bumuo ng mataas na pagganap, parallel processing workflows kung saan maraming AI agents ang nagpapatupad nang sabay-sabay, na lubos na nagpapabuti sa throughput at nagpapahintulot sa sopistikadong multi-threaded na mga proseso ng negosyo.
#
# > **Tala sa migrasyon:** Ang sample na ito ay dating nagre-refer sa GitHub Models. Ang GitHub Models ay deprecated (magtatapos sa Hulyo 2026), kaya ngayon ay gumagamit ito ng **Microsoft Foundry** sa pamamagitan ng `FoundryChatClient`, na nakatuon sa Azure OpenAI **Responses API**.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🚀 **Pangunahing Kaalaman sa Kasabay-sabay na Pagproseso**
# - **Parallel Agent Execution**: Patakbuhin ang maraming ahente nang sabay-sabay para sa pinakamataas na kahusayan
# - **Workflow Orchestration**: I-coordinate ang mga kasabay-sabay na operasyon habang pinananatili ang pagkakapareho ng data
# - **Performance Optimization**: Makamit ang makabuluhang pagpapabilis sa pamamagitan ng parallel processing
# - **Resource Management**: Epektibong gamitin ang mga AI model resources sa mga kasabay-sabay na operasyon
#
# ### 🏗️ **Mga Advanced na Pattern ng Kasabay-sabay**
# - **Fork-Join Processing**: Hatiin ang trabaho sa maraming ahente at pag-isahin ang mga resulta
# - **Pipeline Parallelism**: Nag-o-overlap na mga yugto ng pagpapatupad para sa tuloy-tuloy na throughput
# - **Load Balancing**: Pantay-pantay na ipamahagi ang trabaho sa magagamit na mga ahente
# - **Synchronization Points**: I-coordinate ang mga kasabay-sabay na ahente sa mga kritikal na yugto ng workflow
#
# ### 🏢 **Mga Kasabay-sabay na Aplikasyon sa Enterprise**
# - **High-Volume Document Processing**: Proseso ang maraming dokumento nang sabay-sabay
# - **Real-Time Content Analysis**: Kasabay-sabay na pagsusuri ng papasok na mga stream ng data
# - **Batch Processing Optimization**: Maksimahin ang throughput para sa malawakang operasyon
# - **Multi-Modal Analysis**: Parallel na pagproseso ng iba't ibang uri ng nilalaman (teksto, mga imahe, data)
#
# ## ⚙️ Mga Kinakailangan at Setup
#
# ### 📦 **Mga Kinakailangang Depinisensya**
#
# I-install ang Agent Framework na may kakayahan sa kasabay-sabay na workflow:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Configuration**
#
# Mag-sign in gamit ang Azure CLI (`az login`) upang ma-authenticate ang `AzureCliCredential`, pagkatapos ay itakda ang mga detalye ng iyong Microsoft Foundry project.
#
# **Pag-setup ng Kapaligiran (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Mga Pagsasaalang-alang sa Kasabay-sabay na Pagproseso:**
# - **Rate Limits**: Subaybayan ang mga limitasyon ng rate ng Azure OpenAI para sa mga kasabay-sabay na kahilingan
# - **Resource Usage**: Isaalang-alang ang paggamit ng memorya at CPU sa maraming kasabay-sabay na ahente
# - **Error Handling**: Magpatupad ng matibay na error recovery para sa mga parallel na operasyon
#
# ### 🏗️ **Arkitektura ng Kasabay-sabay na Workflow**
#
# ```mermaid
# graph TD
#     A[Simula ng Daloy ng Trabaho] --> B[Kasabay na Pagsasagawa]
#     B --> C[Pool ng Ahente 1]
#     B --> D[Pool ng Ahente 2]
#     B --> E[Pool ng Ahente 3]
#     C --> F[Pagsasama-sama ng Resulta]
#     D --> F
#     E --> F
#     F --> G[Panghuling Output]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Mga Pangunahing Benepisyo:**
# - **⚡ Performance**: Makabuluhang pagpapabilis sa pamamagitan ng parallel execution
# - **📈 Scalability**: Harapin ang pinalaking mga gawain nang hindi proporsyonal na pagtaas ng oras
# - **🔄 Efficiency**: Mas mahusay na paggamit ng magagamit na mga computational resources
# - **🎯 Throughput**: Proseso ng mas maraming trabaho sa parehong oras
#
# ## 🎨 **Mga Disenyo ng Kasabay-sabay na Workflow**
#
# ### 🔍 **Pananaliksik at Pagsusuri ng Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow sa Pagproseso ng Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline sa Paggawa ng Nilalaman**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Mga Benepisyo sa Pagganap ng Enterprise**
#
# ### ⚡ **Pag-optimize ng Throughput**
# - **Parallel Execution**: Maraming ahente ang gumagana nang sabay-sabay
# - **Resource Utilization**: Pinakamataas na kahusayan ng magagamit na kapasidad ng AI model
# - **Time Reduction**: Makabuluhang pagbabawas ng kabuuang oras ng pagproseso
# - **Scalable Architecture**: Madaling magdagdag ng mas maraming kasabay-sabay na ahente kung kinakailangan
#
# ### 🛡️ **Katiyakan at Katatagan**
# - **Fault Tolerance**: Ang mga pagkabigo ng indibidwal na ahente ay hindi hihinto sa buong workflow
# - **Error Isolation**: Ang mga problema sa isang kasabay-sabay na sangay ay hindi nakakaapekto sa iba
# - **Graceful Degradation**: Patuloy na gumagana ang sistema kahit na may nabawasang kapasidad ng ahente
# - **Recovery Mechanisms**: Awtomatikong retry at error handling para sa mga nabigong operasyon
#
# ### 📊 **Pagsubaybay at Obserbabilidad**
# - **Concurrent Execution Tracking**: Subaybayan ang progreso ng lahat ng parallel na operasyon
# - **Performance Metrics**: Sukatin ang pagpapabilis at mga pakinabang sa kahusayan
# - **Resource Usage Analytics**: I-optimize ang alokasyon ng mga kasabay-sabay na ahente
# - **Bottleneck Identification**: Hanapin at lutasin ang mga limitasyon sa pagganap
#
# Tara, gawing mataas ang pagganap ng kasabay-sabay na AI workflows! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
