# %% [markdown]
# # ⚡ Mga Sabay-sabay na Daloy ng Gawain ng Ahente gamit ang GitHub Models (Python)
#
# ## 📋 Tutorial sa Advanced Parallel Processing
#
# Ipinapakita ng notebook na ito ang **mga sabay-sabay na pattern ng daloy ng gawain** gamit ang Microsoft Agent Framework. Matututuhan mong bumuo ng mga mataas na pagganap, parallel processing workflows kung saan sabay-sabay ang pagtakbo ng maraming AI agents, na malaki ang pinapabilis ng throughput at nagpapagana ng mga sopistikadong multi-threaded na mga proseso ng negosyo.
#
# ## 🎯 Mga Layunin sa Pag-aaral
#
# ### 🚀 **Mga Pangunahing Kaalaman sa Sabay-sabay na Pagproseso**
# - **Parallel Agent Execution**: Patakbuhin ang maraming agents nang sabay-sabay para sa pinakamataas na kahusayan
# - **Workflow Orchestration**: Isaayos ang sabay-sabay na mga operasyon habang pinananatili ang pagiging pare-pareho ng datos
# - **Performance Optimization**: Makamit ang malaking bilis sa pamamagitan ng parallel processing
# - **Resource Management**: Mabisang paggamit ng mga resource ng AI model sa magkakasabay na operasyon
#
# ### 🏗️ **Mga Advanced na Pattern ng Sabay-sabay na Pagproseso**
# - **Fork-Join Processing**: Hatiin ang trabaho sa maraming agents at pagsamahin ang mga resulta
# - **Pipeline Parallelism**: Pagtutulungan ng bawat yugto ng pagsasakatuparan para sa tuloy-tuloy na throughput
# - **Load Balancing**: Pantay-pantay na pamamahagi ng trabaho sa mga magagamit na agent resources
# - **Synchronization Points**: Pagsasabay-sabay ng mga agents sa mga kritikal na yugto ng daloy ng gawain
#
# ### 🏢 **Mga Sabay-sabay na Application ng Enterprise**
# - **High-Volume Document Processing**: Sabay-sabay na pagproseso ng maraming dokumento
# - **Real-Time Content Analysis**: Sabay-sabay na pagsusuri ng mga papasok na data streams
# - **Batch Processing Optimization**: Maksimahin ang throughput para sa malalaking operasyon
# - **Multi-Modal Analysis**: Parallel processing ng iba't ibang uri ng nilalaman (teksto, mga imahe, datos)
#
# ## ⚙️ Mga Kinakailangan at Setup
#
# ### 📦 **Mga Kinakailangang Dependency**
#
# I-install ang Agent Framework na may kakayahan para sa sabay-sabay na daloy ng gawain:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Konfigurasyon ng GitHub Models**
#
# **Pag-setup ng Kapaligiran (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Mga Pagsasaalang-alang sa Sabay-sabay na Pagproseso:**
# - **Rate Limits**: Subaybayan ang mga limitasyon ng rate ng GitHub Models API para sa sabay-sabay na mga kahilingan
# - **Resource Usage**: Isaalang-alang ang paggamit ng memorya at CPU sa maraming sabay-sabay na ahente
# - **Error Handling**: Magpatupad ng matibay na recovery sa error para sa parallel na operasyon
#
# ### 🏗️ **Arkitektura ng Sabay-sabay na Daloy ng Gawain**
#
# ```mermaid
# graph TD
#     A[Simula ng Daloy ng Trabaho] --> B[Sabayan na Pagpapatupad]
#     B --> C[Pool ng Ahente 1]
#     B --> D[Pool ng Ahente 2]
#     B --> E[Pool ng Ahente 3]
#     C --> F[Pagsasama-sama ng Resulta]
#     D --> F
#     E --> F
#     F --> G[Pangwakas na Output]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Pangunahing Benepisyo:**
# - **⚡ Performance**: Malaking pabilis sa pamamagitan ng parallel execution
# - **📈 Scalability**: Hawakan ang tumataas na workload nang hindi proporsyonal na tumataas ang oras
# - **🔄 Efficiency**: Mas mahusay na paggamit ng magagamit na mga computational resource
# - **🎯 Throughput**: Gumawa ng mas maraming trabaho sa parehong oras
#
# ## 🎨 **Mga Disenyo ng Pattern ng Sabay-sabay na Daloy ng Gawain**
#
# ### 🔍 **Pipeline ng Pananaliksik at Pagsusuri**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Daloy ng Pagsusuri ng Datos**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline ng Paglikha ng Nilalaman**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Mga Benepisyo sa Performance ng Enterprise**
#
# ### ⚡ **Optimization ng Throughput**
# - **Parallel Execution**: Maraming agents na nagtatrabaho nang sabay-sabay
# - **Resource Utilization**: Pinakamataas na kahusayan ng magagamit na kapasidad ng AI model
# - **Time Reduction**: Malaking pagbawas sa kabuuang oras ng pagproseso
# - **Scalable Architecture**: Madaling magdagdag ng mas maraming sabay-sabay na agents kung kinakailangan
#
# ### 🛡️ **Katatagan at Resilience**
# - **Fault Tolerance**: Ang pagkabigo ng isang ahente ay hindi humahadlang sa buong daloy ng gawain
# - **Error Isolation**: Ang mga problema sa isang sanga ng sabay-sabay na gawain ay hindi nakakaapekto sa iba
# - **Graceful Degradation**: Patuloy ang operasyon kahit na may nabawas na kapasidad ng ahente
# - **Recovery Mechanisms**: Awtomatikong retry at error handling para sa mga nabigong operasyon
#
# ### 📊 **Pagsubaybay at Observability**
# - **Concurrent Execution Tracking**: Subaybayan ang progreso ng lahat ng parallel na operasyon
# - **Performance Metrics**: Sukatin ang bilis at mga dagdag na kahusayan
# - **Resource Usage Analytics**: I-optimize ang alokasyon ng sabay-sabay na mga ahente
# - **Bottleneck Identification**: Hanapin at lutasin ang mga hadlang sa performance
#
# Bumuo tayo ng mataas na pagganap na sabay-sabay na AI workflows! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
