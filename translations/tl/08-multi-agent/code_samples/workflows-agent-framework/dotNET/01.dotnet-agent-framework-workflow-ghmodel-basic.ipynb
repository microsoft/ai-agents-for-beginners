# %% [markdown]
# # 🔄 Pangunahing Mga Daloy ng Trabaho ng Ahente gamit ang Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Tutorial sa Orkestrasyon ng Daloy ng Trabaho
#
# Ipinapakita ng notebook na ito kung paano bumuo ng sopistikadong **daloy ng trabaho ng ahente** gamit ang Microsoft Agent Framework para sa .NET at Azure OpenAI (Responses API). Matututuhan mong lumikha ng mga multi-step na proseso ng negosyo kung saan nagtutulungan ang mga AI agent upang maisagawa ang mga kumplikadong gawain sa pamamagitan ng mga istrukturadong pattern ng orkestrasyon.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🏗️ **Mga Pangunahing Kaalaman sa Arkitektura ng Daloy ng Trabaho**
# - **Tagabuo ng Daloy ng Trabaho**: Disenyo at orkestrasyon ng mga komplikadong multi-step na proseso ng AI
# - **Koordinasyon ng Ahente**: Pagkoordina sa maraming espesyal na ahente sa loob ng mga daloy ng trabaho
# - **Azure OpenAI (Responses API)**: Paggamit ng Azure OpenAI Responses API sa mga daloy ng trabaho
# - **Visual na Disenyo ng Daloy ng Trabaho**: Lumikha at biswal na ipakita ang mga estruktura ng daloy ng trabaho para sa mas mahusay na pag-unawa
#
# ### 🔄 **Mga Pattern ng Orkestrasyon ng Proseso**
# - **Sunud-sunod na Pagproseso**: Pagsunod sunod ng mga gawain ng ahente sa lohikal na pagkakasunod
# - **Pamamahala ng Estado**: Panatilihin ang konteksto at pagdaloy ng datos sa mga yugto ng daloy ng trabaho
# - **Pangangalaga sa Pagkakamali**: Magpatupad ng matibay na pagharap sa pag-recover ng pagkakamali at katatagan ng daloy ng trabaho
# - **Pag-optimize ng Pagganap**: Disenyo ng epektibong mga daloy ng trabaho para sa operasyon sa antas ng enterprise
#
# ### 🏢 **Mga Aplikasyon ng Daloy ng Trabaho ng Enterprise**
# - **Automasyon ng Proseso ng Negosyo**: Automate ang mga kumplikadong daloy ng trabaho ng organisasyon
# - **Pipeline ng Produksyon ng Nilalaman**: Mga editorial na daloy ng trabaho na may mga yugto ng pagsusuri at pag-apruba
# - **Automasyon ng Serbisyo sa Customer**: Resolusyon ng multi-step na mga inquiry ng customer
# - **Mga Daloy ng Trabaho sa Pagproseso ng Datos**: Mga ETL workflow na may AI-powered na transformasyon
#
# ## ⚙️ Mga Kinakailangan at Setup
#
# ### 📦 **Mga Kinakailangang NuGet Packages**
#
# Ginagamit ng demonstrasyong ito sa daloy ng trabaho ang ilang mahahalagang .NET packages:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.13.1" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Konfigurasiyon ng Azure OpenAI**
#
# **Setup ng Kapaligiran (file na .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-4o-mini
# ```
#
# **Access sa Azure OpenAI:**
# 1. Gumawa ng Azure OpenAI resource sa Azure portal
# 2. Mag-deploy ng modelo (halimbawa, `gpt-4o-mini`) at tandaan ang pangalan ng deployment
# 3. Mag-sign in gamit ang `az login` at i-configure ang mga environment variable tulad ng ipinakita sa itaas
#
# ### 🏗️ **Pangkalahatang Pagsusuri ng Arkitektura ng Daloy ng Trabaho**
#
# ```mermaid
# graph TD
#     A[Tagabuo ng Daloy ng Trabaho] --> B[Rehistro ng Ahente]
#     B --> C[Engine ng Pagsasagawa ng Daloy ng Trabaho]
#     C --> D[Agent 1: Tagabuo ng Nilalaman]
#     C --> E[Agent 2: Tagasuri ng Nilalaman]
#     D --> F[Mga Resulta ng Daloy ng Trabaho]
#     E --> F
#     G[Azure OpenAI (Mga Tugon sa API)] --> D
#     G --> E
# ```
#
# **Mahahalagang Bahagi:**
# - **WorkflowBuilder**: Pangunahing engine ng orkestrasyon para sa pagdidisenyo ng mga daloy ng trabaho
# - **AIAgent**: Mga indibidwal na espesyal na ahente na may partikular na kakayahan
# - **Azure OpenAI Client**: Integrasyon ng Azure OpenAI Responses API
# - **Execution Context**: Namamahala ng estado at daloy ng datos sa pagitan ng mga yugto ng daloy ng trabaho
#
# ## 🎨 **Mga Disenyo ng Daloy ng Trabaho ng Enterprise**
#
# ### 📝 **Daloy ng Trabaho sa Produksyon ng Nilalaman**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Pipeline ng Pagproseso ng Dokumento**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Daloy ng Trabaho ng Business Intelligence**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Automasyon ng Serbisyo sa Customer**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Mga Benepisyo ng Enterprise**
#
# ### 🎯 **Pagkakatiwalaan at Scalability**
# - **Deterministic Execution**: Konsistenteng, paulit-ulit na mga resulta ng daloy ng trabaho
# - **Pag-recover mula sa Error**: Maayos na paghawak ng mga pagkabigo sa anumang yugto ng daloy ng trabaho
# - **Pagmo-monitor ng Pagganap**: Pagsubaybay sa mga sukatan ng pagpapatupad at mga oportunidad para sa pag-optimize
# - **Pamamahala ng Resource**: Mabisang alokasyon at paggamit ng mga AI model na resource
#
# ### 🔒 **Seguridad at Pagsunod**
# - **Secure Authentication**: Microsoft Entra ID authentication sa pamamagitan ng `az login` (AzureCliCredential)
# - **Audit Trails**: Kompletong pag-log ng pagpapatupad ng daloy ng trabaho at mga punto ng desisyon
# - **Access Control**: Detalyadong mga pahintulot para sa pagpapatupad at pagmo-monitor ng daloy ng trabaho
# - **Data Privacy**: Ligtas na paghawak ng sensitibong impormasyon sa buong daloy ng trabaho
#
# ### 📊 **Observability at Pamamahala**
# - **Visual Workflow Design**: Malinaw na representasyon ng mga daloy ng proseso at dependencies
# - **Execution Monitoring**: Real-time na pagsubaybay sa progreso at pagganap ng daloy ng trabaho
# - **Error Reporting**: Detalyadong pagsusuri ng error at mga kakayahan para sa debugging
# - **Performance Analytics**: Mga sukatan para sa pag-optimize at pagpaplano ng kapasidad
#
# Tara, gawin natin ang iyong unang enterprise-ready na AI workflow! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-4o-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Visit the Louvre Museum. It's a must-see for art enthusiasts and history lovers.That recommendation is quite popular and likely to attract many tourists. To refine it for a more local and authentic experience, consider suggesting an alternative that focuses on smaller, lesser-known art venues or galleries. Look for places where local artists exhibit or community spaces that host cultural events. This approach allows travelers to connect with the local art scene more intimately, away from the typical tourist routes.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
