# %% [markdown]
# # 🔄 Pangunahing Workflow ng Ahente gamit ang Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Tutorial sa Workflow Orchestration
#
# Ipinakikita ng notebook na ito kung paano bumuo ng sopistikadong **workflow ng ahente** gamit ang Microsoft Agent Framework para sa .NET at Azure OpenAI (Responses API). Matututuhan mong gumawa ng multi-step na proseso ng negosyo kung saan nakikipagtulungan ang mga AI agent para magawa ang masalimuot na mga gawain sa pamamagitan ng istrukturadong mga pattern ng orchestration.
#
# ## 🎯 Mga Layuning Matutuhan
#
# ### 🏗️ **Pangunahing Kaalaman sa Arkitektura ng Workflow**
# - **Workflow Builder**: Magdisenyo at mag-orkestra ng mga masalimuot na multi-step na proseso ng AI
# - **Agent Coordination**: Magkoordina ng maraming espesyalisadong ahente sa loob ng mga workflow
# - **Azure OpenAI (Responses API)**: Gamitin ang Azure OpenAI Responses API sa mga workflow
# - **Visual Workflow Design**: Gumawa at magpakita ng istruktura ng workflow para sa mas malinaw na pag-intindi
#
# ### 🔄 **Mga Pattern ng Process Orchestration**
# - **Sequential Processing**: Pagkonek-konek ng maraming gawain ng ahente ayon sa lohikal na pagkakasunod
# - **State Management**: Pangangalaga ng konteksto at daloy ng data sa mga yugto ng workflow
# - **Error Handling**: Magpatupad ng matatag na pag-recover mula sa error at katatagan ng workflow
# - **Performance Optimization**: Magdisenyo ng mahusay na mga workflow para sa operasyon ng antas-nga-enterprise
#
# ### 🏢 **Mga Aplikasyon ng Enterprise Workflow**
# - **Business Process Automation**: Pag-automate ng mga masalimuot na workflow ng organisasyon
# - **Content Production Pipeline**: Mga editorial workflow na may mga yugto ng pagsusuri at pag-apruba
# - **Customer Service Automation**: Multi-step na paglutas ng mga inquiry ng customer
# - **Data Processing Workflows**: Mga ETL workflow na may AI-powered na transformasyon
#
# ## ⚙️ Mga Kinakailangan & Setup
#
# ### 📦 **Kinakailangang Mga NuGet Package**
#
# Ang demonstrasyon ng workflow na ito ay gumagamit ng ilang mahahalagang .NET package:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI Configuration**
#
# **Pagsasaayos ng Kapaligiran (.env file):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Access sa Azure OpenAI:**
# 1. Gumawa ng Azure OpenAI resource sa Azure portal
# 2. Mag-deploy ng modelo (halimbawa, `gpt-5-mini`) at tandaan ang pangalan ng deployment
# 3. Mag-sign in gamit ang `az login` at i-configure ang mga environment variable gaya ng ipinakita sa itaas
#
# ### 🏗️ **Pangkalahatang-ideya ng Arkitektura ng Workflow**
#
# ```mermaid
# graph TD
#     A[Tagabuo ng Daloy ng Trabaho] --> B[Rehistro ng Ahente]
#     B --> C[Engine ng Pagsasagawa ng Daloy ng Trabaho]
#     C --> D[Agent 1: Tagabuo ng Nilalaman]
#     C --> E[Agent 2: Tagasuri ng Nilalaman]
#     D --> F[Mga Resulta ng Daloy ng Trabaho]
#     E --> F
#     G[Azure OpenAI (Mga Tugon na API)] --> D
#     G --> E
# ```
#
# **Pangunahing Mga Bahagi:**
# - **WorkflowBuilder**: Pangunahing makina ng orchestration para sa pagdidisenyo ng mga workflow
# - **AIAgent**: Mga indibidwal na espesyalisadong ahente na may tiyak na kakayahan
# - **Azure OpenAI Client**: Integrasyon ng Azure OpenAI Responses API
# - **Execution Context**: Namamahala ng estado at daloy ng data sa pagitan ng mga yugto ng workflow
#
# ## 🎨 **Mga Pattern ng Disenyo ng Enterprise Workflow**
#
# ### 📝 **Content Production Workflow**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Document Processing Pipeline**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Business Intelligence Workflow**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Customer Service Automation**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Mga Benepisyo ng Enterprise**
#
# ### 🎯 **Pagkakatiwalaan at Kayang Lumaki**
# - **Deterministic Execution**: Konsistent, paulit-ulit na resulta ng workflow
# - **Pag-recover mula sa Error**: Maayos na paghawak ng mga pagkabigo sa anumang yugto ng workflow
# - **Pagsubaybay sa Performance**: Subayon ang mga sukatan ng pagpapatupad at mga pagkakataon para sa pag-optimize
# - **Pamamahala ng Mga Resource**: Mahusay na alokasyon at paggamit ng mga AI model resources
#
# ### 🔒 **Seguridad at Pagsunod**
# - **Secure Authentication**: Microsoft Entra ID authentication sa pamamagitan ng `az login` (AzureCliCredential)
# - **Audit Trails**: Kumpletong pag-log ng pagpapatupad ng workflow at mga puntong desisyon
# - **Access Control**: Pinong mga permiso para sa pagpapatupad at pagsubaybay ng workflow
# - **Data Privacy**: Secure na paghawak ng sensitibong impormasyon sa buong workflow
#
# ### 📊 **Observability at Pamamahala**
# - **Visual Workflow Design**: Maliwanag na representasyon ng daloy ng proseso at mga dependencies
# - **Execution Monitoring**: Real-time na pagsubaybay ng progreso at performance ng workflow
# - **Error Reporting**: Detalyadong pagsusuri ng error at mga kakayahan sa pag-debug
# - **Performance Analytics**: Mga sukatan para sa pag-optimize at pagpaplano ng kapasidad
#
# Simulan natin ang iyong unang AI workflow na handa para sa enterprise! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
