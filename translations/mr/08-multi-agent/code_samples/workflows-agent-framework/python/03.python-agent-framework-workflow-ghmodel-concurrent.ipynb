# %% [markdown]
# # ⚡ GitHub मॉडेल्ससह समसामयिक एजंट वर्कफ्लोज (Python)
#
# ## 📋 प्रगत समानकालिक प्रक्रिया शिकवणी
#
# हा नोटबुक मायक्रोसॉफ्ट एजंट फ्रेमवर्क वापरून **समसामयिक वर्कफ्लो नमुने** दर्शवितो. तुम्हाला शिकायला मिळेल की कसे बहुतेक AI एजंट एकाच वेळी कार्यान्वित होतात अशा उच्च कार्यक्षम, समांतर प्रक्रिया वर्कफ्लोज तयार करायचे, ज्यामुळे थ्रूपुट नाटकीक पद्धतीने वाढतो आणि सुसंवादी मल्टी-थ्रेडेड व्यवसाय प्रक्रियांना सक्षम करते.
#
# ## 🎯 शिक्षण उद्दिष्टे
#
# ### 🚀 **समसामयिक प्रक्रियेच्या मूलभूत गोष्टी**
# - **समांतर एजंट अंमलबजावणी**: जास्तीत जास्त कार्यक्षमतेसाठी एकाच वेळी अनेक एजंट चालवा
# - **वर्कफ्लो समन्वय**: डेटा सुसंगती राखत समसामयिक ऑपरेशन्सचे समन्वय साधा
# - **कामगिरी अनुकूलन**: समांतर प्रक्रियेने महत्त्वपूर्ण गती वाढ मिळवा
# - **स्रोत्र व्यवस्थापन**: समसामयिक ऑपरेशन्समध्ये AI मॉडेल स्रोत्रे कार्यक्षमपणे वापरा
#
# ### 🏗️ **प्रगत समसामयिक नमुने**
# - **फोर्क-जॉईन प्रक्रिया**: काम अनेक एजंटमध्ये विभाजित करा आणि निकाल एकत्र करा
# - **पाईपलाइन समांतरता**: सातत्यपूर्ण थ्रूपुटसाठी अंमलबजावणी टप्पे ओव्हरलॅप करा
# - **लोड बॅलन्सिंग**: उपलब्ध एजंट स्रोत्रांमध्ये काम समानरूपेण वितरित करा
# - **सिंक्रोनायझेशन पॉइंट्स**: महत्त्वाच्या वर्कफ्लो टप्प्यांवर समसामयिक एजंट समन्वयित करा
#
# ### 🏢 **एंटरप्राइझ समसामयिक अनुप्रयोग**
# - **उच्च-खंड दस्तऐवज प्रक्रिया**: एकाच वेळी अनेक दस्तऐवज प्रक्रिया करा
# - **प्रत्यक्ष वेळेतील सामग्री विश्लेषण**: येणाऱ्या डेटा स्ट्रीम्सचे समसामयिक विश्लेषण
# - **बॅच प्रक्रिया अनुकूलन**: मोठ्या प्रमाणात ऑपरेशन्ससाठी थ्रूपुट वाढवा
# - **बहुमोही विश्लेषण**: वेगवेगळ्या सामग्री प्रकारांची (माहिती, प्रतिमा, डेटा) समांतर प्रक्रिया करा
#
# ## ⚙️ पूर्वग्रह व सेटअप
#
# ### 📦 **आवश्यक अवलंबन**
#
# समानकालिक वर्कफ्लो क्षमता असणारा एजंट फ्रेमवर्क इन्स्टॉल करा:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub मॉडेल्स कॉन्फिगरेशन**
#
# **पर्यावरण सेटअप (.env फाइल):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **समांतर प्रक्रिया विचार**
# - **रेट लिमिट्स**: समसामयिक विनंत्यांसाठी GitHub मॉडेल्स API रेट लिमिट्सची देखरेख करा
# - **स्रोत वापर**: अनेक समसामयिक एजंट्ससह मेमरी आणि CPU वापराचा विचार करा
# - **त्रुटी हाताळणी**: समांतर ऑपरेशन्ससाठी मजबूत त्रुटी पुनर्प्राप्ती अंमलात आणा
#
# ### 🏗️ **समसामयिक वर्कफ्लो आर्किटेक्चर**
#
# ```mermaid
# graph TD
#     A[वर्कफ्लो प्रारंभ] --> B[समांतर कार्यान्वयन]
#     B --> C[एजंट पूल 1]
#     B --> D[एजंट पूल 2]
#     B --> E[एजंट पूल 3]
#     C --> F[परिणाम संकलन]
#     D --> F
#     E --> F
#     F --> G[अंतिम आउटपुट]
#
#     H[GitHub मॉडेल API] --> C
#     H --> D
#     H --> E
# ```
#
# **महत्त्वाचे फायदे:**
# - **⚡ कामगिरी**: समांतर अंमलबजावणीमुळे महत्त्वपूर्ण गती वाढ
# - **📈 स्केलेबिलिटी**: वाढलेल्या कार्यभारांना वेळेत वाढ न करता हाताळा
# - **🔄 कार्यक्षमता**: उपलब्ध संगणकीय स्रोत्रांचा अधिक चांगला वापर
# - **🎯 थ्रूपुट**: समान वेळेत अधिक प्रमाणात काम करा
#
# ## 🎨 **समसामयिक वर्कफ्लो डिझाईन नमुने**
#
# ### 🔍 **संशोधन व विश्लेषण पाईपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रक्रिया वर्कफ्लो**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री निर्मिती पाईपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **अनेक टप्प्यांची प्रक्रिया**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **एंटरप्राइझ कार्यक्षमता फायदे**
#
# ### ⚡ **थ्रूपुट अनुकूलन**
# - **समांतर अंमलबजावणी**: अनेक एजंटस एकाच वेळी कार्यरत
# - **स्रोत उपयोग**: उपलब्ध AI मॉडेल क्षमतेचा कमाल वापर
# - **वेळ कपात**: एकूण प्रक्रिया वेळेत मोठी घट
# - **वाढवता येण्याजोगी रचना**: आवश्यकतेनुसार समांतर एजंट सहज वाढवा
#
# ### 🛡️ **विश्वसनीयता व टिकाऊपणा**
# - **फॉल्ट टॉलरन्स**: व्यक्तिगत एजंट अयशस्वी झाल्यास संपूर्ण वर्कफ्लो थांबत नाही
# - **त्रुटी विभाजन**: एका समसामयिक शाखेतील समस्या इतरांना प्रभावित करत नाहीत
# - **मऊ घट्टपणा**: कमी एजंट क्षमतेसहही सिस्टम कार्यरत राहतो
# - **पुनर्प्राप्ती यंत्रणा**: अयशस्वी ऑपरेशन्ससाठी आपोआप पुन:प्रयत्न व त्रुटी हाताळणी
#
# ### 📊 **निरीक्षण व निरीक्षणक्षमता**
# - **समसामयिक अंमलबजावणी ट्रॅकिंग**: सर्व समांतर ऑपरेशन्सचा प्रगतीवेध घेतला जातो
# - **कार्यक्षमता मापदंड**: गती वाढ व कार्यक्षमता नोंदवा
# - **स्रोत वापर विश्लेषण**: समसामयिक एजंट वाटप अनुकूलित करा
# - **बॉटलनेक ओळख**: कार्यक्षमता मर्यादा शोधा व निवारण करा
#
# चला उच्च कार्यक्षम समसामयिक AI वर्कफ्लोज तयार करूया! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# हा दस्तऐवज AI भाषांतर सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) चा वापर करून अनुवादित केला आहे. जरी आम्ही अचूकतेसाठी प्रयत्न करतो, तरी कृपया लक्षात घ्या की स्वयंचलित भाषांतरांमध्ये त्रुटी किंवा अचूकतेची कमतरता असू शकते. मूळ दस्तऐवज त्याच्या मूळ भाषेत अधिकृत स्रोत मानला पाहिजे. महत्त्वाची माहिती असल्यास, व्यावसायिक मानवी भाषांतराची शिफारस केली जाते. या भाषांतराच्या वापरामुळे उद्भवणाऱ्या कोणत्याही गैरसमज किंवा चुकीच्या अर्थलावणीसाठी आम्ही जबाबदार नाही.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
