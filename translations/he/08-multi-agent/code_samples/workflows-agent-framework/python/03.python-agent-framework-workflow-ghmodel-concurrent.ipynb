# %% [markdown]
# # ⚡ זרימות עבודה במקביל עם סוכני GitHub (Python)
#
# ## 📋 מדריך עיבוד מקבילי מתקדם
#
# מחברת זו מדגימה **תבניות זרימת עבודה מקבילות** באמצעות מסגרת הסוכן של Microsoft. תלמד כיצד לבנות זרימות עבודה עם ביצועים גבוהים ועיבוד מקבילי בו סוכני AI מרובים מבצעים פעולות במקביל, מה שמשפר משמעותית את הקצב ומאפשר תהליכים עסקיים מתקדמים ורב-סביבתיים.
#
# ## 🎯 מטרות הלמידה
#
# ### 🚀 **יסודות העיבוד המקבילי**
# - **הרצת סוכנים במקביל**: הפעלת סוכנים מרובים במקביל למקסום היעילות
# - **תאום זרימת עבודה**: תיאום פעולות מקבילות תוך שמירה על עקביות הנתונים
# - **אופטימיזציית ביצועים**: השגת מהירות משמעותית בזכות עיבוד מקבילי
# - **ניהול משאבים**: ניצול יעיל של משאבי מודל ה-AI בעבודה מקבילה
#
# ### 🏗️ **תבניות מתקדמות במקביליות**
# - **עיבוד בפיצול-איחוד (Fork-Join)**: חלוקת עבודה בין סוכנים מרובים ואיחוד התוצאות
# - **מקביליות בצינור עיבוד (Pipeline)**: שלבי ביצוע חופפים לקצב עיבוד רציף
# - **איזון עומסים**: חלוקת עבודה שווה בין משאבי סוכן זמינים
# - **נקודות סינכרון**: תאום סוכנים מקבילים בשלבים קריטיים בזרימת העבודה
#
# ### 🏢 **יישומים ארגוניים מקבילים**
# - **עיבוד מסמכים בהיקף גבוה**: עיבוד מסמכים מרובים בו זמנית
# - **ניתוח תוכן בזמן אמת**: ניתוח מקבילי של זרמי מידע נכנסים
# - **אופטימיזציית עיבוד אצווה**: מקסום קצב לעיבודים גדולים
# - **ניתוח מולטימודלי**: עיבוד מקביל של סוגי תוכן שונים (טקסט, תמונות, נתונים)
#
# ## ⚙️ דרישות והגדרה
#
# ### 📦 **תלויות נדרשות**
#
# התקן את מסגרת הסוכן עם תמיכה בזרימות עבודה מקבילות:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **הגדרת דגמי GitHub**
#
# **הגדרת סביבה (קובץ .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **היבטים לעיבוד מקבילי:**
# - **מגבלות קצב**: נטר מגבלות קצב של API דגמי GitHub לבקשות מקבילות
# - **שימוש במשאבים**: שקול את זיכרון ומעבד בשימוש סוכנים רבים במקביל
# - **טיפול בשגיאות**: הטמעת התאוששות תקינה משגיאות בעיבוד מקבילי
#
# ### 🏗️ **אדריכלות זרימות עבודה מקבילות**
#
# ```mermaid
# graph TD
#     A[התחלת זרימת עבודה] --> B[ביצוע מקבילי]
#     B --> C[מאגר סוכנים 1]
#     B --> D[מאגר סוכנים 2]
#     B --> E[מאגר סוכנים 3]
#     C --> F[איגוד תוצאות]
#     D --> F
#     E --> F
#     F --> G[פלט סופי]
#
#     H[API של דגמי GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **יתרונות מרכזיים:**
# - **⚡ ביצועים**: מהירות משמעותית בזכות ביצוע מקבילי
# - **📈 מדרגיות**: טיפול בעומסי עבודה גדולים בלי הגדלת זמן פרופורציונלי
# - **🔄 יעילות**: ניצול טוב יותר של משאבי חישוב זמינים
# - **🎯 קצב עיבוד**: עיבוד כמות גדולה יותר של עבודה באותו הזמן
#
# ## 🎨 **תבניות עיצוב לזרימות עבודה מקבילות**
#
# ### 🔍 **צינור מחקר וניתוח**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **זרימת עיבוד נתונים**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **צינור יצירת תוכן**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **עיבוד רב שלבים**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **יתרונות ביצועים ברמת הארגון**
#
# ### ⚡ **אופטימיזציית קצב עיבוד**
# - **ביצוע במקביל**: סוכנים מרובים עובדים בו זמנית
# - **ניצול משאבים**: יעילות מקסימלית של קיבולת מודל ה-AI הזמינה
# - **הורדת זמן**: הפחתה משמעותית בזמן העיבוד הכולל
# - **אדריכלות מדרגית**: הוספה פשוטה של סוכנים מקבילים לפי הצורך
#
# ### 🛡️ **אמינות ועמידות**
# - **התמודדות עם תקלות**: כישלון סוכן בודד אינו מפסיק את כל זרימת העבודה
# - **בידוד שגיאות**: בעיות בענף אחד של מקביליות לא משפיעות על האחרים
# - **התדרדרות מתונה**: המערכת ממשיכה לפעול גם עם קיבולת סוכנים מופחתת
# - **מנגנוני התאוששות**: ניסיון מחודש וטיפול בשגיאות באופן אוטומטי
#
# ### 📊 **מעקב ותצפית**
# - **מעקב ביצוע מקבילי**: נטר התקדמות כל הפעולות המקבילות
# - **מדדי ביצועים**: מדידת מהירות ועלייה ביעילות
# - **אנליטיקות שימוש במשאבים**: אופטימיזציה להקצאת סוכנים מקבילים
# - **איתור צווארי בקבוק**: זיהוי ופתרון מגבלות ביצועים
#
# בואו לבנות זרימות עבודה מקבילות של AI עם ביצועים גבוהים! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **כתב ויתור**:
# מסמך זה תורגם באמצעות שירות תרגום אוטומטי [Co-op Translator](https://github.com/Azure/co-op-translator). למרות שאנו שואפים לדיוק, יש לקחת בחשבון שתרגומים אוטומטיים עלולים להכיל שגיאות או אי-דיוקים. יש להחשיב את המסמך המקורי בשפתו הטבעית כמקור הסמכות. למידע קריטי מומלץ להשתמש בתרגום מקצועי על ידי מתרגם אדם. אנו לא אחראים לכל אי-הבנה או פירוש שגוי הנובע מהשימוש בתרגום זה.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
