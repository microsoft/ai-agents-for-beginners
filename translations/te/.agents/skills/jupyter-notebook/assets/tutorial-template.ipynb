# %% [markdown]
# # ట్యుటోరియల్: TITLE
#
# ప్రేక్షకులు:
# - దీని కోసం ఎవరికో వివరించండి.
#
# ముందస్తు అవసరాలు:
# - అవసరమైన భావనలు లేదా సెటప్‌ను జాబితా చేయండి.
#
# అధ్యయన లక్ష్యాలు:
# - చివరికి, పాఠకుడు చేయగలడు...

# %% [markdown]
# ## రూపరేఖ
#
# 1. సెటప్
# 2. ఒక కనీసంగా పనిచేసే ఉదాహరణ
# 3. వేరియేషన్లు మరియు జాగ్రత్తగా ఉండాల్సిన విషయాలు
# 4. అభ్యాసాలు

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## దశ 1 - ఒక చిన్న ఉదాహరణతో ప్రారంభించండి
#
# తర్వాతి సెల్ ఏమి చేస్తుందో సాధారణ భాషలో వివరించండి.

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## అభ్యాసాలు
#
# - వేరే ఇన్‌పుట్ ప్రయత్నించండి.
# - కోడ్ నడపడానికి ముందు అవుట్‌పుట్‌ను ఊహించండి.
# - ఒక సాధారణ తప్పును గుర్తించి దాన్ని ఎలా పరిష్కరించాలో చెప్పండి.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# డిస్క్లెయిమర్:
# ఈ పత్రం AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించబడింది. మేము ఖచ్చితత్వానికి శ్రమించినప్పటికీ, ఆటోమెటెడ్ అనువాదాల్లో తప్పులు లేదా లోపాలు ఉండవచ్చని దయచేసి గమనించండి. దాని స్థానిక భాషలో ఉన్న మూల పత్రాన్ని అధికారిక మూలంగా పరిగణించాలి. కీలకమైన సమాచారానికి వృత్తిపరులైన మానవ అనువాదాన్ని చేయించుకోవాలని సిఫార్సు చేస్తున్నాము. ఈ అనువాదాన్ని ఉపయోగించడంవల్ల ఏర్పడిన ఏవైనా అపార్థాలు లేదా తప్పుదారుల కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
