# %% [markdown]
# # ⚡ Microsoft Foundry (Python)తో సమకాలీన ఏజెంట్ వర్క్‌ఫ్లోలు
#
# ## 📋 అభివృద్ధి చెందిన సమాంతర ప్రాసెసింగ్ పాఠం
#
# ఈ నోట్‌బుక్ Microsoft Agent Framework ఉపయోగించి **సమకాలీన వర్క్‌ఫ్లో నమూనాలు**ను చూపిస్తుంది. మీరు ఎలా నిర్మించాలో నేర్చుకోవడం జరుగుతుంది, ఒకేసారి అనేక AI ఏజెంట్లు అమలు అవుతూ, అత్యధిక పనితీరుతో సమాంతర ప్రాసెసింగ్ వర్క్‌ఫ్లోలను, దాని ద్వారా అవుట్‌పుట్ మెరుగుపడుతూ మరియు సున్నితమైన బహుభాగాల వ్యాపార ప్రక్రియలను సాధించడానికి వీలు కల్పిస్తుంది.
#
# > **మైగ్రేషన్ గమనిక:** ఈ నమూనా ఇప్పటికే GitHub Models ను సూచించింది. GitHub Models డిప్రికేటెడ్ (జూలై 2026లో రిటైర్ అవుతుంది), కనుక ఇప్పుడు అది **Microsoft Foundry**ని `FoundryChatClient` ద్వారా ఉపయోగిస్తుంది, ఇది Azure OpenAI **Responses API**ని లక్ష్యంగా చేస్తుంది.
#
# ## 🎯 ప్రయోజన లక్ష్యాలు
#
# ### 🚀 **సమకాలీన ప్రాసెసింగ్ ప్రాథమికాలు**
# - **సమాంతర ఏజెంట్ అమలు**: గరిష్ట సామర్థ్యం కొరకు అంతేకాకుండా అనేక ఏజెంట్లు ఒకేసారి ప్రదర్శించండి
# - **వర్క్‌ఫ్లో ఆర్కెస్ట్‌రేషన్**: డేటా సరళి కల్పనతో సమకాలీన ఆపరేషన్లను సమన్వయపరచండి
# - **పనితీరు మెరుగుదల**: సమాంతర ప్రాసెసింగ్ ద్వారా గణనీయమైన వేగవంతం సాధించండి
# - **వనరు నిర్వహణ**: సమకాలీన ఆపరేషన్ల పాటు AI మోడల్ వనరులను సక్రమంగా ఉపయోగించండి
#
# ### 🏗️ **అభివృద్ధి చెందిన సమకాలీన నమూనాలు**
# - **ఫోర్క్-జాయిన్ ప్రాసెసింగ్**: అనేక ఏజెంట్ల మధ్య పనిని విభజించి ఫలితాల్ని కలపండి
# - **పైప్‌లైన్ సమాంతరత**: నిరంతర అవుట్‌పుట్ కొరకు అమలు దశలను ఒకదానికి ఒకటి కవర్ చేయడం
# - **లోడ్ బ్యాలెన్సింగ్**: లభ్యమయ్యే ఏజెంట్ వనరుల మధ్య పనిని సమానంగా విస్తరించండి
# - **సంకలన బింధువులు**: కీలక వర్క్‌ఫ్లో దశల్లో సమకాలీన ఏజెంట్లను సమన్వయ పరచండి
#
# ### 🏢 **ఎంటర్‌ప్రైజ్ సమకాలీన అనువర్తనాలు**
# - **పెద్ద మొత్తంలో డాక్యుమెంట్ ప్రాసెసింగ్**: ఒకేసారి అనేక డాక్యుమెంట్లను ప్రాసెస్ చేయండి
# - **రియల్-టైమ్ కంటెంట్ విశ్లేషణ**: సమకాలీనంగా వచ్చే డేటా స్ట్రీమ్‌ల విశ్లేషణ
# - **బ్యాచ్ ప్రాసెసింగ్ మెరుగుదల**: పెద్ద స్థాయిలో ఆపరేషనుల throughput ను గరిష్టం చేయండి
# - **మల్టీ-మోడ్ విశ్లేషణ**: వేర్వేరు కంటెంట్ రకాల (టెక్స్ట్, చిత్రాలు, డేటా) సమాంతర ప్రాసెసింగ్
#
# ## ⚙️ ముందస్తు అవసరాలు & సెటప్
#
# ### 📦 **అవసరమైన ఆధారాలు**
#
# సమకాలీన వర్క్‌ఫ్లో సామర్థ్యాలతో Agent Framework ను ఇన్స్టాల్ చేయండి:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry కాన్ఫిగరేషన్**
#
# `az login`తో Azure CLIలో సైన్ ఇన్ చేయండి, తద్వారా `AzureCliCredential` ప్రామాణీకరణ చేస్తుంది, ఆపై మీ Microsoft Foundry ప్రాజెక్ట్ వివరాలను సెట్ చేయండి.
#
# **పరిసరాల సెటప్ (.env ఫైలు):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **సమకాలీన ప్రాసెసింగ్ పరిశీలన:**
# - **రిట్ లిమిట్లు**: సమకాలీన అభ్యర్థనల కొరకు Azure OpenAI రేటు పరిమితులను పర్యవేక్షించండి
# - **వనరు వినియోగం**: అనేక ఏజెంట్లతో మేమోరీ మరియు CPU వినియోగాన్ని పరిగణించండి
# - **లోప నిర్వహణ**: సమాంతర ఆపరేషన్ల కొరకు బలమైన లోప పునఃపరిశీలన అమలు చేయండి
#
# ### 🏗️ **సమకాలీన వర్క్‌ఫ్లో నిర్మాణం**
#
# ```mermaid
# graph TD
#     A[వర్క్‌ఫ్లో ప్రారంభం] --> B[సమకాలీన అమలు]
#     B --> C[ఏజెంట్ పూల్ 1]
#     B --> D[ఏజెంట్ పూల్ 2]
#     B --> E[ఏజెంట్ పూల్ 3]
#     C --> F[ఫలితాల సమాహారం]
#     D --> F
#     E --> F
#     F --> G[చివరి అవుట్పుట్]
#
#     H[మైక్రోసాఫ్ట్ ఫౌండ్రి] --> C
#     H --> D
#     H --> E
# ```
#
# **ప్రధాన లాభాలు:**
# - **⚡ పనితీరు**: సమాంతర అమలుతో గణనీయమైన వేగవంతమైన ప్రదర్శన
# - **📈 స్కేలబిలిటీ**: పడతిరుగుల లేకుండా భారీ పని భారాన్ని నిర్వహించండి
# - **🔄 సామర్థ్యం**: లభ్యమయ్యే కంప్యూటేషనల్ వనరులను మెరుగుపరచి వినియోగించండి
# - **🎯 అవుట్‌పుట్**: అత్యల్ప సమయంలో ఎక్కువ పని చేయండి
#
# ## 🎨 **సమకాలీన వర్క్‌ఫ్లోడిజైన్ నమూనాలు**
#
# ### 🔍 **గవేషణ & విశ్లేషణ పైప్‌లైన్**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **డేటా ప్రాసెసింగ్ వర్క్‌ఫ్లో**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **కంటెంట్ తయారీ పైప్‌లైన్**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **బహుస్థాయి ప్రాసెసింగ్**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ఎంటర్‌ప్రైజ్ పనితీరు లాభాలు**
#
# ### ⚡ **అవుట్‌పుట్ మెరుగుదల**
# - **సమాంతర అమలు**: అనేక ఏజెంట్లు ఒకేసారి పని చేయడం
# - **వనరు వినియోగం**: లభ్యమయ్యే AI మోడల్ సామర్థ్యాన్ని గరిష్ట సామర్థ్యంతో ఉపయోగించండి
# - **సమయ తగ్గింపు**: మొత్తం ప్రాసెసింగ్ సమయం గణనీయంగా తగ్గించబడింది
# - **స్కేలబుల్ ఆర్కిటెక్చర్**: అవసరమైతే మరిన్ని ఏజెంట్లను సులభంగా జోడించండి
#
# ### 🛡️ **నమ్మకదారు & సహనశీలత**
# - **పాడుకోకుండా పని చేస్తుంది**: వ్యక్తిగత ఏజెంట్ వైఫల్యాలు మొత్తం వర్క్‌ఫ్లోని నిలిపేను కాదు
# - **లోపాల వివక్ష**: ఒక సమకాలీన బ్రాంచ్లో సమస్యలు ఇతరులను ప్రభావితం చేయవు
# - **మెరుగ్గా తగ్గువల్సిన**: ఏజెంట్ సామర్థ్యం తగ్గినా సిస్టమ్ కొనసాగుతుంది
# - **పునరుద్ధరణ విధానాలు**: విఫలమైన ఆపరేషన్ల కోసం ఆటోమేటిక్ మళ్ళీ ప్రయత్నం & లోప నిర్వహణ
#
# ### 📊 **మానిటరింగ్ & వీక్షణ సామర్థ్యం**
# - **సమకాలీన అమలు ట్రాకింగ్**: సమాంతర ఆపరేషన్ల పురోగతిని పర్యవేక్షించండి
# - **పనితీరు మెట్రిక్స్**: వేగవంతం మరియు సామర్థ్య పెరుగుదలను కొలవండి
# - **వనరు వినియోగ విశ్లేషణ**: సమాంతర ఏజెంట్ కేటాయింపుని మెరుగుపరుచండి
# - **గర్వపు గుర్తింపు**: పనితీరు పరిమితులను కనుగొని పరిష్కరించండి
#
# మనం అత్యధిక పనితీరు గల సమకాలీన AI వర్క్‌ఫ్లోలను నిర్మిద్దాం! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **అస్వీకరణ**:
# ఈ పత్రం AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించబడింది. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలు తప్పులు లేదా అసమగ్రతలను కలిగి ఉండవచ్చు. దాని స్వదేశ భాషలో ఉన్న అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదం ఉపయోగం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
