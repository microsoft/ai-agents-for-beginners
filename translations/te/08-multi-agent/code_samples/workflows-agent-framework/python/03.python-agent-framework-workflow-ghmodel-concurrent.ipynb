# %% [markdown]
# # ⚡ GitHub మోడల్స్‌తో అనుకూల ఏజెంట్ వర్క్‌ఫ్లోలు (Python)
#
# ## 📋 అభివృద్ధి చెందిన సమాంతర ప్రాసెసింగ్ ట్యుటోరియల్
#
# ఈ నోట్‌బుక్ Microsoft Agent Framework ఉపయోగించి **ఒకేసారి వర్క్‌ఫ్లో నమూనాలు** ప్రదర్శిస్తుంది. మీరు బహు AI ఏజెంట్లు ఒక్కసారి నిర్వాహణ చేసే ఉన్నత-పనితీరు, సమాంతర ప్రాసెసింగ్ వర్క్‌ఫ్లోలను ఎలా నిర్మించాలో నేర్చుకుంటారు, ఇది గమనీయమైన పనితీరు పెరుగుదల మరియు నిపుణులైన బహుళ-తారోపకార వ్యాపార ప్రక్రియలకు దారితీస్తుంది.
#
# ## 🎯 నేర్చుకోవాల్సిన లక్ష్యాలు
#
# ### 🚀 **సమాంతర ప్రాసెసింగ్ ప్రాత్మికాలు**
# - **పారాలల్ ఏజెంట్ ఎగ్జిక్యూషన్**: గరిష్ట సామర్థ్యం కోసం బహు ఏజెంట్లు ఒకేసారి నడపండి
# - **వర్క్‌ఫ్లో సమన్వయం**: డేటా సారూప్యత్వం కొనసాగిస్తూ అనేక కార్యకలాపాలను సమన్వయించండి
# - **పనితీరు అభివృద్ధి**: సమాంతర ప్రాసెసింగ్ ద్వారా గణనీయమైన వేగవంతం సాధించండి
# - **వనరుల నిర్వహణ**: సమాంతర కార్యకలాపాల కోసం AI మోడల్ వనరులను సమర్థవంతంగా ఉపయోగించండి
#
# ### 🏗️ **అధునిక సమాంతర నమూనాలు**
# - **ఫోర్క్-జాయిన్ ప్రాసెసింగ్**: పని విభజించి బహు ఏజెంట్ల వద్ద చేర్చు ఫలితాలు సమీకరించండి
# - **పైప్‌లైన్ సమాంతరత**: నిరంతర ధార పరంగా overlapping నిలువలు అమలు
# - **లోడ్ బ్యాలెన్సింగ్**: అందుబాటులో ఉన్న ఏజెంట్ వనరులకు పని సమానంగా పంపిణీ చేయండి
# - **సంకలనం పాయింట్లు**: ముఖ్య వర్క్‌ఫ్లో దశలలో ఏజెంట్లను సమన్వయించండి
#
# ### 🏢 **ఎంటర్ప్రైజ్ సమాంతర అనువర్తనాలు**
# - **హై వాల్యూమ్ డాక్యుమెంట్ ప్రాసెసింగ్**: బహు డాక్యుమెంట్లను ఒకేసారి ప్రాసెస్ చేయండి
# - **రియల్ టైమ్ కంటెంట్ విశ్లేషణ**: అనుకూల డేటా స్ట్రీమ్స్ విశ్లేషణ
# - **బ్యాచ్ ప్రాసెసింగ్ ఆప్టిమైజేషన్**: విశాల స్థాయి కార్యకలాపాల కోసం గరిష్ట వ్యతిరేకత సాధించండి
# - **బహుళ మోడ్ విశ్లేషణ**: వేరే వేరే కంటెంట్ రకాల (పాఠం, చిత్రాలు, డేటా) సమాంతర ప్రాసెసింగ్
#
# ## ⚙️ ముందస్తు అర్హతలు & సెటప్
#
# ### 📦 **అవసరమైన ఆధారాలు**
#
# సమాంతర వర్క్‌ఫ్లో సామర్థ్యాలతో Agent Framework ను ఇన్‌స్టాల్ చేయండి:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub మోడల్స్ కాంఫిగరేషన్**
#
# **పరిసర సెటప్ (.env ఫైల్):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **సమాంతర ప్రాసెసింగ్ పరిగణనలు:**
# - **రేట్ లిమిట్స్**: సమాంతర అభ్యర్థనలకు GitHub మోడల్స్ API వేగ పరిమితులను పర్యవేక్షించండి
# - **వనరుల వినియోగం**: బహు ఏజెంట్లతో మెమొరీ మరియు CPU వినియోగాన్ని పరిగణించండి
# - **లోప నిర్వహణ**: సమాంతర చర్యల కోసం బలమైన లోప పునరుద్ధరణ అమలు చేయండి
#
# ### 🏗️ **సమాంతర వర్క్‌ఫ్లో ఆర్కిటెక్చర్**
#
# ```mermaid
# graph TD
#     A[వర్క్‌ఫ్లో ప్రారంభం] --> B[అంతర్వాహిక అమలు]
#     B --> C[ఏజెంట్ పూల్ 1]
#     B --> D[ఏజెంట్ పూల్ 2]
#     B --> E[ఏజెంట్ పూల్ 3]
#     C --> F[ఫలిత సంగ్రహణ]
#     D --> F
#     E --> F
#     F --> G[చివరి అవుట్‌పుట్]
#
#     H[GitHub మోడల్స్ API] --> C
#     H --> D
#     H --> E
# ```
#
# **ప్రధాన ప్రయోజనాలు:**
# - **⚡ పనితీరు**: సమాంతర అమలుతో గణనీయమైన వేగవంతం
# - **📈 విస్తరణ సామర్థ్యం**: సమయానుగుణంగా పెరుగుతున్న పని భారాలను నిర్వహించండి
# - **🔄 సమర్థత**: అందుబాటులోని గణన వనరుల మెరుగైన వినియోగం
# - **🎯 throughput**: సమానం సమయలో మరింత పని చేయగలిగే సామర్థ్యం
#
# ## 🎨 **సమాంతర వర్క్‌ఫ్లో డిజైన్ నమూనాలు**
#
# ### 🔍 **అన్వేషణ & విశ్లేషణ పైప్‌లైన్**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **డేటా ప్రాసెసింగ్ వర్క్‌ఫ్లో**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **కంటెంట్ సృష్టి పైప్‌లైన్**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **బహుళ దశ ప్రాసెసింగ్**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ఎంటర్ప్రైజ్ పనితీరు లాభాలు**
#
# ### ⚡ **thuroughput ఆప్టిమైజేషన్**
# - **పారలల్ అమలు**: బహు ఏజెంట్లు ఒక్కేసారి పనిచేస్తారు
# - **వనరు వినియోగం**: అందుబాటులో ఉన్న AI మోడల్ సామర్థ్యాన్ని గరిష్టంగా ఉపయోగించండి
# - **సమయ తగ్గింపు**: మొత్తం ప్రాసెసింగ్ సమయం గణనీయంగా తగ్గుతుంది
# - **పరిమాణం పెంచదగ్గ ఆర్కిటెక్చర్**: అవసరమైతే మరిన్ని ఏజెంట్లను సులభంగా చేర్చవచ్చు
#
# ### 🛡️ **నమ్మకదారితనం & మన్నిక**
# - **లోప సహనం**: వ్యక్తిగత ఏజెంట్ విఫలమయినా మొత్తం వర్క్‌ఫ్లో నిలిచిపోదు
# - **లోపాల వేరు చేయడం**: ఒక సమాంతర శాఖలో సమస్యలు ఇతరలను ప్రభావితం చేయవు
# - **సౌమ్య తగ్గుదల**: ఏజెంట్ సామర్థ్యం తక్కువ అయినప్పటికీ వ్యవస్థ పనిచేస్తూనే ఉంటుంది
# - **పునరుద్ధరణ విధానాలు**: విఫలమైన కార్యకలాపాల కోసం ఆటోమేటిక్ రీట్రై మరియు లోప నిర్వహణ
#
# ### 📊 **నిరీక్షణ & పరిశీలన**
# - **సమాంతర అమలును ట్రాక్ చేయడం**: అన్ని సమాంతర కార్యకలాపాల పురోగతిని పర్యవేక్షించండి
# - **పనితీరు కొలతలు**: వేగవంతం మరియు సమర్థత లాభాలను కొలవండి
# - **వనరు వినియోగ విశ్లేషణ**: సమాంతర ఏజెంట్ కేటాయింపును ఆప్టిమైజ్ చేయండి
# - **బాటిల్‌నెక్ గుర్తింపు**: పనితీరు పరిమితులను కనుగొని పరిష్కరించండి
#
# చేర్గలిగిన, అధిక పనితీరు గల సమాంతర AI వర్క్‌ఫ్లోలను నిర్మిద్దాం! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **అస్వీకరణ**:
# ఈ పత్రం AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించబడింది. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలు తప్పులు లేదా అసమగ్రతలను కలిగి ఉండవచ్చు. దాని స్వదేశ భాషలో ఉన్న అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదం ఉపయోగం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
