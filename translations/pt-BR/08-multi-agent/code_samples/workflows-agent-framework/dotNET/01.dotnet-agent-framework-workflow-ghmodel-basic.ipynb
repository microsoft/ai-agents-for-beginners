# %% [markdown]
# # 🔄 Fluxos de Trabalho Básicos de Agentes com Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Tutorial de Orquestração de Fluxos de Trabalho
#
# Este notebook demonstra como construir **fluxos de trabalho de agentes** sofisticados usando o Microsoft Agent Framework para .NET e Azure OpenAI (Responses API). Você aprenderá a criar processos de negócios em múltiplas etapas onde agentes de IA colaboram para realizar tarefas complexas por meio de padrões estruturados de orquestração.
#
# ## 🎯 Objetivos de Aprendizagem
#
# ### 🏗️ **Fundamentos da Arquitetura de Fluxos de Trabalho**
# - **Construtor de Fluxos (Workflow Builder)**: Projetar e orquestrar processos complexos de IA em múltiplas etapas
# - **Coordenação de Agentes**: Coordenar vários agentes especializados dentro dos fluxos de trabalho
# - **Azure OpenAI (Responses API)**: Aproveitar a API Responses do Azure OpenAI nos fluxos de trabalho
# - **Design Visual de Fluxos de Trabalho**: Criar e visualizar estruturas de workflow para melhor compreensão
#
# ### 🔄 **Padrões de Orquestração de Processos**
# - **Processamento Sequencial**: Encadear múltiplas tarefas de agentes em ordem lógica
# - **Gerenciamento de Estado**: Manter contexto e fluxo de dados entre as etapas do fluxo de trabalho
# - **Tratamento de Erros**: Implementar recuperação robusta de falhas e resiliência no workflow
# - **Otimização de Performance**: Projetar fluxos eficientes para operações em escala empresarial
#
# ### 🏢 **Aplicações Empresariais de Fluxos de Trabalho**
# - **Automação de Processos de Negócio**: Automatizar fluxos organizacionais complexos
# - **Pipeline de Produção de Conteúdo**: Workflows editoriais com etapas de revisão e aprovação
# - **Automação de Atendimento ao Cliente**: Resolução de consultas de clientes em múltiplas etapas
# - **Workflows de Processamento de Dados**: Fluxos ETL com transformação alimentada por IA
#
# ## ⚙️ Pré-requisitos e Configuração
#
# ### 📦 **Pacotes NuGet Necessários**
#
# Esta demonstração de workflow utiliza vários pacotes .NET principais:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Configuração do Azure OpenAI**
#
# **Configuração do Ambiente (arquivo .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Acesso ao Azure OpenAI:**
# 1. Crie um recurso Azure OpenAI no portal Azure
# 2. Implante um modelo (por exemplo, `gpt-5-mini`) e anote o nome da implantação
# 3. Faça login com `az login` e configure as variáveis de ambiente conforme mostrado acima
#
# ### 🏗️ **Visão Geral da Arquitetura do Fluxo de Trabalho**
#
# ```mermaid
# graph TD
#     A[Construtor de Fluxo de Trabalho] --> B[Registro de Agentes]
#     B --> C[Motor de Execução de Fluxo de Trabalho]
#     C --> D[Agent 1: Gerador de Conteúdo]
#     C --> E[Agent 2: Revisor de Conteúdo]
#     D --> F[Resultados do Fluxo de Trabalho]
#     E --> F
#     G[Azure OpenAI (API de Respostas)] --> D
#     G --> E
# ```
#
# **Componentes Principais:**
# - **WorkflowBuilder**: Motor principal de orquestração para projetar fluxos de trabalho
# - **AIAgent**: Agentes especializados individuais com capacidades específicas
# - **Cliente Azure OpenAI**: Integração com Azure OpenAI Responses API
# - **Contexto de Execução**: Gerencia estado e fluxo de dados entre etapas do workflow
#
# ## 🎨 **Padrões de Design de Fluxos Empresariais**
#
# ### 📝 **Workflow de Produção de Conteúdo**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Pipeline de Processamento de Documentos**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Workflow de Inteligência de Negócios**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Automação do Atendimento ao Cliente**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Benefícios Empresariais**
#
# ### 🎯 **Confiabilidade & Escalabilidade**
# - **Execução Determinística**: Resultados consistentes e repetíveis do fluxo de trabalho
# - **Recuperação de Erros**: Tratamento elegante de falhas em qualquer etapa do workflow
# - **Monitoramento de Performance**: Acompanhar métricas de execução e oportunidades de otimização
# - **Gerenciamento de Recursos**: Alocação eficiente e utilização dos recursos de modelos de IA
#
# ### 🔒 **Segurança & Conformidade**
# - **Autenticação Segura**: Autenticação Microsoft Entra ID via `az login` (AzureCliCredential)
# - **Trilhas de Auditoria**: Registro completo da execução do workflow e pontos de decisão
# - **Controle de Acesso**: Permissões granulares para execução e monitoramento do fluxo
# - **Privacidade de Dados**: Manipulação segura de informações sensíveis durante os workflows
#
# ### 📊 **Observabilidade & Gestão**
# - **Design Visual dos Workflows**: Representação clara de fluxos de processo e dependências
# - **Monitoramento da Execução**: Acompanhamento em tempo real do progresso e performance do workflow
# - **Relatórios de Erros**: Análise detalhada de erros e capacidades de depuração
# - **Análise de Performance**: Métricas para otimização e planejamento de capacidade
#
# Vamos construir seu primeiro workflow de IA pronto para o ambiente corporativo! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Aviso Legal**:
# Este documento foi traduzido usando o serviço de tradução por IA [Co-op Translator](https://github.com/Azure/co-op-translator). Embora nos esforcemos pela precisão, por favor, esteja ciente de que traduções automatizadas podem conter erros ou imprecisões. O documento original em seu idioma nativo deve ser considerado a fonte autorizada. Para informações críticas, recomenda-se tradução profissional humana. Não nos responsabilizamos por quaisquer mal-entendidos ou interpretações incorretas decorrentes do uso desta tradução.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
