# %% [markdown]
# # ⚡ GitHubモデルによる並行エージェントワークフロー（Python）
#
# ## 📋 高度な並列処理チュートリアル
#
# このノートブックでは、Microsoft Agent Framework を使った<strong>並行ワークフローパターン</strong>を紹介します。複数のAIエージェントが同時に実行される、高性能な並列処理ワークフローの構築方法を学び、スループットを劇的に向上させ、洗練されたマルチスレッドのビジネスプロセスを可能にします。
#
# ## 🎯 学習目標
#
# ### 🚀 <strong>並行処理の基本</strong>
# - <strong>エージェントの並列実行</strong>：複数エージェントを同時に実行して最大効率を実現
# - <strong>ワークフローオーケストレーション</strong>：データ整合性を保ちながら並行操作を調整
# - <strong>パフォーマンス最適化</strong>：並列処理による大幅な高速化を達成
# - <strong>リソース管理</strong>：並行処理でのAIモデルリソースの効率的な活用
#
# ### 🏗️ <strong>高度な並行パターン</strong>
# - <strong>フォーク・ジョイン処理</strong>：複数エージェントに仕事を分割し結果を統合
# - <strong>パイプライン並列処理</strong>：実行ステージを重ねて連続的なスループットを実現
# - <strong>負荷分散</strong>：利用可能なエージェントリソースに均等に作業を割り当て
# - <strong>同期ポイント</strong>：重要なワークフローステージで並行エージェントを調整
#
# ### 🏢 <strong>エンタープライズ向け並行アプリケーション</strong>
# - <strong>大量文書処理</strong>：複数文書を同時に処理
# - <strong>リアルタイムコンテンツ分析</strong>：受信データストリームの同時分析
# - <strong>バッチ処理最適化</strong>：大規模処理のスループット最大化
# - <strong>マルチモーダル分析</strong>：異なるコンテンツタイプ（テキスト、画像、データ）を並行処理
#
# ## ⚙️ 前提条件とセットアップ
#
# ### 📦 <strong>必要な依存関係</strong>
#
# 並行ワークフロー機能付きのAgent Frameworkをインストール：
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Modelsの構成**
#
# **環境セットアップ（.envファイル）：**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **並行処理に関する注意点：**
# - <strong>レート制限</strong>：GitHub Models APIの並行リクエストにおけるレート制限を監視
# - <strong>リソース使用量</strong>：複数並行エージェントのメモリおよびCPU使用を考慮
# - <strong>エラー処理</strong>：並列操作における堅牢なエラー回復を実装
#
# ### 🏗️ <strong>並行ワークフローアーキテクチャ</strong>
#
# ```mermaid
# graph TD
#     A[ワークフロー開始] --> B[並行実行]
#     B --> C[エージェントプール 1]
#     B --> D[エージェントプール 2]
#     B --> E[エージェントプール 3]
#     C --> F[結果の集約]
#     D --> F
#     E --> F
#     F --> G[最終出力]
#
#     H[GitHub モデル API] --> C
#     H --> D
#     H --> E
# ```
#
# **主なメリット：**
# - **⚡ パフォーマンス**：並列実行による大幅な高速化
# - **📈 スケーラビリティ**：負荷が増えても比例した時間増加なしで対応
# - **🔄 効率性**：利用可能な計算リソースのより良い活用
# - **🎯 スループット**：同じ時間内により多くの作業を処理
#
# ## 🎨 <strong>並行ワークフローデザインパターン</strong>
#
# ### 🔍 <strong>調査・分析パイプライン</strong>
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 <strong>データ処理ワークフロー</strong>
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 <strong>コンテンツ作成パイプライン</strong>
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 <strong>多段階処理</strong>
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 <strong>エンタープライズにおけるパフォーマンス利点</strong>
#
# ### ⚡ <strong>スループット最適化</strong>
# - <strong>並列実行</strong>：複数エージェントが同時に作業
# - <strong>リソース利用</strong>：利用可能なAIモデル容量の最大効率
# - <strong>時間短縮</strong>：全体処理時間の大幅削減
# - <strong>スケーラブル設計</strong>：必要に応じて並行エージェントを簡単に追加可能
#
# ### 🛡️ <strong>信頼性とレジリエンス</strong>
# - <strong>フォールトトレランス</strong>：個別エージェントの障害がワークフロー全体を停止させない
# - <strong>エラー隔離</strong>：一つの並行ブランチの問題が他に影響を与えない
# - <strong>優雅な劣化</strong>：エージェント容量が減ってもシステムは継続稼働
# - <strong>復旧機構</strong>：失敗した操作の自動リトライやエラー処理
#
# ### 📊 <strong>モニタリングと可観測性</strong>
# - <strong>並行実行トラッキング</strong>：すべての並列操作の進捗監視
# - <strong>パフォーマンス指標</strong>：高速化および効率向上を測定
# - <strong>リソース使用解析</strong>：並行エージェント割り当ての最適化
# - <strong>ボトルネック特定</strong>：パフォーマンス制約の検出＆解決
#
# 高性能な並行AIワークフローを一緒に構築しましょう！🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **免責事項**：
# 本書類は AI 翻訳サービス [Co-op Translator](https://github.com/Azure/co-op-translator) を使用して翻訳されています。正確性を期していますが、自動翻訳には誤りや不正確な部分が含まれる可能性があることをご承知おきください。原文の原語版が正式な情報源とみなされるべきです。重要な情報については、専門の人間による翻訳を推奨します。本翻訳の利用により生じたいかなる誤解や解釈違いについても、当方は責任を負いかねます。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
