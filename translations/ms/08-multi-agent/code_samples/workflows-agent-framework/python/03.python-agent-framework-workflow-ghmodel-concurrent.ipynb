# %% [markdown]
# # ⚡ Aliran Kerja Ejen Serentak dengan Microsoft Foundry (Python)
#
# ## 📋 Tutorial Pemprosesan Selari Lanjutan
#
# Notebook ini menunjukkan **corak aliran kerja serentak** menggunakan Rangka Kerja Ejen Microsoft. Anda akan belajar cara membina aliran kerja pemprosesan selari berprestasi tinggi di mana beberapa ejen AI melaksanakan secara serentak, secara dramatik meningkatkan hasil dan membolehkan proses perniagaan pelbagai-utasan yang canggih.
#
# > **Nota migrasi:** Contoh ini sebelum ini merujuk Model GitHub. Model GitHub telah tidak digunakan (akan dihentikan pada Julai 2026), jadi kini ia menggunakan **Microsoft Foundry** melalui `FoundryChatClient`, yang menyasarkan Azure OpenAI **API Respons**.
#
# ## 🎯 Objektif Pembelajaran
#
# ### 🚀 **Asas Pemprosesan Serentak**
# - **Pelaksanaan Ejen Selari**: Jalankan pelbagai ejen serentak untuk kecekapan maksimum
# - **Penyelarasan Aliran Kerja**: Atur operasi serentak sambil mengekalkan konsistensi data
# - **Pengoptimuman Prestasi**: Capai percepatan signifikan melalui pemprosesan selari
# - **Pengurusan Sumber**: Gunakan sumber model AI dengan cekap merentasi operasi serentak
#
# ### 🏗️ **Corak Kesedaran Serentak Lanjutan**
# - **Pemprosesan Fork-Join**: Bahagikan kerja merentasi pelbagai ejen dan gabungkan hasil
# - **Paralelisme Saluran Paip**: Tahap pelaksanaan bertindih untuk hasil berterusan
# - **Penyeimbangan Beban**: Agihkan kerja secara merata merentasi sumber ejen yang tersedia
# - **Titik Penyelarasan**: Atur ejen serentak di peringkat kritikal aliran kerja
#
# ### 🏢 **Aplikasi Serentak Perusahaan**
# - **Pemprosesan Dokumen Berjumlah Tinggi**: Proses pelbagai dokumen serentak
# - **Analisis Kandungan Masa-Nyata**: Analisis serentak aliran data masuk
# - **Pengoptimuman Pemprosesan Sekumpulan**: Maksimumkan hasil untuk operasi skala besar
# - **Analisis Pelbagai Mod**: Pemprosesan selari jenis kandungan berbeza (teks, imej, data)
#
# ## ⚙️ Prasyarat & Persediaan
#
# ### 📦 **Kebergantungan Diperlukan**
#
# Pasang Rangka Kerja Ejen dengan keupayaan aliran kerja serentak:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurasi Microsoft Foundry**
#
# Log masuk dengan Azure CLI (`az login`) supaya `AzureCliCredential` boleh mengesahkan, kemudian tetapkan butiran projek Microsoft Foundry anda.
#
# **Persediaan Persekitaran (fail .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Pertimbangan Pemprosesan Serentak:**
# - **Had Kadar**: Pantau had kadar Azure OpenAI untuk permintaan serentak
# - **Penggunaan Sumber**: Pertimbangkan penggunaan memori dan CPU dengan beberapa ejen serentak
# - **Pengendalian Ralat**: Laksanakan pemulihan ralat yang kukuh untuk operasi selari
#
# ### 🏗️ **Senibina Aliran Kerja Serentak**
#
# ```mermaid
# graph TD
#     A[Mula Aliran Kerja] --> B[Pelaksanaan Serentak]
#     B --> C[Kolam Ejen 1]
#     B --> D[Kolam Ejen 2]
#     B --> E[Kolam Ejen 3]
#     C --> F[Pengumpulan Keputusan]
#     D --> F
#     E --> F
#     F --> G[Output Akhir]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Faedah Utama:**
# - **⚡ Prestasi**: Percepatan signifikan melalui pelaksanaan selari
# - **📈 Kebolehskalaan**: Tangani beban kerja bertambah tanpa peningkatan masa berkadar
# - **🔄 Kecekapan**: Penggunaan lebih baik sumber pengkomputeran yang tersedia
# - **🎯 Hasil**: Proses lebih banyak kerja dalam masa yang sama
#
# ## 🎨 **Corak Reka Bentuk Aliran Kerja Serentak**
#
# ### 🔍 **Saluran Penyelidikan & Analisis**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Aliran Kerja Pemprosesan Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Saluran Penciptaan Kandungan**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Pemprosesan Berperingkat Pelbagai**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Faedah Prestasi Perusahaan**
#
# ### ⚡ **Pengoptimuman Hasil**
# - **Pelaksanaan Selari**: Pelbagai ejen bekerja serentak
# - **Penggunaan Sumber**: Kecekapan maksimum kapasiti model AI yang tersedia
# - **Pengurangan Masa**: Pengurangan signifikan dalam jumlah masa pemprosesan
# - **Senibina Boleh Skala**: Mudah tambah lebih banyak ejen serentak mengikut keperluan
#
# ### 🛡️ **Kebolehpercayaan & Ketahanan**
# - **Toleransi Kegagalan**: Kegagalan ejen individu tidak menghentikan keseluruhan aliran kerja
# - **Pengasingan Ralat**: Masalah dalam satu cawangan serentak tidak menjejaskan yang lain
# - **Pengurangan Anggun**: Sistem terus beroperasi walaupun dengan kapasiti ejen berkurang
# - **Mekanisme Pemulihan**: Cuba semula automatik dan pengendalian ralat untuk operasi yang gagal
#
# ### 📊 **Pemantauan & Kebolehpantauan**
# - **Penjejakan Pelaksanaan Serentak**: Pantau kemajuan semua operasi selari
# - **Metik Prestasi**: Ukur kelajuan dan peningkatan kecekapan
# - **Analitik Penggunaan Sumber**: Optimumkan peruntukan ejen serentak
# - **Pengecaman Sempadan**: Cari dan selesaikan kekangan prestasi
#
# Mari bina aliran kerja AI serentak berprestasi tinggi! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Penafian**:
# Dokumen ini telah diterjemahkan menggunakan perkhidmatan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Walaupun kami berusaha untuk ketepatan, sila ambil maklum bahawa terjemahan automatik mungkin mengandungi kesilapan atau ketidaktepatan. Dokumen asal dalam bahasa asalnya harus dianggap sebagai sumber yang sahih. Untuk maklumat penting, terjemahan oleh manusia profesional adalah disyorkan. Kami tidak bertanggungjawab terhadap sebarang salah faham atau salah tafsir yang timbul daripada penggunaan terjemahan ini.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
