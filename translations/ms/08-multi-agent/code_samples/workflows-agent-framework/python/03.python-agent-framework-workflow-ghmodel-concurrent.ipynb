# %% [markdown]
# # ⚡ Aliran Kerja Ejen Serentak dengan Model GitHub (Python)
#
# ## 📋 Tutorial Pemprosesan Selari Lanjutan
#
# Notebook ini menunjukkan **corak aliran kerja serentak** menggunakan Microsoft Agent Framework. Anda akan belajar bagaimana membina aliran kerja pemprosesan selari berprestasi tinggi di mana pelbagai ejen AI menjalankan tugas secara serentak, meningkatkan hasil dengan ketara dan membolehkan proses perniagaan berbilang-thread yang canggih.
#
# ## 🎯 Objektif Pembelajaran
#
# ### 🚀 **Asas Pemprosesan Serentak**
# - **Pelaksanaan Ejen Selari**: Jalankan pelbagai ejen serentak untuk kecekapan maksimum
# - **Orkestrasi Aliran Kerja**: Menyelaras operasi serentak sambil mengekalkan konsistensi data
# - **Pengoptimuman Prestasi**: Capai peningkatan kelajuan yang signifikan melalui pemprosesan selari
# - **Pengurusan Sumber**: Gunakan sumber model AI dengan cekap merentas operasi serentak
#
# ### 🏗️ **Corak Serentak Lanjutan**
# - **Pemprosesan Fork-Join**: Bahagikan kerja merentasi pelbagai ejen dan gabungkan hasil
# - **Selari Rantaian Paip**: Melakukan peringkat pelaksanaan bertindih untuk aliran keluar yang berterusan
# - **Penyeimbangan Beban**: Edarkan kerja secara rata di seluruh sumber ejen yang tersedia
# - **Titik Penyelarasan**: Menyelaras ejen serentak pada peringkat aliran kerja yang kritikal
#
# ### 🏢 **Aplikasi Serentak Perusahaan**
# - **Pemprosesan Dokumen Berkapasiti Tinggi**: Memproses pelbagai dokumen secara serentak
# - **Analisis Kandungan Masa Nyata**: Analisis serentak aliran data masuk
# - **Pengoptimuman Pemprosesan Pukal**: Maksimumkan hasil untuk operasi berskala besar
# - **Analisis Pelbagai Modaliti**: Pemprosesan selari pelbagai jenis kandungan (teks, imej, data)
#
# ## ⚙️ Prasyarat & Persediaan
#
# ### 📦 **Kebergantungan Diperlukan**
#
# Pasang Agent Framework dengan kemampuan aliran kerja serentak:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Konfigurasi Model GitHub**
#
# **Persediaan Persekitaran (fail .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Pertimbangan Pemprosesan Serentak:**
# - **Had Kadar**: Pantau had kadar API Model GitHub untuk permintaan serentak
# - **Penggunaan Sumber**: Pertimbangkan penggunaan memori dan CPU dengan pelbagai ejen serentak
# - **Pengendalian Ralat**: Laksanakan pemulihan ralat yang teguh untuk operasi selari
#
# ### 🏗️ **Seni Bina Aliran Kerja Serentak**
#
# ```mermaid
# graph TD
#     A[Mula Aliran Kerja] --> B[Pelaksanaan Serentak]
#     B --> C[Kumpulan Ejen 1]
#     B --> D[Kumpulan Ejen 2]
#     B --> E[Kumpulan Ejen 3]
#     C --> F[Penggabungan Keputusan]
#     D --> F
#     E --> F
#     F --> G[Output Akhir]
#
#     H[API Model GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **Manfaat Utama:**
# - **⚡ Prestasi**: Peningkatan kelajuan yang signifikan melalui pelaksanaan selari
# - **📈 Kebolehskalaan**: Menangani beban kerja yang meningkat tanpa penambahan masa sepadan
# - **🔄 Kecekapan**: Penggunaan sumber pengkomputeran yang lebih baik
# - **🎯 Hasil**: Memproses lebih banyak kerja dalam masa yang sama
#
# ## 🎨 **Corak Reka Bentuk Aliran Kerja Serentak**
#
# ### 🔍 **Rantaian Paip Penyelidikan & Analisis**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Aliran Kerja Pemprosesan Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Rantaian Paip Penciptaan Kandungan**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Pemprosesan Berperingkat Pelbagai**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Faedah Prestasi Perusahaan**
#
# ### ⚡ **Pengoptimuman Hasil**
# - **Pelaksanaan Selari**: Pelbagai ejen bekerja serentak
# - **Penggunaan Sumber**: Kecekapan maksimum kapasiti model AI yang tersedia
# - **Pengurangan Masa**: Pengurangan ketara dalam jumlah masa pemprosesan
# - **Seni Bina Boleh Skala**: Mudah menambah lebih banyak ejen serentak mengikut keperluan
#
# ### 🛡️ **Kebolehpercayaan & Ketahanan**
# - **Tahan Ralat**: Kegagalan ejen individu tidak menghentikan keseluruhan aliran kerja
# - **Pengasingan Ralat**: Masalah dalam satu cabang serentak tidak menjejaskan yang lain
# - **Penurunan Berhemah**: Sistem terus beroperasi walaupun dengan kapasiti ejen yang berkurang
# - **Mekanisme Pemulihan**: Cuba semula secara automatik dan pengendalian ralat untuk operasi yang gagal
#
# ### 📊 **Pemantauan & Kebolehamatan**
# - **Penjejakan Pelaksanaan Serentak**: Pantau kemajuan semua operasi selari
# - **Metrik Prestasi**: Ukur peningkatan kelajuan dan kecekapan
# - **Analitik Penggunaan Sumber**: Optimumkan peruntukan ejen serentak
# - **Pengenalpastian Halangan**: Cari dan selesaikan kekangan prestasi
#
# Mari bangunkan aliran kerja AI serentak berprestasi tinggi! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Penafian**:
# Dokumen ini telah diterjemahkan menggunakan perkhidmatan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Walaupun kami berusaha untuk ketepatan, sila ambil maklum bahawa terjemahan automatik mungkin mengandungi kesilapan atau ketidaktepatan. Dokumen asal dalam bahasa asalnya harus dianggap sebagai sumber yang sahih. Untuk maklumat penting, terjemahan oleh manusia profesional adalah disyorkan. Kami tidak bertanggungjawab terhadap sebarang salah faham atau salah tafsir yang timbul daripada penggunaan terjemahan ini.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
