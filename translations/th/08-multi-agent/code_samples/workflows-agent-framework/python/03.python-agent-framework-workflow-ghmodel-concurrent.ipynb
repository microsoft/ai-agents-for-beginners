# %% [markdown]
# # ⚡ การทำงานพร้อมกันของ Agent Workflow กับ GitHub Models (Python)
#
# ## 📋 บทเรียนการประมวลผลขนานขั้นสูง
#
# สมุดบันทึกนี้แสดงให้เห็น **รูปแบบ workflow ที่ทำงานพร้อมกัน** โดยใช้ Microsoft Agent Framework คุณจะได้เรียนรู้วิธีสร้าง workflow การประมวลผลขนานประสิทธิภาพสูงที่เอเจนต์ AI หลายตัวทำงานพร้อมกัน ซึ่งช่วยเพิ่มประสิทธิภาพและเปิดโอกาสให้กับกระบวนการทางธุรกิจแบบมัลติเทรดขั้นสูงได้
#
# ## 🎯 วัตถุประสงค์การเรียนรู้
#
# ### 🚀 **พื้นฐานการประมวลผลพร้อมกัน**
# - **การรันเอเจนต์แบบขนาน**: รันเอเจนต์หลายตัวพร้อมกันเพื่อประสิทธิภาพสูงสุด
# - **การประสานงาน Workflow**: ประสานงานการทำงานพร้อมกันขณะรักษาความสอดคล้องของข้อมูล
# - **การปรับแต่งประสิทธิภาพ**: บรรลุความเร็วที่เพิ่มขึ้นอย่างมากด้วยการประมวลผลขนาน
# - **การจัดการทรัพยากร**: ใช้ทรัพยากรโมเดล AI อย่างมีประสิทธิภาพในงานพร้อมกัน
#
# ### 🏗️ **รูปแบบความพร้อมกันขั้นสูง**
# - **การประมวลผลแบบ Fork-Join**: แบ่งงานให้เอเจนต์หลายตัวแล้วรวมผลลัพธ์
# - **Pipeline Parallelism**: ทำงานในขั้นตอนทับซ้อนกันเพื่อ throughput ต่อเนื่อง
# - **การกระจายโหลด**: กระจายงานอย่างเท่าเทียมกันในทรัพยากรเอเจนต์ที่มี
# - **จุดซิงโครไนซ์**: ประสานงานเอเจนต์พร้อมกันในขั้นตอนสำคัญของ workflow
#
# ### 🏢 **แอปพลิเคชันพร้อมกันสำหรับองค์กร**
# - **การประมวลผลเอกสารปริมาณสูง**: ประมวลผลงานเอกสารหลายชิ้นพร้อมกัน
# - **การวิเคราะห์เนื้อหาเรียลไทม์**: วิเคราะห์ข้อมูลที่เข้ามาแบบพร้อมกัน
# - **การปรับแต่งการประมวลผลแบบแบตช์**: เพิ่ม throughput สำหรับงานขนาดใหญ่
# - **การวิเคราะห์หลายรูปแบบ**: ประมวลผลขนานของเนื้อหาหลากหลายประเภท (ข้อความ, รูปภาพ, ข้อมูล)
#
# ## ⚙️ ข้อกำหนดเบื้องต้น & การตั้งค่า
#
# ### 📦 **การติดตั้งที่จำเป็น**
#
# ติดตั้ง Agent Framework พร้อมความสามารถ workflow พร้อมกัน:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **การตั้งค่า GitHub Models**
#
# **การตั้งค่าสภาพแวดล้อม (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ข้อควรพิจารณาการประมวลผลพร้อมกัน:**
# - **ขีดจำกัดการใช้งาน**: ตรวจสอบขีดจำกัด API ของ GitHub Models สำหรับคำขอพร้อมกัน
# - **การใช้งานทรัพยากร**: พิจารณาการใช้หน่วยความจำและ CPU กับเอเจนต์หลายตัวพร้อมกัน
# - **การจัดการข้อผิดพลาด**: ทำการกู้คืนข้อผิดพลาดอย่างแข็งแรงสำหรับงานแบบขนาน
#
# ### 🏗️ **สถาปัตยกรรม Workflow พร้อมกัน**
#
# ```mermaid
# graph TD
#     A[เริ่มต้นเวิร์กโฟลว์] --> B[การดำเนินการพร้อมกัน]
#     B --> C[กลุ่มเอเจนต์ 1]
#     B --> D[กลุ่มเอเจนต์ 2]
#     B --> E[กลุ่มเอเจนต์ 3]
#     C --> F[การรวบรวมผลลัพธ์]
#     D --> F
#     E --> F
#     F --> G[ผลลัพธ์สุดท้าย]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **ประโยชน์หลัก:**
# - **⚡ ประสิทธิภาพ**: เพิ่มความเร็วอย่างมีนัยสำคัญด้วยการรันขนาน
# - **📈 การปรับขนาด**: รองรับงานที่เพิ่มขึ้นโดยไม่เพิ่มเวลาสัดส่วน
# - **🔄 ประสิทธิผล**: ใช้ทรัพยากรคอมพิวเตอร์ที่มีอย่างคุ้มค่า
# - **🎯 Throughput**: ประมวลผลงานได้มากขึ้นในเวลาที่เท่ากัน
#
# ## 🎨 **แบบแผนการออกแบบ Workflow พร้อมกัน**
#
# ### 🔍 **ระบบวิจัย & วิเคราะห์**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow การประมวลผลข้อมูล**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline การสร้างเนื้อหา**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **การประมวลผลหลายขั้นตอน**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ประโยชน์ประสิทธิภาพสำหรับองค์กร**
#
# ### ⚡ **การเพิ่ม throughput**
# - **การรันพร้อมกัน**: หลายเอเจนต์ทำงานพร้อมกัน
# - **การใช้ทรัพยากร**: ประสิทธิผลสูงสุดจากความสามารถโมเดล AI ที่มี
# - **การลดเวลา**: ลดเวลาการประมวลผลรวมอย่างมาก
# - **สถาปัตยกรรมที่ปรับขนาดได้**: เพิ่มเอเจนต์ขนานได้ง่ายตามความต้องการ
#
# ### 🛡️ **ความน่าเชื่อถือ & ความยืดหยุ่น**
# - **ความทนทานต่อข้อผิดพลาด**: เอเจนต์ล้มเหลวรายตัวไม่หยุด workflow ทั้งหมด
# - **การแยกข้อผิดพลาด**: ปัญหาในแยกงานขนานไม่กระทบงานอื่น
# - **การลดลงอย่างนุ่มนวล**: ระบบยังทำงานได้แม้เอเจนต์มีความสามารถลดลง
# - **กลไกกู้คืน**: ลองใหม่อัตโนมัติและจัดการข้อผิดพลาดของงานที่ล้มเหลว
#
# ### 📊 **การติดตาม & การสังเกตการณ์**
# - **ติดตามการรันพร้อมกัน**: ตรวจสอบความคืบหน้าของการทำงานขนานทั้งหมด
# - **มาตรวัดประสิทธิภาพ**: วัดความเร็วและประสิทธิผลที่ได้
# - **วิเคราะห์การใช้ทรัพยากร**: ปรับแต่งการจัดสรรเอเจนต์ขนาน
# - **การหาคอขวด**: ค้นหาและแก้ไขข้อจำกัดประสิทธิภาพ
#
# มาเริ่มสร้าง workflow AI พร้อมกันประสิทธิภาพสูงกันเถอะ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ปฏิเสธความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) ขณะที่เราพยายามให้ความถูกต้อง โปรดทราบว่าการแปลโดยอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาต้นทางควรถูกพิจารณาเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ แนะนำให้ใช้การแปลโดยมนุษย์มืออาชีพ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความที่ผิดพลาดที่เกิดขึ้นจากการใช้การแปลนี้
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
