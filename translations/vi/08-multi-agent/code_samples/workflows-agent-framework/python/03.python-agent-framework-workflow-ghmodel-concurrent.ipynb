# %% [markdown]
# # ⚡ Quy Trình Công Việc Song Song với Các Mô Hình GitHub (Python)
#
# ## 📋 Hướng Dẫn Xử Lý Song Song Nâng Cao
#
# Notebook này trình bày các **mẫu quy trình công việc song song** sử dụng Microsoft Agent Framework. Bạn sẽ học cách xây dựng các quy trình công việc xử lý song song hiệu suất cao, nơi nhiều tác nhân AI thực thi đồng thời, cải thiện đáng kể thông lượng và cho phép các quy trình kinh doanh đa luồng phức tạp.
#
# ## 🎯 Mục Tiêu Học Tập
#
# ### 🚀 **Các Nguyên Tắc Xử Lý Song Song**
# - **Thực thi Tác nhân Song Song**: Chạy nhiều tác nhân đồng thời để đạt hiệu quả tối đa
# - **Điều phối Quy trình Công việc**: Phối hợp các hoạt động song song đồng thời duy trì nhất quán dữ liệu
# - **Tối ưu Hiệu suất**: Đạt được tăng tốc đáng kể thông qua xử lý song song
# - **Quản lý Tài nguyên**: Sử dụng hiệu quả tài nguyên mô hình AI trên các hoạt động đồng thời
#
# ### 🏗️ **Mẫu Mã Đồng Thời Nâng Cao**
# - **Xử lý Fork-Join**: Phân chia công việc cho nhiều tác nhân và hợp nhất kết quả
# - **Đường ống Song song**: Thực thi các giai đoạn chồng lấp để duy trì thông lượng liên tục
# - **Cân bằng Tải**: Phân phối công việc đều trên các tài nguyên tác nhân có sẵn
# - **Điểm Đồng bộ**: Phối hợp các tác nhân đồng thời tại các giai đoạn quan trọng của quy trình công việc
#
# ### 🏢 **Ứng dụng Song song cho Doanh nghiệp**
# - **Xử lý Tài liệu Lượng lớn**: Xử lý nhiều tài liệu đồng thời
# - **Phân tích Nội dung Thời gian Thực**: Phân tích đồng thời các luồng dữ liệu đến
# - **Tối ưu Xử lý Theo Lô**: Tối đa hóa thông lượng cho các hoạt động quy mô lớn
# - **Phân tích Đa phương tiện**: Xử lý song song nhiều loại nội dung khác nhau (văn bản, hình ảnh, dữ liệu)
#
# ## ⚙️ Yêu Cầu & Cài Đặt
#
# ### 📦 **Phụ Thuộc Cần Thiết**
#
# Cài đặt Agent Framework với khả năng quy trình công việc song song:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Cấu Hình Mô hình GitHub**
#
# **Thiết lập Môi trường (file .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Lưu ý Xử lý Song song:**
# - **Giới hạn Tốc độ**: Giám sát giới hạn tốc độ API mô hình GitHub cho các yêu cầu đồng thời
# - **Sử dụng Tài nguyên**: Cân nhắc bộ nhớ và CPU khi chạy nhiều tác nhân song song
# - **Xử lý Lỗi**: Triển khai cơ chế phục hồi lỗi vững chắc cho các hoạt động song song
#
# ### 🏗️ **Kiến trúc Quy trình Công việc Song song**
#
# ```mermaid
# graph TD
#     A[Bắt đầu luồng công việc] --> B[Thực thi đồng thời]
#     B --> C[Nhóm tác nhân 1]
#     B --> D[Nhóm tác nhân 2]
#     B --> E[Nhóm tác nhân 3]
#     C --> F[Tổng hợp kết quả]
#     D --> F
#     E --> F
#     F --> G[Kết quả cuối cùng]
#
#     H[API Mô hình GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **Lợi ích Chính:**
# - **⚡ Hiệu suất**: Tăng tốc đáng kể qua thực thi song song
# - **📈 Khả năng Mở rộng**: Xử lý khối lượng công việc tăng mà không tăng thời gian tỉ lệ thuận
# - **🔄 Hiệu quả**: Tận dụng tốt hơn các tài nguyên tính toán sẵn có
# - **🎯 Thông lượng**: Xử lý nhiều công việc hơn trong cùng một khoảng thời gian
#
# ## 🎨 **Mẫu Thiết kế Quy trình Công việc Song song**
#
# ### 🔍 **Đường ống Nghiên cứu & Phân tích**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Quy trình Xử lý Dữ liệu**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Đường ống Tạo Nội dung**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Xử lý Đa giai đoạn**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Lợi ích Hiệu suất Doanh nghiệp**
#
# ### ⚡ **Tối ưu Thông lượng**
# - **Thực thi Song song**: Nhiều tác nhân làm việc đồng thời
# - **Sử dụng Tài nguyên**: Hiệu quả tối đa công suất mô hình AI có sẵn
# - **Giảm Thời gian**: Giảm đáng kể thời gian xử lý tổng thể
# - **Kiến trúc Mở rộng**: Dễ dàng thêm nhiều tác nhân song song khi cần thiết
#
# ### 🛡️ **Độ Tin cậy & Độ Bền**
# - **Chịu lỗi**: Sự cố của tác nhân riêng lẻ không làm gián đoạn toàn bộ quy trình công việc
# - **Cô lập Lỗi**: Sự cố trong nhánh đồng thời không ảnh hưởng đến các nhánh khác
# - **Giảm cấp Có kiểm soát**: Hệ thống tiếp tục vận hành ngay cả khi giảm công suất tác nhân
# - **Cơ chế Phục hồi**: Tự động thử lại và xử lý lỗi cho các thao tác thất bại
#
# ### 📊 **Giám sát & Quan sát**
# - **Theo dõi Thực thi Song song**: Giám sát tiến trình của tất cả các hoạt động song song
# - **Chỉ số Hiệu suất**: Đo lường tốc độ và hiệu quả tăng lên
# - **Phân tích Sử dụng Tài nguyên**: Tối ưu phân bổ tác nhân song song
# - **Xác định Nút thắt**: Tìm và giải quyết các giới hạn hiệu suất
#
# Hãy cùng xây dựng các quy trình AI song song hiệu suất cao! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Tuyên bố miễn trừ trách nhiệm**:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi cố gắng đảm bảo độ chính xác, xin lưu ý rằng bản dịch tự động có thể chứa lỗi hoặc sai sót. Tài liệu gốc bằng ngôn ngữ gốc nên được coi là nguồn tin chính thức. Đối với thông tin quan trọng, nên sử dụng dịch vụ dịch thuật chuyên nghiệp bởi con người. Chúng tôi không chịu trách nhiệm về bất kỳ hiểu lầm hoặc giải thích sai nào phát sinh từ việc sử dụng bản dịch này.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
