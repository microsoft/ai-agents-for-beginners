# %% [markdown]
# # 🔄 Luồng công việc cơ bản của Agent với Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Hướng dẫn phối hợp luồng công việc
#
# Bản ghi chú này trình bày cách xây dựng các **luồng công việc agent** tinh vi sử dụng Microsoft Agent Framework cho .NET và Azure OpenAI (Responses API). Bạn sẽ học cách tạo ra các quy trình kinh doanh đa bước, nơi các agent AI hợp tác để hoàn thành các tác vụ phức tạp thông qua các mẫu phối hợp có cấu trúc.
#
# ## 🎯 Mục tiêu học tập
#
# ### 🏗️ **Kiến trúc luồng công việc cơ bản**
# - **Trình xây dựng luồng công việc**: Thiết kế và phối hợp các quy trình AI đa bước phức tạp
# - **Phối hợp agent**: Điều phối nhiều agent chuyên môn trong các luồng công việc
# - **Azure OpenAI (Responses API)**: Tận dụng Azure OpenAI Responses API trong các luồng công việc
# - **Thiết kế luồng công việc trực quan**: Tạo và hình dung cấu trúc luồng công việc để hiểu rõ hơn
#
# ### 🔄 **Mẫu phối hợp quy trình**
# - **Xử lý tuần tự**: Chuỗi các tác vụ agent theo thứ tự logic
# - **Quản lý trạng thái**: Duy trì ngữ cảnh và luồng dữ liệu qua các giai đoạn luồng công việc
# - **Xử lý lỗi**: Triển khai phục hồi lỗi bền bỉ và khả năng chịu lỗi trong luồng công việc
# - **Tối ưu hiệu suất**: Thiết kế luồng công việc hiệu quả cho vận hành quy mô doanh nghiệp
#
# ### 🏢 **Ứng dụng luồng công việc doanh nghiệp**
# - **Tự động hóa quy trình kinh doanh**: Tự động hóa các luồng công việc tổ chức phức tạp
# - **Quy trình sản xuất nội dung**: Luồng công việc biên tập có các bước xem xét và phê duyệt
# - **Tự động hóa dịch vụ khách hàng**: Giải quyết truy vấn khách hàng đa bước
# - **Luồng công việc xử lý dữ liệu**: Luồng ETL với chuyển đổi hỗ trợ AI
#
# ## ⚙️ Yêu cầu & Cài đặt
#
# ### 📦 **Gói NuGet cần thiết**
#
# Mẫu luồng công việc này sử dụng một số gói .NET chính:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Cấu hình Azure OpenAI**
#
# **Cài đặt môi trường (tệp .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Truy cập Azure OpenAI:**
# 1. Tạo một tài nguyên Azure OpenAI trong cổng Azure
# 2. Triển khai một mô hình (ví dụ, `gpt-5-mini`) và ghi lại tên triển khai
# 3. Đăng nhập với `az login` và cấu hình biến môi trường như đã trình bày ở trên
#
# ### 🏗️ **Tổng quan kiến trúc luồng công việc**
#
# ```mermaid
# graph TD
#     A[Trình xây dựng quy trình làm việc] --> B[Đăng ký đại lý]
#     B --> C[Công cụ thực thi quy trình làm việc]
#     C --> D[Agent 1: Trình tạo nội dung]
#     C --> E[Agent 2: Người đánh giá nội dung]
#     D --> F[Kết quả quy trình làm việc]
#     E --> F
#     G[Azure OpenAI (API phản hồi)] --> D
#     G --> E
# ```
#
# **Các thành phần chính:**
# - **WorkflowBuilder**: Động cơ phối hợp chính để thiết kế các luồng công việc
# - **AIAgent**: Các agent chuyên môn riêng biệt với các khả năng cụ thể
# - **Azure OpenAI Client**: Tích hợp Azure OpenAI Responses API
# - **Execution Context**: Quản lý trạng thái và luồng dữ liệu giữa các giai đoạn luồng công việc
#
# ## 🎨 **Mẫu thiết kế luồng công việc doanh nghiệp**
#
# ### 📝 **Luồng công việc sản xuất nội dung**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Quy trình xử lý tài liệu**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Luồng công việc quản trị kinh doanh**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Tự động hóa dịch vụ khách hàng**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Lợi ích doanh nghiệp**
#
# ### 🎯 **Độ tin cậy & Khả năng mở rộng**
# - **Thực thi xác định**: Kết quả luồng công việc nhất quán và có thể lặp lại
# - **Phục hồi lỗi**: Xử lý khéo léo các lỗi ở bất kỳ giai đoạn luồng công việc nào
# - **Giám sát hiệu suất**: Theo dõi các chỉ số thực thi và cơ hội tối ưu hóa
# - **Quản lý tài nguyên**: Phân bổ và sử dụng tài nguyên mô hình AI hiệu quả
#
# ### 🔒 **Bảo mật & Tuân thủ**
# - **Xác thực an toàn**: Xác thực Microsoft Entra ID qua `az login` (AzureCliCredential)
# - **Theo dõi kiểm toán**: Ghi lại đầy đủ các điểm thực thi và quyết định luồng công việc
# - **Kiểm soát truy cập**: Phân quyền chi tiết cho việc thực thi và giám sát luồng công việc
# - **Bảo mật dữ liệu**: Xử lý an toàn thông tin nhạy cảm xuyên suốt luồng công việc
#
# ### 📊 **Khả năng quan sát & Quản lý**
# - **Thiết kế luồng công việc trực quan**: Biểu diễn rõ ràng các luồng và phụ thuộc quá trình
# - **Giám sát thực thi**: Theo dõi tiến trình và hiệu suất luồng công việc trong thời gian thực
# - **Báo cáo lỗi**: Phân tích lỗi chi tiết và khả năng gỡ lỗi
# - **Phân tích hiệu suất**: Các chỉ số dành cho tối ưu hóa và kế hoạch năng lực
#
# Hãy cùng xây dựng luồng công việc AI sẵn sàng cho doanh nghiệp đầu tiên của bạn! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Tuyên bố miễn trừ trách nhiệm**:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi cố gắng đảm bảo độ chính xác, xin lưu ý rằng bản dịch tự động có thể chứa lỗi hoặc sai sót. Tài liệu gốc bằng ngôn ngữ gốc nên được coi là nguồn tin chính thức. Đối với thông tin quan trọng, nên sử dụng dịch vụ dịch thuật chuyên nghiệp bởi con người. Chúng tôi không chịu trách nhiệm về bất kỳ hiểu lầm hoặc giải thích sai nào phát sinh từ việc sử dụng bản dịch này.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
