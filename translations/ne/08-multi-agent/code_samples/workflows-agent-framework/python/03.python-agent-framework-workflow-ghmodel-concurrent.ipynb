# %% [markdown]
# # ⚡ GitHub मोडेलहरू सहित समकालीन एजेन्ट कार्यप्रवाहहरू (Python)
#
# ## 📋 उन्नत समानान्तर प्रशोधन ट्युटोरियल
#
# यो नोटबुकले Microsoft Agent Framework प्रयोग गरी **समकालीन कार्यप्रवाह ढाँचाहरू** देखाउँछ। तपाईंले कसरी उच्च-प्रदर्शन, समानान्तर प्रशोधन कार्यप्रवाहहरू निर्माण गर्ने सिक्नुहुनेछ जहाँ बहु AI एजेन्टहरू एकैपटक कार्यान्वयन हुन्छन्, जसले थ्रुपुटमा नाटकीय सुधार गर्छ र जटिल बहु-थ्रेडेड व्यापार प्रक्रियाहरू सक्षम बनाउँछ।
#
# ## 🎯 सिकाइ लक्ष्यहरू
#
# ### 🚀 **समकालीन प्रशोधन आधारभूतहरू**
# - **समानान्तर एजेन्ट कार्यान्वयन**: अधिकतम दक्षताका लागि एकै पटक धेरै एजेन्टहरू चलाउनुहोस्
# - **कार्यप्रवाह समन्वय**: डाटा स्थिरता कायम राख्दै समकालीन सञ्चालनहरू समन्वय गर्नुहोस्
# - **प्रदर्शन अनुकूलन**: समानान्तर प्रशोधनमार्फत महत्वपूर्ण तीव्रता प्राप्त गर्नुहोस्
# - **स्रोत व्यवस्थापन**: समकालीन सञ्चालनहरूमा AI मोडेल स्रोतहरू प्रभावकारी रूपमा उपयोग गर्नुहोस्
#
# ### 🏗️ **उन्नत समकालीन ढाँचाहरू**
# - **फर्क-जोड प्रशोधन**: धेरै एजेन्टहरूमा काम विभाजन गरी परिणामहरू एकत्रित गर्नुहोस्
# - **पाइपलाइन समानान्तरता**: निरन्तर थ्रुपुटका लागि कार्यान्वयन चरणहरू ओवरलैप गर्नुहोस्
# - **लोड ब्यालेन्सिङ**: उपलब्ध एजेन्ट स्रोतहरूमा काम समान रूपमा वितरण गर्नुहोस्
# - **समकालीन बिन्दुहरू**: महत्वपूर्ण कार्यप्रवाह चरणहरूमा समकालीन एजेन्टहरू समन्वय गर्नुहोस्
#
# ### 🏢 **उद्यम समकालीन अनुप्रयोगहरू**
# - **उच्च-परिमाण कागजात प्रशोधन**: धेरै कागजातहरू एकैपटक प्रशोधन गर्नुहोस्
# - **रियल-टाइम सामग्री विश्लेषण**: आगमन डेटास्ट्रीमहरूको समकालीन विश्लेषण
# - **ब्याच प्रशोधन अनुकूलन**: ठुलो-स्तरीय सञ्चालनहरूको लागि अधिकतम थ्रुपुट
# - **बहु-मोडाल विश्लेषण**: फरक सामग्री प्रकारहरूको समानान्तर प्रशोधन (पाठ, छविहरू, डेटा)
#
# ## ⚙️ पूर्वशर्तहरू र सेटअप
#
# ### 📦 **आवश्यक निर्भरताहरू**
#
# समकालीन कार्यप्रवाह क्षमताहरू सहित Agent Framework स्थापना गर्नुहोस्:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub मोडेलहरू कन्फिगरेसन**
#
# **पर्यावरण सेटअप (.env फाइल):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **समकालीन प्रशोधन विचारहरू:**
# - **रेट सीमा**: समकालीन अनुरोधहरूको लागि GitHub मोडेल API रेट सीमाहरू अनुगमन गर्नुहोस्
# - **स्रोत प्रयोग**: बहु समकालीन एजेन्टहरूसँग मेमोरी र CPU प्रयोग विचार गर्नुहोस्
# - **त्रुटि व्यवस्थापन**: समानान्तर अपरेसनहरूका लागि मजबूत त्रुटि पुनर्प्राप्ति कार्यान्वयन गर्नुहोस्
#
# ### 🏗️ **समकालीन कार्यप्रवाह संरचना**
#
# ```mermaid
# graph TD
#     A[कार्यप्रवाह सुरु] --> B[समान्तर कार्यान्वयन]
#     B --> C[एजेन्ट पूल १]
#     B --> D[एजेन्ट पूल २]
#     B --> E[एजेन्ट पूल ३]
#     C --> F[परिणाम संकलन]
#     D --> F
#     E --> F
#     F --> G[अन्तिम आउटपुट]
#
#     H[GitHub मोडलहरू API] --> C
#     H --> D
#     H --> E
# ```
#
# **प्रमुख लाभहरू:**
# - **⚡ प्रदर्शन**: समानान्तर कार्यान्वयनमा उल्लेखनीय तीव्रता
# - **📈 स्केलेबिलिटी**: अनुपातहीन समय वृद्धि बिना भार बढाउनुहोस्
# - **🔄 दक्षता**: उपलब्ध कम्प्युटेशनल स्रोतहरूको राम्रो उपयोग
# - **🎯 थ्रुपुट**: समान समय अवधिमा बढी काम प्रशोधन गर्नुहोस्
#
# ## 🎨 **समकालीन कार्यप्रवाह डिजाइन ढाँचाहरू**
#
# ### 🔍 **अनुसन्धान र विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रशोधन कार्यप्रवाह**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री सिर्जना पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **बहु-चरण प्रशोधन**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **उद्यम प्रदर्शन लाभहरू**
#
# ### ⚡ **थ्रुपुट अनुकूलन**
# - **समानान्तर कार्यान्वयन**: धेरै एजेन्टहरू एकैसाथ काम गरिरहेका छन्
# - **स्रोत उपयोगिता**: उपलब्ध AI मोडेल क्षमता अधिकतम दक्षतामा
# - **समय कटौती**: कुल प्रशोधन समयमा ठूलो कमी
# - **स्केलेबल संरचना**: आवश्यक अनुसार सजिलै थप समकालीन एजेन्टहरू थप्ने
#
# ### 🛡️ **विश्वसनीयता र लचिलोपन**
# - **त्रुटि सहिष्णुता**: व्यक्तिगत एजेन्ट असफलताले पूरै कार्यप्रवाह रोकिने छैन
# - **त्रुटि पृथकीकरण**: एक समकालीन शाखामा समस्याले अन्यलाई असर पार्दैन
# - **सौम्य पतन**: घटाइएको एजेन्ट क्षमता भए तापनि प्रणाली सञ्चालनमा रहन्छ
# - **पुनरावृत्ति संयन्त्रहरू**: असफल अपरेसनहरूको लागि स्वचालित पुन: प्रयास र त्रुटि व्यवस्थापन
#
# ### 📊 **अनुगमन र अवलोकनयोग्यता**
# - **समकालीन कार्यान्वयन ट्र्याकिङ**: सम्पूर्ण समानान्तर अपरेसनहरूको प्रगतिको अनुगमन
# - **प्रदर्शन मेट्रिक्स**: तीव्रता र दक्षता वृद्धिको मापन
# - **स्रोत प्रयोग विश्लेषण**: समकालीन एजेन्ट विनियोजन अनुकूलन
# - **बोटलनेक पहिचान**: प्रदर्शन प्रतिबन्धहरू फेला पार्नुहोस् र समाधान गर्नुहोस्
#
# उच्च प्रदर्शन समकालीन AI कार्यप्रवाहहरू बनाऔं! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यो दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरेर अनुवाद गरिएको हो। हामी सही हुन प्रयास गर्छौं, तर कृपया जानकार हुनुस् कि स्वचालित अनुवादमा त्रुटिहरू वा अशुद्धताहरू हुन सक्छन्। मूल दस्तावेज़ यसको मूल भाषामा आधिकारिक स्रोत मानिनुपर्छ। महत्वपूर्ण जानकारीका लागि व्यावसायिक मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न कुनै पनि गलत बुझाइ वा त्रुटिको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
