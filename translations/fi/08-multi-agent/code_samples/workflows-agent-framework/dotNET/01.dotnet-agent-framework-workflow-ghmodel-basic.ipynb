# %% [markdown]
# # 🔄 Perusagenttien työnkulut Azure OpenAI:lla (Responses API) (.NET)
#
# ## 📋 Työnkulun orkestroinnin opas
#
# Tämä muistikirja havainnollistaa, kuinka rakentaa monimutkaisia **agenttien työnkulkuja** Microsoft Agent Frameworkin .NET-versiolla ja Azure OpenAI:lla (Responses API). Opit luomaan monivaiheisia liiketoimintaprosesseja, joissa tekoälyagentit tekevät yhteistyötä suorittaakseen monimutkaisia tehtäviä rakenteellisten orkestrointimallien avulla.
#
# ## 🎯 Oppimistavoitteet
#
# ### 🏗️ **Työnkulun arkkitehtuurin perusteet**
# - **Workflow Builder**: Suunnittele ja orkestraoi monimutkaisia monivaiheisia tekoälyprosesseja
# - **Agenttien koordinointi**: Koordinoi useita erikoistuneita agentteja työnkuluissa
# - **Azure OpenAI (Responses API)**: Hyödynnä Azure OpenAI Responses API:a työnkuluissa
# - **Visuaalinen työnkulun suunnittelu**: Luo ja visualisoi työnkulun rakenteita paremman ymmärryksen saamiseksi
#
# ### 🔄 **Prosessin orkestrointimallit**
# - **Peräkkäinen käsittely**: Ketjuta useita agenttitehtäviä loogisessa järjestyksessä
# - **Tilanhallinta**: Säilytä konteksti ja tiedonkulku työnkulun vaiheiden välillä
# - **Virheenkäsittely**: Toteuta vankka virheiden palautuminen ja työnkulun kestävyys
# - **Suorituskyvyn optimointi**: Suunnittele tehokkaita työnkulkuja suuryrityksen mittakaavaan
#
# ### 🏢 **Yritystason työnkulkujen sovellukset**
# - **Liiketoimintaprosessien automaatio**: Automatisoi monimutkaisia organisaation työnkulkuja
# - **Sisällöntuotantoputki**: Toimitukselliset työnkulut tarkistus- ja hyväksymisvaiheineen
# - **Asiakaspalvelun automaatio**: Monivaiheinen asiakaskyselyiden ratkaisu
# - **Datan käsittelytyönkulut**: ETL-työnkulut tekoälypohjaisella muunnoksella
#
# ## ⚙️ Esivaatimukset & asetukset
#
# ### 📦 **Vaaditut NuGet-paketit**
#
# Tämä työnkulun esimerkkiohjelma käyttää useita keskeisiä .NET-paketteja:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI -konfiguraatio**
#
# **Ympäristöasetukset (.env-tiedosto):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI -käyttöoikeus:**
# 1. Luo Azure OpenAI -resurssi Azure-portaaliin
# 2. Ota käyttöön malli (esim. `gpt-5-mini`) ja kirjaa käyttöönoton nimi ylös
# 3. Kirjaudu sisään komennolla `az login` ja määritä ympäristömuuttujat yllä kuvatulla tavalla
#
# ### 🏗️ **Työnkulun arkkitehtuurin yleiskatsaus**
#
# ```mermaid
# graph TD
#     A[Työnkulun rakentaja] --> B[Agenttirekisteri]
#     B --> C[Työnkulun suoritusmoottori]
#     C --> D[Agent 1: Sisällön luoja]
#     C --> E[Agent 2: Sisällön tarkastaja]
#     D --> F[Työnkulun tulokset]
#     E --> F
#     G[Azure OpenAI (Vastaus-API)] --> D
#     G --> E
# ```
#
# **Keskeiset osat:**
# - **WorkflowBuilder**: Pääorkestrointimoottori työnkulkujen suunnitteluun
# - **AIAgent**: Yksittäiset erikoistuneet agentit tiettyjen kykyjen kanssa
# - **Azure OpenAI Client**: Azure OpenAI Responses API -integraatio
# - **Execution Context**: Hallinnoi tilaa ja tiedonkulkua työnkulun vaiheiden välillä
#
# ## 🎨 **Yrityksen työnkulun suunnittelumallit**
#
# ### 📝 **Sisällöntuotannon työnkulku**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Asiakirjojen käsittelyputki**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Liiketoimintatiedon työnkulku**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Asiakaspalvelun automaatio**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Yrityksen hyödyt**
#
# ### 🎯 **Luotettavuus & Skaalautuvuus**
# - **Deterministinen suoritus**: Johdonmukaiset, toistettavat työnkulun tulokset
# - **Virheiden palautuminen**: Sujuva virheiden käsittely missä tahansa työnkulun vaiheessa
# - **Suorituskyvyn seuranta**: Seuraa suoritusaikaisia mittareita ja optimointimahdollisuuksia
# - **Resurssien hallinta**: Tekoälymallien resurssien tehokas kohdentaminen ja hyödyntäminen
#
# ### 🔒 **Tietoturva & vaatimustenmukaisuus**
# - **Turvallinen todennus**: Microsoft Entra ID -todennus `az login` -komennon kautta (AzureCliCredential)
# - **Auditointilokit**: Täydellinen työnkulun suorituksen ja päätöspisteiden lokitus
# - **Käyttöoikeuksien hallinta**: Yksityiskohtaiset oikeudet työnkulkujen suorittamiseen ja seurantaan
# - **Tietosuoja**: Sensitiivisten tietojen turvallinen käsittely työnkuluissa
#
# ### 📊 **Havaitseminen & hallinta**
# - **Visuaalinen työnkulun suunnittelu**: Selkeä esitys prosessivirroista ja riippuvuuksista
# - **Suorituksen seuranta**: Reaaliaikainen työnkulun etenemisen ja suorituskyvyn seuranta
# - **Virheraportointi**: Yksityiskohtainen virheanalyysi ja virheenkorjausmahdollisuudet
# - **Suorituskyvyn analytiikka**: Mittarit optimointiin ja kapasiteetin suunnitteluun
#
# Rakennetaan ensimmäinen yrityskäyttöön valmis tekoälytyönkulku! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, otathan huomioon, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäinen asiakirja sen alkuperäiskielellä on virallinen lähde. Tärkeissä asioissa suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai tulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
