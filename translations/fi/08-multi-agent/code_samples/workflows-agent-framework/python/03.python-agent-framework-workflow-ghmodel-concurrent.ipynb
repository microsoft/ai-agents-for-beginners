# %% [markdown]
# # ⚡ Samanaikaiset agenttityönkulut Microsoft Foundryn kanssa (Python)
#
# ## 📋 Edistynyt rinnakkaisprosessointiohjeistus
#
# Tämä muistio demonstroi **samanaikaisia työnkulkujen malleja** Microsoft Agent Frameworkin avulla. Opit rakentamaan suorituskykyisiä, rinnakkaisia työnkulkuja, joissa useat tekoälyagentit toimivat samanaikaisesti, parantaen huomattavasti läpimenoa ja mahdollistavat monimutkaiset monisäikeiset liiketoimintaprosessit.
#
# > **Siirtohuomautus:** Tämä esimerkki viittasi aiemmin GitHub-malleihin. GitHub-mallit on poistettu käytöstä (poistuu heinäkuussa 2026), joten nyt se käyttää **Microsoft Foundrya** `FoundryChatClient`in kautta, joka kohdistuu Azure OpenAI:n **Responses API:in**.
#
# ## 🎯 Oppimistavoitteet
#
# ### 🚀 **Samanaikaisen prosessoinnin perusteet**
# - **Rinnakkainen agenttien suoritus**: Aja useita agentteja samanaikaisesti maksimaalisen tehokkuuden saavuttamiseksi
# - **Työnkulun orkestrointi**: Koordinoi samanaikaisia toimintoja tiedon johdonmukaisuuden ylläpitämiseksi
# - **Suorituskyvyn optimointi**: Saavuta merkittävä nopeutus rinnakkaisprosessoinnin avulla
# - **Resurssien hallinta**: Hyödynnä tehokkaasti tekoälymallien resursseja samanaikaisissa toiminnoissa
#
# ### 🏗️ **Edistyneet samanaikaisuuden mallit**
# - **Fork-Join-prosessointi**: Jaa työtä useiden agenttien kesken ja yhdistä tulokset
# - **Putkiriviprosessointi**: Suorituksen vaiheiden päällekkäisyys jatkuvan läpimenon takaamiseksi
# - **Kuormantasapainotus**: Jaa työ tasaisesti käytettävissä olevien agenttiresurssien kesken
# - **Synkronointipisteet**: Koordinoi samanaikaisia agentteja kriittisissä työnkulun vaiheissa
#
# ### 🏢 **Yritysten samanaikaiset sovellukset**
# - **Suuri dokumenttikäsittelymäärä**: Käsittele useita asiakirjoja samanaikaisesti
# - **Reaaliaikainen sisällönanalyysi**: Samanaikainen saapuvien datavirtojen analysointi
# - **Eräprosessoinnin optimointi**: Maksimoi läpimeno suuressa mittakaavassa
# - **Monimodaalinen analyysi**: Eri sisältötyyppien (teksti, kuvat, data) rinnakkainen prosessointi
#
# ## ⚙️ Esivaatimukset & asennus
#
# ### 📦 **Vaaditut riippuvuudet**
#
# Asenna Agent Framework, jolla on samanaikaisen työnkulun ominaisuudet:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundryn konfigurointi**
#
# Kirjaudu Azure CLI:llä (`az login`), jotta `AzureCliCredential` voi todentaa, ja määritä sitten Microsoft Foundryn projekti-tiedot.
#
# **Ympäristön asetustiedosto (.env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Samanaikaisen prosessoinnin huomioitavaa:**
# - **Käyttörajoitukset**: Seuraa Azure OpenAI:n samanaikaisia pyyntörajoja
# - **Resurssien käyttö**: Huomioi muistin ja suorittimen käyttö useilla samanaikaisilla agenteilla
# - **Virheenkäsittely**: Toteuta vankka virheiden palautus rinnakkaisoperaatioissa
#
# ### 🏗️ **Samanaikaisen työnkulun arkkitehtuuri**
#
# ```mermaid
# graph TD
#     A[Työnkulun aloitus] --> B[Samanaikainen suoritus]
#     B --> C[Agenttipooli 1]
#     B --> D[Agenttipooli 2]
#     B --> E[Agenttipooli 3]
#     C --> F[Tulosten kokoaminen]
#     D --> F
#     E --> F
#     F --> G[Lopullinen tulos]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Keskeiset hyödyt:**
# - **⚡ Suorituskyky**: Merkittävä nopeutus rinnakkaisella suorituksella
# - **📈 Skaalautuvuus**: Käsittele kasvavia työmääriä ilman suhteellista aikalisäystä
# - **🔄 Tehokkuus**: Parempi olemassa olevien laskentaresurssien hyödyntäminen
# - **🎯 Läpäisykyky**: Käsittele enemmän töitä samassa ajassa
#
# ## 🎨 **Samanaikaisten työnkulkujen suunnittelumallit**
#
# ### 🔍 **Tutkimus- ja analyysiputki**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Datan käsittelyn työnkulku**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisällöntuotantoputki**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Monivaiheinen prosessointi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Yritysten suorituskykyhyödyt**
#
# ### ⚡ **Läpimeno-optimointi**
# - **Rinnakkainen suoritus**: Useat agentit toimivat samanaikaisesti
# - **Resurssien hyödyntäminen**: Maksimaalinen tehokkuus käytettävissä olevalle tekoälymallin kapasiteetille
# - **Ajan lyheneminen**: Merkittävä kokonaisprosessointiajan väheneminen
# - **Skaalautuva arkkitehtuuri**: Lisää helposti tarpeen mukaan lisää samanaikaisia agentteja
#
# ### 🛡️ **Luotettavuus & Resilienssi**
# - **Vikansietokyky**: Yksittäiset agenttiviat eivät pysäytä koko työnkulkua
# - **Virheeristyminen**: Ongelmien eristäminen yhdellä samanaikaisella haaralla ei vaikuta muihin
# - **Sulava degradeeraus**: Järjestelmä jatkaa toimintaa, vaikka agenttikapasiteetti olisi vähentynyt
# - **Palautusmekanismit**: Automaattinen uudelleenyrittäminen ja virheenkäsittely epäonnistuneille toiminnoille
#
# ### 📊 **Seuranta & Näkyvyys**
# - **Samanaikaisen suorituksen seuranta**: Tarkkaile kaikkien rinnakkaistoimintojen etenemistä
# - **Suorituskykymittarit**: Mittaa nopeutusta ja tehokkuuden parannuksia
# - **Resurssien käytön analytiikka**: Optimoi samanaikaisten agenttien kohdentaminen
# - **Pullonkaulojen tunnistus**: Löydä ja ratkaise suorituskykyyn liittyvät rajoitteet
#
# Rakennetaan suorituskykyisiä, samanaikaisia tekoälytyönkulkuja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, otathan huomioon, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäinen asiakirja sen alkuperäiskielellä on virallinen lähde. Tärkeissä asioissa suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai tulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
