# %% [markdown]
# # ⚡ Samanaikaiset agenttityönkulut GitHub-malleilla (Python)
#
# ## 📋 Kehittynyt rinnakkaiskäsittelyopas
#
# Tässä muistikirjassa esitellään **samanaikaiset työnkulkujen mallit** Microsoft Agent -kehyksen avulla. Opit rakentamaan suorituskykyisiä, rinnakkaisia työnkulkuja, joissa useat tekoälyagentit toimivat samaan aikaan, mikä parantaa läpimenonopeutta huomattavasti ja mahdollistaa kehittyneet monisäikeiset liiketoimintaprosessit.
#
# ## 🎯 Oppimistavoitteet
#
# ### 🚀 **Samanaikaisen käsittelyn perusteet**
# - **Rinnakkainen agenttien suoritus**: Suorita useita agentteja samanaikaisesti maksimaalisen tehokkuuden saavuttamiseksi
# - **Työnkulun orkestrointi**: Koordinoi samanaikaiset toiminnot säilyttäen tietojen yhdenmukaisuuden
# - **Suorituskyvyn optimointi**: Saavuta merkittävä nopeutuminen rinnakkaiskäsittelyn avulla
# - **Resurssien hallinta**: Hyödynnä tehokkaasti tekoälymallien resursseja samanaikaisissa toiminnoissa
#
# ### 🏗️ **Edistyneet samanaikaisuuden mallit**
# - **Fork-Join-käsittely**: Jaa työ useiden agenttien kesken ja yhdistä tulokset
# - **Putkiston rinnakkaisuus**: Suorituksen vaiheiden päällekkäisyys jatkuvan läpimenon varmistamiseksi
# - **Kuormantasapaino**: Jaa työ tasaisesti saatavilla olevien agenttiresurssien kesken
# - **Synkronointipisteet**: Koordinoi samanaikaisia agenteja kriittisissä työnkulkupisteissä
#
# ### 🏢 **Yritysten samanaikaiset sovellukset**
# - **Suurvolyyminen asiakirjakäsittely**: Käsittele useita asiakirjoja samanaikaisesti
# - **Reaaliaikainen sisällön analyysi**: Saapuvien datavirtojen samanaikainen analysointi
# - **Eräajojen optimointi**: Maksimoi läpimeno suurissa operaatioissa
# - **Monimuotoinen analyysi**: Eri sisältötyyppien (teksti, kuvat, data) rinnakkainen käsittely
#
# ## ⚙️ Esivaatimukset & asennus
#
# ### 📦 **Vaaditut riippuvuudet**
#
# Asenna Agent Framework, jolla on samanaikaiset työnkulkuominaisuudet:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub-mallien määritykset**
#
# **Ympäristön asetukset (.env-tiedosto):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Samanaikaisuuden huomioitavat asiat:**
# - **Käyttörajoitukset**: Seuraa GitHub-mallien API-käyttörajoituksia samanaikaisille pyynnöille
# - **Resurssien käyttö**: Huomioi muisti- ja suorittimen käyttö useiden samanaikaisten agenttien kanssa
# - **Virheenkäsittely**: Toteuta vankka virheiden palautus rinnakkaisissa toiminnoissa
#
# ### 🏗️ **Samanaikaisen työnkulun arkkitehtuuri**
#
# ```mermaid
# graph TD
#     A[Työnkulun aloitus] --> B[Samanaikainen suoritus]
#     B --> C[Agenttipooli 1]
#     B --> D[Agenttipooli 2]
#     B --> E[Agenttipooli 3]
#     C --> F[Tulosten kokoaminen]
#     D --> F
#     E --> F
#     F --> G[Lopullinen tulos]
#
#     H[GitHub-mallit API] --> C
#     H --> D
#     H --> E
# ```
#
# **Keskeiset hyödyt:**
# - **⚡ Suorituskyky**: Merkittävä nopeutuminen rinnakkaissuorituksen ansiosta
# - **📈 Skaalautuvuus**: Käsittele lisääntyviä työkuormia ilman vastaavaa aikalisäystä
# - **🔄 Tehokkuus**: Parempi laskentaresurssien hyödyntäminen
# - **🎯 Läpimeno**: Käsittele enemmän töitä samassa ajassa
#
# ## 🎨 **Samanaikaisten työnkulkujen suunnittelumallit**
#
# ### 🔍 **Tutkimus- ja analyysiputki**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Datankäsittelytyönkulku**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisällöntuotantoputki**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Monivaiheinen käsittely**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Yritystason suorituskykyedut**
#
# ### ⚡ **Läpimenon optimointi**
# - **Rinnakkainen suoritus**: Useat agentit työskentelevät samanaikaisesti
# - **Resurssien käyttö**: Maksimaalinen tekoälymallien kapasiteetin hyödyntäminen
# - **Ajan lyhennys**: Merkittävä kokonaiskäsittelyajan väheneminen
# - **Skaalautuva arkkitehtuuri**: Lisää helposti samanaikaisia agentteja tarpeen mukaan
#
# ### 🛡️ **Luotettavuus & Resilienssi**
# - **Virhekestoisuus**: Yksittäisten agenttien virheet eivät pysäytä koko työnkulkua
# - **Virheiden eristäminen**: Ongelmien rajoittaminen yhteen samanaikaiseen haaraan vaikuttamatta muihin
# - **Hallittu heikkeneminen**: Järjestelmä jatkaa toimintaansa myös vähentyneen agenttikapasiteetin kanssa
# - **Palautusmekanismit**: Automaattinen uudelleenyrittäminen ja virheenkäsittely epäonnistuneille toiminnoille
#
# ### 📊 **Seuranta & havainnointi**
# - **Samanaikaisen suorituksen seuranta**: Valvo kaikkien rinnakkaisten toimintojen edistymistä
# - **Suorituskykymittarit**: Mittaa nopeutusta ja tehokkuuden parannuksia
# - **Resurssien käytön analyysi**: Optimoi samanaikaisten agenttien allokointi
# - **Pullonkaulojen tunnistus**: Löydä ja ratkaise suorituskykyrajoitteet
#
# Rakennetaan yhdessä suorituskykyisiä samanaikaisia tekoälytyönkulkuja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, otathan huomioon, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäinen asiakirja sen alkuperäiskielellä on virallinen lähde. Tärkeissä asioissa suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai tulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
