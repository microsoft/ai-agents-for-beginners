# %% [markdown]
# # ⚡ Súbežné pracovné toky agentov s modelmi GitHub (Python)
#
# ## 📋 Pokročilý návod na paralelné spracovanie
#
# Tento notebook demonštruje **vzory súbežných pracovných tokov** pomocou Microsoft Agent Framework. Naučíte sa, ako vytvoriť výkonné paralelné spracovacie toky, kde viacerí AI agenti pracujú súčasne, čo výrazne zlepšuje priepustnosť a umožňuje sofistikované viacvláknové obchodné procesy.
#
# ## 🎯 Ciele učenia
#
# ### 🚀 **Základy súbežného spracovania**
# - **Paralelná exekúcia agentov**: Spustenie viacerých agentov súčasne pre maximálnu efektivitu
# - **Orchestrace pracovného toku**: Koordinácia súbežných operácií pri zachovaní konzistentnosti dát
# - **Optimalizácia výkonu**: Dosiahnutie výrazného zrýchlenia pomocou paralelného spracovania
# - **Manažment zdrojov**: Efektívne využívanie zdrojov AI modelov naprieč súbežnými operáciami
#
# ### 🏗️ **Pokročilé vzory súbežnosti**
# - **Fork-Join spracovanie**: Rozdelenie práce medzi viacerých agentov a zjednotenie výsledkov
# - **Pipeline paralelizmus**: Prelínanie etáp vykonávania pre kontinuálnu priepustnosť
# - **Vyvažovanie záťaže**: Rovnomerné rozdelenie práce medzi dostupné agentné zdroje
# - **Synchronizačné body**: Koordinácia súbežných agentov v kritických fázach pracovného toku
#
# ### 🏢 **Podnikové súbežné aplikácie**
# - **Spracovanie veľkého množstva dokumentov**: Paralelné spracovanie viacerých dokumentov súčasne
# - **Analýza obsahu v reálnom čase**: Súbežná analýza prichádzajúcich dátových tokov
# - **Optimalizácia dávkového spracovania**: Maximalizácia priepustnosti pre rozsiahle operácie
# - **Viacmodálna analýza**: Paralelné spracovanie rôznych typov obsahu (text, obrázky, dáta)
#
# ## ⚙️ Predpoklady a nastavenie
#
# ### 📦 **Požadované závislosti**
#
# Nainštalujte Agent Framework s podporou súbežných pracovných tokov:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Konfigurácia modelov GitHub**
#
# **Nastavenie prostredia (súbor .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Úvahy o súbežnom spracovaní:**
# - **Limity rýchlosti**: Sledujte limity GitHub Models API pre súbežné požiadavky
# - **Využitie zdrojov**: Zvážte pamäť a CPU pri viacerých súbežných agentoch
# - **Riešenie chýb**: Implementujte robustné obnovovanie chýb pre paralelné operácie
#
# ### 🏗️ **Architektúra súbežného pracovného toku**
#
# ```mermaid
# graph TD
#     A[Začiatok pracovného toku] --> B[Súbežné vykonávanie]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Zlúčenie výsledkov]
#     D --> F
#     E --> F
#     F --> G[Konečný výstup]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Kľúčové výhody:**
# - **⚡ Výkon**: Výrazné zrýchlenie vďaka paralelnej exekúcii
# - **📈 Škálovateľnosť**: Riešenie narastajúcej záťaže bez úmerného zvýšenia času
# - **🔄 Efektivita**: Lepšie využitie dostupných výpočtových zdrojov
# - **🎯 Priepustnosť**: Spracujte viac práce za rovnaký čas
#
# ## 🎨 **Vzory návrhu súbežných pracovných tokov**
#
# ### 🔍 **Výskumný a analytický pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow spracovania dát**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline tvorby obsahu**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Viacfázové spracovanie**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Podnikové výhody výkonu**
#
# ### ⚡ **Optimalizácia priepustnosti**
# - **Paralelná exekúcia**: Viacerí agenti pracujúci súčasne
# - **Využitie zdrojov**: Maximálna efektivita kapacity AI modelu
# - **Skrátenie času**: Významné zníženie celkového času spracovania
# - **Škálovateľná architektúra**: Ľahko pridajte viac súbežných agentov podľa potreby
#
# ### 🛡️ **Spoľahlivosť a odolnosť**
# - **Tolerance chýb**: Zlyhania jednotlivých agentov nezastavia celý pracovný tok
# - **Izolácia chýb**: Problémy v jednej súbežnej vetve neovplyvňujú ostatné
# - **Láskavé degradovanie**: Systém pokračuje v činnosti aj pri zníženej kapacite agentov
# - **Mechanizmy obnovy**: Automatické opakovanie a riešenie chýb pre neúspešné operácie
#
# ### 📊 **Monitorovanie a pozorovateľnosť**
# - **Sledovanie súbežnej exekúcie**: Monitorujte priebeh všetkých paralelných operácií
# - **Metriky výkonu**: Merajte zrýchlenie a zisky efektivity
# - **Analýza využitia zdrojov**: Optimalizujte prideľovanie súbežných agentov
# - **Identifikácia úzkych miest**: Nájdite a vyriešte obmedzenia výkonu
#
# Postavme vysokovýkonné súbežné AI pracovné toky! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vyhlásenie o zodpovednosti**:
# Tento dokument bol preložený pomocou AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Hoci sa snažíme o presnosť, vezmite prosím na vedomie, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho natívnom jazyku by mal byť považovaný za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nie sme zodpovední za žiadne nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
