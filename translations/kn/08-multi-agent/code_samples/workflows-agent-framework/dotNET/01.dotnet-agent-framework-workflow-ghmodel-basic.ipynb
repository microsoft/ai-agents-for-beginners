# %% [markdown]
# # 🔄 ಅಳವಡಿಕೆ ಏಜೆಂಟ್ ವರ್ಕ್‌ಫ್ಲೋಸ್ ಸಹಿತ ಆಜೂರ್ ಓಪನ್‌ಎಐ (ಪ್ರತಿಕ್ರಿಯೆಗಳು API) (.NET)
#
# ## 📋 ವರ್ಕ್‌ಫ್ಲೋ ಸಂಯೋಜನೆ ಪಾಠ
#
# ಈ ನೋಟ್ಬುಕ್ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಏಜೆಂಟ್ ಫ್ರೇಮ್ವರ್ಕ್ ಫಾರ್ .NET ಮತ್ತು ಆಜೂರ್ ಓಪನ್‌ಎಐ (ಪ್ರತಿಕ್ರಿಯೆಗಳು API) ಬಳಸಿ ಸುಕ್ಷ್ಮ **ಏಜೆಂಟ್ ವರ್ಕ್‌ಫ್ಲೋಸ್** ನಿರ್ಮಿಸುವ ವಿಧಾನವನ್ನು ತೋರಿಸುತ್ತದೆ. ನೀವು AI ಏಜೆಂಟ್‌ಗಳು ಸಂಯೋಜಿತ ಸಂಯೋಜನೆ ಪ್ಯಾಟರ್ನ್‌ಗಳ ಮೂಲಕ ಸಂಕೀರ್ಣ ಕಾರ್ಯಗಳನ್ನು ನಿಭಾಯಿಸಲು ಸಹಕರಿಸುವ ಬಹು ಹಂತದ ವ್ಯವಹಾರದ ಪ್ರಕ್ರಿಯೆಗಳನ್ನು ರಚಿಸುವುದನ್ನು ಕಲಿಯುತ್ತಾರೆ.
#
# ## 🎯 ಕಲಿಕೆ ಉದ್ದೇಶಗಳು
#
# ### 🏗️ **ವರ್ಕ್‌ಫ್ಲೋ ಸ್ಥಾಪನೆಗೆ ಮೂಲಭೂತ ವಿಚಾರಗಳು**
# - **ವರ್ಕ್‌ಫ್ಲೋ ಬಿಲ್ಡರ್**: ಸಂಕೀರ್ಣ ಬಹು ಹಂತದ AI ಪ್ರಕ್ರಿಯೆಗಳಿಗೆ ವಿನ್ಯಾಸ ಮತ್ತು ಸಂಯೋಜನೆ ಮಾಡುವುದು
# - **ಏಜೆಂಟ್ ಸಂಯೋಜನೆ**: ವರ್ಕ್‌ಫ್ಲೋಗಳಲ್ಲಿ ಬಹು ವಿಶೇಷ ಏಜೆಂಟ್‌ಗಳನ್ನು ಸಂಯೋಜಿಸುವುದು
# - **ಆಜೂರ್ ಓಪನ್‌ಎಐ (ಪ್ರತಿಕ್ರಿಯೆಗಳು API)**: ವರ್ಕ್‌ಫ್ಲೋಗಳಲ್ಲಿ ಆಜೂರ್ ಓಪನ್‌ಎಐ ಪ್ರತಿಕ್ರಿಯೆಗಳು API ಬಳಕೆ ಮಾಡುವುದು
# - **ವಿಜುಯಲ್ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ**: ಉತ್ತಮ ಅರ್ಥಮಾಡಿಕೊಳ್ಳಲು ವರ್ಕ್‌ಫ್ಲೋ ರಚನೆಗಳನ್ನು ನಿರ್ಮಿಸಿ ಹಾಗೂ ದೃಶ್ಯೀಕರಿಸುವುದು
#
# ### 🔄 **ಪ್ರಕ್ರಿಯೆ ಸಂಯೋಜನೆ ಪ್ಯಾಟರ್ನ್‌ಗಳು**
# - **ಕ್ರಮಬದ್ಧ ಪ್ರಕ್ರಿಯೆ**: ಲಾಜಿಕಲ್ ಕ್ರಮದಲ್ಲಿ ಬಹು ಏಜೆಂಟ್ ಕಾರ್ಯಗಳನ್ನು ಸರಣಿಗೊಳಿಸುವುದು
# - **ಸ್ಥಿತಿ ನಿರ್ವಹಣೆ**: ವರ್ಕ್‌ಫ್ಲೋ ಹಂತಗಳಲ್ಲಿ ಪ್ರಾಸಂಗಿಕತೆ ಮತ್ತು ಡೇಟಾ ಹರಿವನ್ನು ನಿರ್ವಹಿಸುವುದು
# - **ದೋಷ ನಿರ್ವಹಣೆ**: ದೃಢವಾದ ದೋಷ ಪೂರೈಕೆ ಮತ್ತು ವರ್ಕ್‌ಫ್ಲೋ ಸಂರಕ್ಷಣೆ ಜಾರಿಗೆ ಹಾಕುವುದು
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಆಪ್ಟಿಮೈಜೇಶನ್**: ಸಂಸ್ಥಾತ್ಮಕ ಮಟ್ಟದ ಕಾರ್ಯಾಚರಣೆಗಳಿಗೆ ಪರಿಣಾಮಕಾರಿ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ
#
# ### 🏢 **ಸಂಸ್ಥಾತ್ಮಕ ವರ್ಕ್‌ಫ್ಲೋ ಅನ್ವಯಗಳು**
# - **ವ್ಯವಹಾರ ಪ್ರಕ್ರಿಯೆ ಸ್ವಯಂಕ್ರಿಯೆ**: ಸಂಕೀರ್ಣ ಸಂಸ್ಥೆಯ ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ಸ್ವಯಂಚಾಲಿತಗೊಳಿಸುವುದು
# - **ವಿಷಯ ಉತ್ಪಾದನಾ ಪೈಪ್ಲೈನ್**: ಪರಿಶೀಲನೆ ಮತ್ತು ಅನುಮೋದನೆ ಹಂತಗಳೊಂದಿಗೆ ಸಂಪಾದಕೀಯ ವರ್ಕ್‌ಫ್ಲೋಗಳು
# - **ಗ್ರಾಹಕ ಸೇವೆ ಸ್ವಯಂಕ್ರಿಯೆ**: ಬಹು ಹಂತದ ಗ್ರಾಹಕ ವಿಚಾರ ನಿರಾಕರಣೆ
# - **ಡೇಟಾ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್‌ಫ್ಲೋಗಳು**: AI-ಶಕ್ತಿ ಪ್ರಾರಂಭಿತ ಪರಿವರ್ತನೆಯೊಂದಿಗೆ ETL ವರ್ಕ್‌ಫ್ಲೋಗಳು
#
# ## ⚙️ ಅಗತ್ಯಗಳು ಮತ್ತು ಸಂರಚನೆ
#
# ### 📦 **ಅವಶ್ಯಕ NuGet ಪ್ಯಾಕೇಜ್‌ಗಳು**
#
# ಈ ವರ್ಕ್‌ಫ್ಲೋ ಪ್ರದರ್ಶನವು ಕೆಲವು ಪ್ರಮುಖ .NET ಪ್ಯಾಕೇಜ್‌ಗಳನ್ನು ಉಪಯೋಗಿಸುತ್ತದೆ:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **ಆಜೂರ್ ಓಪನ್‌ಎಐ ಸಂರಚನೆ**
#
# **ಪರಿಸರ ಸಂರಚನೆ (.env ಫೈಲ್):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **ಆಜೂರ್ ಓಪನ್‌ಎಐ ಪ್ರವೇಶ:**
# 1. ಆಜೂರ್ ಪೋರ್ಟಲ್‌ನಲ್ಲಿ ಆಜೂರ್ ಓಪನ್‌ಎಐ ಸಂಪನ್ಮೂಲವನ್ನು ರಚಿಸಿ
# 2. ಮಾದರಿಯನ್ನು ನಿಯೋಜಿಸಿ (ಉದಾಹರಣೆಗೆ, `gpt-5-mini`) ಮತ್ತು ನಿಯೋಜನೆಯ ಹೆಸರನ್ನು ಗಮನಿಸಿ
# 3. `az login` ಸಹಿತ-sign in ಮಾಡಿ ಮತ್ತು ಮೇಲ್ಕಂಡಂತೆ ಪರಿಸರ ಚರಗಳನ್ನು ಸಂರಚಿಸಿ
#
# ### 🏗️ **ವರ್ಕ್‌ಫ್ಲೋ ಸ್ಥಾಪನೆ ಅವಲೋಕನ**
#
# ```mermaid
# graph TD
#     A[ವರ್ಕ್‌ಫ್ಲೋ ಬಿಲ್ಡರ್] --> B[ಏಜೆಂಟ್ ದಾಖಲಾತಿ]
#     B --> C[ವರ್ಕ್‌ಫ್ಲೋ ಕಾರ್ಯಗತಗೊಳಿಸುವ انجಿನ್]
#     C --> D[Agent 1: ವಿಷಯ ರಚನೆಗಾರ
#     C --> E[Agent 2: ವಿಷಯ ವಿಮರ್ಶಕ
#     D --> F[ವರ್ಕ್‌ಫ್ಲೋ ಫಲಿತಾಂಶಗಳು]
#     E --> F
#     G[ಅಜ್ಯೂರ್ ಓಪನ್‌ಎಐ (ಪ್ರತಿಕ್ರಿಯೆಗಳು API)] --> D
#     G --> E
# ```
#
# **ಪ್ರಮುಖ ഘಟಕಗಳು:**
# - **WorkflowBuilder**: ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ವಿನ್ಯಾಸಗೊಳಿಸುವ ಮತ್ತು ಸಂಯೋಜಿಸುವ ಮುಖ್ಯ ಎಂಜಿನ್
# - **AIAgent**: ನಿರ್ದಿಷ್ಟ ಸಾಮರ್ಥ್ಯಗಳೊಂದಿಗೆ ವೈಯಕ್ತಿಕ ವಿಶೇಷ ಏಜೆಂಟ್‌ಗಳು
# - **ಆಜೂರ್ ಓಪನ್‌ಎಐ ಕ್ಲೈಂಟ್**: ಆಜೂರ್ ಓಪನ್‌ಎಐ ಪ್ರತಿಕ್ರಿಯೆಗಳು API ಸಂಯೋಜನೆ
# - **ಕಾರ್ಯ ನಿರ್ವಹಣಾ ಪ್ರಾಸಂಗ**: ವರ್ಕ್‌ಫ್ಲೋ ಹಂತಗಳ ನಡುವೆ ಸ್ಥಿತಿ ಮತ್ತು ಡೇಟಾ ಹರಿವನ್ನು ನಿರ್ವಹಿಸುತ್ತದೆ
#
# ## 🎨 **ಸಂಸ್ಥಾತ್ಮಕ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ ಪ್ಯಾಟರ್ನ್‌ಗಳು**
#
# ### 📝 **ವಿಷಯ ಉತ್ಪಾದನಾ ವರ್ಕ್‌ಫ್ಲೋ**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **ದಾಖಲು ಪ್ರಕ್ರಿಯೆ ಪೈಪ್ಲೈನ್**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **ವ್ಯವಹಾರ ಬುದ್ದಿವಂತಿಕೆ ವರ್ಕ್‌ಫ್ಲೋ**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **ಗ್ರಾಹಕ ಸೇವೆ ಸ್ವಯಂಕ್ರಿಯೆ**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **ಸಂಸ್ಥೆಯ ಲಾಭಗಳು**
#
# ### 🎯 **ನಂಬಿಕೆಯಿಂದುವಿಕೆ ಮತ್ತು ಮಾಪನ ಸಾಮರ್ಥ್ಯ**
# - **ನಿರ್ಣಾಯಕ ಕಾರ್ಯಗತಗೊಳಿಸುವಿಕೆ**: ಸತತ, ಪುನರಾವರ್ತಿತ ವರ್ಕ್‌ಫ್ಲೋ ಫಲಿತಾಂಶಗಳು
# - **ದೋಷ ಪುನಃಪ್ರಾಪ್ತಿ**: ಯಾವುದೇ ವರ್ಕ್‌ಫ್ಲೋ ಹಂತದಲ್ಲಿ ವೈಫಲ್ಯವನ್ನು ಮೃದುವಾಗಿ ನಿರ್ವಹಿಸುವುದು
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಮೇಲ್ವಿಚಾರಣೆ**: ಕಾರ್ಯಗತಗೊಳಿಸುವಿಕೆ ಮೀಟ್ರಿಕ್‌ಗಳು ಮತ್ತು ಆಪ್ಟಿಮೈಜೇಶನ್ ಅವಕಾಶಗಳನ್ನು ಪತ್ತೆ ಮಾಡುವುದು
# - **ಸಂಪನ್ಮೂಲ ನಿರ್ವಹಣೆ**: AI ಮಾದರಿ ಸಂಪನ್ಮೂಲಗಳ ಪರಿಣಾಮಕಾರಿ ಹಬ್ಬಳಿಕೆ ಮತ್ತು ಬಳಕೆ
#
# ### 🔒 **ಭದ್ರತೆ ಮತ್ತು ಅನುಕೂಲತೆ**
# - **ಭದ್ರವಾದ ಪ್ರಮಾಣಿಕರಣ**: `az login` ಮೂಲಕ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಎಂಟ್ರಾ ID ಪ್ರಮಾಣಿಕರಣ (AzureCliCredential)
# - **ಅಡಿಟ್ ಟ್ರೇಲ್‌ಗಳು**: ವರ್ಕ್‌ಫ್ಲೋ ಕಾರ್ಯಗತಗೊಳಿಸುವಿಕೆಯ ಮತ್ತು ನಿರ್ಧಾರ ಬಿಂದುಗಳ ಸಂಪೂರ್ಣ ಲಾಗಿಂಗ್
# - **ಪ್ರವೇಶ ನಿಯಂತ್ರಣ**: ವರ್ಕ್‌ಫ್ಲೋ ಕಾರ್ಯಗತಗೊಳಿಸುವಿಕೆ ಮತ್ತು ಮೇಲ್ವಿಚಾರಣೆಗೆละเอียด ಪರವಾನಗಿಗಳು
# - **ಡೇಟಾ ಗೌಪ್ಯತೆ**: ವರ್ಕ್‌ಫ್ಲೋಗಳಾದ್ಯಂತ ಸಂವೇದನಾಶೀಲ ಮಾಹಿತಿಯ ಭದ್ರತೆಯೊಂದಿಗೆ ನಿರ್ವಹಣೆ
#
# ### 📊 **ನಿರೀಕ್ಷಣೆ ಮತ್ತು ನಿರ್ವಹಣೆ**
# - **ವಿಜುಯಲ್ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ**: ಪ್ರಕ್ರಿಯೆ ಹರಿವು ಮತ್ತು ಅವಲಂಬನೆಗಳ ಸ್ಪಷ್ಟ ಪ್ರತಿನಿಧಾನ
# - **ಕಾರ್ಯಗತಗತ ಮೇಲ್ವಿಚಾರಣೆ**: ವರ್ಕ್‌ಫ್ಲೋ ಪ್ರಗತಿ ಮತ್ತು ಕಾರ್ಯಕ್ಷಮತೆಯ实时 ಗಮನ
# - **ದೋಷ ವರದಿ**: ವಿವರವಾದ ದೋಷ ವಿಶ್ಲೇಷಣೆ ಮತ್ತು ಡೀಬಗ್ ಸಾಮರ್ಥ್ಯಗಳು
# - **ಕಾರ್ಯಕ್ಷಮತೆ ವಿಶ್ಲೇಷಣೆ**: ಆಪ್ಟಿಮೈಜೇಶನ್ ಮತ್ತು ಸಾಮರ್ಥ್ಯ ಯೋಜನೆಗೆ ಮೀಟ್ರಿಕ್‌ಗಳು
#
# ನಿಮ್ಮ ಮೊದಲ ಸಂಸ್ಥಾತ್ಮಕ AI ವರ್ಕ್‌ಫ್ಲೋ ಅನ್ನು ನಿರ್ಮಿಸೋಣ! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸ್ವೀಕಾರ**:
# ಈ ದಸ್ತಾವೇಜು AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ನಿಖರತೆಯನ್ನು ಸಾಧಿಸಲು ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಡ್ಡೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಸ್ತಾವೇಜು ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದವನ್ನು ಬಳಸುವ ಮೂಲಕ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪು ಅರ್ಥಗಳ ಅಥವಾ ತಪ್ಪು ವ್ಯಾಖ್ಯಾನಗಳ ಬಗ್ಗೆ ನಾವು ಹೊಣೆಗಾರರಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
