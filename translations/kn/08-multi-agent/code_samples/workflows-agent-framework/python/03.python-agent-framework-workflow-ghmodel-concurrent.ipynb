# %% [markdown]
# # ⚡ GitHub ಮಾದರಿಗಳೊಂದಿಗೆ ಸಮಕಾಲೀನ ಏಜೆಂಟ್ ವರ್ಕ್‌ಫ್ಲೋಗಳು (Python)
#
# ## 📋 ಮುಂದುವರೆದ ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ಪಾಠ
#
# ಈ ನೋಟ್‌ಬುಕ್ Microsoft ಏಜೆಂಟ್ ಫ್ರೇಮ್ವರ್ಕ್ ಬಳಸಿ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಮಾದರಿಗಳನ್ನು** ಪ್ರದರ್ಶಿಸುತ್ತದೆ. ನೀವು ಹೆಚ್ಚಿನ ಕಾರ್ಯಕ್ಷಮತೆ, ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ನಿರ್ಮಿಸುವಿಕೆ ಹೇಗೆ ಎಂದು ಕಲಿಯಬಹುದು, ಅಲ್ಲಿ ಅನೇಕ AI ಏಜೆಂಟ್‌ಗಳು ಒಂದೇ ಸಮಯದಲ್ಲಿ ಕಾರ್ಯನಿರ್ವಹಿಸಿ, ಬಹಳ ಹೆಚ್ಚಿದ ಔಟ್‌ಪುಟ್ ಮತ್ತು ಸುಧಾರಿತ ಬಹು-ತಂತಿ ವ್ಯವಹಾರ ಪ್ರಕ್ರಿಯೆಗಳನ್ನು ಸಾಧ್ಯ ಮಾಡುತ್ತಾರೆ.
#
# ## 🎯 ಕಲಿಕಾ ಉದ್ದೇಶಗಳು
#
# ### 🚀 **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆಯ ಮೂಲಭೂತಗಳು**
# - **ಸಮಾಂತರ ಏಜೆಂಟ್ ಕಾರ್ಯನಿರ್ವಹಣೆ**: ಗರಿಷ್ಠ ಕಾರ್ಯಕ್ಷಮತೆಗಾಗಿ ಅನೇಕ ಏಜೆಂಟ್‌ಗಳನ್ನು ಒಂದೇ ಸಮಯದಲ್ಲಿ ನಡಿಸುವುದು
# - **ವರ್ಕ್‌ಫ್ಲೋ ಸಂಯೋಜನೆ**: ಡೇಟಾ тұрақಿತೆಯನ್ನು ಕಾಯ್ದುಕೊಂಡು ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳನ್ನು ಸಮನ್ವಯಗೊಳಿಸುವುದು
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಉದ್ಧಾರಣೆ**: ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ಮೂಲಕ ಮಹತ್ವದ ವೇಗವರ್ಧನೆ ಸಾಧಿಸುವುದು
# - **ಸಂಪನ್ಮೂಲ ನಿರ್ವಹಣೆ**: ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳಲ್ಲಿ AI ಮಾದರಿ ಸಂಪನ್ಮೂಲಗಳನ್ನು ಪರಿಣಾಮಕಾರಿಯಾಗಿ ಬಳಸುವುದು
#
# ### 🏗️ **ಮುಂದುವರೆದ ಸಮಕಾಲೀನ ಮಾದರಿಗಳು**
# - **ಫೋರ್ಕ್-ಜಾಯಿನ್ ಪ್ರಕ್ರಿಯೆ**: ಕೆಲಸವನ್ನು ಹಲವಾರು ಏಜೆಂಟ್‌ಗಳ ನಡುವೆ ಹಂಚಿ ಫಲಿತಾಂಶಗಳನ್ನು ಸಮನ್ವಯಿಸುವುದು
# - **ಪೈಪ್ಲೈನ್ ಸಮಾಂತರತೆ**: ನಿರಂತರ ಔಟ್‌ಪುಟ್‌ಗಾಗಿ ನಿರ್ವಹಣಾ ಹಂತಗಳನ್ನು ಅತಿಕ್ರಮಿಸುವುದು
# - **ಭಾರತೀಯ ಸಮತೋಲನೆ**: ಲಭ್ಯವಿರುವ ಏಜೆಂಟ್ ಸಂಪನ್ಮೂಲಗಳ ನಡುವೆ ಕೆಲಸವನ್ನು ಸಮಾನವಾಗಿ ಹಂಚುವಿಕೆ
# - **ಸಮకాలಿಕತೆಗೆ ಪಾಯಿಂಟ್‌ಗಳು**: ನಿರ್ದಿಷ್ಟ ವರ್ಕ್‌ಫ್ಲೋ ಹಂತಗಳಲ್ಲಿ ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳನ್ನು ಸಂಯೋಜಿಸುವುದು
#
# ### 🏢 **ಉದ್ಯಮ ಸಮಕಾಲೀನ ಅನ್ವಯಿಕೆಗಳು**
# - **ಹೆಚ್ಚು ಪ್ರಮಾಣದ ದಸ್ತಾವೇಜು ಪ್ರಕ್ರಿಯೆ**: ಅನೇಕ ದಸ್ತಾವೇಜುಗಳನ್ನು ಒಂದೇ ಸಮಯದಲ್ಲಿ ಪ್ರಕ್ರಿಯೆ ಮಾಡುವದು
# - **ನಿಜ-ಸಮಯ ವಿಷಯ ವಿಶ್ಲೇಷಣೆ**: ಬರುತ್ತಿರುವ ದತ್ತಾಂಶ stroom ಗಳ ಸಮಕಾಲೀನ ವಿಶ್ಲೇಷಣೆ
# - **ಬ್ಯಾಚ್ ಪ್ರಕ್ರಿಯೆ ಸುಧಾರಣೆ**: ದೊಡ್ಡ ಪ್ರಮಾಣದ ಕಾರ್ಯಗಳಿಗೆ ಹೆಚ್ಚಿದ ಔಟ್‌ಪುಟ್ ಸಾಧಿಸುವಿಕೆ
# - **ಬಹುಮುಖ ವಿಶ್ಲೇಷಣೆ**: ವಿಭಿನ್ನ ವಿಷಯಗಳ (ಲೇಖನ, ಚಿತ್ರಗಳು, ದತ್ತಾಂಶ) ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ
#
# ## ⚙️ ಪೂರ್ವಾಪೇಕ್ಷೆಗಳು ಮತ್ತು ಸೆಟ್ಅಪ್
#
# ### 📦 **ಅಗತ್ಯ ಅವಲಂಬನೆಗಳು**
#
# ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಸಾಮರ್ಥ್ಯಗಳೊಂದಿಗೆ ಏಜೆಂಟ್ ಫ್ರೇಮ್ವರ್ಕ್ ಅನ್ನು ಸ್ಥಾಪಿಸಿ:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub ಮಾದರಿಗಳ ಸಂರಚನೆ**
#
# **ಪರಿಸರ ಸೆಟ್ಅಪ್ (.env ಫೈಲ್):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆ ಪರಿಗಣನೆಗಳು:**
# - **ರೇಟ್ ಮಿತಿಗಳು**: GitHub Models API ರೇಟ್ ಮಿತಿಗಳನ್ನು ಸಮಕಾಲೀನ ವಿನಂತಿಗಳಿಗೆ ನಿಗಾ ಮಾಡುವುದು
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ**: ಅನೇಕ ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳೊಂದಿಗೆ ಮೆಮೊರಿ ಮತ್ತು CPU ಬಳಕೆಯನ್ನು ಪರಿಗಣಿಸುವುದು
# - **ದೋಷ ಹ್ಯಾಂಡ್ಲಿಂಗ್**: ಸಮಾಂತರ ಕಾರ್ಯಗಳಿಗೆ ದೋಷ ಪೂನಃಪಡೆಯುವಿಕೆ ದೃಢಪಡಿಸುವುದು
#
# ### 🏗️ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಆರ್ಕಿಟೆಕ್ಚರ್**
#
# ```mermaid
# graph TD
#     A[ಕಾರ್ಯದ ਪ੍ਰವಾಹ ಪ್ರಾರಂಭ] --> B[ಸಮಾನಾಂತರ ಕಾರ್ಯನിർವಾಹ]
#     B --> C[ಎಜೆಂಟ್ ಪೂಲ್ 1]
#     B --> D[ಎಜೆಂಟ್ ಪೂಲ್ 2]
#     B --> E[ಎಜೆಂಟ್ ಪೂಲ್ 3]
#     C --> F[ಫಲಿತಾಂಶ ಸಂಗ್ರಹಣೆ]
#     D --> F
#     E --> F
#     F --> G[ಅಂತಿಮ ಔಟ್‌ಪುಟ್]
#
#     H[GitHub ಮಾದರಿ API] --> C
#     H --> D
#     H --> E
# ```
#
# **ಮುಖ್ಯ ಪ್ರಯೋಜನಗಳು:**
# - **⚡ ಕಾರ್ಯಕ್ಷಮತೆ**: ಸಮಾಂತರ ಕಾರ್ಯನಿರ್ವಹಣೆಯಿಂದ ಮಹತ್ವದ ವೇಗವರ್ಧನೆ
# - **📈 ವಿಸ್ತರಣೆ ಸಾಮರ್ಥ್ಯ**: ಹೆಚ್ಚಿದ ಕೆಲಸದ ಭಾರವನ್ನು ಸಮಯದ ಪರಿಮಾಣವಿಲ್ಲದೆ ನಿರ್ವಹಿಸುವುದು
# - **🔄 ಪ್ರಭಾವಕಾರಿಕೆ**: ಲಭ್ಯವಿರುವ ಗಣನಾ ಸಂಪನ್ಮೂಲಗಳ ಉತ್ತಮ ಬಳಸಿಕೊಳಿಕೆ
# - **🎯 ಔಟ್‌ಪುಟ್**: ಅದೇ ಸಮಯದಲ್ಲಿ ಹೆಚ್ಚು ಕೆಲಸವನ್ನು ಪ್ರಕ್ರಿಯೆ ಮಾಡುವುದು
#
# ## 🎨 **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ ಮಾದರಿಗಳು**
#
# ### 🔍 **ಶೋಧನೆ ಮತ್ತು ವಿಶ್ಲೇಷಣೆಯ ಪೈಪ್ಲೈನ್**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ದತ್ತಾಂಶ ಪ್ರಕ್ರಿಯೆ ನಿವಾಸ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ವಿಷಯ ನಿರ್ಮಾಣ ಪೈಪ್ಲೈನ್**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ಬಹು ಹಂತ ಪ್ರಕ್ರಿಯೆ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ಉದ್ಯಮ ಕಾರ್ಯಕ್ಷಮತೆ ಪ್ರಯೋಜನಗಳು**
#
# ### ⚡ **ಔಟ್‌ಪುಟ್ ಸುಧಾರಣೆ**
# - **ಸಮಾಂತರ ಕಾರ್ಯನಿರ್ವಹಣೆ**: ಅನೇಕ ಏಜೆಂಟ್‌ಗಳು ಒಂದೇ ಸಮಯದಲ್ಲಿ ಕಾರ್ಯरत
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ**: ಲಭ್ಯವಿರುವ AI ಮಾದರಿ ಸಾಮರ್ಥ್ಯದ ಗರಿಷ್ಟ ಕಾರ್ಯಕ್ಷಮತೆ
# - **ಸಮಯ ಕಡಿತ**: ಒಟ್ಟಾರೆ ಪ್ರಕ್ರಿಯೆ ಸಮಯದಲ್ಲಿ ಮಹತ್ವದ ಇಳಿಕೆ
# - **ವಿಸ್ತಾರಗೊಳ್ಳುವ ಆರ್ಕಿಟೆಕ್ಚರ್**: ಅಗತ್ಯವಿದ್ದರೆ ಸುಲಭವಾಗಿ ಹೆಚ್ಚಿನ ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳನ್ನು ಸೇರಿಸುವುದು
#
# ### 🛡️ **ನಂಬಿಕೆಯುಳ್ಳತೆ ಮತ್ತು ಸ್ಥೈರ್ಯ**
# - **ತಪ್ಪು ಒಡೆಯುವಿಕೆ**: ವೈಯಕ್ತಿಕ ಏಜೆಂಟ್ ವೈಫಲ್ಯದ ಪರಿಣಾಮವೇ ಉಳಿದ ವರ್ಕ್‌ಫ್ಲೋ ಅನ್ನು ತಡೆದುಿಲ್ಲ
# - **ದೋಷ ಹರಿತ ನಿಲ್ಲಾಪನೆ**: ಒಂದು ಸಮಕಾಲೀನ ಶಾಖೆಯಲ್ಲಿ ಸಮಸ್ಯೆ ಇತರರ ಮೇಲೆ ಪ್ರಭಾವ ಬೀರುವುದಿಲ್ಲ
# - **ಸುಸಜ್ಜಿತ ಕುಸಿತ**: ಏಜೆಂಟ್ ಸಾಮರ್ಥ್ಯ ಕಡಿಮೆ ಆಗಿದ್ದರೂ ವ್ಯವಸ್ಥೆ ಕಾರ್ಯ ನಿರ್ವಹಣೆ ಮುಂದುವರಿಯುತ್ತದೆ
# - **ಪುನಃಪ್ರಯತ್ನ ಮತ್ತು ದೋಷ ನಿರ್ವಹಣೆ**: ವಿಫಲವಾದ ಕಾರ್ಯಗಳಿಗೆ ಸ್ವಯಂಚಾಲಿತ ಮರುಪ್ರಯತ್ನ ಮತ್ತು ದೋಷ ಸಂಚಾರ
#
# ### 📊 **ನಿಗಾ ಮತ್ತು ಪ್ರತ್ಯಕ್ಷತೆ**
# - **ಸಮಕಾಲೀನ ಕಾರ್ಯನಿರ್ವಹಣೆ ಟ್ರಾಣಿಕೆ-**: ಎಲ್ಲಾ ಸಮಾಂತರ ಕಾರ್ಯಗಳ ಪ್ರಗತಿಯನ್ನು ನಿಗಾ ಮಾಡುವುದು
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಮಾಪನಗಳು**: ವೇಗ ವೃದ್ಧಿ ಮತ್ತು ಕಾರ್ಯಕ್ಷಮತೆ ಇಳಿಕೆಗಳನ್ನು ಮಾಪುವುದು
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ ವಿಶ್ಲೇಷಣೆ**: ಸಮಂತರ ಏಜೆಂಟ್ ಹಂಚಿಕೆಯನ್ನು ಸೂಕ್ತಮಾಡುವುದು
# - **ಬಾಟ್ಲ್‌ನೆಕ್ ಗುರುತುಹಚ್ಚುವುದು**: ಕಾರ್ಯಕ್ಷಮತೆಯ ಮಿತಿ ಸೌಲಭ್ಯಗಳನ್ನು ಕಂಡುಹಿಡಿದು ಪರಿಹರಿಸುವುದು
#
# ಹೆಚ್ಚು ಕಾರ್ಯಕ್ಷಮ ಸಮಕಾಲೀನ AI ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ನಿರ್ಮಿಸೋಣ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸ್ವೀಕಾರ**:
# ಈ ದಸ್ತಾವೇಜು AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ನಿಖರತೆಯನ್ನು ಸಾಧಿಸಲು ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಡ್ಡೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಸ್ತಾವೇಜು ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದವನ್ನು ಬಳಸುವ ಮೂಲಕ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪು ಅರ್ಥಗಳ ಅಥವಾ ತಪ್ಪು ವ್ಯಾಖ್ಯಾನಗಳ ಬಗ್ಗೆ ನಾವು ಹೊಣೆಗಾರರಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
