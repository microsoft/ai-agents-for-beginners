# %% [markdown]
# # ⚡ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಫೌಂಡ್ರಿಯೊಂದಿಗೆ ಸಮಕಾಲೀನ ಏಜೆಂಟ್ ವರ್ಕ್‌ಫ್ಲෝಗಳು (ಪೈಥಾನ್)
#
# ## 📋 ಉನ್ನತ ಮಟ್ಟದ ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ಟ್ಯೂಟೋರಿಯಲ್
#
# ಈ ನೋಟಬುಕ್ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಏಜೆಂಟ್ ಫ್ರೇಮ್ವರ್ಕ್ ಬಳಸಿ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಮಾದರಿಗಳು** ಅನ್ನು ಪ್ರದರ್ಶಿಸುತ್ತದೆ. ನೀವು ಹೈ-ಪರ್ಫಾರ್ಮೆನ್ಸ್, ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್ಫ್ಲೋಗಳನ್ನು ನಿರ್ಮಿಸುವ ವಿಧಾನವನ್ನು ಕಲಿಯುತ್ತೀರಿ, ಅಲ್ಲಿ ಹಲವಾರು AI ಏಜೆಂಟ್ಸ್ ಒಂದೇ ಸಮಯದಲ್ಲಿ ಕಾರ್ಯನಿರ್ವಹಿಸುತ್ತಾರೆ, ಪಾಳುವರ್ಗಳ ಮುಖಾಂತರ ಮಹತ್ವಪೂರ್ಣ ಸುಧಾರಣೆಗೊಳ್ಳುತ್ತದೆ ಮತ್ತು ಸುಧಾರಿತ ಬಹು-ಥ್ರೆಡಡ್ ವ್ಯವಹಾರ ಪ್ರಕ್ರಿಯೆಗಳ ನೆರವಿನಿಂದ ಸಾಧ್ಯವಾಗುತ್ತದೆ.
#
# > **ಸ್ಥಳಾಂತರ ಟಿಪ್ಪಣಿ:** ಈ ಮಾದರಿ ಮೊದಲು GitHub Models ಅನ್ನು ಉಲ್ಲೇಖಿಸಿತು. GitHub Models ನಿಯೋಜನೆಯಿಂದ (ಜುಲೈ 2026 ರಲ್ಲಿ ನಿವೃತ್ತವಾಗಿದೆ), ಈಗ ಇದು `FoundryChatClient` ಮೂಲಕ **Microsoft Foundry** ಅನ್ನು ಬಳಸುತ್ತದೆ, ಇದು Azure OpenAI **Responses API** ಗುರಿಯಾಗಿದೆ.
#
# ## 🎯 ಕಲಿಕೆ ಮೂಲಗಳು
#
# ### 🚀 **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆಯ ಮೂಲಭೂತ ತತ್ತ್ವಗಳು**
# - **ಸಮನ್ವಯ ಏಜೆಂಟ್ ಕಾರ್ಯನಿರ್ವಹಣೆ**: ಗರಿಷ್ಠ ಸಮರ್ಥತೆಯಿಗಾಗಿ ಹಲವಾರು ಏಜೆಂಟ್ಸ್ ಒಂದೇ ಸಮಯದಲ್ಲಿ ಕೆಲಸ ಮಾಡುತ್ತಾರೆ
# - **ವರ್ಕ್‌ಫ್ಲೋ ಸಂಯೋಜನೆ**: ಡೇಟಾ ಸಮ್ಮತಿ ಕಾಯ್ದುಕೊಳ್ಳುತ್ತಿರುವಾಗ ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳನ್ನು ಹೊಂದಿಸಿ
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಗರಿಷ್ಠಗೊಳಿಸುವಿಕೆ**: ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ಮೂಲಕ ಮಹತ್ವಪೂರ್ಣ ವೇಗವರ್ಧನೆ ಸಾಧಿಸಿ
# - **ಸಂಪನ್ಮೂಲ ನಿರುದ್ಯೋಗ**: ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳಲ್ಲಿ AI ಮಾದರಿ ಸಂಪನ್ಮೂಲಗಳನ್ನು ಸಮರ್ಥವಾಗಿ ಬಳಸಿ
#
# ### 🏗️ **ಅತ್ಯಾಧುನಿಕ ಸಮಕಾಲೀನ ಮಾದರಿಗಳು**
# - **ಫೋರ್ಕ್-ಜಾಯಿನ್ ಪ್ರಕ್ರಿಯೆ**: ಹಲವಾರು ಏಜೆಂಟ್ಗಳ ನಡುವೆ ಕೆಲಸವನ್ನು ಹಂಚಿ ಫಲಿತಾಂಶಗಳನ್ನು ಸೇರಿಸಿ
# - **ಪೈಪ್ಲೈನ್ ಸಮಾಂತರತೆ**: ನಿರಂತರ ಪಾಳುಮಾರ್ಗದ ಕಾರ್ಯಾಚರಣೆಯ ಹಂತಗಳನ್ನು ಹೊಂದಿಸಿ
# - **ಲೋಡ್ ಬ್ಯಾಲನ್ಸಿಂಗ್**: ಲಭ್ಯವಿರುವ ಏಜೆಂಟ್ ಸಂಪನ್ಮೂಲಗಳ ಮೇಲೆ ಸಮಾನವಾಗಿ ಕೆಲಸ ಹಂಚಿಕೆ
# - **ಸమన್ವಯ ಬಿಂದುಗಳು**: ಪ್ರಮುಖ ವರ್ಕ್‌ಫ್ಲೋ ಹಂತಗಳಲ್ಲಿ ಸಮಕಾಲೀನ ಏಜೆಂಟ್ಗಳನ್ನು ಸಂಯೋಜಿಸಿ
#
# ### 🏢 **ಉದ್ಯಮ ಸಮಕಾಲೀನ ಅಪ್ಲಿಕೇಶನ್ಗಳು**
# - **ಹೆಚ್ಚು ಪ್ರಮಾಣದ ದಾಖಲೆ ಪ್ರಕ್ರಿಯೆ**: ಒಂದೇ ಸಮಯದಲ್ಲಿ ಹಲವು ದಾಖಲೆಗಳನ್ನು ಪ್ರಕ್ರಿಯೆ ಮಾಡಿ
# - **ನಿಜ-ಸಮಯ ವಿಷಯ ವಿಶ್ಲೇಷಣೆ**: ಬರುವ ಡೇಟಾ ಸ್ಟ್ರೀಮ್‌ಗಳ ಸಮಕಾಲೀನ ವಿಶ್ಲೇಷಣೆ
# - **ಬ್ಯಾಚ್ ಪ್ರಕ್ರಿಯೆಯ ಗರಿಷ್ಠಗೊಳಿಸುವಿಕೆ**: ದೊಡ್ಡ ಮಟ್ಟದ ಕಾರ್ಯಗಳಿಗೆ ಗರಿಷ್ಠ ವೇಗವರ್ಧನೆ
# - **ಬಹು-ಮೋಡಲ್ ವಿಶ್ಲೇಷಣೆ**: ವಿಭಿನ್ನ ವಿಷಯ ಪ್ರಕಾರಗಳ (ಪಠ್ಯ, ಚಿತ್ರಗಳು, ಡೇಟಾ) ಸಮಂತರ ಪ್ರಕ್ರಿಯೆ
#
# ## ⚙️ ಪೂರ್ವಾವಶ್ಯಕತೆಗಳು ಮತ್ತು ಸ್ಥಾಪನೆ
#
# ### 📦 **ಗೌರವಾರ್ಹ ಅವಲಂಬನೆಗಳು**
#
# ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಸಾಮರ್ಥ್ಯಗಳೊಂದಿಗೆ ಏಜೆಂಟ್ ಫ್ರೇಮ್ವರ್ಕ್ ನುಳಿಸಿ:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ಸಂರಚನೆ**
#
# `az login` ಬಳಸಿ Azure CLI ನೊಂದಿಗೆ ಸೈನ್ ಇನ್ ಮಾಡಿ, ನಂತರ `AzureCliCredential` ಧೃಡೀಕರಣ ಮಾಡಬಹುದು ಮತ್ತು ನಿಮ್ಮ Microsoft Foundry ಪ್ರಾಜೆಕ್ಟ್ ವಿವರಗಳನ್ನು ಹೊಂದಿಸಿ.
#
# **ಪರಿಸರ ಸ್ಥಾಪನೆ (.env ಫೈಲ್):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆ ಪರಿಗಣನೆಗಳು:**
# - **ರೇಟ್ ಮಿತಿಗಳು**: ಸಮಕಾಲೀನ ವಿನಂತಿಗಳಿಗೆ Azure OpenAI ರೇಟ್ ಮಿತಿಗಳನ್ನುelessೈಸೂರು
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ**: ಬಹು ಸಮಕಾಲೀನ ಏಜೆಂಟ್ಗಳೊಂದಿಗೆ ಮೆಮೊರಿ ಮತ್ತು CPU ಬಳಕೆಯನ್ನು ಪರಿಗಣಿಸಿ
# - **ದೋಷ ನಿರ್ವಹಣೆ**: ಸಮಂತರ ಕಾರ್ಯಾಚರಣೆಗಳಿಗೆ ದೃಢ ದೋಷ ಪುನರುತ್ಪಾದನೆ ಅನುಷ್ಠಾನಗೊಳಿಸಿ
#
# ### 🏗️ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ವಾಸ್ತುಶಿಲ್ಪ**
#
# ```mermaid
# graph TD
#     A[ವರ್ಕ್‌ಫ್ಲೋ ಪ್ರಾರಂಭ] --> B[ಸಮಕಾಲೀನ ಕಾರ್ಯಾಚರಣೆ]
#     B --> C[ಏಜೆಂಟ್ ಪೂಲ್ 1]
#     B --> D[ಏಜೆಂಟ್ ಪೂಲ್ 2]
#     B --> E[ಏಜೆಂಟ್ ಪೂಲ್ 3]
#     C --> F[ಫಲಿತಾಂಶ ಸಂಗ್ರಹಣೆ]
#     D --> F
#     E --> F
#     F --> G[ಅಂತಿಮ输出]
#
#     H[ಮೈಸ್ಕ್ರೋಸಾಫ್ಟ್ ಫೌಂಡ್ರಿ] --> C
#     H --> D
#     H --> E
# ```
#
# **ಮುಖ್ಯ ಪ್ರಯೋಜನಗಳು:**
# - **⚡ ಆದಾಯ**: ಸಮಾಂತರ ಕಾರ್ಯಾಚರಣೆಯ ಮೂಲಕ ಮಹತ್ವದ ವೇಗವರ್ಧನೆ
# - **📈 ವಿಸ್ತರಣೆ ಸಾಮರ್ಥ್ಯ**: ಹೆಚ್ಚಿದ ಕಾರ್ಯಭಾರಗಳನ್ನು ಅನುಗುಣ ಸಮಯವಿಲ್ಲದೆ ನಿರ್ವಹಿಸಿ
# - **🔄 ದಕ್ಷತೆ**: ಲಭ್ಯವಿರುವ ಗಣನಾ ಸಂಪನ್ಮೂಲಗಳ ಉತ್ತಮ ಬಳಕೆ
# - **🎯 ಪಾಳುಮಾರ್ಗೀಕರಣ**: ಒಂದೇ ಸಮಯದಲ್ಲಿ ಹೆಚ್ಚು ಕೆಲಸಗಳನ್ನು ಪ್ರಕ್ರಿಯೆ ಮಾಡಿ
#
# ## 🎨 **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ ಮಾದರಿಗಳು**
#
# ### 🔍 **ಶೋಧನೆ ಮತ್ತು ವಿಶ್ಲೇಷಣೆ ಪೈಪ್ಲೈನ್**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ಡೇಟಾ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್‌ಫ್ಲೋ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ವಿಷಯ ರಚನೆ ಪೈಪ್ಲೈನ್**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ಬಹು ಹಂತ ಪ್ರಕ್ರಿಯೆ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ಉದ್ಯಮ ಕಾರ್ಯಕ್ಷಮತೆ ಪ್ರಯೋಜನಗಳು**
#
# ### ⚡ **ಪಾಳುಮಾರ್ಗಗಳ ಗರಿಷ್ಠತ್ಮಕೀಕರಣ**
# - **ಸಮನ್ವಯ ಕಾರ್ಯನಿರ್ವಹಣೆ**: ಹಲವಾರು ಏಜೆಂಟ್ಸ್ ಒಟ್ಟಿಗೆ ಕಾರ್ಯನಿರ್ವಹಿಸುತ್ತಾರೆ
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ**: ಲಭ್ಯವಿರುವ AI ಮಾದರಿ ಸಾಮರ್ಥ್ಯದ ಗರಿಷ್ಠ ದಕ್ಷತೆ
# - **ಸಮಯ ಇಳಿಕೆ**: ಒಟ್ಟು ಪ್ರಕ್ರಿಯೆ ಸಮಯದಲ್ಲಿ ಬಹುಮಾನ ಇಳಿಕೆ
# - **ವಿಸ್ತರಣೀಯ ವಾಸ್ತುಶಿಲ್ಪ**: ಅಗತ್ಯವಿರುವಷ್ಟು ಹೆಚ್ಚು ಸಮಕಾಲೀನ ಏಜೆಂಟ್ ಗಳನ್ನು ಸುಲಭವಾಗಿ ಸೇರಿಸಬಹುದು
#
# ### 🛡️ **ನಂಬಿಕೆಯಿಂದ ಮತ್ತು ಸ್ಥೈರ್ಯ**
# - **ತಪ್ಪು ಸಹನೆ**: ವೈಯಕ್ತಿಕ ಏಜೆಂಟ್ ವೈಫಲ್ಯಗಳು ಸಂಪೂರ್ತ workflows ನ್ನು ನಿಲ್ಲಿಸುವುದಿಲ್ಲ
# - **ದೋಷ ವಿಭಜನೆ**: ಒಬ್ಬ ಸಮಕಾಲೀನ ಶಾಖೆಯಲ್ಲಿ ತೊಂದರೆಗಳು ಇತರರ ಮೇಲೆ ಪರಿಣಾಮ ಬೀರುವುದಿಲ್ಲ
# - **ಸುಮಧುರ ಕುಗ್ಗುತಿ**: ಕಡಿಮೆ ಏಜೆಂಟ್ ಸಾಮರ್ಥ್ಯ ಹೊಂದಿದರೂ ವ್ಯವಸ್ಥೆ ಕಾರ್ಯನಿರ್ವಹಿಸುತ್ತದೆ
# - **ಪುನಃಗ್ರಹಣ ಯಂತ್ರಗಳು**: ವಿಫಲವಾದ ಕಾರ್ಯಗಳಿಗಾಗಿ ಸ್ವಯಂಚಾಲಿತ ಪುನಃಪ್ರಯತ್ನ ಮತ್ತು ದೋಷ ನಿರ್ವಹಣೆ
#
# ### 📊 **ನಿರೀಕ್ಷಣೆ ಮತ್ತು ಅವಲೋಕನ**
# - **ಸಮಕಾಲೀನ ಕಾರ್ಯನಿರ್ವಹಣೆ ಹಾದಿಯ ಹಾದುಹೋಗುವಿಕೆ**: ಎಲ್ಲಾ ಸಮಾಂತರ ಕಾರ್ಯಗಳ ಪ್ರಗತಿ ನೋಡಿಕೊಳ್ಳಿ
# - **ಕಾರ್ಯಕ್ಷಮತೆ ಮೀಟ್ರಿಕ್‌ಗಳು**: ವೇಗ ಮತ್ತು ದಕ್ಷತೆ ಮಾಹಿತಿ ಸಂಗ್ರಹಿಸಿ
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ ವಿಶ್ಲೇಷಣೆ**: ಸಮಾಂತರ ಏಜೆಂಟ್ ಹಂಚಿಕೆಯನ್ನು ಗರಿಷ್ಠಗೊಳಿಸಿ
# - **ಬಾಟಲ್ನೇಕ್ ಗುರುತಿಸುವಿಕೆ**: ಕಾರ್ಯಕ್ಷಮತೆ ನಿಯಂತ್ರಣಗಳನ್ನು ಕಂಡುಹಿಡಿದು ಪರಿಹರಿಸಿ
#
# ಉನ್ನತ ಕಾರ್ಯಕ್ಷಮತೆಯ ಸಮಂತರ AI ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ನಿರ್ಮಿಸೋಣ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸ್ವೀಕಾರ**:
# ಈ ದಸ್ತಾವೇಜು AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ನಿಖರತೆಯನ್ನು ಸಾಧಿಸಲು ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಡ್ಡೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಸ್ತಾವೇಜು ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದವನ್ನು ಬಳಸುವ ಮೂಲಕ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪು ಅರ್ಥಗಳ ಅಥವಾ ತಪ್ಪು ವ್ಯಾಖ್ಯಾನಗಳ ಬಗ್ಗೆ ನಾವು ಹೊಣೆಗಾರರಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
