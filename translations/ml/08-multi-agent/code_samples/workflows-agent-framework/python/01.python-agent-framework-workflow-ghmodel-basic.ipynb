# %% [markdown]
# # 🔄 GitHub മോഡലുകളോടൊപ്പം ബേസിക് ഏജന്റ് വർക്‌ഫ്ലോകൾ (Python)
#
# ## 📋 വർക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ ട്യൂട്ടോറിയൽ
#
# Microsoft Agent Framework ന്റെ ശക്തമായ **Workflow Builder** ശേഷികളെ ഈ നോട്ട്‌ബുക്കിൽ പരിചയപ്പെടുത്തുന്നു. സങ്കീർണ്ണമായ ബിസിനസ് പ്രക്രിയകൾ കൈകാര്യം ചെയ്ത് നിരവധി AI പ്രവർത്തനങ്ങൾ സുതാര്യമായി ഏകോപിപ്പിക്കാൻ കഴിയുന്ന പ്രഗാധ, ബഹുവർണ്ണ ഏജന്റ് വർക്‌ഫ്ലോകൾ സൃഷ്ടിക്കുന്നത് എങ്ങനെ എന്നത് പഠിക്കൂ.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🏗️ **Workflow ആർക്കിടെക്ചർ**
# - **Workflow Builder**: സങ്കീർണ്ണമായ ബഹുവർണ്ണ പ്രക്രിയകൾ രൂപകൽപ്പന ചെയ്ത് ഓർക്കസ്ട്രേറ്റ് ചെയ്യുക
# - **ഇവന്റ്-ഡ്രിവൻ എക്സ്‌ക്യൂഷൻ**: വർക്‌ഫ്ലോ ഇവന്റുകളും സ്റ്റേറ്റ് ട്രാൻസിഷനുകളും കൈകാര്യംചെയ്യുക
# - **വിജുവൽ Workflow ഡിസൈൻ**: Workflow ഘടനകൾ സൃഷ്ടിച്ച് ദൃശ്യമാക്കുക
# - **GitHub മോഡല്‍ ഇന്റഗ്രേഷൻ**: വർക്‌ഫ്ലോക്കളിൽ AI മോഡലുകൾ പ്രയോജനപ്പെടുത്തുക
#
# ### 🔄 **പ്രക്രിയ ഓർക്കസ്ട്രേഷൻ**
# - **ക്രമാനുസൃത ഓപ്പറേഷനുകൾ**: ബഹുവർണ്ണ ഏജന്റ് ടാസ്കുകൾ ലജിക്കൽ ഓർഡറിൽ ബന്ധിപ്പിക്കുക
# - **വൈകല്പിക ലాజിക്ക്**: തീരുമാനബിന്ദുക്കളും ബ്രാഞ്ചിംഗ് വർക്‌ഫ്ലോകളും നടപ്പിലാക്കുക
# - **പിശക് കൈകാര്യംചെയ്യൽ**: കാര്യക്ഷമമായ പിശക് വീണ്ടെടുക്കൽ, വർക്‌ഫ്ലോ സ്റ്റബി
# - **സ്റ്റേറ്റ് മാനേജ്‌മെന്റ്**: Workflow എക്സിക്യൂഷൻ സ്റ്റേറ്റ് ട്രാക്ക് ചെയ്യുക
#
# ### 📊 **എന്റർപ്രൈസ് Workflow പാറ്റേൺസ്**
# - **ബിസിനസ്സ് പ്രക്രിയ ഓട്ടോമേഷൻ**: സങ്കീർണ്ണമായ സ്ഥാപന വാർക്ക്‌ഫ്ലോകൾ ഓട്ടോമേറ്റ് ചെയ്യുക
# - **മൾട്ടി-ഏജന്റ് കോർഡിനേഷൻ**: പ്രത്യേകിച്ച ഏജന്റ்களின் പുരോഗതിയെ ഏകോപിപ്പിക്കുക
# - **സ്കെയിലബിള്‍ എക്സിക്യൂഷൻ**: എന്റർപ്രൈസ് സ്കെയിലിനുള്ള വർക്‌ഫ്ലോകൾ ഡിസൈൻ ചെയ്യുക
# - **മോണിറ്ററിംഗ് & ഓബ്സർവബിലിറ്റി**: വർക്‌ഫ്ലോ പ്രകടനവും ഫലങ്ങളും നിരീക്ഷിക്കുക
#
# ## ⚙️ മുൻ‌പരിചയങ്ങളും സെറ്റപ്പും
#
# ### 📦 **ആവശ്യമായ Dependencies**
#
# വർക്‌ഫ്ലോ ശേഷിയുള്ള Agent Framework ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub മോഡലുകളുടെയും കൺഫിഗറേഷൻ**
#
# **Environment Setup (.env ഫയൽ):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **എന്റർപ്രൈസ് ഉപയോഗപ്പകർ**
#
# **ബിസിനസ്സ് പ്രക്രിയ ഉദാഹരണങ്ങൾ:**
# - **കസ്റ്റമർ ഓൺ‌ബോർഡിംഗ്**: ബഹു ഘട്ട സ്ഥിരീകരണവും സെറ്റപ്പും workflows
# - **Content Pipeline**: സ്വയംമാറ്റിനുള്ള ഉള്ളടക്കം രൂപപ്പെടുത്തൽ, സംശോധന, പ്രസിദ്ധീകരണം
# - **ഡേറ്റാ പ്രോസസ്സിംഗ്**: AI ശക്തിയുള്ള ട്രാൻസ്ഫർമേഷൻ ഉൾക്കൊള്ളുന്ന ETL workflows
# - **ക്വാളിറ്റി അഷ്വറൻസ്**: ഓട്ടോമേറ്റഡ് ടെസ്റ്റിംഗ്, വാലിഡേഷൻ പ്രക്രിയകൾ
#
# **Workflow ലാഭങ്ങൾ:**
# - 🎯 **നിർവ്വചനക്ഷമത**: പിശക് വീണ്ടെടുക്കലോടൊപ്പം ഉറപ്പുള്ള എക്സിക്യൂഷൻ
# - 📈 **സ്കെയിലബിലിറ്റി**: ഉയർന്ന വലുപ്പം പ്രക്രിയ ഓട്ടോമേഷൻ കൈകാര്യംചെയ്യുക
# - 🔍 **ഓബ്സർവബിലിറ്റി**: സമ്പൂർണ്ണ ഓഡിറ്റ് ട്രെയിലുകളും നിരീക്ഷണവും
# - 🔧 **മെന്റൈനബിലിറ്റി**: ദൃശ്യ ഡിസൈൻ, ഘടകങ്ങളുടെ മൊഡുലാർ ഘടന
#
# ## 🎨 Workflow ഡിസൈൻ പാറ്റേൺസ്
#
# ### ബേസിക് Workflow ഘടന
# ```mermaid
# graph TD
#     A[ആരംഭം] --> B[പ്രതിനിധി ജോലി 1]
#     B --> C{തിരഞ്ഞെടുപ്പ് പോയിന്റ്}
#     C -->|വിജയം| D[പ്രതിനിധി ജോലി 2]
#     C -->|തെറ്റ്| E[തെറ്റ് കൈകാര്യം ചെയ്യുന്നത്]
#     D --> F[അവസാനം]
#     E --> F
# ```
#
# **പ്രധാന ഘടകങ്ങൾ:**
# - **WorkflowBuilder**: മുഖ്യ ഓർക്കസ്ട്രേഷൻ എഞ്ചിൻ
# - **WorkflowEvent**: ഇവന്റ് കൈകാര്യംചെയ്യൽ, കമ്മ്യൂണിക്കേഷൻ
# - **WorkflowViz**: Workflow ദൃശ്യമാക്കലും ഡീബഗിംഗും
#
# നിങ്ങളുടെ ആദ്യ ബുദ്ധിമുട്ടേറിയ workflow സൃഷ്ടിക്കാം! 🚀

# %%
! pip install agent-framework-core -U

# %%
# 🔄 Import Workflow and Agent Framework Components
# Core components for building sophisticated agent workflows

from agent_framework.openai import OpenAIChatClient    # 🤖 GitHub Models client integration
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz  # 🏗️ Workflow orchestration tools

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()

# %%
# 🔗 Initialize GitHub Models Chat Client for Workflow Operations
# Create the AI client that will power agents within our workflow
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # 🌐 GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # 🔑 Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # 🎯 Selected AI model
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent   = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

front_desk_agent = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(front_desk_agent).add_edge(front_desk_agent, reviewer_agent).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
result =''
async for event in workflow.run_stream('I would like to go to Paris.'):
    if isinstance(event, DatabaseEvent):
        print(f"{event}")
    if isinstance(event, WorkflowEvent):
        result += str(event.data)
        # print(f"Workflow output: {event.data}")

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
