# %% [markdown]
# # ⚡ Microsoft Foundry (Python) ഉപയോഗിച്ചുള്ള സമകാലിക ഏജന്റ് വർക്‌ഫ്ലോകൾ
#
# ## 📋 ആധുനിക സാങ്കേതിക അനുപാത വ്യവസ്ഥാസൂത്രണം
#
# Microsoft ഏജന്റ് ഫ്രെയിംവർക്ക് ഉപയോഗിച്ച് **സമകാലിക വർക്‌ഫ്ലോ മാതൃകകൾ** പ്രവൃത്തി നിര്‍വഹിക്കുന്നു. ഒരേ സമയം നിരവധി AI ഏജന്റുകൾ പ്രവർത്തിക്കുന്ന ഉയർന്ന പ്രകടനക്ഷമമായ പരലൽ പ്രോസസിംഗ് വർക്‌ഫ്ലോകൾ നിർമ്മിക്കുന്നതിന് നിങ്ങൾക്ക് ഇതിലൂടെ പഠിക്കാം, ഇത് throughput നെ വിപുലമായി മെച്ചപ്പെടുത്തുന്നു, ഉയർന്ന മൾട്ടി-ത്രെഡ് ബിസിനസ് പ്രക്രിയകൾ സാധ്യമാക്കുന്നു.
#
# > **മൈഗ്രേഷൻ കുറിപ്പ്:** ഈ സാമ്പിൾ മുമ്പ് GitHub Models നെ സൂചിപ്പിച്ചിരുന്നു. GitHub Models വിരമിക്കുക (ജൂലൈ 2026 മുതൽ), അതിനാൽ ഇപ്പോൾ ഇത് `FoundryChatClient` മുഖാന്തിരം **Microsoft Foundry** ഉപയോഗിക്കുന്നു, ഇത് Azure OpenAI **Responses API** നെ ലക്ഷ്യമിടുന്നു.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🚀 **സമകാലിക പ്രോസസിംഗിന്റെ അടിസ്ഥാനങ്ങൾ**
# - **പരലൽ ഏജന്റ് നിർവഹണം**: പരമാവധി പ്രയോജനം നേടാൻ ഒരേ സമയം നിരവധി ഏജന്റുകൾ നടത്തുക
# - **വർക്‌ഫ്ലോ ഏകോപനം**: ഡാറ്റ സ്ഥിരത നിലനിറുത്തിക്കൊണ്ട് സമകാലിക പ്രവർത്തനങ്ങൾ ഏകോപിപ്പിക്കുക
# - **പ്രകടന മെച്ചപ്പെടുത്തൽ**: പരലൽ പ്രോസസിംഗിലൂടെ ഗണനീയമായ വേഗമേറിയ്‌ക്ക് കൈവരിക്കുക
# - **വിഭവ ഡയറക്ഷൻ**: സമകാലിക പ്രവർത്തനങ്ങളിൽ AI മോഡൽ വിഭവങ്ങൾ ഫലപ്രദമായി ഉപയോഗിക്കുക
#
# ### 🏗️ **ഉന്നത സമകാലിക മോഡലുകൾ**
# - **ഫോർക്ക്-ജോയിൻ പ്രോസസിംഗ്**: ഒരേ പ്രവർത്തനം പല ഏജന്റുകൾക്ക് വിഭജിച്ച് ഫലം ഒന്നാക്കൽ
# - **പൈപ്പ്‌ലൈൻ പരലലിസം**: തുടർച്ചയായി throughput വേണ്ടി പ്രവർത്തന ഘട്ടങ്ങൾ ഒറ്റനിലയിൽ നടത്തൽ
# - **ലോഡ് ബാലൻസിംഗ്**: ലഭ്യമായ ഏജന്റ് വിഭവങ്ങൾ തുല്യം തിരഞ്ഞിവെക്കൽ
# - **സമന്വയം പോയിന്റുകൾ**: പ്രധാന വർക്‌ഫ്ലോ ഘട്ടങ്ങളിൽ സമകാലിക ഏജന്റുകൾ ഏകോപിപ്പിക്കൽ
#
# ### 🏢 **എന്റർപ്രൈസ് സമകാലിക ആപ്ലിക്കേഷനുകൾ**
# - **ഉയർന്ന തോതിലുള്ള ഡോക്യുമെന്റ് പ്രോസസിംഗ്**: ഒരേ സമയം നിരവധി ഡോക്യുമെന്റുകൾ പ്രോസസ്സ് ചെയ്യൽ
# - **തത്സമയ ഉള്ളടക്കം വിശകലനം**: വരവേൽക്കുന്ന ഡാറ്റാ സ്ട്രീമുകളുടെ സമകാലിക വിശകലനo
# - **ബാച്ച് പ്രോസസിംഗ് മെച്ചപ്പെടുത്തൽ**: വലിയ തോതിലുള്ള പ്രവർത്തനങ്ങൾക്ക് പരമാവധി throughput
# - **മൾട്ടി-മോഡൽ വിശകലനം**: വ്യത്യസ്ത ഉള്ളടക്ക തരം (പഠ്യം, ചിത്രം, ഡാറ്റ) പരലൽ പ്രോസസിംഗ്
#
# ## ⚙️ മുൻകൂട്ടി വേണ്ടതും ക്രമീകരണവും
#
# ### 📦 **ആവശ്യമായ ഡയറക്ഷനുകൾ**
#
# സമകാലിക workflow കഴിവുകളുള്ള ഏജന്റ് ഫ്രെയിംവർക്ക് ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ക്രമീകരണം**
#
# Azure CLI (`az login`) ഉപയോഗിച്ച് സൈൻ ഇൻ ചെയ്യുക যাতে `AzureCliCredential` ഓർത്തന്റിക്കേഷൻ നടത്താനാകൂ, തുടർന്ന് നിങ്ങളുടെ Microsoft Foundry പ്രോജക്ട് വിശദാംശങ്ങൾ നൽകുക.
#
# **പരിസ്ഥിതി ക്രമീകരണം (.env ഫയൽ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **സമകാലിക പ്രോസസിംഗിന് ശ്രദ്ധിക്കേണ്ടത്:**
# - **റേറ്റ് പരിധികൾ**: സമകാലിക അഭ്യർത്ഥനകൾക്കായുള്ള Azure OpenAI റേറ്റ് പരിധികൾ നിരീക്ഷിക്കുക
# - **വിഭവ ഉപയോഗം**: നിരവധി സമകാലിക ഏജന്റുകളുടെ മെമ്മറി, CPU ഉപയോഗം പരിശോധിക്കുക
# - **പിശക് കൈകാര്യം**: പരലൽ പ്രവർത്തനങ്ങൾക്ക് ശക്തമായ പിഴവ് പുനരുദ്ധാരണ സംവിധാനം നടപ്പിലാക്കുക
#
# ### 🏗️ **സമകാലിക വർക്‌ഫ്ലോ നിർമ്മാണം**
#
# ```mermaid
# graph TD
#     A[പ്രവൃത്തി പ്രവാഹം ആരംഭിക്കുക] --> B[സമകാലിക നിർവ്വഹണം]
#     B --> C[ഏജന്റ് പൂൾ 1]
#     B --> D[ഏജന്റ് പൂൾ 2]
#     B --> E[ഏജന്റ് പൂർള്‍ 3]
#     C --> F[ഫലം സമാഹരണം]
#     D --> F
#     E --> F
#     F --> G[അന്തിമ ഔട്ട്‌പുട്ട്]
#
#     H[മൈക്രോസോഫ്റ്റ് ഫൗണ്ട്രി] --> C
#     H --> D
#     H --> E
# ```
#
# **പ്രധാന നേട്ടങ്ങൾ:**
# - **⚡ പ്രകടനം**: പരലൽ നിർവ്വഹണത്തിൽ ഗണനീയമായ വേഗം
# - **📈 സ്കെയിലബിലിറ്റി**: വർദ്ധിക്കുന്ന ജോലിചുമതലകൾ സമയമനുസരിച്ചുള്ള വർദ്ധനവിനു പുറത്തു കൈകാര്യം ചെയ്യുക
# - **🔄 കാര്യക്ഷമത**: ലഭ്യമായ ഗണിത വിഭവങ്ങൾ നന്നായി ഉപയോഗിക്കൽ
# - **🎯 throughput**: ഒരേ സമയത്ത് കൂടുതൽ പ്രവർത്തനം പ്രോസസ്സ് ചെയ്യുക
#
# ## 🎨 **സമകാലിക വർക്‌ഫ്ലോ ഡിസൈൻ മാതൃകകൾ**
#
# ### 🔍 **ഗവേഷണവും വിശകലനവും പൈപ്പ്‌ലൈൻ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ഡേറ്റ പ്രോസസിംഗ് വർക്‌ഫ്ലോ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ഉള്ളടക്കം സൃഷ്ടി പൈപ്പ്‌ലൈൻ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **മൾട്ടി-ഘട്ട പ്രൊസസിംഗ്**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് പ്രകടന നേട്ടങ്ങൾ**
#
# ### ⚡ **throughput മെച്ചപ്പെടുത്തൽ**
# - **പരലൽ നിർവ്വഹണം**: ഒരേ സമയം നിരവധി ഏജന്റുകൾ പ്രവർത്തിക്കുന്നത്
# - **വിഭവ ഉപയോഗം**: ലഭ്യമായ AI മോഡൽ ശേഷിയുടെ പരമാവധി കാര്യക്ഷമത
# - **സമയ ലാഭം**: മൊത്തം പ്രോസസിംഗ് സമയത്തിലെ ഗണ്യമായ ഇടിവ്
# - **സ്കെയിലബിൾ ആർക്കിടെക്ചർ**: ആവശ്യാനുസരണം കൂടുതൽ സമകാലിക ഏജന്റുകൾ ചേർക്കാം
#
# ### 🛡️ **വിശ്വാസ്യതയും പ്രതിരോധ ശേഷിയും**
# - **ഫാൾട്ട് തോലറൻസ്**: ഒരു ഏജന്റിന്റെ പരാജയം മുഴുവൻ വർക്‌ഫ്ലോയെ തടയില്ല
# - **പിശക് വേർതിരിക്കൽ**: ഒരു സമകാലിക ശാഖയിൽ പ്രശ്നം മറ്റുകളെ ബാധിക്കില്ല
# - **സൗമ്യ തകർച്ച**: ഏജന്റ് ശേഷി കുറയ്ക്കിക്കൊണ്ടും സിസ്റ്റം പ്രവർത്തി തുടരും
# - **പുനർപ്രവേശന മാർഗ്ഗങ്ങൾ**: പരാജയപ്പെട്ട പ്രവർത്തനങ്ങൾക്ക് സ്വയം വീണ്ടും ശ്രമിക്കുകയും പിഴവ് കൈകാര്യം ചെയ്യുകയും ചെയ്യുക
#
# ### 📊 **നിരീക്ഷണവും ദൃശ്യവത്കരണവും**
# - **സമകാലിക നിർവ്വഹണ ട്രാക്കിംഗ്**: എല്ലാ പരലൽ പ്രവർത്തനങ്ങളും പുരോഗതി നിരീക്ഷിക്കുക
# - **പ്രകടന മെട്രിക്‌സ്**: വേഗതയും കാര്യക്ഷമതുമെasure ചെയ്യുക
# - **വിഭവ ഉപയോഗ വിശകലനം**: സമകാലിക ഏജന്റ് വിനിയോഗം മെച്ചപ്പെടുത്തുക
# - **ബോട്ടിൽനെക്ക് തിരിച്ചറിവ്**: പ്രകടന പരിധികൾ കണ്ടെത്തുകയും പരിഹരിക്കുകയും ചെയ്യുക
#
# ഉയർന്ന പ്രകടനമുള്ള സമകാലിക AI വർക്‌ഫ്ലോകൾ ഞങ്ങൾ നിർമ്മിക്കാം! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
