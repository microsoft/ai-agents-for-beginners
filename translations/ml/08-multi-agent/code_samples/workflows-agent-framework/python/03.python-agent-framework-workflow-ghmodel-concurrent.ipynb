# %% [markdown]
# # ⚡ GitHub മോഡലുകളുമായി ഏകകാലിക ഏജന്റ് വർക്‌ഫ്ലോകൾ (Python)
#
# ## 📋 അസാധാരണ സമാന്തര പ്രോസസ്സിങ് ട്യൂട്ടോറിയൽ
#
# ഈ നോട്ട്‌ബുക്ക് Microsoft Agent Framework ഉപയോഗിച്ച് **ഏകകാലിക വർക്‌ഫ്ലോ പാറ്റേണുകൾ** പ്രദർശിപ്പിക്കുന്നു. ഒട്ടനവധി AI ഏജന്റുകൾ ഒരേസമയം പ്രവർത്തിച്ച് പ്രവർത്തനക്ഷമത തികഞ്ഞ, സമാന്തര പ്രോസസ്സിങ് വർക്‌ഫ്ലോകൾ നിർമ്മിക്കുന്നത് നിങ്ങൾക്ക് പഠിക്കാം, ഇത് ത്രൂപ്‌ട് വിപുലീകരിക്കുകയും സങ്കീർണ്ണമായ മൾട്ടി-ത്രെഡഡ് ബിസിനസ് പ്രോസസ്സുകൾ സജ്ജീകരിക്കാനും സഹായിക്കുന്നു.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🚀 **ഏകകാലിക പ്രോസസ്സിങ് അടിസ്ഥാനങ്ങൾ**
# - **സമാന്തര ഏജന്റ് പ്രവർത്തനം**: പരമാവധി കാര്യക്ഷമതയ്ക്ക് ഓജനേറെ ഏജന്റുകൾ ഒരേസമയം പ്രവർത്തിപ്പിക്കുക
# - **വർക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ**: ഡേറ്റാ സുസंരക്ഷിത ഡേറ്റ ഉറപ്പാക്കി ഏകകാലിക പ്രവർത്തനങ്ങൾ ഏകോപിപ്പിക്കുക
# - **പ്രൈവലക്ഷ മെച്ചപ്പെടുത്തൽ**: സമാന്തര പ്രോസസ്സിങുവുള്ള മികച്ച വേഗത നേടുക
# - **വിഭവവ്യവസ്ഥാപനം**: ഏകകലിക പ്രവർത്തനങ്ങളിൽ AI മോഡൽ വിഭവങ്ങൾ കാര്യക്ഷമമായി ഉപയോഗിക്കുക
#
# ### 🏗️ **അധുനിക ഏകകാലിക പാറ്റേണുകൾ**
# - **ഫോർക്ക-ജോയിൻ പ്രോസസ്സിങ്**: ജോലികൾ നിരവധി ഏജന്റുകൾക്ക് വിഭജിച്ച് ഫലങ്ങൾ സംയോജിപ്പിക്കുക
# - **പൈപ്പ്‌ലൈൻ സമാന്തരം**: തുടർച്ചയായ ത്രൂപ്‌ട് പ്ലാനുകൾക്കായി പാതിവഴികളിൽ സമാന്തര പ്രവർത്തനം
# - **ഭാരം തുല്യീകരണം**: ലഭ്യമായ ഏജന്റ് വിഭവങ്ങളിൽ മിതമായ ജോലി വിതരണം
# - **സിങ്ക്രണൈസേഷൻ പോയിന്റുകൾ**: നിർണായക വർക്‌ഫ്ലോ ഘട്ടങ്ങളിൽ ഏജന്റ് പ്രവർത്തനങ്ങൾ ഏകോപിപ്പിക്കുക
#
# ### 🏢 **എന്റർപ്രൈസ് ഏകകാലിക ആപ്ലിക്കേഷനുകൾ**
# - **ഉയർന്ന വോളിയം ഡോക്യുമെന്റ് പ്രോസസ്സിങ്**: ഒട്ടനവധി ഡോക്യുമെന്റുകൾ ഒരേയ సమయంలో പ്രോസസ്സ് ചെയ്യുക
# - **യഥാസമയം ഉള്ളടക്കം വിശകലനം**: വരവിട്ട ഡാറ്റാ സ്ട്രീമുകളുടെ ഏകകാലിക വിശകലനം
# - **ബാച്ച് പ്രോസസ്സിങ് മെച്ചപ്പെടുത്തൽ**: വലിയ തോതിലുണ്ടാകുന്ന പ്രവർത്തനങ്ങൾക്കായി പരമാവധി പ്രിവർത്തനം
# - **മൾട്ടി-മോഡൽ വിശകലനം**: വ്യത്യസ്ത ഉള്ളടക്കം തരം (ടെക്സ്റ്റ്, ചിത്രങ്ങൾ, ഡാറ്റ) സമാന്തര പ്രോസസ്സിങ്
#
# ## ⚙️ മുൻപരിചയങ്ങളും സെറ്റ്‌അപ്പും
#
# ### 📦 **ആവശ്യമായ ആശ്രിതങ്ങൾ**
#
# ഏകകാലിക വർക്‌ഫ്ലോ കഴിവുകൾ ഉള്ള Agent Framework ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub മോഡലുകൾ സജ്ജീകരണം**
#
# **പരിസ്ഥിതി ക്രമീകരണം (.env ഫയൽ):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ഏകകാലിക പ്രോസസ്സിങ് കണക്കുകൾ:**
# - **റേറ്റ് ലിമിറ്റുകൾ**: GitHub മോഡലുകളുടെ API റേറ്റ് ലിമിറ്റുകൾ ഏകകാലിക അഭ്യർത്ഥനകൾക്ക് കണ്ട് നിർത്തുക
# - **വിഭവ ഉപയോഗം**: ഒരേസമയം പ്രവർത്തിക്കുന്ന ഏജന്റുകൾക്ക് മെമ്മറി, CPU ഉപയോഗം പരിഗണിക്കുക
# - **പിശക് കൈകാര്യം**: സമാന്തര പ്രവർത്തനങ്ങൾക്ക് ദൃഢമായ പിശക് പുനരുദ്ധാരണ മികവുകൾ നടപ്പിലാക്കുക
#
# ### 🏗️ **ഏകകാലിക വർക്‌ഫ്ലോ ആർക്കിടെക്ചർ**
#
# ```mermaid
# graph TD
#     A[വർക്ക്ഫ്ലോ ആരംഭം] --> B[സമകാലിക നിർവഹണം]
#     B --> C[ഏജന്റ് പൂൾ 1]
#     B --> D[ഏജന്റ് പൂൾ 2]
#     B --> E[ഏജന്റ് പൂൾ 3]
#     C --> F[ഫലം ഏകീകരണം]
#     D --> F
#     E --> F
#     F --> G[അവസാന ഔട്ട്‌പുട്ട്]
#
#     H[ഗിറ്റ്ഹബ് മോഡൽസ് API] --> C
#     H --> D
#     H --> E
# ```
#
# **പ്രധാന നേട്ടങ്ങൾ:**
# - **⚡ പ്രകടനം**: സമാന്തര പ്രവർത്തനത്തിലൂടെ വേഗതയിൽ ലാഭം
# - **📈 സ്കേലബിൾ**: വർദ്ധിച്ച തുകൽഭാരങ്ങൾ പ്രാസംഗിക സമയവർദ്ധനയില്ലാതെ കൈകാര്യം ചെയ്യുക
# - **🔄 കാര്യക്ഷമത**: ലഭ്യമായ കംപ്യൂട്ടേഷൻ വിഭവങ്ങളുടെ മികച്ച ഉപയോഗം
# - **🎯 ത്രൂപുട്ട്**: ഒരേ സമയം കൂടുതൽ ജോലികൾ പ്രോസസ്സ് ചെയ്യുക
#
# ## 🎨 **ഏകകാലിക വർക്‌ഫ്ലോ ഡിസൈൻ പാറ്റേണുകൾ**
#
# ### 🔍 **ഗവേഷണവും വിശകലന പൈപ്പ്‌ലൈൻ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ഡാറ്റാ പ്രോസസ്സിങ് വർക്‌ഫ്ലോ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ഉള്ളടക്കം സൃഷ്ടി പൈപ്പ്‌ലൈൻ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **മൾട്ടി-ഘട്ട പ്രോസസ്സിങ്**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് പ്രകടന നേട്ടങ്ങൾ**
#
# ### ⚡ **ത്രൂപുട്ട് മെച്ചപ്പെടുത്തൽ**
# - **സമാന്തര പ്രവർത്തനം**: അനേകം ഏജന്റുകൾ ഒരേസമയം പ്രവർത്തിക്കുന്നു
# - **വിഭവ ഉപയോഗം**: ലഭ്യമായ AI മോഡൽ ശേഷിയുടെ പരമാവധി കാര്യക്ഷമത
# - **സമയം കുറവ്**: മൊത്തം പ്രോസസ്സിംഗ് സമയം ഗണ്യമായി കുറക്കുന്നു
# - **സ്കേലബിൾ ആർക്കിടെക്ചർ**: ആവശ്യമുള്ളപ്പോൾ കൂടുതൽ ഏകകാലിക ഏജന്റുകൾ ജോഡിക്കുക
#
# ### 🛡️ **വിശ്വാസ്യതയും പ്രതിരോധശേഷിയുമുള്ളതും**
# - **ദോഷ ക്ഷമത**: സ്വകാര്യ ഏജന്റ് പരാജയങ്ങൾ മുഴുവൻ വർക്‌ഫ്ലോ ഒതുക്കാറില്ല
# - **പിശക് ത്വരിതവിവരം**: ഒരു ഏകകല ശാഖയിലെ ചുരുക്കങ്ങൾ മറ്റു ശാഖകളെ ബാധിക്കാറില്ല
# - **സാന്ദ്രമായ കുറഞ്ഞ പ്രകടനം**: ഏജന്റ് ശേഷി കുറയ്ക്കപ്പെട്ടാലും സിസ്റ്റം പ്രവർത്തനക്ഷമത സൂക്ഷിക്കുന്നു
# - **പുനരുജ്ജീവന ഘടകങ്ങൾ**: പരാജയപ്പെട്ട പ്രവർത്തനങ്ങൾക്ക് സ്വയം വീണ്ടും ശ്രമിക്കുകയും പിശക് കൈകാര്യം ചെയ്യുകയും ചെയ്യുക
#
# ### 📊 **മോണിറ്ററിംഗ് & കാണൽക്ഷമത**
# - **ഏകകാലിക പ്രവർത്തനം ട്രാക്കിംഗ്**: എല്ലാ സമാന്തര പ്രവർത്തനങ്ങൾ പുരോഗതി നിരീക്ഷിക്കുക
# - **പ്രകടന മെട്രിക്‌സ്**: വേഗതയും കാര്യക്ഷമതയും അളക്കുക
# - **വിഭവ ഉപയോഗ വിശകലനം**: ഏകകാലിക ഏജന്റ് സ്ഥാനം മെച്ചപ്പെടുത്തുക
# - **ബോട്ടിൽനെക്ക് കണ്ടെത്തുക**: പ്രകടന സങ്കുചിത പ്രദേശങ്ങൾ കണ്ടെത്തി പരിഹരിക്കുക
#
# ഉയർന്ന പ്രകടനമുള്ള ഏകകാലിക AI വർക്‌ഫ്ലോകൾ നമുക്ക് നിർമ്മിക്കാം! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
