# %% [markdown]
# # 🔄 മൗലിക ഏജന്റ് വർക്ക്‌ഫ്ലോകൾ Azure OpenAI (Responses API) ഉപയോഗിച്ച് (.NET)
#
# ## 📋 വർക്ക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ ട്യൂട്ടോറിയൽ
#
# ഈ നോട്ട്ബുക്ക് മൈക്രോസോഫ്റ്റ് ഏജന്റ് ഫ്രെയിമ്വർക്കും .NET കൂടാതെ Azure OpenAI (Responses API) ഉപയോഗിച്ചും സങ്കീർണമായ **ഏജന്റ് വർക്ക്‌ഫ്ലോകൾ** എങ്ങനെ നിർമ്മിക്കാമെന്ന് കാണിക്കുന്നു. എഐ ഏജന്റുകൾ തമ്മിൽ സഹകരിച്ച് സങ്കീർണ്ണമായ ಕಾರ್ಯങ്ങൾ നടത്തിയുകൊണ്ട് ഘടനാപരമായ ഓർക്കസ്ട്രേഷൻ മാതൃകകൾ ഉപയോഗിച്ച് മൾട്ടി-സ്റ്റെപ്പ് ബിസിനസ് പ്രോസസ്സുകൾ നിങ്ങൾ പഠിക്കും.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🏗️ **വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ അടിസ്ഥാനങ്ങൾ**
# - **വർക്ക്‌ഫ്ലോ ബിൽഡർ**: സങ്കീർണ്ണമായ മൾട്ടി-സ്റ്റെപ്പ് എഐ പ്രോസസ്സുകൾ രൂപകൽപനയും ഓർക്കസ്ട്രേഷനും ചെയ്യുക
# - **ഏജന്റ് കോർഡിനേഷൻ**: വർക്ക്‌ഫ്ലോകളിൽ ഒന്നിലധികം പ്രത്യേക വകുപ്പുള്ള ഏജന്റുകൾ ഏകീകരിക്കുക
# - **Azure OpenAI (Responses API)**: വർക്ക്‌ഫ്ലോകളിൽ Azure OpenAI Responses API ഉപയോഗിക്കുക
# - **വിസ്വൽ വർക്ക്‌ഫ്ലോ ഡിസൈൻ**: വർക്ക്‌ഫ്ലോ ഘടനകൾ രൂപകൽപിക്കുകയും ദൃശ്യവത്കരിക്കുകയും ചെയ്യുക
#
# ### 🔄 **പ്രോസസ്സ് ഓർക്കസ്ട്രേഷൻ മാതൃകകൾ**
# - **ക്രമീകരിച്ച പ്രോസസ്സിംഗ്**: ലൈജിക്കൽ ഓർഡറിൽ ഒന്നിലധികം ഏജന്റ് ടാസ്ക്കുകൾ ചൈനിംഗ് ചെയ്യുക
# - **സ്റ്റേറ്റ് മാനേജ്മെന്റ്**: വർക്ക്‌ഫ്ലോ ഘട്ടങ്ങളിലൊടെ കോൺടെകസ്റ്റ്, ഡാറ്റാഫ്ലോ സംരക്ഷിക്കുക
# - **എറർ ഹാൻഡ്ലിംഗ്**: ശക്തമായ പിശകു പരിഹാരവും വർക്ക്‌ഫ്ലോ തുണുന്നതിനും വേണ്ടി പ്രയോഗിക്കുക
# - **പ്രവർത്തനക്ഷമത മെച്ചപ്പെടുത്തൽ**: എന്റർപ്രൈസ് മാപകത്വ പ്രവർത്തനങ്ങൾക്ക് കാര്യക്ഷമമായ വർക്ക്‌ഫ്ലോകൾ രൂപകൽപിക്കുക
#
# ### 🏢 **എന്റർപ്രൈസ് വർക്ക്‌ഫ്ലോ അപ്ലിക്കേഷനുകൾ**
# - **ബിസിനസ് പ്രോസസ് ഓട്ടോമേഷൻ**: സങ്കീർണ്ണസംഘടനാ വർക്ക്‌ഫ്ലോകളിൽ സ്വയമേഖല ആക്കുക
# - **കോണ്ടന്റ് പ്രൊഡക്ഷൻ പൈപ്പ്ലൈൻ**: റിവ്യൂ, അംഗീകാര ഘട്ടങ്ങളോടൊടു എഡിറ്റോറിയൽ വർക്ക്‌ഫ്ലോകൾ
# - **കസ്റ്റമർ സർവ്വീസ് ഓട്ടോമേഷൻ**: മൾട്ടി-സ്റ്റെപ്പ് ഉപഭോക്തൃ അന്വേഷണം പരിഹരിക്കൽ
# - **ഡാറ്റാ പ്രോസസ്സിംഗ് വർക്ക്‌ഫ്ലോകൾ**: എഐ-ചരിതപരമായ മാറ്റങ്ങളോടുള്ള ETL വർക്ക്‌ഫ്ലോകൾ
#
# ## ⚙️ മുൻകൂട്ടി ആവശ്യങ്ങളേയും ക്രമീകരണവും
#
# ### 📦 **ആവശ്യമായ NuGet പാക്കേജുകൾ**
#
# ഈ വർക്ക്‌ഫ്ലോ ഡെമൺസ്ട്രേഷൻ ചില പ്രധാന .NET പാക്കേജുകൾ ഉപയോഗിക്കുന്നു:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI കോൺഫിഗറേഷൻ**
#
# **പാരിസ്ഥിതിക ക്രമീകരണം (.env ഫയൽ):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI ആക്‌സസ്:**
# 1. Azure പോർട്ടലിൽ ഒരു Azure OpenAI റിസോഴ്‌സ് സൃഷ്ടിക്കുക
# 2. ഒരു മോഡൽ (ഉദാ., `gpt-5-mini`) വിവിധമാക്കി റോളിംഗ് നാവു കുറിക്കുക
# 3. `az login` ഉപയോഗിച്ച് സൈൻ ഇൻ ചെയ്ത് മുകളിൽ കാണിച്ച പാരിസ്ഥിതിക വ്യത്യാസങ്ങൾ ക്രമീകരിക്കുക
#
# ### 🏗️ **വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ അവലോകനം**
#
# ```mermaid
# graph TD
#     A[പ്രവൃത്തി പ്രവാഹ നിർമാതാവ്] --> B[ഏജന്റ് രജിസ്റ്റრი]
#     B --> C[പ്രവൃത്തി പ്രവാഹ നിർവഹണ എഞ്ചിൻ]
#     C --> D[Agent 1: ഉള്ളടക്കം ജനറേറ്റർ
#     C --> E[Agent 2: ഉള്ളടക്കം പരിശോധകൻ
#     D --> F[പ്രവൃത്തി ഫലങ്ങൾ]
#     E --> F
#     G[ആസ്യൂർ ഓപ്പൺഎഐ (ഉത്തരങ്ങൾ API)] --> D
#     G --> E
# ```
#
# **പ്രധാന ഘടകങ്ങൾ:**
# - **WorkflowBuilder**: വർക്ക്‌ഫ്ലോകളുടെ രൂപകൽപനയ്ക്കും ഓർക്കസ്ട്രേഷനുകളിലുമായി പ്രധാന എൻജിൻ
# - **AIAgent**: പ്രത്യേക കഴിവുകൾ ഉള്ള വ്യക്തിഗത പ്രത്യേക ഏജന്റുകൾ
# - **Azure OpenAI Client**: Azure OpenAI Responses API ഇൻ‌റ്റഗ്രേഷൻ
# - **Execution Context**: വർക്ക്‌ഫ്ലോ ഘട്ടങ്ങളിൽ സ്റ്റേറ്റും ഡാറ്റാഫ്ലോയും നിയന്ത്രിക്കുന്നു
#
# ## 🎨 **എന്റർപ്രൈസ് വർക്ക്‌ഫ്ലോ ഡിസൈൻ മാതൃകകൾ**
#
# ### 📝 **കോണ്ടന്റ് പ്രൊഡക്ഷൻ വർക്ക്‌ഫ്ലോ**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **ഡോക്യുമെന്റ് പ്രിസസ്സിംഗ് പൈപ്പ്ലൈൻ**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **ബിസിനസ് ഇന്റലിജൻസ് വർക്ക്‌ഫ്ലോ**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **കസ്റ്റമർ സർവ്വീസ് ഓട്ടോമേഷൻ**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് ലാഭങ്ങൾ**
#
# ### 🎯 **വിശ്വാസ്യതയും സ്കെയിലബിലിറ്റിയും**
# - **ഡിറ്റെർമിനിസ്റ്റിക് എക്സിക്യൂഷൻ**: സ്ഥിരതയുള്ള, ആവർത്തന സാധ്യതയുള്ള വർക്ക്‌ഫ്ലോ ഫലം
# - **എറർ റീക്കവറി**: വർക്ക്‌ഫ്ലോയിലെ ഏത് ഘട്ടത്തിലും പരാജയങ്ങളെ പരിഗണിച്ച് കൈകാര്യം ചെയ്യൽ
# - **പരീക്ഷണ നിരീക്ഷണം**: എക്സിക്യൂഷൻ മാർഗ്ഗങ്ങളും മെച്ചപ്പെടുത്തലിനുള്ള അവസരങ്ങളും ട്രാക്കുചെയ്യൽ
# - **റിസോഴ്‌സ് മാനേജ്മെന്റ്**: എഐ മോഡൽ വിഭവങ്ങളുടെ കാര്യക്ഷമമായ അവകാശവത്കരണം
#
# ### 🔒 **സുരക്ഷയും അനുസരണയും**
# - **സുരക്ഷിത प्रमाणीकरणം**: Microsoft Entra ID प्रमाणीकरण `az login` വഴി (AzureCliCredential)
# - **ഓഡിറ്റ് ട്രെയിലുകൾ**: വർക്ക്‌ഫ്ലോ നടത്തിപ്പ്, തീരുമാനം പോയിന്റുകൾ പൂർണ്ണമായി ലോഗ് ചെയ്യൽ
# - **ആക്സസ് നിയന്ത്രണം**: വർക്ക്‌ഫ്ലോ നടപ്പാക്കലിനും നിരീക്ഷണത്തിനും കൃത്യമായ അനുമതികൾ
# - **ഡാറ്റാ സ്വകാര്യത**: സങ്കീർണ്ണ വിവരങ്ങളുടെ സുരക്ഷിത കൈകാര്യം വർക്ക്‌ഫ്ലോയെത്രയുംതാണ്ടി
#
# ### 📊 **പ്രവേഗദൃശ്യതയും മാനേജ്മെന്റും**
# - **വിസ്വൽ വർക്ക്‌ഫ്ലോ ഡിസൈൻ**: പ്രോസസ്സ് ഫ്ലോകളുടെ വ്യക്തമായ പ്രതിനിധാനം, ആശ്രിതത്വങ്ങൾ
# - **എക്സിക്യൂഷൻ നിരീക്ഷണം**: വർക്ക്‌ഫ്ലോ പുരോഗതിയും പ്രവർത്തനക്ഷമതയും റിയൽ-ടൈം ട്രാക്കിംഗ്
# - **എറർ റിപ്പോർട്ടിംഗ്**: പിശക് വിശകലനം വിശദവിവരവും ഡീബഗ്ഗിംഗ് കഴിവുകളും
# - **പ്രവർത്തന വിശകലനങ്ങൾ**: മെച്ചപ്പെടുത്തലിന്റെയും ശേഷി പദ്ധതിയിടലിന്റെയും കണക്കുകൾ
#
# നിങ്ങളുടെ ആദ്യ എന്റർപ്രൈസ് തയ്യാറുള്ള എഐ വർക്ക്‌ഫ്ലോ നമുക്ക് നിർമ്മിക്കാം! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
