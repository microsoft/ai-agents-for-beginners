# %% [markdown]
# # ⏩ Azure OpenAI (Responses API) နှင့်အတူ တန်းစီအားနည်းမှုအေးဂျင့်လုပ်ငန်းစဉ်များ (.NET)
#
# ## 📋 အဆင့်မြင့် တန်းစီလုပ်ဆောင်ခြင်း သင်ခန်းစာ
#
# ဤ notebook သည် Microsoft Agent Framework for .NET နှင့် Azure OpenAI (Responses API) ကို အသုံးပြု၍ **တန်းစီလုပ်ငန်းစဉ် ပုံစံများ** ကို ပြသသည်။ အေးဂျင့်များသည် သတ်မှတ်ထားသော အစီအစဉ်အတိုင်း တစ်ဆင့်ချင်း ပြုလုပ်ပြီး၊ ယခင်ဆင့်ရဲ့ အဖြေများအပေါ်မှာ အလားတူ တည်ဆောက်သည့် နည်းလမ်းများကို တည်ဆောက်ပုံကို သင်ယူနိုင်ပါမည်။
#
# ## 🎯 သင်ယူရမည့် ရည်ရွယ်ချက်များ
#
# ### 🔄 **တန်းစီလုပ်ငန်းစဉ် ရုပ်ပုံဖွဲ့စည်းမှု**
# - **တန်းတူ လုပ်ငန်းစဉ်ဒီဇိုင်း**: ကျယ်ပြန့်စွာ ချိတ်ဆက်မှုများအတည်ပြု၍ တစ်ဆင့်ခြင်း ဆောင်ရွက်ခြင်းလုပ်ငန်းစဉ်များ ဖန်တီးခြင်း
# - **အခြေအနေ စီမံခန့်ခွဲမှု**: တန်းစီလုပ်ငန်းစဉ်ဆင့်ဆင့်တွင် ဆက်သွယ်မှုနှင့် ဒေတာလည်ပတ်မှု ထိန်းသိမ်းခြင်း
# - **Azure OpenAI (Responses API)**: multi-stage .NET workflow များမှာ Azure OpenAI အမျိုးအစားများကို အသုံးပြုခြင်း
# - **လုပ်ငန်းစဉ် ပစ္စည်းလုပ်ငန်းပုံစံများ**: ထုတ်လုပ်မှုပိုင်းအတွက် အသင့်ပြင်ဆင်ပြီးသော တန်းစီလုပ်ငန်းစဉ်စနစ်များတည်ဆောက်ခြင်း
#
# ### 🏗️ **အဆင့်မြင့်တန်းစီပုံစံများ**
# - **အဆင့်တိုးအတား ပေါ်တင်ခြင်း**: လုပ်ငန်းစဉ်အဆင့်များအတွင်း အတည်ပြုချက်များ ထည့်သွင်းဆောင်ရွက်ခြင်း
# - **အခြေအနေ ထိန်းသိမ်းခြင်း**: အဆင့်အားလုံးတွင် အခြေအနေနှင့် သိမြင်မှုစုဆောင်းထားမှုထိန်းသိမ်းခြင်း
# - **အမှား ပျံ့ပွားခြင်းကို စီမံခန့်ခွဲခြင်း**: တန်းစီလုပ်ငန်းစဉ်တွဲများတွင် ချို့ယွင်းမှုများကို ညှိနှိုင်းအပ်နှံခြင်း
# - **ဆောင်ရွက်မှု မြှင့်တင်ခြင်း**: အသုံးချမှုနည်းလမ်းနှင့် အမြန်ဆုံး တန်းစီအကောင်အထည်ဖော်မှု
#
# ### 🏢 **လုပ်ငန်းအတွက် တန်းစီလျှောက်လွှာများ**
# - **စာရွက်စာတမ်း ဖြစ်စဉ်တာဝန်ခွဲခြင်း**: အဆင့်ခွဲ စာရွက်စာတမ်း စိစစ်၊ ပြောင်းလဲနှင့် အတည်ပြုမှုလုပ်ငန်းစဉ်များ
# - **အရည်အသွေး အာမခံ လုပ်ငန်းစဉ်များ**: တန်းစီ ပြန်လည်စစ်ဆေးခြင်း၊ အတည်ပြုခြင်း နှင့် ခွင့်ပြုမှုလုပ်ငန်းစဉ်များ
# - **အကြောင်းအရာ ထုတ်လုပ်မှု လုပ်ငန်းစဉ်**: သုတေသန → ရေးသားခြင်း → အယ်ဒီတင်း → စစ်ဆေး → ထုတ်ဝေခြင်း
# - **စီးပွားရေးလုပ်ငန်း အလိုအလျောက်စနစ်**: အဆင့်သတ်မှတ်ချက်များ ပါဝင်သည့် စီးပွားရေးလုပ်ငန်း စနစ်များ
#
# ## ⚙️ လိုအပ်ချက်များနှင့် ပြင်ဆင်ခြင်း
#
# ### 📦 **လိုအပ်သော NuGet အထုပ်များ**
#
# .NET တန်းစီလုပ်ငန်းစဉ်များအတွက် မရှိမဖြစ် လိုအပ်သော အထုပ်များ:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
#
# <!-- Azure Identity and Async LINQ Support -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
# ```
#
# ### 🔑 **Azure OpenAI ဆက်တင်များ**
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်မှု (.env ဖိုင်):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **ဆက်တင် စီမံခန့်ခွဲမှု:**
# ```csharp
# // Load environment variables securely
# Env.Load("../../../.env");
# var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT");
# var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT");
# ```
#
# ### 🏗️ **တန်းစီလုပ်ငန်းစဉ် မျှော်မှန်းမှု**
#
# ```mermaid
# graph TD
#     A[Initial Input] --> B[Stage 1: သုံးသပ်မှု ကိုယ်စားလှယ်]
#     B --> C[စစ်ဆေးခုံ 1]
#     C --> D[Stage 2: ခရီးစဉ် ကိုယ်စားလှယ်]
#     D --> E[စစ်ဆေးခုံ 2]
#     E --> F[Stage 3: အတည်ပြုမှု ကိုယ်စားလှယ်]
#     F --> G[နောက်ဆုံး ထုတ်လွှင့်မှု]
#
#     H[အခြေအနေ ဖော်ပြချက်] --> B
#     H --> D
#     H --> F
#
#     I[Azure OpenAI (တုံ့ပြန်မှု API)] --> B
#     I --> D
#     I --> F
# ```
#
# **အဓိက ပါဝင်ပစ္စည်းများ:**
# - **တန်းစီ အေးဂျင့်များ**: တန်းစီလုပ်ငန်းအဆင့်တိုင်းအတွက် အထူးပြုအေးဂျင့်များ
# - **အခြေအနေ ပတ်ဝန်းကျင်**: အဆင့်အလိုက် စုစည်းထားသည့် ဒေတာနှင့် ဆုံးဖြတ်ချက်များ ထိန်းသိမ်းခြင်း
# - **စစ်ဆေးမှုများ**: အဆင့်အတွင်း အရည်အသွေးနှင့် တိကျမှု အာမခံရန် စစ်ဆေးရာများ
# - **Azure OpenAI Client**: လုပ်ငန်းစဉ်အဆင့်များစွာအတွင်း AI မော်ဒယ် သက်ဆိုင်သော အခြေခံဝန်ဆောင်မှုများ
#
# ## 🎨 **တန်းစီလုပ်ငန်းစဉ် ဒီဇိုင်း ပုံစံများ**
#
# ### 📝 **စာရွက်စာတမ်း ဖြစ်စဉ် တပ်ဆင်မှု**
# ```
# Raw Document → Content Extraction → Analysis → Validation → Structured Output
# ```
#
# ### 🎯 **အကြောင်းအရာ ဖန်တီးခြင်း လုပ်ငန်းစဉ်**
# ```
# Brief/Requirements → Research → Content Creation → Review → Final Polish
# ```
#
# ### 🔍 **အရည်အသွေး အာမခံ လုပ်ငန်းစဉ်**
# ```
# Initial Review → Technical Validation → Compliance Check → Final Approval
# ```
#
# ### 💼 **စီးပွားရေး ကိုယ်ပိုင်အကြံဥာဏ် လုပ်ငန်းစဉ်**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ## 🏢 **လုပ်ငန်းအတွက် တန်းစီလုပ်ငန်းစဉ် အကျိုးကျေးဇူးများ**
#
# ### 🎯 **ယုံကြည်စိတ်ချရမှုနှင့် အရည်အသွေး**
# - **သတ်မှတ်ထားသည့် လုပ်ငန်းစဉ်**: ဖွဲ့စည်းတည်ဆောက်ထား သော အဆင့်များမှတဆင့် တိကျနှင့် ထပ်မံ ပြုလုပ်နိုင်သောရလဒ်များ
# - **အရည်အသွေးအတားများ**: အဆင့်တိုင်းတွင် အရည်အသွေးကို အတည်ပြုနိုင်သော စစ်ဆေးချက်များ
# - **အမှား ခွဲခြားရေး**: တစ်ဆင့်မှ ပြဿနာများသည် နောက်ဆင့်များသို့ မပျံ့နှံ နိုင်စေရန်
# - **စာရင်းစစ် ခရီးစဉ်များ**: ဆုံးဖြတ်ချက်များနှင့် ပြောင်းလဲမှုများ အဆင့်တိုင်း မှတ်တမ်းတင်ခြင်း
#
# ### 📈 **ချဲ့ထွင်နိုင်မှုနှင့် စွမ်းဆောင်ရည်**
# - **အစိတ်အပိုင်း ဖွဲ့စည်းမှု**: အဆင့်တိုင်းကို မိမိ လိုအပ်သလို အချိန်မရွေး ပြုပြင်တိုးတက်နိုင်ခြင်း
# - **အရင်းအမြစ် စီမံခန့်ခွဲမှု**: AI မော်ဒယ် အရင်းအမြစ်များကို အဆင့်တစ်ဆင့်ချင်း လျင်မြန်စွာ ချိန်ညှိအသုံးပြုခြင်း
# - **အခြေအနေတိုးတက်မှု**: အဆင့်အလိုက် အခြေအနေများ ကို အနည်းဆုံး ပြောင်းလဲ ထည့်သွင်းခြင်းဖြင့် အကျိုးရှိမြန်ဆန်မှု
# - **အဆင့်အုပ်စုများ ထပ်တူတင်ဆောင်ခြင်း**: တန်းစီလုပ်ငန်းစဉ်များ များစွာကို ဆက်တင်၍ အတူတကွ လည်ပတ်နိုင်ခြင်း
#
# ### 🔒 **လုံခြုံရေးနှင့် လိုက်နာမှု**
# - **အဆင့်လိုက် လုံခြုံရေး**: လုပ်ငန်းစဉ်အဆင့်များအလိုက် လုံခြုံရေး မူဝါဒကွဲပြားခြားနားမှု
# - **ဒေတာ အတည်ပြုခြင်း**: စစ်ဆေးမှုတစ်ချက်ချင်းတွင် ဒေတာတိကျမှုနှင့် လိုက်နာခြင်း အာမခံခြင်း
# - **အက်ဆက် ထိန်းချုပ်မှု**: တန်းစီ လုပ်ငန်းစဉ်အဆင့် အလိုက် လိုအပ်သော ခွင့်ပြုချက်များ ထိန်းသိမ်းခြင်း
# - **ဥပဒေရေးရာ လိုက်နာမှု**: ဖွဲ့စည်းတည်ဆောက်ထားသော လုပ်ငန်းစဉ်များမှတဆင့် နိုင်ငံတော်ဥပဒေပေါ်မူတည်၍ လိုက်နာခြင်း
#
# ### 📊 **စောင့်ကြည့်မှုနှင့် ချတ်ချင်းသုံးသပ်မှု**
# - **အဆင့်အလိုက် သတ်မှတ်ချက်များ**: အဆင့်တစ်ဆင့်စီ၏ စွမ်းဆောင်ရည် စောင့်ကြည့်မှု
# - **အတားကန့် အများဆုံး ဖြတ်တောက်ခြင်း**: သွေဖင်းတာနှင့် လုပ်ငန်းအဆင်မပြေသောအဆင့်များ ရှာဖွေပြုပြင်ခြင်း
# - **အရည်အသွေး သတ်မှတ်ချက်များ**: အဆင့်တိုင်းတွင် အရည်အသွေးနှင့် အောင်မြင်မှုနှုန်းများ ထောက်လှမ်းခြင်း
# - **လုပ်ငန်းစဉ် တိုးတက်မှု**: အဆင့်အလိုက် ချတ်ချင်း သုံးသပ်မှုများ အပေါ်မူတည်ပြီး ဆက်လက် တိုးတက်အောင်လုပ်ဆောင်ခြင်း
#
# ကြံ့ခိုင်၍ တန်းစီ AI လုပ်ငန်းစဉ်များ တည်ဆောက်ကြပါစို့! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 10.*</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.*</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.*</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.*-*</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

var imgPath ="../imgs/home.png";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string SalesAgentName = "Sales-Agent";
const string SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
const string PriceAgentName = "Price-Agent";
const string PriceAgentInstructions = @"You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale.";

# %%
const string QuoteAgentName = "Quote-Agent";
const string QuoteAgentInstructions = @"You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
imageBytes
# Out:
# <div class="dni-plaintext"><pre>[ 137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 3, 142 ... (823194 more) ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
AIAgent salesagent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:SalesAgentName,instructions:SalesAgentInstructions);
AIAgent priceagent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:PriceAgentName,instructions:PriceAgentInstructions);
AIAgent quoteagent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:QuoteAgentName,instructions:QuoteAgentInstructions);

# %%
var workflow = new WorkflowBuilder(salesagent)
            .AddEdge(salesagent,priceagent)
            .AddEdge(priceagent, quoteagent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new DataContent(imageBytes, "image/png"),new TextContent("Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture.Finally Output generates a quotation") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete && executorComplete.Data is not null)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data?.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
    }
}

Console.WriteLine(messageData);
# Out:
# Here are the furniture pieces identified in the image along with estimated prices based on typical market rates for similar items. The prices may vary depending on the retailer or brand.
#
# ### Furniture Elements:
# 1. **Modern TV Console:**
#    - Description: A mid-century-style wooden TV console with ample storage and a sleek design.
#    - Estimated Price: $350
#
# 2. **Flat Screen TV (optional):**
#    - Description: A wall-mounted flat screen TV as shown.
#    - Estimated Price: $400 (optional add-on)
#
# 3. **Armchair (Blue Accent Chair):**
#    - Description: A modern navy-blue armchair with a curved back and comfortable seating.
#    - Estimated Price: $250
#
# 4. **Minimalist Coffee Table:**
#    - Description: A white, slightly oval coffee table with a wooden base for a modern look.
#    - Estimated Price: $150
#
# 5. **Neutral Fabric Sofa:**
#    - Description: A long, white upholstered sofa with cushions in varying tones of blue and gray.
#    - Estimated Price: $700
#
# ...

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
