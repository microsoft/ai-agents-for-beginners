# %% [markdown]
# # 🔄 Azure OpenAI (Responses API) နဲ့ အခြေခံ Agent အလုပ်လှုပ်ရှားမှုများ (.NET)
#
# ## 📋 အလုပ်လှုပ်ရှားမှု စီမံခန့်ခွဲခြင်း သင်ကြားမှု
#
# ဤ notebook သည် Microsoft Agent Framework for .NET နှင့် Azure OpenAI (Responses API) ကို အသုံးပြု၍ တိုးတက်သော **agent အလုပ်လှုပ်ရှားမှုများ** ဖန်တီးနည်းကို ပြသသည်။ AI agents များသည် ဖွဲ့စည်းတည်ဆောက်ပုံ မော်ဒယ်များဖြင့် ရှေ့နောက် ဆက်သွယ်၍ ရှုပ်ထွေးသော လုပ်ငန်းများကို အမြောက်အများ ပြီးမြောက်စေသည့် မျက်နှာသာ ကွဲပြားသည့် စီးပွားရေး လုပ်ငန်းစဉ်များကို ဖန်တီးသင်ယူမည်ဖြစ်သည်။
#
# ## 🎯 လေ့လာရမည့် ရည်ရွယ်ချက်များ
#
# ### 🏗️ **အလုပ်လှုပ်ရှားမှု ဖွဲ့စည်းပုံ အခြေခံများ**
# - **Workflow Builder**: ရှုပ်ထွေးသော အဆင့်များစုံပါသော AI လုပ်ငန်းစဉ်များကို ဒီဇိုင်းဆွဲခြင်းနှင့် စီမံခန့်ခွဲခြင်း
# - **Agent Coordination**: အလုပ်လှုပ်ရှားမှုများအတွင်း စွမ်းရည် အထူးပြုထားသော agent များစုပေါင်းညှိနှိုင်းခြင်း
# - **Azure OpenAI (Responses API)**: အလုပ်လှုပ်ရှားမှုများတွင် Azure OpenAI Responses API ကို အသုံးပြုခြင်း
# - **Visual Workflow Design**: အလုပ်လှုပ်ရှားမှု ဖွဲ့စည်းပုံများကို ဖန်တီးကာ မြင်တင်ပြခြင်းဖြင့် နားလည်ထားစေခြင်း
#
# ### 🔄 **လုပ်ငန်းစဉ် စီမံခန့်ခွဲမှု မော်ဒယ်များ**
# - **Sequential Processing**: အာရုံစိုက်ဖို့ အလုပ်အတန်းလိုက် agent တာဝန်များ ချိတ်ဆက်ခြင်း
# - **State Management**: အလုပ်လှုပ်ရှားမှု အဆင့်များအတွင်း အခြေအနေ နှင့် ဒေတာ လှုပ်ရှားမှုကို ထိန်းသိမ်းခြင်း
# - **Error Handling**: ပြဿနာဖြေရှင်းခြင်း နှင့် အလုပ်လှုပ်ရှားမှု ခိုင်မာမှု ဖြစ်ပေါ်စေခြင်း
# - **Performance Optimization**: စီးပွားရေးအဆင့်အတန်းအတွက် ထိရောက်ပြီး တိုးတက်သော အလုပ်လှုပ်ရှားမှုများ ဒီဇိုင်းဆွဲခြင်း
#
# ### 🏢 **စီးပွားရေး အလုပ်လှုပ်ရှားမှု ချမှတ်မှုများ**
# - **Business Process Automation**: ရှုပ်ထွေးသော စီးပွားရေးလုပ်ငန်းစဉ်များကို အလိုအလျောက်ပြုလုပ်ခြင်း
# - **Content Production Pipeline**: သုံးသပ်ခြင်းနှင့် အတည်ပြုခြင်း အဆင့်များပါတဲ့ အကြောင်းအရာ ထုတ်လုပ်မှု အလုပ်လှုပ်ရှားမှုများ
# - **Customer Service Automation**: အကြိမ်အများ ရှေ့နောက် ရှင်းလင်းဖြေရှင်းခြင်းနှင့် သုံးစွဲသူ ဝန်ဆောင်မှု အလိုအလျောက်လုပ်ငန်းစဉ်များ
# - **Data Processing Workflows**: AI ပါဝင်သော ပြောင်းလဲမှုများ ပါသော ETL အလုပ်လှုပ်ရှားမှုများ
#
# ## ⚙️ ကြိုတင်လိုအပ်ချက်များ နှင့် စတင်ပြင်ဆင်ခြင်း
#
# ### 📦 **လိုအပ်သော NuGet ပက်ကေ့ဂျ်များ**
#
# ဤ အလုပ်လှုပ်ရှားမှု ပြသမှုသည် အခြေခံ .NET ပက်ကေ့ဂျ် အချို့ကို အသုံးပြုသည်။
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.13.1" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI ပြင်ဆင်ခြင်း**
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်ခြင်း (.env ဖိုင်):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-4o-mini
# ```
#
# **Azure OpenAI အသုံးပြုခွင့်:**
# 1. Azure portal တွင် Azure OpenAI ရင်းမြစ်ကို ဖန်တီးပါ
# 2. မော်ဒယ် (ဥပမာ `gpt-4o-mini`) တစ်ခု သွင်းထည့်ပြီး deployment နာမည်ကို မှတ်ယူပါ
# 3. `az login` ဖြင့် လက်မှတ်ထိုးဝင်ပြီး ပတ်ဝန်းကျင် အပြောင်းအလဲကိစ္စများကို အထက်ပါအတိုင်း ပြင်ဆင်ပါ
#
# ### 🏗️ **အလုပ်လှုပ်ရှားမှု ဖွဲ့စည်းပုံ ခွဲခြမ်းစိတ်ဖြာခြင်း**
#
# ```mermaid
# graph TD
#     A[လုပ်ငန်းစဉ်ဆောက်လုပ်ညွှန်ကြားကိရိယာ] --> B[အေးဂျင့် မှတ်ပုံတင်စာအုပ်]
#     B --> C[လုပ်ငန်းစဉ် အကောင်အထည်ဖော်စက်]
#     C --> D[Agent 1: အကြောင်းအရာထုတ်လုပ်သူ]
#     C --> E[Agent 2: အကြောင်းအရာ စစ်ဆေးသူ]
#     D --> F[လုပ်ငန်းစဉ် ရလဒ်များ]
#     E --> F
#     G[Azure OpenAI (တုံ့ပြန်မှု API)] --> D
#     G --> E
# ```
#
# **အဓိက အစိတ်အပိုင်းများ:**
# - **WorkflowBuilder**: အလုပ်လှုပ်ရှားမှုများ ဒီဇိုင်းဆွဲခြင်းအတွက် အဓိက စီမံခန့်ခွဲသူ
# - **AIAgent**: အထူးပြု စွမ်းရည်များရှိသူ AI agent တစ်ဦးချင်း
# - **Azure OpenAI Client**: Azure OpenAI Responses API ပေါင်းစပ်မှု
# - **Execution Context**: အလုပ်လှုပ်ရှားမှု အဆင့်များအတွင်း အခြေအနေနှင့် ဒေတာလည်ပတ်မှုကို စီမံချက်တည်ဆောက်သူ
#
# ## 🎨 **စီးပွားရေးအတွက် အလုပ်လှုပ်ရှားမှု ဒီဇိုင်း မော်ဒယ်များ**
#
# ### 📝 **အကြောင်းအရာ ထုတ်လုပ်မှု အလုပ်လှုပ်ရှားမှု**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **စာရွက်စာတမ်း လုပ်ငန်းစဉ်**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **စီးပွားရေး အချက်အလက် အလုပ်လှုပ်ရှားမှု**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **ဖောက်သည် ဝန်ဆောင်မှုပြုလုပ်ခြင်း အလိုအလျောက်လုပ်ငန်း စဉ်**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **စီးပွားရေး အကျိုးအမြတ်များ**
#
# ### 🎯 **ယုံကြည်စိတ်ချမှု နှင့် တိုးချဲ့နိုင်မှု**
# - **တိတိကျကျ ဆောင်ရွက်မှု**: အလုပ်လှုပ်ရှားမှုရလဒ်များ ချိန်ညှိခြင်းမရှိပဲ တိုးတက်ပြုလုပ်ခြင်း
# - **အမှားဖြေရှင်းခြင်း**: အလုပ်လှုပ်ရှားမှု အဆင့်ရှိ ဘေးကင်းလုံခြုံစွာ အမှားများကို ပြန်လည်ကောင်းစေခြင်း
# - **စွမ်းဆောင်ရည် ထိန်းသိမ်းမှု**: ဆောင်ရွက်ချက်ကို တိုင်းတာခြင်းနှင့် တိုးတက်ရေး အခွင့်အလမ်းရှာဖွေခြင်း
# - **ရင်းနှီးမြှုပ်နှံမှု စီမံခန့်ခွဲမှု**: AI မော်ဒယ်များ၏ အရင်းအနှီးကို ထိရောက်စွာ မျှဝေခြင်းနှင့် အသုံးပြုခြင်း
#
# ### 🔒 **လုံခြုံမှု နှင့် စည်းကမ်းရှိမှု**
# - **လုံခြုံသော အသိမှတ်ပြုခြင်း**: Microsoft Entra ID လက်မှတ်ထိုး ဝင်ခြင်းဖြင့် (`az login` AzureCliCredential)
# - **စာရင်းဇယား ထားရှိခြင်း**: အလုပ်လှုပ်ရှားမှု ဆောင်ရွက်မှုနှင့် ဆုံးဖြတ်ချက်အချက်အလက်များကို စာရင်းတင်အသေးစိတ် မှတ်တမ်းတင်ခြင်း
# - **ဝင်ရောက်ခွင့် ထိန်းချုပ်မှု**: အလုပ်လှုပ်ရှားမှု ဆောင်ရွက်မှုနှင့် ကြည့်ရှုမှုအတွက် ခွင့်ပြုချက်အသေးစိတ်
# - **ဒေတာအရေးပါမှု ပုဂ္ဂိုလ်ရေးကာကွယ်မှု**: အလုပ်လှုပ်ရှားမှုများအတွင်း အရေးပါသော သတင်းအချက်အလက်ကို လုံခြုံစွာ ကိုင်တွယ်ခြင်း
#
# ### 📊 **ကြည့်ရှုနိုင်မှုနှင့် စီမံခန့်ခွဲမှု**
# - **မြင်သာသော အလုပ်လှုပ်ရှားမှု ဒီဇိုင်း**: လုပ်ငန်းစဉ်များနှင့် ဆက်သွယ်မှုများကို ရှင်းလင်းစွာ ဖော်ပြခြင်း
# - **ဆောင်ရွက်မှု ကြည့်ရှုခြင်း**: အလုပ်လှုပ်ရှားမှု တိုးတက်မှုနှင့် စွမ်းဆောင်ရည်ကို အချိန်နောက်တစ်ပြေးညီ ထိန်းသိမ်းခြင်း
# - **အမှားအစီရင်ခံခြင်း**: အသေးစိတ် အမှားစစ်ဆေးခြင်းနှင့် အသုံးပြုပုံပြန်လည် ပြင်ဆင်နိုင်မှု
# - **စွမ်းဆောင်ရည် ဆန်းစစ်သုံးသပ်မှု**: တိုးတက်မှုပြုလုပ်ခြင်းနှင့် စွမ်းဆောင်ရည်အစီအစဉ်များတွက်ချက်ခြင်း
#
# သင့် ပထမဆုံး စီးပွားရေး AI အလုပ်လှုပ်ရှားမှုကို တည်ဆောက်ကြစို့! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-4o-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Visit the Louvre Museum. It's a must-see for art enthusiasts and history lovers.That recommendation is quite popular and likely to attract many tourists. To refine it for a more local and authentic experience, consider suggesting an alternative that focuses on smaller, lesser-known art venues or galleries. Look for places where local artists exhibit or community spaces that host cultural events. This approach allows travelers to connect with the local art scene more intimately, away from the typical tourist routes.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
