# %% [markdown]
# # ⚡ Microsoft Foundry ဖြင့် အချိန်တစ်ချက်တည်းအလုပ်လုပ်နေသော Agent Workflow များ (Python)
#
# ## 📋 အဆင့်မြင့် 병렬 처리 များ သင်ခန်းစာ
#
# ဤ notebook သည် Microsoft Agent Framework ကို အသုံးပြု၍ **အချိန်တစ်ချက်တည်းအလုပ်လုပ်မည့် workflow ပုံစံများ** ကို ရှင်းပြသည်။ AI agent များစွာက တစ်ပြိုင်နက်တွင် လုပ်ဆောင်သောနှုန်းကို တိုးမြှင့်ပေးပြီး ခိုင်မာသော multi-threaded စီးပွားရေးလုပ်ငန်းစဉ်များကို ဖန်တီးနိုင်ပြီဖြစ်သည်။
#
# > **ပြောင်းရွှေ့မှုမှတ်ချက်:** ဤနမူနာသည် ယခင်က GitHub Models ကို ကိုးကားခဲ့သည်။ GitHub Models သည် ပယ်ချခံရပြီး (2026 ခုနှစ် ဇူလായ്တွင် ပယ်ချမှုဖြစ်မည်) ယခင်သုံးပြီးဖြစ်သည့်အစား Microsoft Foundry ကို `FoundryChatClient` မှတစ်ဆင့် အသုံးပြုပါသည်။ ၎င်းသည် Azure OpenAI **Responses API** ကို ရည်ညွှန်းပါသည်။
#
# ## 🎯 သင်ယူရန် ရည်မှန်းချက်များ
#
# ### 🚀 **အချိန်တစ်ချက်တည်း လုပ်ငန်းဆောင်တာအခြေခံချက်များ**
# - **မတူညီသော Agent များကို တပြိုင်နက်မှာ ဆောင်ရွက်မှု**: အကျိုးအမြတ်အများဆုံးရရှိရန် agent များကို တပြိုင်နက်တွင် တိုးမြှင့်လုပ်ဆောင်ပါ
# - **Workflow အစီအစဉ်ဆွဲခြင်း**: အချက်များ တပြိုင်နက်တွင် လုပ်ငန်းဆောင်တာများကို အချိန်မီနှင့် စည်းကမ်းပြည့်စုံစွာ စီမံဆောင်ရွက်မှု
# - **စွမ်းဆောင်ရည် မြှင့်တင်ခြင်း**: 병렬 처리 ဖြင့် အရှိန်မြှင့်ပါ
# - **အရင်းအမြစ် စီမံခန့်ခွဲမှု**: အချိန်တစ်ချက်တည်း လုပ်ငန်းဆောင်တာများအတွင်း AI model အရင်းအမြစ်များကို ထိရောက်စွာ အသုံးပြုခြင်း
#
# ### 🏗️ **အဆင့်မြင့် အချိန်တစ်ချက်တည်းပုံစံများ**
# - **Fork-Join 처리**: လုပ်ငန်းကို agent များစွာ ပြန်ခွဲပြီး ရလဒ်များကို ပေါင်းစပ်ခြင်း
# - **Pipeline 병렬 처리**: ဆက်တိုက် throughput အတွက် အဆင့်ဆင့် အလုပ်ဆောင်ခြင်း
# - **Load Balancing**: ရနိုင်သော agent အရင်းအမြစ်များအလိုက် အလုပ်များကို ကြီးကြပ်ဖြန့်ဝေခြင်း
# - **Synchronization Points**: workflow အရေးကြီးသောအဆင့်များတွင် concurrent agent များကို ညှိနှိုင်းခြင်း
#
# ### 🏢 **ကုမ္ပဏီအဆင့် အချိန်တစ်ချက်တည်း အပလီကေးရှင်းများ**
# - **အများအပြား့စာရွက်စာတမ်းကို တပြိုင်နက် ပါလုပ်ခြင်း**
# - **အချိန်နှင့်တပြေးညီ အကြောင်းအရာ စိစစ်ခြင်း**: လက်ခံသောဒေတာ စီးရီးများကို concurrent မှာ စိစစ်ခြင်း
# - **အဖွဲ့လိုက် 처리 최적화**: ကြီးမားသော စီးပွားရေးလုပ်ငန်းများအတွက် throughput ကို အများဆုံးတိုးမြှင့်ခြင်း
# - **Multi-Modal 분석**: စာသား၊ ပုံများ၊ ဒေတာ အမျိုးမျိုးကို 병렬 처리 ပြုလုပ်ခြင်း
#
# ## ⚙️ ပြင်ဆင်ရန်လိုအပ်ချက်များနှင့် စတင်ဆောင်ရွက်ခြင်း
#
# ### 📦 **လိုအပ်သော အရာများ**
#
# concurrent workflow စွမ်းရည်များပါဝင်သော Agent Framework ကို 설치ပါ:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry 設定**
#
# Azure CLI (`az login`) ဖြင့် ဝင်ရောက်ခွင့်ပြုလိုက်ပါ၊ ထို့နောက် Microsoft Foundry ပရောဂျက် အချက်အလက်များကို သတ်မှတ်ပါ။
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်ခြင်း (.env ဖိုင်):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **အချိန်တစ်ချက်တည်း 처리 တွင် သတိပြုရန်များ:**
# - **နှုန်းထားကန့်သတ်ချက်များ**: Azure OpenAI၏ concurrent တောင်းဆိုမှု rate limits ကို စောင့်ကြည့်ပါ
# - **အရင်းအမြစ် အသုံးပြုမှု**: မြောက်မြားသော concurrent agent များဖြင့် မှတ်ဉာဏ်နှင့် CPU အသုံးပြုမှုကို တွေးခေါ်ပါ
# - **အမှား စီမံခန့်ခွဲမှု**: 병렬 လုပ်ငန်းများအတွက် တော့မြန်သော အမှား ဖော်ထုတ်ခြင်းနှင့် ပြန်လည် ပြုပြင်ခြင်း ဆောင်ရွက်ပါ
#
# ### 🏗️ **concurrent workflow 아키텍처**
#
# ```mermaid
# graph TD
#     A[လုပ်ငန်းစဉ် စတင်ခြင်း] --> B[đồng thời ပြုလုပ်ခြင်း]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[ရလဒ် ထပ်မံစုစည်းခြင်း]
#     D --> F
#     E --> F
#     F --> G[အဆုံးသတ် အထွက်အနေ]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **အဓိကအကျိုးကျေးဇူးများ:**
# - **⚡ စွမ်းဆောင်ရည်**: 병렬 실행 မှတစ်ဆင့် အရှိန်မြှင့်ခြင်း
# - **📈 확장성**: အလုပ်များနည်းပညာပိုင်းတိုးတက်မှုမရှိဘဲ workload တိုးလာတာကို ကိုင်တွယ်နိုင်မည်
# - **🔄 ထိရောက်မှု**: ရနိုင်သည့် ကွန်ပျူတာအရင်းအမြစ်များကို ပိုမိုထိရောက်စွာ အသုံးချနိုင်ခြင်း
# - **🎯 처리량**: တပြိုင်နက်အလုပ်များကို ပိုမိုပြည့်စုံစွာ ဆောင်ရွက်နိုင်ခြင်း
#
# ## 🎨 **concurrent workflow ဒီဇိုင်း ပုံစံများ**
#
# ### 🔍 **သုတေသနနှင့် စိစစ်ခြင်း Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ဒေတာ 처리 workflow**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **အကြောင်းအရာ ဖန်တီးခြင်း Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **အဆင့်အတန်းများ များစွာ 처리**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ကုမ္ပဏီအဆင့် စွမ်းဆောင်ရည် အကျိုးကျေးဇူးများ**
#
# ### ⚡ **처리량 최적화**
# - **병렬 실행**: အမျိုးမျိုးသော agent များ တပြိုင်နက် မှာ လုပ်ဆောင်နေခြင်း
# - **အရင်းအမြစ် အသုံးပြုမှု**: ရနိုင်သော AI model အတောအတွင်း အများဆုံး ထိရောက်စွာ အသုံးပြု
# - **အချိန် လျှော့ချခြင်း**: စုစုပေါင်း 처리 အချိန်ကို လျှော့ချခြင်း
# - **확장 가능한 아키텍처**: လိုအပ်သလို concurrent agent များ အသစ် ထည့်သွင်းနိုင်ခြင်း
#
# ### 🛡️ **ယုံကြည်စိတ်ချရမှုနှင့် တားမြစ်နိုင်မှု**
# - **ဖောလ့်ရှားခြင်းခံနိုင်ရည်**: တစ်ဦးတည်း agent ပျက်ပြတ်မှုဖြစ်ပွားလည်း workflow အားလုံး မရပ်နားခြင်း
# - **အမှား ချက်ချင်း ကိုယ်ပိုင် ဝေးကွာခြားမှု**: concurrent branch တစ်ခုခုရှိ ပြဿနာ များထွက်ပေါက်လည်း အခြား branch များကို မထိခိုက်စေခြင်း
# - **Graceful Degradation**: agent အရင်းအမြစ် လျော့နည်းသော်လည်း စနစ် ဆက်လက် လုပ်ဆောင်ခြင်း
# - **ပြန်လည် အသက်သွင်းခြင်း နည်းလမ်းများ**: ပြတ်တောက်သော လုပ်ငန်းများအတွက် အလိုအလျောက် ထပ်မံကြိုးစားခြင်းနှင့် အမှား ကိုင်တွယ်ခြင်း
#
# ### 📊 **ကြည့်ရှု သတိထားခြင်းနှင့် မှတ်တမ်းတင်ခြင်း**
# - **concurrent 실행 လုပ်ငန်း အခြေအနေ စောင့်ကြည့်ခြင်း**: 병렬 လုပ်ငန်းအားလုံး၏ တိုးတက်မှုကို စောင့်ကြည့်ခြင်း
# - **စွမ်းဆောင်ရည် ရလဒ်များ**: အရှိန်နှုန်း တိုးတက်မှုနှင့် ထိရောက်မှု ချိန်မှတ်ခြင်း
# - **အရင်းအမြစ် အသုံးပြုမှု စာရင်းဇယား**: concurrent agent များ လိုက်ဖက်စွာ ချိန်ညှိခြင်း
# - **အနားကပ်စရာ တွေ့ရှိခြင်း**: စွမ်းဆောင်ရည် ကန့်သတ်ချက်များ ကို ရှာဖွေ ဖြေရှင်းခြင်း
#
# အလွန်မြန်နှုန်းမြင့် concurrent AI workflow များ ဖန်တီးကြပါစို့! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
