# %% [markdown]
# # ⚡ GitHub मॉडल्स के साथ समवर्ती एजेंट वर्कफ़्लोज़ (Python)
#
# ## 📋 उन्नत समानांतर प्रसंस्करण ट्यूटोरियल
#
# यह नोटबुक Microsoft Agent Framework का उपयोग करके **समवर्ती कार्यप्रवाह पैटर्न** प्रदर्शित करता है। आप सीखेंगे कि उच्च-प्रदर्शन, समानांतर प्रसंस्करण वर्कफ़्लोज़ कैसे बनाएं जहां कई AI एजेंट समानांतर रूप से निष्पादित होते हैं, इससे थ्रूपुट में नाटकीय सुधार होता है और जटिल मल्टी-थ्रेडेड बिजनेस प्रक्रियाएं संभव होती हैं।
#
# ## 🎯 सीखने के उद्देश्य
#
# ### 🚀 **समवर्ती प्रसंस्करण मूल बातें**
# - **समांतर एजेंट निष्पादन**: अधिकतम दक्षता के लिए एक साथ कई एजेंट चलाएं
# - **वर्कफ़्लो समन्वय**: डेटा स्थिरता बनाए रखते हुए समवर्ती संचालन का समन्वय करें
# - **प्रदर्शन अनुकूलन**: समांतर प्रसंस्करण के माध्यम से महत्वपूर्ण गति वृद्धि हासिल करें
# - **संसाधन प्रबंधन**: समवर्ती संचालन में AI मॉडल संसाधनों का कुशलतापूर्वक उपयोग करें
#
# ### 🏗️ **उन्नत समवर्ती पैटर्न**
# - **फोर्क-जॉइन प्रसंस्करण**: कई एजेंट्स में काम विभाजित करें और परिणामों को मर्ज करें
# - **पाइपलाइन समानांतरता**: निरंतर थ्रूपुट के लिए निष्पादन चरणों का ओवरलैपिंग
# - **लोड बैलेंसिंग**: उपलब्ध एजेंट संसाधनों में काम का समान वितरण करें
# - **सिंक पॉइंट्स**: महत्वपूर्ण वर्कफ़्लो चरणों पर समवर्ती एजेंट्स का समन्वय करें
#
# ### 🏢 **एंटरप्राइज समवर्ती अनुप्रयोग**
# - **उच्च-आयतन दस्तावेज़ प्रसंस्करण**: एक साथ कई दस्तावेज़ों को संसाधित करें
# - **रीयल-टाइम कंटेंट विश्लेषण**: आने वाले डेटा स्ट्रीम्स का समवर्ती विश्लेषण
# - **बैच प्रोसेसिंग अनुकूलन**: बड़े पैमाने पर संचालन के लिए थ्रूपुट अधिकतम करें
# - **मल्टी-मोडल विश्लेषण**: विभिन्न सामग्री प्रकारों (टेक्स्ट, इमेज, डेटा) का समानांतर प्रसंस्करण
#
# ## ⚙️ पूर्व आवश्यकताएँ और सेटअप
#
# ### 📦 **आवश्यक निर्भरताएँ**
#
# समानांतर वर्कफ़्लो क्षमताओं के साथ Agent Framework इंस्टॉल करें:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub मॉडल्स कॉन्फ़िगरेशन**
#
# **पर्यावरण सेटअप (.env फ़ाइल):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **समवर्ती प्रसंस्करण विचार:**
# - **रेट लिमिट्स**: समवर्ती अनुरोधों के लिए GitHub मॉडल्स API रेट लिमिट्स की निगरानी करें
# - **संसाधन उपयोग**: कई समवर्ती एजेंट्स के साथ मेमोरी और CPU उपयोग पर विचार करें
# - **त्रुटि हैंडलिंग**: समानांतर संचालन के लिए मजबूत त्रुटि पुनर्प्राप्ति लागू करें
#
# ### 🏗️ **समवर्ती वर्कफ़्लो वास्तुकला**
#
# ```mermaid
# graph TD
#     A[कार्यप्रवाह प्रारंभ] --> B[समानांतर निष्पादन]
#     B --> C[एजेंट पूल 1]
#     B --> D[एजेंट पूल 2]
#     B --> E[एजेंट पूल 3]
#     C --> F[परिणाम एकत्रीकरण]
#     D --> F
#     E --> F
#     F --> G[अंतिम आउटपुट]
#
#     H[GitHub मॉडल्स API] --> C
#     H --> D
#     H --> E
# ```
#
# **मुख्य लाभ:**
# - **⚡ प्रदर्शन**: समांतर निष्पादन के माध्यम से महत्वपूर्ण गति वृद्धि
# - **📈 स्केलेबिलिटी**: अनुपातिक समय वृद्धि के बिना बढ़े हुए कार्यभार को संभालें
# - **🔄 दक्षता**: उपलब्ध कम्प्यूटेशनल संसाधनों का बेहतर उपयोग
# - **🎯 थ्रूपुट**: समान समय में अधिक काम संसाधित करें
#
# ## 🎨 **समवर्ती वर्कफ़्लो डिज़ाइन पैटर्न**
#
# ### 🔍 **अनुसंधान और विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रसंस्करण वर्कफ़्लो**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री निर्माण पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **मल्टी-स्टेज प्रसंस्करण**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **एंटरप्राइज प्रदर्शन लाभ**
#
# ### ⚡ **थ्रूपुट अनुकूलन**
# - **समानांतर निष्पादन**: कई एजेंट एक साथ काम कर रहे हैं
# - **संसाधन उपयोग**: उपलब्ध AI मॉडल क्षमता का अधिकतम दक्षता से उपयोग
# - **समय में कमी**: कुल प्रसंस्करण समय में महत्वपूर्ण कमी
# - **स्केलेबल आर्किटेक्चर**: आवश्यकता अनुसार अधिक समवर्ती एजेंट जोड़ना आसान
#
# ### 🛡️ **विश्वसनीयता और लचीलापन**
# - **फ़ॉल्ट टॉलरेंस**: व्यक्तिगत एजेंट विफलताएं पूरे वर्कफ़्लो को रोकती नहीं हैं
# - **त्रुटि पृथक्करण**: एक समवर्ती शाखा में समस्याएं दूसरों को प्रभावित नहीं करतीं
# - **सुव्यवस्थित ह्रास**: एजेंट क्षमता कम होने पर भी सिस्टम चलना जारी रखता है
# - **रिकवरी मैकेनिज्म**: विफल ऑपरेशनों के लिए स्वचालित पुन: प्रयास और त्रुटि प्रबंधन
#
# ### 📊 **निगरानी और अवलोकनीयता**
# - **समवर्ती निष्पादन ट्रैकिंग**: सभी समानांतर संचालन की प्रगति की निगरानी करें
# - **प्रदर्शन मेट्रिक्स**: गति वृद्धि और दक्षता लाभ मापें
# - **संसाधन उपयोग विश्लेषण**: समवर्ती एजेंट आवंटन का अनुकूलन करें
# - **बॉटलनेक पहचान**: प्रदर्शन बाधाओं को खोजें और सुलझाएं
#
# आइए उच्च-प्रदर्शन समवर्ती AI वर्कफ़्लोज़ बनाएं! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# इस दस्तावेज़ का अनुवाद AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके किया गया है। जबकि हम सटीकता के लिए प्रयास करते हैं, कृपया ध्यान दें कि स्वचालित अनुवादों में त्रुटियाँ या अशुद्धियाँ हो सकती हैं। मूल दस्तावेज़ अपनी मूल भाषा में ही प्रामाणिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए, पेशेवर मानव अनुवाद की सिफारिश की जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफहमी या गलत व्याख्या के लिए हम उत्तरदायी नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
