# %% [markdown]
# # ⚡ Ροές Εργασίας Συγχρόνων Πρακτόρων με Μοντέλα GitHub (Python)
#
# ## 📋 Εκτεταμένο Σεμινάριο Παράλληλης Επεξεργασίας
#
# Αυτό το σημειωματάριο παρουσιάζει **πρότυπα συγχρόνων ροών εργασίας** χρησιμοποιώντας το Microsoft Agent Framework. Θα μάθετε πώς να δημιουργείτε ροές εργασίας υψηλής απόδοσης με παράλληλη επεξεργασία όπου πολλοί πράκτορες AI εκτελούνται ταυτόχρονα, βελτιώνοντας δραστικά τη ροή και επιτρέποντας εξελιγμένες πολυνηματικές επιχειρησιακές διαδικασίες.
#
# ## 🎯 Μαθησιακοί Στόχοι
#
# ### 🚀 **Βασικά Στοιχεία Παράλληλης Επεξεργασίας**
# - **Παράλληλη Εκτέλεση Πρακτόρων**: Εκτέλεση πολλών πρακτόρων ταυτόχρονα για μέγιστη αποδοτικότητα
# - **Ορχήστρωση Ροής Εργασίας**: Συντονισμός συγχρόνων λειτουργιών διατηρώντας την συνέπεια των δεδομένων
# - **Βελτιστοποίηση Απόδοσης**: Επίτευξη σημαντικής επιτάχυνσης μέσω παράλληλης επεξεργασίας
# - **Διαχείριση Πόρων**: Αποδοτική χρήση των πόρων των μοντέλων AI σε συγχρόνες λειτουργίες
#
# ### 🏗️ **Προχωρημένα Πρότυπα Σύγχρονης Εκτέλεσης**
# - **Fork-Join Επεξεργασία**: Διαχωρισμός εργασίας σε πολλούς πράκτορες και συγχώνευση αποτελεσμάτων
# - **Παράλληλη Διαδικασία Πλαισίου**: Επικάλυψη σταδίων εκτέλεσης για συνεχή ροή
# - **Ισορροπία Φόρτου**: Ομοιόμορφη κατανομή εργασίας στους διαθέσιμους πόρους πρακτόρων
# - **Σημεία Συγχρονισμού**: Συντονισμός συγχρόνων πρακτόρων σε κρίσιμα στάδια ροής εργασίας
#
# ### 🏢 **Επιχειρησιακές Εφαρμογές Συγχρόνου Χρόνου**
# - **Επεξεργασία Μεγάλου Όγκου Εγγράφων**: Επεξεργασία πολλών εγγράφων ταυτόχρονα
# - **Ανάλυση Περιεχομένου σε Πραγματικό Χρόνο**: Σύγχρονη ανάλυση εισερχόμενων ροών δεδομένων
# - **Βελτιστοποίηση Παρτίδων Επεξεργασίας**: Μέγιστη απόδοση για μεγάλου όγκου λειτουργίες
# - **Πολυμορφική Ανάλυση**: Παράλληλη επεξεργασία διαφορετικών τύπων περιεχομένου (κείμενο, εικόνες, δεδομένα)
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# ### 📦 **Απαιτούμενες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες συγχρόνης ροής εργασίας:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Ρύθμιση Μοντέλων GitHub**
#
# **Ρύθμιση Περιβάλλοντος (.env αρχείο):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Θέματα που αφορούν την Παράλληλη Επεξεργασία:**
# - **Όρια Ρυθμού**: Παρακολούθηση ορίων ρυθμού API των GitHub Models για συγχρόνες αιτήσεις
# - **Χρήση Πόρων**: Λήψη υπόψη της χρήσης μνήμης και CPU με πολλούς παράλληλους πράκτορες
# - **Διαχείριση Σφαλμάτων**: Υλοποίηση στιβαρής ανάκτησης σφαλμάτων για παράλληλες λειτουργίες
#
# ### 🏗️ **Αρχιτεκτονική Συγχρόνου Ροής Εργασίας**
#
# ```mermaid
# graph TD
#     A[Έναρξη Ροής Εργασίας] --> B[Ταυτόχρονη Εκτέλεση]
#     B --> C[Πισίνα Πρακτόρων 1]
#     B --> D[Πισίνα Πρακτόρων 2]
#     B --> E[Πισίνα Πρακτόρων 3]
#     C --> F[Συγκέντρωση Αποτελεσμάτων]
#     D --> F
#     E --> F
#     F --> G[Τελική Έξοδος]
#
#     H[API Μοντέλων GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **Κύρια Οφέλη:**
# - **⚡ Απόδοση**: Σημαντική επιτάχυνση μέσω παράλληλης εκτέλεσης
# - **📈 Επεκτασιμότητα**: Αντιμετώπιση αυξημένου φόρτου χωρίς ανάλογη αύξηση χρόνου
# - **🔄 Αποδοτικότητα**: Καλύτερη αξιοποίηση διαθέσιμων υπολογιστικών πόρων
# - **🎯 Ροή Δουλειάς**: Επεξεργασία περισσότερης εργασίας στον ίδιο χρόνο
#
# ## 🎨 **Πρότυπα Σχεδίασης Συγχρόνων Ροών Εργασίας**
#
# ### 🔍 **Διαδικασία Έρευνας & Ανάλυσης**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Ροή Επεξεργασίας Δεδομένων**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Διαδικασία Δημιουργίας Περιεχομένου**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Πολυσταδιακή Επεξεργασία**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Επιχειρησιακά Οφέλη Απόδοσης**
#
# ### ⚡ **Βελτιστοποίηση Ροής**
# - **Παράλληλη Εκτέλεση**: Πολλοί πράκτορες που εργάζονται ταυτόχρονα
# - **Αξιοποίηση Πόρων**: Μέγιστη αποδοτικότητα διαθέσιμης χωρητικότητας μοντέλων AI
# - **Μείωση Χρόνου**: Σημαντική μείωση συνολικού χρόνου επεξεργασίας
# - **Επεκτάσιμη Αρχιτεκτονική**: Εύκολη προσθήκη περισσότερων παράλληλων πρακτόρων όποτε χρειάζεται
#
# ### 🛡️ **Αξιοπιστία & Ανθεκτικότητα**
# - **Ανοχή Σφαλμάτων**: Οι αποτυχίες μεμονωμένων πρακτόρων δεν σταματούν ολόκληρη τη ροή εργασίας
# - **Απομόνωση Σφαλμάτων**: Τα προβλήματα σε ένα συγχρόνως κλαδί δεν επηρεάζουν τα υπόλοιπα
# - **Ομαλή Υποβάθμιση**: Το σύστημα συνεχίζει να λειτουργεί ακόμη και με μειωμένη χωρητικότητα πρακτόρων
# - **Μηχανισμοί Ανάκτησης**: Αυτόματη επανεκκίνηση και διαχείριση σφαλμάτων για αποτυχημένες λειτουργίες
#
# ### 📊 **Παρακολούθηση & Επισκοπία**
# - **Παρακολούθηση Παράλληλης Εκτέλεσης**: Παρακολουθήστε την πρόοδο όλων των παράλληλων λειτουργιών
# - **Μετρικές Απόδοσης**: Μέτρηση επιτάχυνσης και κερδών αποδοτικότητας
# - **Αναλύσεις Χρήσης Πόρων**: Βελτιστοποίηση κατανομής παράλληλων πρακτόρων
# - **Εντοπισμός Φραγμών**: Εύρεση και επίλυση περιορισμών απόδοσης
#
# Ας δημιουργήσουμε ροές εργασίας AI υψηλής απόδοσης με συγχρονισμό! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Αποποίηση ευθυνών**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
