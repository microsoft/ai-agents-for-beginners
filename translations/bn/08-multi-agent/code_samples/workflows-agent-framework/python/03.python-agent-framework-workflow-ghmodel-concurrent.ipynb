# %% [markdown]
# # ⚡ GitHub মডেলের সাথে সমান্তরাল এজেন্ট ওয়ার্কফ্লো (পাইথন)
#
# ## 📋 উন্নত সমান্তরাল প্রক্রিয়াকরণ টিউটোরিয়াল
#
# এই নোটবুকটি Microsoft Agent Framework ব্যবহার করে **সমান্তরাল ওয়ার্কফ্লো প্যাটার্ন** প্রদর্শন করে। আপনি শিখবেন কীভাবে উচ্চ কার্যক্ষমতা সম্পন্ন, সমান্তরাল প্রক্রিয়াকরণ ওয়ার্কফ্লো তৈরি করতে হয় যেখানে একাধিক AI এজেন্ট সমান্তরালে কাজ করে, যা বিপুল পরিমাণ প্রক্রিয়াকরণ ক্ষমতা বৃদ্ধি করে এবং জটিল মাল্টি-থ্রেডেড ব্যবসায়িক প্রক্রিয়া সক্ষম করে।
#
# ## 🎯 শেখার উদ্দেশ্য
#
# ### 🚀 **সমান্তরাল প্রক্রিয়াকরণের মৌলিক বিষয়াবলী**
# - **সমান্তরাল এজেন্ট কার্যক্রম**: সর্বোচ্চ দক্ষতার জন্য একাধিক এজেন্ট একযোগে চালান
# - **ওয়ার্কফ্লো সমন্বয়**: ডেটা সামঞ্জস্য বজায় রেখে সমান্তরাল অপারেশন সমন্বয় করুন
# - **কর্মদক্ষতা উন্নতি**: সমান্তরাল প্রক্রিয়াকরণের মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি অর্জন করুন
# - **রিসোর্স ব্যবস্থাপনা**: সমান্তরাল অপারেশন জুড়ে AI মডেল রিসোর্স দক্ষতার সঙ্গে ব্যবহার করুন
#
# ### 🏗️ **উন্নত সমান্তরাল প্যাটার্ন**
# - **ফর্ক-জয়েন প্রক্রিয়াকরণ**: একাধিক এজেন্টের মধ্যে কাজ ভাগ করুন এবং ফলাফল একত্রিত করুন
# - **পাইপলাইন সমান্তরালতা**: ধারাবাহিক প্রক্রিয়াকরণের জন্য একাধিক ধাপ একত্রে চালান
# - **লোড ব্যালান্সিং**: উপলব্ধ এজেন্ট রিসোর্সের মধ্যে কাজ সমানভাবে বন্টন করুন
# - **সমন্বয় পয়েন্ট**: গুরুত্বপূর্ণ ওয়ার্কফ্লো ধাপে সমান্তরাল এজেন্টদের সমন্বয় করুন
#
# ### 🏢 **এন্টারপ্রাইজ সমান্তরাল অ্যাপ্লিকেশন**
# - **উচ্চ-পরিমাণ নথি প্রক্রিয়াকরণ**: একাধিক নথি একযোগে প্রক্রিয়াকরণ করুন
# - **রিয়েল-টাইম বিষয় বিশ্লেষণ**: আসন্ন ডেটা স্ট্রিমের সমান্তরাল বিশ্লেষণ
# - **ব্যাচ প্রক্রিয়াকরণ উন্নতি**: বৃহৎ পরিসরের অপারেশনের জন্য অধিক গতি নিশ্চিত করুন
# - **মাল্টি-মোডাল বিশ্লেষণ**: বিভিন্ন ধরনের বিষয়বস্তু (টেক্সট, ছবি, ডেটা) সমান্তরালে প্রক্রিয়াকরণ করুন
#
# ## ⚙️ পূর্বশর্ত ও সেটআপ
#
# ### 📦 **প্রয়োজনীয় ডিপেন্ডেন্সি**
#
# সমান্তরাল ওয়ার্কফ্লো সক্ষমতা সহ Agent Framework ইনস্টল করুন:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub মডেল কনফিগারেশন**
#
# **পরিবেশ সেটআপ (.env ফাইল):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **সমান্তরাল প্রক্রিয়াকরণ বিবেচনা:**
# - **হার লিমিট**: সমান্তরাল অনুরোধের জন্য GitHub মডেলের API হার লিমিট পর্যবেক্ষণ করুন
# - **রিসোর্স ব্যবহারের বিষয়**: একাধিক সমান্তরাল এজেন্টের সঙ্গে মেমরি ও CPU ব্যবহারের হিসাব রাখুন
# - **ত্রুটি হ্যান্ডলিং**: সমান্তরাল অপারেশনের জন্য দৃঢ় ত্রুটি পুনরুদ্ধার প্রয়োগ করুন
#
# ### 🏗️ **সমান্তরাল ওয়ার্কফ্লো আর্কিটেকচার**
#
# ```mermaid
# graph TD
#     A[ওয়ার্কফ্লো শুরু] --> B[সমান্তরাল সম্পাদন]
#     B --> C[এজেন্ট পুল ১]
#     B --> D[এজেন্ট পুল ২]
#     B --> E[এজেন্ট পুল ৩]
#     C --> F[ফলাফল সম্মিলন]
#     D --> F
#     E --> F
#     F --> G[ফাইনাল আউটপুট]
#
#     H[GitHub মডেলস API] --> C
#     H --> D
#     H --> E
# ```
#
# **মূল সুবিধাসমূহ:**
# - **⚡ কর্মক্ষমতা**: সমান্তরাল কার্যক্রমের মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি
# - **📈 পরিসর বৃদ্ধি**: বেশি কাজের চাপ সামলাতে পারে সময় বৃদ্ধি ছাড়াই
# - **🔄 দক্ষতা**: উপলব্ধ কম্পিউটেশনাল রিসোর্স কুশলতা বৃদ্ধি
# - **🎯 কার্যক্ষমতা**: একই সময়ে অধিক কাজ সম্পাদন
#
# ## 🎨 **সমান্তরাল ওয়ার্কফ্লো ডিজাইন প্যাটার্ন**
#
# ### 🔍 **গবেষণা ও বিশ্লেষণ পাইপলাইন**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ডেটা প্রক্রিয়াকরণ ওয়ার্কফ্লো**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **বিষয়বস্তু নির্মাণ পাইপলাইন**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **মাল্টি-স্টেজ প্রক্রিয়াকরণ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **এন্টারপ্রাইজ কর্মক্ষমতা সুবিধা**
#
# ### ⚡ **পরিবহন অনুকূলন**
# - **সমান্তরাল কার্যক্রম**: একাধিক এজেন্ট একযোগে কাজ করছে
# - **রিসোর্স ব্যবহার**: উপলব্ধ AI মডেল ক্ষমতার সর্বোচ্চ ব্যবহার
# - **সময় সাশ্রয়**: মোট প্রক্রিয়াকরণের সময় উল্লেখযোগ্য হ্রাস
# - **পরিসর বৃদ্ধি আর্কিটেকচার**: প্রয়োজনে সহজেই আরও সমান্তরাল এজেন্ট যোগ করতে পারেন
#
# ### 🛡️ **বিড়ম্বনা প্রতিরোধ ও স্থিতিশীলতা**
# - **ত্রুটি সহনশীলতা**: পৃথক এজেন্টের ব্যর্থতা সম্পূর্ণ ওয়ার্কফ্লো বন্ধ করে না
# - **ত্রুটি পৃথকীকরণ**: একটি সমান্তরাল শাখার সমস্যা অন্যগুলোকে প্রভাবিত করে না
# - **সুন্দর ক্ষয়**: সীমিত এজেন্ট ক্ষমতা থাকার পরেও সিস্টেম চালু থাকে
# - **পুনরুদ্ধার পদ্ধতি**: ব্যর্থ অপারেশনের জন্য স্বয়ংক্রিয় পুনরায় চেষ্টা ও ত্রুটি হ্যান্ডলিং
#
# ### 📊 **নিয়ন্ত্রণ ও পর্যবেক্ষণ**
# - **সমান্তরাল কার্যক্রম ট্র্যাকিং**: সব সমান্তরাল অপারেশনের অগ্রগতি পর্যবেক্ষণ
# - **কর্মক্ষমতা পরিমাপক**: গতি এবং দক্ষতা লাভ পরিমাপ করুন
# - **রিসোর্স ব্যবহারের বিশ্লেষণ**: সমান্তরাল এজেন্ট বরাদ্দ অনুকূলন করুন
# - **বাধা সনাক্তকরণ**: কর্মক্ষমতা সীমাবদ্ধতা চিহ্নিত ও সমাধান করুন
#
# উচ্চ কর্মক্ষমতা সম্পন্ন সমান্তরাল AI ওয়ার্কফ্লো তৈরি করা যাক! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **অস্বীকৃতি**:
# এই নথিটি AI অনুবাদ পরিষেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনূদিত হয়েছে। যদিও আমরা শুদ্ধতার জন্য চেষ্টা করি, অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা অসঙ্গতি থাকতে পারে। মূল নথিটি তার স্বভাষায় কর্তৃত্বপূর্ণ উৎস হিসেবে বিবেচিত হওয়া উচিত। গুরুত্বপূর্ণ তথ্যের জন্য পেশাদার মানব অনুবাদ সুপারিশ করা হয়। এই অনুবাদের ব্যবহারে প্রয়োজনীয় ভুল বোঝাবুঝি বা ভুল ব্যাখ্যার জন্য আমরা দায়বদ্ধ নই।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
