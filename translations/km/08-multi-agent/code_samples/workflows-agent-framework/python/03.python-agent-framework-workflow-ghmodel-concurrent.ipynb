# %% [markdown]
# # ⚡ សកម្មភាពអ្នកតំណាងសហគ្រិនជាមួយ Microsoft Foundry (Python)
#
# ## 📋 មេរៀនដំណើរការជាក់លាក់មុខងារឆ្លើយតប
#
# សៀវភៅកំណត់នេះបង្ហាញពី **រៀបចំបែបសកម្មភាពសហគ្រិន** ដោយប្រើ Microsoft Agent Framework។ អ្នកនឹងរៀនពីរបៀបបង្កើតសកម្មភាពដំណើរការដែលមានសមត្ថភាពខ្ពស់ និងសកម្មភាពដំណើរការសហគ្រិនដែលមានអ្នកតំណាង AI ជាច្រើនដំណើរការចេញទៅញឹកញាប់ក្នុងពេលតែមួយ ដែលធ្វើឲ្យកំណត់កម្រិតការចេញលទ្ធផលរហ័ស និងអនុញ្ញាតឲ្យមានដំណើរការអាជីវកម្មដែលមានច្រើនខ្សែខ្សែក្នុងរបៀបវេទិកាសំបូរបែប។
#
# > **កំណត់សម្គាល់បម្លាស់ប្តូរ:** ឧទាហរណ៍នេះបានយោងដល់ GitHub Models មុននេះ។ GitHub Models ត្រូវបានបំបាត់ (នឹងផុតកំណត់នៅខែ​កក្កដា ឆ្នាំ ២០២៦) ដូច្នេះឥឡូវនេះវាប្រើប្រាស់ **Microsoft Foundry** តាមរយៈ `FoundryChatClient` ដែលមានគោលដៅទៅលើ Azure OpenAI **Responses API**។
#
# ## 🎯 គោលបំណងរៀន
#
# ### 🚀 **មូលដ្ឋាននៃការចេញដំណើរការសហគ្រិន**
# - **ការដំណើរការអ្នកតំណាងជាមួយគ្នា**: ដំណើរការអ្នកតំណាងជាច្រើននៅពេលតែមួយសម្រាប់ប្រសិទ្ធភាពខ្ពស់បំផុត
# - **ការគ្រប់គ្រងសកម្មភាព**: ផ្គូផ្គងប្រតិបត្ដិការសហគ្រិន ខណៈរក្សាភាពស្របគ្នានៃទិន្នន័យ
# - **បច្ចុប្បន្នភាពកម្រិតប្រសិទ្ធភាព**: ទទួលបានល្បឿនលឿនតាមរយៈការចេញដំណើរការសហគ្រិន
# - **ការគ្រប់គ្រងធនធាន**: ប្រើប្រាស់ធនធានម៉ូដែល AI ប្រកបដោយប្រសិទ្ធភាពក្នុងសកម្មភាពសហគ្រិន
#
# ### 🏗️ **បែបបទសហគ្រិនជាក់លាក់++
# - **ដំណើរការបំបែក-បង្រួម**: បំបែកការងារទៅជាអ្នកតំណាងជាច្រើន ហើយបង្រួមលទ្ធផលឡើងវិញ
# - **លំហូរលើកដំណើរការ**: ដំណើរការសម្របសម្រួលជាមួយគ្នាទៅលើជំហានដំណើរការដែលរួមសម្រប
# - **សមតុល្យបំណងម៉ាស្សា**: ចែកចាយការងារឱ្យសមរម្យនៅលើធនធានអ្នកតំណាងដែលអាចប្រើបាន
# - **ចំណុចសម្របសម្រួល**: ផ្គូផ្គងអ្នកតំណាងសហគ្រិនក្នុងជំហានវិញ្ញាសាសកម្មភាពសំខាន់ៗ
#
# ### 🏢 **កម្មវិធីសហគ្រិនសម្រាប់សហគ្រាស**
# - **ដំណើរការឯកសារច្រើនជាងមួយ**: ដំណើរការឯកសារជាច្រើននៅពេលតែមួយ
# - **វិភាគមាតិកាវិលត្រឡប់ពេលវេលាពិតប្រាកដ**: វិភាគសហគ្រិននៃប្រភពទិន្នន័យចូល
# - **បច្ចុប្បន្នភាពការដំណើរការដុំ**: ផ្តល់សមត្ថភាពបំផុតសម្រាប់សកម្មភាពដែលមានទំហំធំ
# - **វិភាគផ្លូវច្រើនម៉ូដ**: ដំណើរការសហគ្រិនចំពោះប្រភេទមាតិកាផ្សេងៗ (អត្ថបទ រូបភាព ទិន្នន័យ)
#
# ## ⚙️ លក្ខខ័ណ្ឌ និង ការរៀបចំ
#
# ### 📦 **ការពឹងផ្អែកដែលត្រូវការ**
#
# ដំឡើង Agent Framework មានសមត្ថភាពធ្វើ workflow សហគ្រិន:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **ការកំណត់ Microsoft Foundry**
#
# ចូលប្រើដោយ Azure CLI (`az login`) ដើម្បីឲ្យ `AzureCliCredential` អាចធ្វើការផ្ទៀងផ្ទាត់ ហើយបន្ទាប់មកកំណត់ព័ត៌មានគម្រោង Microsoft Foundry របស់អ្នក។
#
# **ការរៀបចំបរិយាកាស (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **ការពិចារណាការដំណើរការសហគ្រិន:**
# - **កំណត់អតិបរិមាបណ្តាល**: ត្រួតពិនិត្យកំណត់អតិបរិមា Azure OpenAI សម្រាប់សំណើសម្រួល
# - **ការប្រើប្រាស់ធនធាន**: ពិចារណាអំពីការប្រើប្រាស់ចងចាំ និង CPU ជាមួយអ្នកតំណាងសហគ្រិនជាច្រើន
# - **ការគ្រប់គ្រងកំហុស**: អនុវត្តការថែមទៀតការជួសជុលកំហុសដ៏រឹងមាំសម្រាប់ការប្រតិបត្ដិការជាមួយគ្នា
#
# ### 🏗️ **រចនាសម្ព័ន្ធសកម្មភាពសហគ្រិន**
#
# ```mermaid
# graph TD
#     A[ចាប់ផ្តើមកិច្ចប្រតិបត្តិការ] --> B[ប្រតិបត្តិការដោយសកម្មភាពជាសម័យ]
#     B --> C[បាកូលតំណាង 1]
#     B --> D[បាកូលតំណាង 2]
#     B --> E[បាកូលតំណាង 3]
#     C --> F[ការប្រមូលផលលទ្ធផល]
#     D --> F
#     E --> F
#     F --> G[លទ្ធផលចុងក្រោយ]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **អត្ថប្រយោជន៍សំខាន់ៗ:**
# - **⚡ ប្រសិទ្ធភាព**: ល្បឿនលឿនយ៉ាងគម្របតាមការចេញដំណើរការជាមួយគ្នា
# - **📈 សមត្ថភាព**: គ្រប់គ្រងទំនើបភាពការងារកើនឡើងដោយគ្មានការកើនឡើងពេលវេលាឲ្យសមមា
# - **🔄 ប្រសិទ្ធភាព**: ប្រើប្រាស់ធនធានគណនា ដែលមានស្រាប់ល្អប្រសើរជាងមុន
# - **🎯 ការចេញលទ្ធផល**: ដំណើរការការងារច្រើនជាងមុនក្នុងពេលវេលាដូចគ្នា
#
# ## 🎨 **បែបបទរចនាសម្ព័ន្ធសកម្មភាពសហគ្រិន**
#
# ### 🔍 **បំពង់ស្រាវជ្រាវ និងវិភាគ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **សកម្មភាពដំណើរការទិន្នន័យ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **បំពង់បង្កប់មាតិកា**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ដំណើរការជាច្រើនជំហាន**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍ប្រសិទ្ធិភាពសហគ្រាស**
#
# ### ⚡ **បង្កើនការចេញលទ្ធផល**
# - **ការចេញដំណើរការជាមួយគ្នា**: អ្នកតំណាងជាច្រើនដែលដំណើរការជាមួយគ្នា
# - **ការប្រើប្រាស់ធនធាន**: ប្រសិទ្ធភាពខ្ពស់បំផុតនៃសមត្ថភាពម៉ូដែល AI ដែលអាចប្រើបាន
# - **ការកាត់បន្ថយពេលវេលា**: ការកាត់បន្ថយយ៉ាងខ្លាំងនៅពេលវេលាដំណើរការទាំងមូល
# - **រចនាសម្ព័ន្ធដែលអាចបង្កើនបាន**: ងាយស្រួលបន្ថែមអ្នកតំណាងសហគ្រិនជាបន្ថែមតាមតម្រូវការ
#
# ### 🛡️ **ភាពរឹងមាំ និងភាពរឹងប៉ីប៉ាញ់**
# - **ការអត្រាកំហុស**: កំហុសអ្នកតំណាងវាយតម្លៃមិនបញ្ឈប់សកម្មភាពទាំងមូល
# - **ការចៀសវាងកំហុស**: ប្រសិនបើមានបញ្ហាតែមួយសាខាសហគ្រិនមិនមានផលប៉ះពាល់ដល់ផ្សេងទៀត
# - **ការថយចុះយ៉ាងសមរម្យ**: ប្រព័ន្ធនៅតែដំណើរការបានបើទោះជាមានការកាត់បន្ថយសមត្ថភាពអ្នកតំណាង
# - **មេកានីចរក្សាថែទាំ**: ការថតបម្លែងឡើងវិញដោយស្វ័យប្រវត្តិ និងការគ្រប់គ្រងកំហុសសម្រាប់ប្រតិបតិ្តការដែលបរាជ័យ
#
# ### 📊 **ការតាមដាន និងការដឹងទាន**
# - **ការតាមដានការចេញដំណើរការសហគ្រិន**: តាមដានវឌ្ឍនភាពនៃប្រតិបតិ្តការជាមួយគ្នាទាំងអស់
# - **វិមាត្រប្រសិទ្ធភាព**: វាស់ល្បឿន និងការបង្កើនប្រសិទ្ធភាព
# - **វិភាគការប្រើប្រាស់ធនធាន**: បង្កើតសមត្ថភាពកំណត់អ្នកតំណាងសហគ្រិនឲ្យល្អបំផុត
# - **កំណត់ចំណុចនៅខ្វះប្រសិទ្ធភាព**: ស្វែងរក និងដោះស្រាយកំណត់ខ្វះប្រសិទ្ធភាព
#
# ចាប់ផ្តើមបង្កើតសកម្មភាព AI សហគ្រិនដែលមានប្រសិទ្ធភាពខ្ពស់! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
