# %% [markdown]
# # ⚡ ការដំណើរការតាមលំនាំរបស់ភ្នាក់ងារដោយសម័យជាមួយម៉ូឌែល GitHub (Python)
#
# ## 📋 មេរៀនបច្ចេកទេសដំណើរការជាលំនាំសម័យ
#
# កំណត់ត្រានេះបង្ហាញពី **លំនាំដំណើរការជាលំនាំសម័យ** ដោយប្រើ Microsoft Agent Framework។ អ្នកនឹងរៀនរបៀបបង្កើតលំនាំដំណើរការនូវការដំណើរការជាលំនាំសម័យដែលភ្នាក់ងារពហុ AI ច្រើនអាចដំណើរការដោយសម័យជាមួយគ្នា ជួយបង្កើនថាមពលបំផុត និងអនុញ្ញាតឱ្យមានដំណើរការអាជីវកម្មច្រើនស្រទាប់ដែលមានស្មុគស្មាញ។
#
# ## 🎯 គោលបំណងការរៀន
#
# ### 🚀 **មូលដ្ឋានដំណើរការជាលំនាំសម័យ**
# - **ការដំណើរការភ្នាក់ងារពហុជាលំនាំសម័យ**: បើកដំណើរការភ្នាក់ងារជាច្រើនក្នុងពេលដដែលសម្រាប់ប្រសិទ្ធភាពអតិបរមា
# - **ការត្រួតត្រាលំនាំដំណើរ**: ធ្វើបច្ចុប្បន្នភាពសម័យនៃដំណើរការអែ្សរ៉េតិងត្រួតកំណត់នៃទិន្នន័យ
# - **ការបង្កើនប្រសិទ្ធភាព**: សម្តែងល្បឿនបានយ៉ាងសំខាន់តាមរយៈការដំណើរការជាលំនាំសម័យ
# - **ការគ្រប់គ្រងធនធាន**: ប្រើប្រាស់ធនធានម៉ូឌែល AI ដោយប្រសិទ្ធភាពលើប្រតិបត្តិការជាលំនាំសម័យ
#
# ### 🏗️ **លំនាំដំណើរការជាលំនាំសម័យកម្រិតខ្ពស់**
# - **ការកំណែក-បញ្ចូល**: បំបែកការងារតាមភ្នាក់ងារពហុ និងបញ្ចូលលទ្ធផល
# - **លំនាំបញ្ជូនជាលំនាំសម័យ**: ដំណើរការផ្នែកផ្សើរផ្សើយគ្នាដើម្បីបន្តការចេញផលិតភាព
# - **ការបែងចែកបន្ទុក**: ចែករំលែកការងារឲ្យស្មើៗគ្នាតាមធនធានភ្នាក់ងារ
# - **ចំណុចសម័យ**: ត្រួតត្រាភ្នាក់ងារជាលំនាំសម័យនៅគន្លងសំខាន់នៃលំនាំដំណើរ
#
# ### 🏢 **កម្មវិធីជាលំនាំសម័យសម្រាប់សហគ្រាស**
# - **ដំណើរការឯកសារច្រើនមាឌ**: ដំណើរការឯកសារជាច្រើនក្នុងពេលដដែល
# - **វិភាគមាតិកាលើកំណត់ពេល**: វិភាគសម័យនៃដំណើរទិន្នន័យចូល
# - **បង្កើនប្រសិទ្ធភាពដំណើរការបណ្ដុំ**: បង្កើនទិន្នផលសម្រាប់ប្រតិបត្តិការទូលំទូលាយ
# - **វិភាគរូបមន្តជាច្រើន**: ដំណើរការជាលំនាំសម័យប្រភេទមាតិកាចម្រុះ (អត្ថបទ រូបភាព ទិន្នន័យ)
#
# ## ⚙️ ទាមទារមុន & ការតំឡើង
#
# ### 📦 **ការពឹងផ្អែកដែលត្រូវការ**
#
# ដំឡើង Agent Framework ដែលមានសមត្ថភាពលំនាំដំណើរការជាលំនាំសម័យ៖
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **ការកំណត់ម៉ូឌែល GitHub**
#
# **ការតំឡើងបរិបទ (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ការពិចារណាក្នុងការដំណើរការជាលំនាំសម័យ៖**
# - **ដែនកំណត់អត្រា**: តាមដានដែនកំណត់អត្រារបស់ GitHub Models API សម្រាប់សំណើជាលំនាំសម័យ
# - **ការប្រើប្រាស់ធនធាន**: ពិចារណារឿងសន្លឹកនិង CPU ជាមួយភ្នាក់ងារជាលំនាំសម័យច្រើន
# - **ការដោះស្រាយកំហុស**: អនុវត្តវិធីសាស្រ្តសម្រួលកំហុសមានភាពរឹងមាំសម្រាប់ប្រតិបត្តិការជាលំនាំសម័យ
#
# ### 🏗️ **ស្ថាបត្យកម្មលំនាំដំណើរការជាលំនាំសម័យ**
#
# ```mermaid
# graph TD
#     A[ចាប់ផ្តើមដំណើរការ] --> B[អនុវត្តជាសម័យស្រប]
#     B --> C[អាងភ្នាក់ងារ 1]
#     B --> D[អាងភ្នាក់ងារ 2]
#     B --> E[អាងភ្នាក់ងារ 3]
#     C --> F[ការរួមបញ្ចូលលទ្ធផល]
#     D --> F
#     E --> F
#     F --> G[លទ្ធផលចុងក្រោយ]
#
#     H[GitHub ម៉ូឌែល API] --> C
#     H --> D
#     H --> E
# ```
#
# **អត្ថប្រយោជន៍សំខាន់ៗ៖**
# - **⚡ ប្រសិទ្ធភាព**: ល្បឿនយ៉ាងសំខាន់តាមរយៈការដំណើរការជាលំនាំសម័យ
# - **📈 កំណើនសមត្ថភាព**: គ្រប់គ្រងបន្ទង់ការងារដែលកើនឡើងដោយមិនមានការពន្យារពេលជាថ្នាក់
# - **🔄 ប្រសិទ្ធភាព**: ប្រើប្រាស់ធនធានកុំព្យូទ័រដែលមានស្រាប់បានល្អប្រសើរ
# - **🎯 ចំណុះរចនា**: ដំណើរការការងារច្រើនជាងវេលាដដែល
#
# ## 🎨 **លំនាំរចនាលំនាំដំណើរការជាលំនាំសម័យ**
#
# ### 🔍 **បណ្ដាញស្រាវជ្រាវ និងវិភាគ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **លំនាំដំណើរការទិន្នន័យ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **បណ្ដាញបង្កើតមាតិកា**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ដំណើរការជាច្រើនជំហាន**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍ប្រសិទ្ធភាពសហគ្រាស**
#
# ### ⚡ **បង្កើនចំណុះដំណើរការ**
# - **ដំណើរការជាលំនាំសម័យ**: ភ្នាក់ងារច្រើនដំណើរការជាមួយគ្នា
# - **ការប្រើប្រាស់ធនធាន**: ប្រសិទ្ធភាពអតិបរមានៃសមត្ថភាពម៉ូឌែល AI
# - **ការកាត់បន្ថយពេលវេលា**: បន្ថយពេលវេលាទូទៅក្នុងការដំណើរការ
# - **ស្ថាបត្យកម្មអាចពង្រីក**: បន្ថែមភ្នាក់ងារជាលំនាំសម័យបានងាយស្រួលតាមតម្រូវការ
#
# ### 🛡️ **ភាពទុកចិត្ត និងភាពរឹងមាំ**
# - **ការព្រួយបារម្ភកំហុស**: ការធ្លាក់ទោសឯកត្តជាភ្នាក់ងារមិនមានឥទ្ធិពលដល់លំនាំដំណើរទាំងមូល
# - **ការបង្ខិតបង្ខំកំហុស**: បញ្ហានៅក្នុងសាខាលំនាំសម័យមួយមិនប៉ះពាល់ទៅសាខាផ្សេងទៀត
# - **ការធ្លាក់ចុះដោយរលូន**: ប្រព័ន្ធបន្តដំណើរការ បើទោះបីមានកម្រិតសមត្ថភាពភ្នាក់ងារកាន់តិច
# - **មេកានិចសម្រាប់ការស្ដារឡើងវិញ**: ស្វ័យប្រវត្តិព្យាយាមឡើងវិញ និងដោះស្រាយកំហុសសម្រាប់ប្រតិបត្តិការដែលបរាជ័យ
#
# ### 📊 **ការត្រួតពិនិត្យ និងការសង្កេតឃើញ**
# - **ការតាមដានដំណើរការជាលំនាំសម័យ**: តាមដានជំនួញនៃប្រតិបត្តិការជាលំនាំសម័យទាំងអស់
# - **រាយការណ៍ប្រសិទ្ធភាព**: វាស់ចំណុះល្បឿននិងកំណើនប្រសិទ្ធភាព
# - **វិភាគការប្រើប្រាស់ធនធាន**: បង្កើនសមត្ថភាពបែងចែកភ្នាក់ងារជាលំនាំសម័យ
# - **កំណត់បញ្ហាការបង្ហូត**: រកហើយដោះស្រាយការរឹតបន្តឹងប្រសិទ្ធភាព
#
# មករួមគ្នាសាងសង់លំនាំដំណើរការ AI ជាលំនាំសម័យដែលមានប្រសិទ្ធភាពខ្ពស់! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
