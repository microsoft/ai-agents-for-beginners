# %% [markdown]
# # 🔄 工作流程ជាមួយ代理ត្រឹមត្រូវជាមួយ Azure OpenAI (Responses API) (.NET)
#
# ## 📋 មាគ៌ាទាំងឡាយសម្រាប់ធ្វើ workflow
#
# សៀវភៅកំណត់ត្រានេះបង្ហាញពីរបៀបសាងសង់ **workflow代理** ដែលស្មុគស្មាញ ដោយប្រើ Microsoft Agent Framework សម្រាប់ .NET និង Azure OpenAI (Responses API)។ អ្នកនឹងរៀនបង្កើតដំណើរការអាជីវកម្មច្រើនជំហាន ដែល代理AI បានសហការគ្នាទៅដល់ការងារដែលស្មុគស្មាញតាមរយៈគំរូ orchestration ដែលមានរចនាសម្ព័ន្ធ។
#
# ## 🎯 គោលបំណងរៀន
#
# ### 🏗️ **មូលដ្ឋានរចនាសម្ព័ន្ធ Workflow**
# - **អ្នកបង្កើត Workflow**៖ ការរចនានិងរុករកដំណើរការ AI ច្រើនជំហានដែលស្មុគស្មាញ
# - **ការសម្របសម្រួល代理**៖ សម្របសម្រួល代理ជាច្រើនដែលមានជំនាញពិសេសក្នុងworkflow
# - **Azure OpenAI (Responses API)**: ប្រើប្រាស់ Azure OpenAI Responses API ក្នុងworkflow
# - **ការរចនាដោយវីស្វល**: បង្កើតនិងបង្ហាញរចនាសម្ព័ន្ធ workflow សម្រាប់ការយល់ដឹងល្អប្រសើរ
#
# ### 🔄 **គំរូ orchestration ដំណើរការ**
# - **ដំណើរការត្រង់ៗតាមលំដាប់**: ជាប់ចងភ្ជាប់បេសកកម្ម代理ច្រើនតាមលំដាប់លូទៅ
# - **ការគ្រប់គ្រងស្ថានភាព**: រក្សាសេចក្ដីស្របនិងការប្រព្រឹត្តទិន្នន័យឆ្លុះទៅមកនានាទៅក្នុងជំហាន workflow
# - **ការដោះស្រាយកំហុស**: អនុវត្តការអ៊ុតចេញកំហុសយ៉ាងរឹងមាំនិងភាពធន់នៃworkflow
# - **ការ៊កលើសមត្ថភាព**: រចនាដើម្បីមានបេសកកម្មមានប្រសិទ្ធភាពសម្រាប់ការប្រតិបត្ដិការរយៈស្ដង់ដារ
#
# ### 🏢 **កម្មវិធី Workflow សម្រាប់សហគ្រាស**
# - **ការបង្កើតដំណើរការអាជីវកម្មស្វಯ-*ហើយកម្ម**: ស្វ័យប្រវត្តិដំណើរការក្រុមហ៊ុនដែលស្មុគស្មាញ
# - **បណ្តាញផលិតមាតិកា**: workflowបោះពុម្ពផ្សាយដែលមានជំហានពិនិត្យនិងអនុម័ត
# - **ស្វ័យប្រវត្តិការផ្តល់សេវាកម្មអតិថិជន**: ដំណើរការអ្នកអ៊ិនគ្រីរុញចំរើនច្រើនជំហាន
# - **ដំណើរការព័ត៌មាន**: workflow ETL ដែលមានការបំលែងដោយAI
#
# ## ⚙️ តម្រូវការ និងការតំឡើង
#
# ### 📦 **Packages NuGet ដែលត្រូវការ**
#
# ការបង្ហាញ workflow នេះប្រើ packages .NET សំខាន់ៗជាច្រើន:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **ការកំណត់ Azure OpenAI**
#
# **ការតំឡើងបរិស្ថាន (.env file):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **ការចូលប្រើ Azure OpenAI:**
# 1. បង្កើតធនធាន Azure OpenAI នៅក្នុង Azure portal
# 2. បង្ហោះម៉ូដែលមួយ (ឧទាហរណ៍, `gpt-5-mini`) ហើយកត់ឈ្មោះបង្ហោះ
# 3. ចូលគណនីដោយ `az login` ហើយកំណត់អថេរបរិស្ថានដូចបានបង្ហាញខាងលើ
#
# ### 🏗️ **ទិដ្ឋភាពទូទៅរចនាសម្ព័ន្ធ Workflow**
#
# ```mermaid
# graph TD
#     A[អ្នកបង្កើតរៀបចំលំហូរ] --> B[ការចុះបញ្ជីភ្នាក់ងារ]
#     B --> C[ម៉ាស៊ីនអនុវត្តលំហូរ]
#     C --> D[Agent 1: កម្មវិធីបង្កើតមាតិកា]
#     C --> E[Agent 2: អ្នកពិនិត្យមាតិកា]
#     D --> F[លទ្ធផលលំហូរ]
#     E --> F
#     G[Azure OpenAI (Responses API)] --> D
#     G --> E
# ```
#
# **ធាតុសំខាន់​៖**
# - **WorkflowBuilder**: ម៉ាស៊ីនស្របគ្នាសម្រាប់រចនាដំណើរការ workflow
# - **AIAgent**:代理ជាក់លាក់នីមួយៗដែលមានសមត្ថភាពជាក់លាក់
# - **Azure OpenAI Client**: ការចូលរួម Azure OpenAI Responses API
# - **Execution Context**: គ្រប់គ្រងស្ថានភាពនិងលំហូរទិន្នន័យរវាងជំហាន workflow
#
# ## 🎨 **គំរូរចនាសម្ព័ន្ធ Workflow សម្រាប់សហគ្រាស**
#
# ### 📝 **ដំណើរការផលិតមាតិកា**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **បណ្តាញដំណើរការឯកសារ**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Workflow យល់ដឹងអាជីវកម្ម**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **ស្វ័យប្រវត្តិការផ្តល់សេវាកម្មអតិថិជន**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍សម្រាប់សហគ្រាស**
#
# ### 🎯 **ភាពទុកចិត្ត & ការពង្រីក**
# - **ការប្រតិបត្ដិជាក់លាក់**: លទ្ធផល workflow ធម្មតានិងអាចកើតឡើងវិញបាន
# - **ការស្ដារកំហុស**: គ្រប់គ្រងកំហុសយ៉ាងស្អាតនៅជំហានណាមួយក្នុងworkflow
# - **ការត្រួតពិនិត្យកម្រិតបញ្ចាស់**: តាមដានសន្ទស្សន៍និងឱកាសបង្កើនប្រសិទ្ធភាព
# - **ការគ្រប់គ្រងធនធាន**: ចែកចាយនិងប្រើប្រាស់ធនធានម៉ូដែល AI យ៉ាងមានប្រសិទ្ធភាព
#
# ### 🔒 **សុវត្ថិភាព & ការចាំបាច់គោរពច្បាប់**
# - **ការផ្ទៀងផ្ទាត់អ្នកប្រើប្រាស់ដែលមានសុវត្ថិភាព**: Microsoft Entra ID ម៉ាស៊ីនផ្ទៀងផ្ទាត់តាមរយៈ `az login` (AzureCliCredential)
# - **របាយការណ៍តាមដាន**: ការចងក្រងកំណត់ហេតុនៃការប្រតិបត្ដិ workflow និងចំណុចសម្រេចចិត្ត
# - **ការត្រួតពិនិត្យការចូលប្រើ**: សិទ្ធិច្បាស់លាស់សម្រាប់ការប្រតិបត្ដិ workflow និងការត្រួតពិនិត្យ
# - **ភាពឯកជនទិន្នន័យ**: ការគ្រប់គ្រងលំអិតនៃព័ត៌មានសំងាត់ទាំងអស់នៅក្នុងworkflow
#
# ### 📊 **ការត្រួតពិនិត្យនិងការគ្រប់គ្រង**
# - **ការរចនាដោយវីស្វលសម្រាប់workflow**: បង្ហាញច្បាស់ពីលំហូរប្រតិបត្ដិការនិងភាពអាស្រ័យលើគ្នា
# - **ការតាមដានការប្រតិបត្ដិ**: តាមដានវិញ្ញាណភាពនិងប្រសិទ្ធភាព workflow នៅពេលវេលាពិត
# - **រាយការណ៍កំហុស**: វិភាគកំហុសលម្អិតនិងសមត្ថភាពដោះស្រាយបញ្ហា
# - **វិភាគប្រសិទ្ធភាព**: សន្ទស្សន៍សម្រាប់បង្កើននិងសម្រួលផែនការ
#
# ចាប់ផ្តើមបង្កើតworkflow AI ដែលស្ថិតក្នុងសេវាសហគ្រាសរបស់អ្នក! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
