# %% [markdown]
# # 🔄 ការប្រតិបត្តិកម្មភ្នាក់ងារមូលដ្ឋានជាមួយ Azure OpenAI (Responses API) (.NET)
#
# ## 📋 មេរៀនអំពីការរៀបចំប្រតិបត្តិការជាលំដាប់
#
# សៀវភៅកំណត់ត្រានេះបង្ហាញពីរបៀបបង្កើត **ការប្រតិបត្តិការភ្នាក់ងារ** ដែលមានភាពស្មុគស្មាញដោយបំពាក់ Microsoft Agent Framework សម្រាប់ .NET និង Azure OpenAI (Responses API)។ អ្នកនឹងរៀនធ្វើដំណើរជាជាច្រើនជាដំណើរការជាក្រុម ដែលភ្នាក់ងារជំនាញ AI ត្រូវធ្វើការសហការគ្នាដើម្បីបញ្ចប់ភារកិច្ចស្មុគស្មាញតាមគម្លាតនៃការរៀបចំប្រតិបត្តិការ។
#
# ## 🎯 គោលបំណងការសិក្សា
#
# ### 🏗️ **មូលដ្ឋានសំណុំរចនាសម្ព័ន្ធការប្រតិបត្តិការ**
# - **កម្មន្តិការ Workflow Builder**: រចនា និងរៀបចំប្រតិបត្តិការជាដំណើរការជាច្រើនជាគន្លង
# - **ការសម្របសម្រួលភ្នាក់ងារ**: សម្របសម្រួលភ្នាក់ងារពិសេសជាច្រើននៅក្នុងប្រតិបត្តិការ
# - **Azure OpenAI (Responses API)**: ប្រើប្រាស់ Azure OpenAI Responses API ក្នុងប្រតិបត្តិការ
# - **រចនាប្រែ Workflow តាមរូបភាព**: បង្កើត និងមើលឃើញរចនាសម្ព័ន្ធប្រតិបត្តិការ ដើម្បីយល់ដឹងល្អប្រសើរ
#
# ### 🔄 **គំរូការរៀបចំប្រតិបត្តិការ**
# - **ការប្រតិបត្តិជាលំដាប់**: ចាក់ខ្សែភារកិច្ចភ្នាក់ងារជាច្រើន តាមលំដាប់ដោយមានលក្ខណៈត្រឹមត្រូវ
# - **ការគ្រប់គ្រងស្ថានភាព**: រក្សាទុកបរិបទ និងចរន្តទិន្នន័យនៅគ្រប់ចំណាត់ថ្នាក់នៃប្រតិបត្តិការ
# - **ការប្រើប្រាស់ករណីកំហុស**: អនុវត្តការស្ដារឡើងវិញកំហុសយ៉ាងរឹងមាំ និងភាពរឹងមាំរបស់ប្រតិបត្តិការ
# - **ការអភិវឌ្ឍន៍អតិភាពកម្រិតប្រសិទ្ធភាព**: រចនាដំណើរការជាគន្លងមានទំនួលបានប្រសិទ្ធភាពសម្រាប់ប្រតិបត្តិការទំហំធំ
#
# ### 🏢 **កម្មវិធីប្រតិបត្តិការអាជីវកម្ម**
# - **ការអូតូម៉ាទិកនៃដំណើរការអាជីវកម្ម**: អូតូម៉ាទិកដំណើរការអង្គការដែលមានភាពស្មុគស្មាញ
# - **ខ្សែផលិតកម្មមាតិកា**: ប្រតិបត្តិការសារព័ត៌មានដែលមានដំណាក់កាលពិនិត្យ និងអនុម័ត
# - **អូតូម៉ាទិកសេវាកម្មអតិថិជន**: ដំណើរការដោះស្រាយសំណួរអតិថិជនជាច្រើនជំហាន
# - **ដំណើរការទិន្នន័យ**: ប្រតិបត្តិការប្រើ ETL ជាមួយ ការផ្លាស់ប្តូរ powered by AI
#
# ## ⚙️ តម្រូវការមុន និងការតំឡើង
#
# ### 📦 **កញ្ចប់ NuGet តម្រូវការ**
#
# ការបង្ហាញនេះប្រើកញ្ចប់ .NET សំខាន់ៗច្រើន:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **ការកំណត់គណនេយ្យ Azure OpenAI**
#
# **ការតំឡើងបរិយាកាស (.env file):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **ចូលដំណើរការជាមួយ Azure OpenAI:**
# 1. បង្កើតធនធាន Azure OpenAI នៅក្នុងរបាយការណ៍ Azure portal
# 2. ផ្ទុកផ្សាយម៉ូដែលមួយ (ឧទាហរណ៏ `gpt-5-mini`) ហើយកត់សម្គាល់ឈ្មោះការផ្ទុកផ្សាយ
# 3. ចូលដោយ `az login` និងកំណត់អថេរបរិយាកាសដូចបានបង្ហាញខាងលើ
#
# ### 🏗️ **ទិដ្ឋភាពមូលដ្ឋានសំណុំរចនាសម្ព័ន្ធប្រតិបត្តិការ**
#
# ```mermaid
# graph TD
#     A[អ្នកបង្កើតចរន្តការងារ] --> B[ការចុះបញ្ជីភ្នាក់ងារ]
#     B --> C[ម៉ាស៊ីនអនុវត្តចរន្តការងារ]
#     C --> D[Agent 1: ជំរើសបង្កើតមាតិកា]
#     C --> E[Agent 2: អ្នកពិនិត្យមាតិកា]
#     D --> F[លទ្ធផលចរន្តការងារ]
#     E --> F
#     G[Azure OpenAI (APIs ចម្លើយ)] --> D
#     G --> E
# ```
#
# **បរិក្ខារសំខាន់ៗ:**
# - **WorkflowBuilder**: ម៉ាស៊ីនចម្បងសម្រាប់រៀបចំប្រតិបត្តិការ
# - **AIAgent**: ភ្នាក់ងារជំនាញឯកត្តិជាមួយសមត្ថភាពពិសេស
# - **Azure OpenAI Client**: ប្រព័ន្ធភ្ជាប់ Azure OpenAI Responses API
# - **Execution Context**: គ្រប់គ្រងស្ថានភាព និងចរន្តទិន្នន័យរវាងដំណាក់កាលប្រតិបត្តិការ
#
# ## 🎨 **រចនាប្រតិបត្តិការ Enterprise**
#
# ### 📝 **ដំណើរការផលិតមាតិកា**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **ខ្សែដំណើរការការប្រមូលព័ត៌មានឯកសារ**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **ដំណើរការព័ត៌មានអាជីវកម្ម**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **អូតូម៉ាទិកសេវាកម្មអតិថិជន**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍សម្រាប់អាជីវកម្ម**
#
# ### 🎯 **ភាពទុកចិត្ត និងសមត្ថភាពបណ្តោះអាសន្ន**
# - **ការប្រតិបត្តិច្បាស់លាស់**: លទ្ធផលរៀងរាល់ពេលនៃប្រតិបត្តិការ
# - **ការស្ដារឡើងវិញករណីកំហុស**: បន្សល់ដោយក្រួសកំហុសនៅតែមាននៅគ្រប់ដំណាក់កាលប្រតិបត្តិការ
# - **ការតាមដានប្រសិទ្ធភាព**: តាមដានវិមាត្រការប្រតិបត្តិ និងឱកាសពង្រឹង
# - **ការគ្រប់គ្រងធនធាន**: ការចែកចាយ និងប្រើប្រាស់ធនធានម៉ូដែល AI មានប្រសិទ្ធភាព
#
# ### 🔒 **សន្តិសុខ និងការអនុលោម**
# - **ការផ្ទៀងផ្ទាត់សុវត្ថិភាព**: ការផ្ទៀងផ្ទាត់ Microsoft Entra ID តាម `az login` (AzureCliCredential)
# - **ការចុះបញ្ជីប្រតិបត្តិការ​តាមពេលវេលា**: កំណត់ហេតុនៃការប្រតិបត្តិ និងចំណុចសម្រេចចិត្ត
# - **ការត្រួតពិនិត្យការចូលប្រើ**: កំណត់សិទ្ធលម្អិតសម្រាប់ប្រតិបត្តិការ និងតាមដាន
# - **ភាពឯកជនទិន្នន័យ**: ការដំណើរការដោយសុវត្ថិភាពសម្រាប់ព័ត៌មានដែលមានអារម្មណ៍ភ្លឺបញ្ជា
#
# ### 📊 **ការត្រួតពិនិត្យ និងគ្រប់គ្រង**
# - **រចនាប្រតិបត្តិកាតាមរូបភាព**: តំណាងច្បាស់លាស់នៃចរន្តដំណើរការ និងការទំនាក់ទំនង
# - **ការតាមដានរត់ប្រតិបត្តិការ**: ការតាមដានពេលវេលាពិតប្រាកដនៃជើងភាព និងសមត្ថភាព
# - **ការរាយការណ៍កំហុស**: វិភាគកំហុសលម្អិត និងសមត្ថភាពបំបែកបញ្ហា
# - **វិភាគសមត្ថភាព**: វិមាត្រសម្រាប់បង្វិលកំណត់លក្ខខណ្ឌនិងផែនការដាក់បញ្ចូល
#
# យើងមកបង្កើតប្រតិបត្តិការជាលំដាប់លេខមួយសម្រាប់អាជីវកម្ម AI របស់អ្នក! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
