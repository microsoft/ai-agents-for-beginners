# %% [markdown]
# # 🔄 Основні робочі процеси агентів з Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Навчальний курс з оркестрації робочих процесів
#
# Цей ноутбук демонструє, як створювати складні **робочі процеси агентів** за допомогою Microsoft Agent Framework для .NET та Azure OpenAI (Responses API). Ви навчитесь створювати багатокрокові бізнес-процеси, у яких агенти штучного інтелекту співпрацюють для виконання складних завдань через структуровані оркестраційні патерни.
#
# ## 🎯 Навчальні цілі
#
# ### 🏗️ **Основи архітектури робочих процесів**
# - **Workflow Builder**: Проєктування та оркестрація складних багатокрокових AI процесів
# - **Координація агентів**: Координація кількох спеціалізованих агентів у робочих процесах
# - **Azure OpenAI (Responses API)**: Використання Azure OpenAI Responses API у робочих процесах
# - **Візуальне проєктування робочих процесів**: Створення та візуалізація структур робочих процесів для кращого розуміння
#
# ### 🔄 **Патерни оркестрації процесів**
# - **Послідовна обробка**: Ланцюжок кількох завдань агентів у логічному порядку
# - **Управління станом**: Підтримка контексту та потоку даних через етапи робочого процесу
# - **Обробка помилок**: Реалізація надійного відновлення після помилок і гнучкості робочого процесу
# - **Оптимізація продуктивності**: Проєктування ефективних робочих процесів для корпоративних операцій
#
# ### 🏢 **Корпоративні застосунки робочих процесів**
# - **Автоматизація бізнес-процесів**: Автоматизація складних організаційних робочих процесів
# - **Потік створення контенту**: Редакційні робочі процеси із стадіями перегляду та затвердження
# - **Автоматизація обслуговування клієнтів**: Багатокрокове вирішення клієнтських запитів
# - **Робочі процеси обробки даних**: ETL робочі процеси з AI-прискореною трансформацією
#
# ## ⚙️ Вимоги та налаштування
#
# ### 📦 **Необхідні пакети NuGet**
#
# Для демонстрації робочого процесу використовуються кілька ключових .NET пакетів:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Конфігурація Azure OpenAI**
#
# **Налаштування середовища (.env файл):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Доступ до Azure OpenAI:**
# 1. Створіть ресурс Azure OpenAI в порталі Azure
# 2. Розгорніть модель (наприклад, `gpt-5-mini`) і запам’ятайте ім’я розгортання
# 3. Увійдіть за допомогою `az login` і налаштуйте змінні середовища, як показано вище
#
# ### 🏗️ **Огляд архітектури робочого процесу**
#
# ```mermaid
# graph TD
#     A[Конструктор робочих процесів] --> B[Реєстр агентів]
#     B --> C[Двигун виконання робочих процесів]
#     C --> D[Agent 1: Генератор контенту]
#     C --> E[Agent 2: Оглядач контенту]
#     D --> F[Результати робочого процесу]
#     E --> F
#     G[Azure OpenAI (Responses API)] --> D
#     G --> E
# ```
#
# **Ключові компоненти:**
# - **WorkflowBuilder**: Головний механізм оркестрації для проєктування робочих процесів
# - **AIAgent**: Окремі спеціалізовані агенти з конкретними можливостями
# - **Azure OpenAI Client**: Інтеграція з Azure OpenAI Responses API
# - **Execution Context**: Управління станом і потоком даних між етапами робочого процесу
#
# ## 🎨 **Патерни проєктування корпоративних робочих процесів**
#
# ### 📝 **Робочий процес створення контенту**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Потік обробки документів**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Робочий процес бізнес-аналітики**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Автоматизація обслуговування клієнтів**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Корпоративні переваги**
#
# ### 🎯 **Надійність і масштабованість**
# - **Детерміноване виконання**: Послідовні, повторювані результати робочого процесу
# - **Відновлення після помилок**: Коректна обробка збоїв на будь-якому етапі робочого процесу
# - **Моніторинг продуктивності**: Відстеження метрик виконання та можливостей оптимізації
# - **Управління ресурсами**: Ефективне розподілення та використання ресурсів AI-моделей
#
# ### 🔒 **Безпека та відповідність**
# - **Безпечна автентифікація**: Аутентифікація Microsoft Entra ID через `az login` (AzureCliCredential)
# - **Аудитні записи**: Повне журналювання виконання робочого процесу та точок прийняття рішень
# - **Контроль доступу**: Гранульовані дозволи на виконання та моніторинг робочих процесів
# - **Конфіденційність даних**: Безпечна обробка конфіденційної інформації в робочих процесах
#
# ### 📊 **Спостережуваність та управління**
# - **Візуальне проєктування процесів**: Чітке відображення потоків процесів і залежностей
# - **Моніторинг виконання**: Відстеження прогресу та продуктивності робочих процесів в реальному часі
# - **Звітність про помилки**: Детальний аналіз помилок і можливості налагодження
# - **Аналітика продуктивності**: Метрики для оптимізації та планування потужностей
#
# Давайте створимо ваш перший AI робочий процес корпоративного рівня! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено за допомогою сервісу штучного інтелекту для перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
