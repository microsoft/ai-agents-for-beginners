# %% [markdown]
# # ⚡ Паралельні робочі процеси агентів із моделями GitHub (Python)
#
# ## 📋 Поглиблений посібник з паралельної обробки
#
# Цей нотатник демонструє **конкурентні патерни робочих процесів** із використанням Microsoft Agent Framework. Ви навчитеся створювати високопродуктивні паралельні робочі процеси, де кілька агентів AI працюють одночасно, значно покращуючи пропускну здатність та дозволяючи реалізовувати складні багатопотокові бізнес-процеси.
#
# ## 🎯 Цілі навчання
#
# ### 🚀 **Основи паралельної обробки**
# - **Паралельне виконання агентів**: Запуск декількох агентів одночасно для максимальної ефективності
# - **Оркестрація робочих процесів**: Координація конкурентних операцій з підтримкою послідовності даних
# - **Оптимізація продуктивності**: Досягнення значного прискорення за рахунок паралельної обробки
# - **Управління ресурсами**: Ефективне використання ресурсів AI-моделей під час конкурентних операцій
#
# ### 🏗️ **Розвинені патерни паралелізму**
# - **Обробка за схемою Fork-Join**: Розподіл роботи між кількома агентами та об’єднання результатів
# - **Паралелізм конвеєра**: Перекривні етапи виконання для безперервної пропускної здатності
# - **Балансування навантаження**: Рівномірний розподіл роботи між доступними агентами
# - **Точки синхронізації**: Координація конкурентних агентів на критичних етапах робочого процесу
#
# ### 🏢 **Паралельні корпоративні застосунки**
# - **Обробка великої кількості документів**: Одночасна обробка численних документів
# - **Аналіз контенту в реальному часі**: Конкурентний аналіз вхідних потоків даних
# - **Оптимізація пакетної обробки**: Максимізація пропускної здатності для великих обсягів операцій
# - **Багатомодальний аналіз**: Паралельна обробка різних типів контенту (текст, зображення, дані)
#
# ## ⚙️ Вимоги та налаштування
#
# ### 📦 **Необхідні залежності**
#
# Встановіть Agent Framework з підтримкою конкурентних робочих процесів:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Налаштування моделей GitHub**
#
# **Налаштування середовища (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Особливості конкурентної обробки:**
# - **Обмеження швидкості**: Моніторинг обмежень API моделей GitHub для конкурентних запитів
# - **Використання ресурсів**: Враховуйте використання пам’яті та CPU при багатопаралельній роботі агентів
# - **Обробка помилок**: Реалізуйте надійне відновлення після помилок у паралельних операціях
#
# ### 🏗️ **Архітектура конкурентного робочого процесу**
#
# ```mermaid
# graph TD
#     A[Початок робочого процесу] --> B[Паралельне виконання]
#     B --> C[Пул агентів 1]
#     B --> D[Пул агентів 2]
#     B --> E[Пул агентів 3]
#     C --> F[Агрегація результатів]
#     D --> F
#     E --> F
#     F --> G[Фінальний вивід]
#
#     H[API моделей GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **Головні переваги:**
# - **⚡ Продуктивність**: Значне прискорення через паралельне виконання
# - **📈 Масштабованість**: Обробка збільшених навантажень без пропорційного збільшення часу
# - **🔄 Ефективність**: Краща задіяність доступних обчислювальних ресурсів
# - **🎯 Пропускна здатність**: Більше виконаної роботи за той самий час
#
# ## 🎨 **Патерни проектування конкурентних робочих процесів**
#
# ### 🔍 **Конвеєр дослідження та аналізу**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Робочий процес обробки даних**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Конвеєр створення контенту**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Багатоступенева обробка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Корпоративні переваги продуктивності**
#
# ### ⚡ **Оптимізація пропускної здатності**
# - **Паралельне виконання**: Одночасна робота кількох агентів
# - **Використання ресурсів**: Максимальна ефективність використання потужностей AI-моделей
# - **Зменшення часу**: Значне скорочення загального часу обробки
# - **Масштабована архітектура**: Легке додавання нових конкурентних агентів за потреби
#
# ### 🛡️ **Надійність і стійкість**
# - **Відмовостійкість**: Збої окремих агентів не зупиняють весь робочий процес
# - **Ізоляція помилок**: Проблеми в одній гілці не впливають на інші паралельні гілки
# - **Плавне деградування**: Система працює далі навіть при зниженій потужності агентів
# - **Механізми відновлення**: Автоматичне повторне виконання та обробка помилок невдалих операцій
#
# ### 📊 **Моніторинг та спостережність**
# - **Відстеження паралельного виконання**: Моніторинг прогресу всіх паралельних операцій
# - **Метрики продуктивності**: Вимірювання прискорення та приросту ефективності
# - **Аналіз використання ресурсів**: Оптимізація розподілу агентів у конкурентних операціях
# - **Виявлення вузьких місць**: Пошук та усунення обмежень продуктивності
#
# Створюємо високопродуктивні конкурентні AI-робочі процеси! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено за допомогою сервісу штучного інтелекту для перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
