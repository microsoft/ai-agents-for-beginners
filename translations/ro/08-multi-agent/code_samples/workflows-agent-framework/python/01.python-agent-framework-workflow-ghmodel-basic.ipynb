# %% [markdown]
# # 🔄 Fluxuri de lucru de bază pentru agenți cu modelele GitHub (Python)
#
# ## 📋 Tutorial pentru Orchestrarea Fluxului de Lucru
#
# Acest notebook introduce puternicele capacități **Workflow Builder** ale Microsoft Agent Framework. Învață cum să creezi fluxuri de lucru sofisticate, cu mai mulți pași, care pot gestiona procese complexe de afaceri și pot coordona mai multe operațiuni AI fără probleme.
#
# ## 🎯 Obiective de Învățare
#
# ### 🏗️ **Arhitectura Fluxului de Lucru**
# - **Workflow Builder**: Proiectează și orchestrează procese complexe cu mai mulți pași
# - **Execuție Bazată pe Evenimente**: Gestionează evenimentele fluxului de lucru și tranzițiile de stare
# - **Proiectare Vizuală a Fluxului de Lucru**: Creează și vizualizează structuri de flux de lucru
# - **Integrarea Modelelor GitHub**: Valorifică modelele AI în contexte de flux de lucru
#
# ### 🔄 **Orchestrarea Procesului**
# - **Operațiuni Secvențiale**: Leagă multiple sarcini ale agentului în ordine logică
# - **Logică Condițională**: Implementează puncte decizionale și ramificații în fluxurile de lucru
# - **Gestionarea Erorilor**: Recuperare robustă și reziliență în fluxul de lucru
# - **Gestionarea Stării**: Urmărește și gestionează starea execuției fluxului de lucru
#
# ### 📊 **Modele de Fluxuri de Lucru Enterprise**
# - **Automatizarea Proceselor de Afaceri**: Automatizează fluxuri de lucru organizaționale complexe
# - **Coordonarea Multi-Agent**: Coordonează mai mulți agenți specializați
# - **Execuție Scalabilă**: Proiectează fluxuri de lucru pentru operațiuni la scară enterprise
# - **Monitorizare și Observabilitate**: Urmărește performanța și rezultatele fluxului de lucru
#
# ## ⚙️ Cerințe și Configurare
#
# ### 📦 **Dependențe Necesare**
#
# Instalează Agent Framework cu capabilități de fluxuri de lucru:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Configurarea Modelelor GitHub**
#
# **Configurarea Mediului (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Cazuri de Utilizare Enterprise**
#
# **Exemple de Procese de Afaceri:**
# - **Integrarea Clienților**: Fluxuri de lucru de verificare și configurare în mai mulți pași
# - **Flux de Conținut**: Crearea, revizuirea și publicarea automată de conținut
# - **Procesarea Datelor**: Fluxuri ETL cu transformare asistată de AI
# - **Asigurarea Calității**: Testare și validare automate
#
# **Beneficiile Fluxului de Lucru:**
# - 🎯 **Fiabilitate**: Execuție deterministă cu recuperare la erori
# - 📈 **Scalabilitate**: Gestionarea automatizării proceselor cu volum mare
# - 🔍 **Observabilitate**: Urmărire completă a auditului și monitorizare
# - 🔧 **Ușurință în Mentenanță**: Proiectare vizuală și componente modulare
#
# ## 🎨 Modele de Proiectare a Fluxului de Lucru
#
# ### Structura de Bază a Fluxului de Lucru
# ```mermaid
# graph TD
#     A[Start] --> B[Sarcina Agentului 1]
#     B --> C{Punct de Decizie}
#     C -->|Succes| D[Sarcina Agentului 2]
#     C -->|Eşec| E[Gestionar de Erori]
#     D --> F[Final]
#     E --> F
# ```
#
# **Componente Cheie:**
# - **WorkflowBuilder**: Motorul principal de orchestrare
# - **WorkflowEvent**: Gestionarea evenimentelor și comunicarea
# - **WorkflowViz**: Reprezentarea vizuală și depanarea fluxului de lucru
#
# Să construim primul tău flux de lucru inteligent! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load GitHub Models API credentials from .env file
load_dotenv()

# %%
# Configure the Azure AI Foundry provider with keyless authentication
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = await provider.create_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = await provider.create_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Declinare a responsabilității**:
# Acest document a fost tradus folosind serviciul de traducere AI [Co-op Translator](https://github.com/Azure/co-op-translator). În timp ce ne străduim pentru acuratețe, vă rugăm să rețineți că traducerile automate pot conține erori sau inexactități. Documentul original în limba sa nativă trebuie considerat sursa autorizată. Pentru informații critice, se recomandă traducerea profesională realizată de un om. Nu ne asumăm responsabilitatea pentru eventualele neînțelegeri sau interpretări greșite care decurg din utilizarea acestei traduceri.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
