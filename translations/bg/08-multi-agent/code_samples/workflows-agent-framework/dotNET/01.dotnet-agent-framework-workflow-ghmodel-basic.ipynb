# %% [markdown]
# # 🔄 Основни работни потоци на агенти с Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Урок за оркестрация на работни потоци
#
# Този бележник показва как да изградите сложни **работни потоци на агенти** с помощта на Microsoft Agent Framework за .NET и Azure OpenAI (Responses API). Ще научите как да създавате многоетапни бизнес процеси, в които AI агенти си сътрудничат за изпълнението на сложни задачи чрез структуриран модел на оркестрация.
#
# ## 🎯 Обучителни цели
#
# ### 🏗️ **Основи на архитектурата на работните потоци**
# - **Създател на работни потоци**: Проектиране и оркестрация на сложни многоетапни AI процеси
# - **Координация на агенти**: Координация на множество специализирани агенти в рамките на работни потоци
# - **Azure OpenAI (Responses API)**: Използване на Responses API на Azure OpenAI в работни потоци
# - **Визуален дизайн на работни потоци**: Създаване и визуализация на структури на работни потоци за по-добро разбиране
#
# ### 🔄 **Модели за оркестрация на процеси**
# - **Последователна обработка**: Свързване на множество задачи на агенти в логичен ред
# - **Управление на състоянието**: Поддържане на контекста и потока на данни през етапите на работния поток
# - **Обработка на грешки**: Имплементиране на надеждно възстановяване от грешки и устойчивост на работния поток
# - **Оптимизация на производителността**: Проектиране на ефективни работни потоци за операции в мащаб на предприятия
#
# ### 🏢 **Приложения на работни потоци за предприятия**
# - **Автоматизация на бизнес процеси**: Автоматизиране на сложни организационни работни потоци
# - **Производствена линия за съдържание**: Редакционни работни потоци с етапи на преглед и одобрение
# - **Автоматизация на обслужване на клиенти**: Многоетапно разрешаване на клиентски заявки
# - **Работни потоци за обработка на данни**: ETL работни потоци с AI-задвижвани трансформации
#
# ## ⚙️ Изисквания и настройка
#
# ### 📦 **Необходими NuGet пакети**
#
# Тази демонстрация на работен поток използва няколко ключови .NET пакети:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Конфигурация на Azure OpenAI**
#
# **Настройка на околната среда (.env файл):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Достъп до Azure OpenAI:**
# 1. Създайте Azure OpenAI ресурс в портала на Azure
# 2. Разположете модел (например `gpt-5-mini`) и запишете името на разполагането
# 3. Влезте с `az login` и конфигурирайте променливите на околната среда, както е показано по-горе
#
# ### 🏗️ **Преглед на архитектурата на работния поток**
#
# ```mermaid
# graph TD
#     A[Създател на Работни Потоци] --> B[Регистър на Агентите]
#     B --> C[Двигател за Изпълнение на Работни Потоци]
#     C --> D[Agent 1: Генератор на Съдържание]
#     C --> E[Agent 2: Ревизор на Съдържание]
#     D --> F[Резултати от Работни Потоци]
#     E --> F
#     G[Azure OpenAI (Responses API)] --> D
#     G --> E
# ```
#
# **Основни компоненти:**
# - **WorkflowBuilder**: Основен двигател за оркестрация за проектиране на работни потоци
# - **AIAgent**: Индивидуални специализирани агенти с конкретни възможности
# - **Azure OpenAI Client**: Интеграция с Azure OpenAI Responses API
# - **Изпълнителен контекст**: Управлява състоянието и потока на данни между етапите на работния поток
#
# ## 🎨 **Дизайнерски модели на работни потоци за предприятия**
#
# ### 📝 **Работен поток за производство на съдържание**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Производствена линия за обработка на документи**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Работен поток за бизнес анализи**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Автоматизация на обслужване на клиенти**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Предимства за предприятия**
#
# ### 🎯 **Надеждност и мащабируемост**
# - **Детерминирано изпълнение**: Последователни, възпроизводими резултати от работните потоци
# - **Възстановяване при грешки**: Гъвкаво обработване на неизправности на всеки етап от работния поток
# - **Мониторинг на производителността**: Отчитане на метрики за изпълнение и възможности за оптимизация
# - **Управление на ресурси**: Ефективно разпределяне и използване на ресурси на AI моделите
#
# ### 🔒 **Сигурност и съответствие**
# - **Сигурна автентикация**: Microsoft Entra ID автентикация чрез `az login` (AzureCliCredential)
# - **Одитни следи**: Пълно логване на изпълнението на работни потоци и точки на вземане на решения
# - **Контрол на достъпа**: Гранулирани разрешения за изпълнение и наблюдение на работни потоци
# - **Поверителност на данните**: Сигурно обработване на чувствителна информация през целия работен поток
#
# ### 📊 **Наблюдаемост и управление**
# - **Визуален дизайн на работни потоци**: Ясно представяне на потоци от процеси и зависимости
# - **Мониторинг на изпълнението**: Проследяване в реално време на напредъка и производителността на работния поток
# - **Отчитане на грешки**: Подробен анализ на грешки и възможности за отстраняване на проблеми
# - **Анализи на производителността**: Метрики за оптимизация и планиране на капацитета
#
# Нека изградим първия ви AI работен поток, готов за предприятие! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
