# %% [markdown]
# # ⚡ Паралелни работни процеси с агенти с Microsoft Foundry (Python)
#
# ## 📋 Урок за напреднала паралелна обработка
#
# Този бележник демонстрира **шаблони за паралелни работни процеси** с използване на Microsoft Agent Framework. Ще научите как да създавате високопроизводителни работни процеси за паралелна обработка, при които множество AI агенти изпълняват задачи едновременно, значително подобрявайки пропускателната способност и позволявайки сложни многонишкови бизнес процеси.
#
# > **Забележка за миграция:** Този пример преди това използваше GitHub Models. GitHub Models се прекратява (спиране юли 2026), затова сега използва **Microsoft Foundry** чрез `FoundryChatClient`, който насочва към Azure OpenAI **Responses API**.
#
# ## 🎯 Учебни цели
#
# ### 🚀 **Основи на паралелната обработка**
# - **Паралелно изпълнение на агенти**: Стартиране на множество агенти едновременно за максимална ефективност
# - **Оркестрация на работни процеси**: Координиране на паралелни операции с поддържане на консистентност на данните
# - **Оптимизация на производителността**: Постигане на значително ускорение чрез паралелна обработка
# - **Управление на ресурси**: Ефективно използване на AI моделите при паралелни операции
#
# ### 🏗️ **Напреднали паралелни модели**
# - **Fork-Join обработка**: Разделяне на работа между множество агенти и обединяване на резултатите
# - **Паралелизъм на потоци**: Прекриване на изпълнителни етапи за непрекъснат поток
# - **Балансировка на натоварването**: Равномерно разпределение на задачите между наличните агенти
# - **Синхронизационни точки**: Координиране на паралелните агенти в критични етапи на работния процес
#
# ### 🏢 **Паралелни приложения за предприятия**
# - **Обработка на големи обеми документи**: Паралелна обработка на множество документи
# - **Анализ в реално време**: Паралелен анализ на входящи потоци от данни
# - **Оптимизация на партидна обработка**: Максимизиране на пропускателната способност при мащабни операции
# - **Многоформатен анализ**: Паралелна обработка на различни типове съдържание (текст, изображения, данни)
#
# ## ⚙️ Изисквания и настройка
#
# ### 📦 **Необходими зависимости**
#
# Инсталирайте Agent Framework с поддръжка на паралелни работни процеси:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Конфигурация на Microsoft Foundry**
#
# Влезте с Azure CLI (`az login`), за да може `AzureCliCredential` да се автентикира, след което задайте параметрите на вашия проект в Microsoft Foundry.
#
# **Настройка на средата (.env файл):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Съображения при паралелна обработка:**
# - **Ограничения на скоростта**: Следете ограниченията на Azure OpenAI за паралелни заявки
# - **Използване на ресурси**: Вземете предвид паметта и CPU използването при множество паралелни агенти
# - **Обработка на грешки**: Внедрете стабилно възстановяване при грешки за паралелни операции
#
# ### 🏗️ **Архитектура на паралелни работни процеси**
#
# ```mermaid
# graph TD
#     A[Начало на работния процес] --> B[Паралелно изпълнение]
#     B --> C[Група агенти 1]
#     B --> D[Група агенти 2]
#     B --> E[Група агенти 3]
#     C --> F[Агрегиране на резултатите]
#     D --> F
#     E --> F
#     F --> G[Краен резултат]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Основни предимства:**
# - **⚡ Производителност**: Значително ускорение чрез паралелно изпълнение
# - **📈 Мащабируемост**: Обработка на увеличени натоварвания без пропорционално увеличаване на времето
# - **🔄 Ефективност**: По-добро използване на наличните изчислителни ресурси
# - **🎯 Пропускателна способност**: Обработка на повече задачи за едно и също време
#
# ## 🎨 **Шаблони за проектиране на паралелни работни процеси**
#
# ### 🔍 **Поток за изследване и анализ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Работен процес за обработка на данни**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Поток за създаване на съдържание**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Многоетапна обработка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Предимства за производителността в предприятията**
#
# ### ⚡ **Оптимизация на пропускателната способност**
# - **Паралелно изпълнение**: Множество агенти работят едновременно
# - **Използване на ресурси**: Максимална ефективност на наличния капацитет на AI модела
# - **Намаляване на времето**: Значително съкращаване на общото време за обработка
# - **Мащабируема архитектура**: Лесно добавяне на повече паралелни агенти според нуждите
#
# ### 🛡️ **Надеждност и устойчивост**
# - **Толерантност към грешки**: Отказите на отделни агенти не спират целия работен процес
# - **Изолация на грешки**: Проблемите в един паралелен клон не влияят на останалите
# - **Грациозно деградиране**: Системата продължава да работи дори при намален агентен капацитет
# - **Механизми за възстановяване**: Автоматично повторение и обработка на грешки при неуспешни операции
#
# ### 📊 **Мониторинг и наблюдение**
# - **Проследяване на паралелно изпълнение**: Следете напредъка на всички паралелни операции
# - **Метрики за производителност**: Измервайте ускорението и печалбите в ефективността
# - **Анализи на използване на ресурси**: Оптимизирайте разпределението на паралелни агенти
# - **Идентифициране на задръствания**: Откривайте и разрешавайте ограничения в производителността
#
# Нека изградим високопроизводителни паралелни AI работни процеси! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
