# %% [markdown]
# # ⚡ Конкурентни работни потоци на агенти с GitHub модели (Python)
#
# ## 📋 Напреднал урок за паралелна обработка
#
# Този бележник демонстрира **шаблони за конкурентни работни потоци** с помощта на Microsoft Agent Framework. Ще научите как да изграждате високоефективни, паралелни работни потоци, при които множество AI агенти изпълняват едновременно, значително подобрявайки пропускателната способност и позволявайки сложни многонишкови бизнес процеси.
#
# ## 🎯 Учебни цели
#
# ### 🚀 **Основи на конкурентната обработка**
# - **Паралелно изпълнение на агенти**: Стартиране на множество агенти едновременно за максимална ефективност
# - **Организация на работния поток**: Координиране на конкурентни операции при запазване на консистентността на данните
# - **Оптимизация на производителността**: Постигане на значително ускорение чрез паралелна обработка
# - **Управление на ресурси**: Ефективно използване на AI моделните ресурси при конкурентни операции
#
# ### 🏗️ **Разширени шаблони за конкурентност**
# - **Fork-Join обработка**: Разпределяне на работата между много агенти и обединяване на резултатите
# - **Паралелизъм на конвейра**: Наслагване на етапи на изпълнение за непрекъсната пропускателна способност
# - **Баланс на натоварването**: Равномерно разпределяне на работата между наличните ресурси на агентите
# - **Точки на синхронизация**: Координиране на конкурентни агенти в критични етапи на работния поток
#
# ### 🏢 **Конкурентни корпоративни приложения**
# - **Обработка на голям обем документи**: Обработка на множество документи едновременно
# - **Анализ на съдържанието в реално време**: Конкурентен анализ на постъпващи потоци от данни
# - **Оптимизация на пакетна обработка**: Максимизиране на пропускателната способност за операции в голям мащаб
# - **Много-модален анализ**: Паралелна обработка на различни типове съдържание (текст, изображения, данни)
#
# ## ⚙️ Изисквания и настройка
#
# ### 📦 **Необходими зависимости**
#
# Инсталирайте Agent Framework с възможности за конкурентни работни потоци:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Конфигурация на GitHub модели**
#
# **Настройка на средата (.env файл):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Съображения при конкурентна обработка:**
# - **Ограничения на честотата**: Следете ограничените нива на GitHub Models API при конкурентни заявки
# - **Използване на ресурси**: Вземете под внимание използването на памет и процесор с множество конкурентни агенти
# - **Обработка на грешки**: Изградете надеждно възстановяване при грешки за паралелни операции
#
# ### 🏗️ **Архитектура на конкурентни работни потоци**
#
# ```mermaid
# graph TD
#     A[Стартиране на работния процес] --> B[Паралелно изпълнение]
#     B --> C[Пул агенти 1]
#     B --> D[Пул агенти 2]
#     B --> E[Пул агенти 3]
#     C --> F[Събиране на резултати]
#     D --> F
#     E --> F
#     F --> G[Крайно изходно]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Основни предимства:**
# - **⚡ Производителност**: Значително ускорение чрез паралелно изпълнение
# - **📈 Скалиране**: Обработка на увеличено натоварване без пропорционално увеличение на времето
# - **🔄 Ефективност**: По-добро използване на наличните изчислителни ресурси
# - **🎯 Пропускателна способност**: Обработка на повече работа за същото време
#
# ## 🎨 **Дизайнерски шаблони за конкурентни работни потоци**
#
# ### 🔍 **Конвейр за изследване и анализ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Работен поток за обработка на данни**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Конвейр за създаване на съдържание**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Многоетапна обработка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Корпоративни ползи за производителността**
#
# ### ⚡ **Оптимизация на пропускателната способност**
# - **Паралелно изпълнение**: Множество агенти, работещи едновременно
# - **Използване на ресурси**: Максимална ефективност на наличния капацитет на AI моделите
# - **Намаляване на времето**: Значително съкращаване на общото време за обработка
# - **Скалируема архитектура**: Лесно добавяне на повече конкурентни агенти при нужда
#
# ### 🛡️ **Надеждност и устойчивост**
# - **Толерантност към повреди**: Отделни неуспехи на агенти не спират целия работен поток
# - **Изолация на грешки**: Проблеми в едно конкурентно разклонение не влияят на другите
# - **Плавно деградиране**: Системата продължава да работи дори при намален капацитет на агентите
# - **Механизми за възстановяване**: Автоматично повторение и обработка на грешки при неуспешни операции
#
# ### 📊 **Мониторинг и наблюдаемост**
# - **Проследяване на конкурентно изпълнение**: Наблюдавайте напредъка на всички паралелни операции
# - **Метрики за производителност**: Измерване на ускорението и печалбите от ефективност
# - **Анализи на използването на ресурси**: Оптимизирайте разпределението на конкурентни агенти
# - **Идентифициране на задръствания**: Откривайте и разрешавайте ограничения на производителността
#
# Нека изграждаме високоефективни конкурентни AI работни потоци! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
