# %% [markdown]
# # ⚡ Mtiririko wa Kazi wa Madai Wengi kwa Muda Mmoja kwa Matumizi ya GitHub Models (Python)
#
# ## 📋 Mafunzo ya Usindikaji Sambamba wa Juu
#
# Kitabu hiki cha maelezo kinaonyesha **mifumo ya mtiririko wa kazi kwa wakati mmoja** kwa kutumia Mfumo wa Maaagent wa Microsoft. Utafunzi jinsi ya kujenga mitiririko ya usindikaji sambamba yenye utendaji wa hali ya juu ambapo midaa mingi za AI zinaendesha kwa wakati mmoja, kuongeza sana ufanisi na kuwezesha michakato ya biashara yenye mfululizo wa nyuzi nyingi.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🚀 **Misingi ya Usindikaji Sambamba**
# - **Uendeshaji wa Madai Wengi kwa Muda Mmoja**: Endesha midaa mingi kwa wakati mmoja kwa ufanisi mkubwa
# - **Uratibu wa Mtiririko wa Kazi**: Ratibu shughuli sambamba huku ukidumisha usawa wa data
# - **Uboreshaji wa Utendaji**: Pata kasi kubwa kupitia usindikaji sambamba
# - **Usimamizi wa Rasilimali**: Tumia kwa ufanisi rasilimali za modeli za AI katika shughuli sambamba
#
# ### 🏗️ **Mifumo ya Kuendelea Kwenye Ushirikiano wa Juu**
# - **Usindikaji wa Fork-Join**: Gawanya kazi kwa midaa mingi na kuziunganisha matokeo
# - **Mtiririko wa Kazi Sambamba wa Pipeline**: Awamu za utekelezaji zinazopingana kwa mtiririko usioyumba
# - **Ugawaji Mizigo**: Gawanya kazi kwa usawa kati ya rasilimali za maagent zinazopatikana
# - **Pointi za Ulinganifu**: Ratibu midaa sambamba katika hatua muhimu za mtiririko wa kazi
#
# ### 🏢 **Matumizi ya Ushirikiano wa Wakati Mmoja katika Biashara**
# - **Usindikaji wa Nyaraka Nyingi kwa Wakati Mmoja**: Fanya usindikaji wa nyaraka nyingi kwa wakati mmoja
# - **Uchambuzi wa Maudhui kwa Wakati Halisi**: Uchambuzi sambamba wa mizunguko ya data inayokuja
# - **Uboreshaji wa Usindikaji wa Batch**: Ongeza ufanisi kwa shughuli kubwa za kiwango kikubwa
# - **Uchambuzi wa Njia Nyingi**: Usindikaji sambamba wa aina mbalimbali za maudhui (maneno, picha, data)
#
# ## ⚙️ Mahitaji ya Awali na Usanidi
#
# ### 📦 **Mategemeo Yanayohitajika**
#
# Sakinisha Mfumo wa Maaagent wenye uwezo wa mitiririko ya kazi sambamba:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Usanidi wa GitHub Models**
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Mazingatio kwa Usindikaji Sambamba:**
# - **Mikomo ya Kiwango**: Angalia vikwazo vya kiwango cha API vya GitHub Models kwa maombi sambamba
# - **Matumizi ya Rasilimali**: Tathmini matumizi ya kumbukumbu na CPU kwa midaa mingi sambamba
# - **Utambuzi wa Makosa**: Tekeleza urejeshaji thabiti wa makosa katika shughuli sambamba
#
# ### 🏗️ **Msingi wa Usanifu wa Mtiririko wa Kazi Sambamba**
#
# ```mermaid
# graph TD
#     A[Kuanza kwa Mtiririko wa Kazi] --> B[Utekelezaji Sambamba]
#     B --> C[Maeneo ya Wakala 1]
#     B --> D[Maeneo ya Wakala 2]
#     B --> E[Maeneo ya Wakala 3]
#     C --> F[Ukusanyaji wa Matokeo]
#     D --> F
#     E --> F
#     F --> G[Tokea la Mwisho]
#
#     H[API za Mifano za GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **Manufaa Muhimu:**
# - **⚡ Utendaji**: Kuongeza kasi kubwa kupitia utekelezaji sambamba
# - **📈 Kuweza Kupanuka**: Shughulikia kazi nyingi bila kuongeza wakati kwa uwiano
# - **🔄 Ufanisi**: Matumizi bora ya rasilimali za kompyuta zinazopatikana
# - **🎯 Ufanisi wa Mtiririko**: Fanya kazi zaidi kwa muda uleule
#
# ## 🎨 **Mifumo ya Ubunifu wa Mtiririko wa Kazi Sambamba**
#
# ### 🔍 **Mtiririko wa Utafiti na Uchambuzi**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Mtiririko wa Usindikaji wa Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Mtiririko wa Uundaji Maudhui**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Usindikaji wa Hatua Nyingi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Manufaa ya Utendaji kwa Biashara**
#
# ### ⚡ **Uboreshaji wa Ufanisi wa Mtiririko**
# - **Utekelezaji Sambamba**: Madai wengi wakifanya kazi kwa wakati mmoja
# - **Matumizi ya Rasilimali**: Ufanisi mkubwa wa uwezo wa modeli za AI zinazopatikana
# - **Kupunguza Muda**: Kupunguzwa kwa kiasi kikubwa cha muda wa usindikaji jumla
# - **Usanifu Unaoweza Kupanuka**: Ongeza midaa zaidi sambamba kadri inavyohitajika
#
# ### 🛡️ **Uaminifu na Ustahimilivu**
# - **Uvumilivu wa Hitilafu**: Kushindwa kwa wakala mmoja hakuzuii mtiririko mzima wa kazi
# - **Kutengwa kwa Makosa**: Matatizo katika tawi moja la sambamba hayalisi wengine
# - **Kupungua Kwa Haki**: Mfumo unaendelea kufanya kazi hata kwa uwezo mdogo wa wakala
# - **Miftahuko ya Urejeshaji**: Jaribio la kiotomatiki na utambuzi wa makosa kwa shughuli zilizoshindikana
#
# ### 📊 **Ufuatiliaji na Uwezekano wa Kuchunguza**
# - **Ufuatiliaji wa Utekelezaji Sambamba**: Angalia maendeleo ya shughuli zote sambamba
# - **Vipimo vya Utendaji**: Pima ongezeko la kasi na faida za ufanisi
# - **Uchambuzi wa Matumizi ya Rasilimali**: Boreshaji la upangaji wa midaa sambamba
# - **Utabiri wa Msingi wa Kasi**: Tafuta na tatua vizingiti vya utendaji
#
# Tujenge mitiririko ya kazi yenye utendaji wa hali ya juu wa AI sambamba! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
