# %% [markdown]
# # ⚡ Mipangilio ya Kazi ya Mawakala Yenye Mshikamano na Microsoft Foundry (Python)
#
# ## 📋 Mafunzo ya Kusindika Sawa-sawa kwa Ngazi ya Juu
#
# Daftari hili linaonyesha **mifumo ya mtiririko wa kazi ya pamoja** kwa kutumia Mfumo wa Mawakala wa Microsoft. Utajifunza jinsi ya kujenga mitiririko ya kazi yenye utendaji wa juu, inayosindika kwa usawa ambapo mawakala wa AI wengi hufanya kazi kwa wakati mmoja, kuboresha kwa kiwango kikubwa kasi ya matokeo na kuwezesha michakato ya biashara yenye nyuzi nyingi kwa ustadi.
#
# > **Kumbuka Kuhamisha:** Sampuli hii hapo awali ilitaja Modeli za GitHub. Modeli za GitHub zimefutwa (zitakuwa zimeisha mwezi Julai 2026), hivyo sasa inatumia **Microsoft Foundry** kupitia `FoundryChatClient`, inayolenga Azure OpenAI **API ya Majibu**.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🚀 **Misingi ya Usindikaji wa Pamoja**
# - **Utekelezaji wa Mawakala kwa Wingi**: Endesha mawakala wengi kwa wakati mmoja kwa ufanisi mkubwa
# - **Uratibu wa Mtiririko wa Kazi**: Panga operesheni zinazofanyika kwa pamoja wakati ukidumisha muafaka wa data
# - **Uboreshaji wa Utendaji**: Fikia ongezeko kubwa la kasi kupitia usindikaji wa pamoja
# - **Usimamizi wa Rasilimali**: Tumia rasilimali za modeli ya AI kwa ufanisi katika operesheni zinazofanyika kwa pamoja
#
# ### 🏗️ **Mifumo ya Juu ya Mshikamano**
# - **Usindikaji wa Fork-Join**: Gawanya kazi kwa mawakala wengi na muungano wa matokeo
# - **Usawa wa Mlolongo**: Hatua za utekelezaji zinazozunguka kwa usawa wa kuendelea
# - **Ugawaji Mizigo**: Sambaza kazi kwa usawa kati ya rasilimali za mawakala zinapatikana
# - **Mambo ya Msimamizi**: Panga mawakala wanaofanya kazi kwa pamoja katika hatua muhimu za mtiririko wa kazi
#
# ### 🏢 **Programu za Biashara Zinazofanya Kazi kwa Pamoja**
# - **Usindikaji wa Nyaraka Nzito**: Tumia nyaraka nyingi kwa wakati mmoja
# - **Uchambuzi wa Maudhui kwa Wakati Halisi**: Uchambuzi wa pamoja wa data zinazoingia
# - **Uboreshaji wa Usindikaji wa Kikundi**: Ongeza kasi ya matokeo kwa operesheni kubwa
# - **Uchambuzi wa Njia Nyingine Mbalimbali**: Usindikaji sambamba wa aina tofauti za maudhui (maandishi, picha, data)
#
# ## ⚙️ Mahitaji na Usanidi
#
# ### 📦 **Vitegemezi Vinavyohitajika**
#
# Sakinisha Mfumo wa Mawakala wenye uwezo wa mitiririko ya kazi ya pamoja:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Usanidi wa Microsoft Foundry**
#
# Ingia kwa kutumia Azure CLI (`az login`) ili `AzureCliCredential` iweze kuthibitisha, kisha weka maelezo ya mradi wako wa Microsoft Foundry.
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Mambo ya Kuzingatia Katika Usindikaji wa Pamoja:**
# - **Mipaka ya Viwango**: Angalia mipaka ya viwango vya Azure OpenAI kwa maombi ya pamoja
# - **Matumizi ya Rasilimali**: Fikiria matumizi ya kumbukumbu na CPU pamoja na mawakala wengi wanaofanya kazi kwa pamoja
# - **Ushughulikiaji wa Makosa**: Tekeleza tiba thabiti ya makosa kwa operesheni sambamba
#
# ### 🏗️ **Mimminyo ya Mtiririko wa Kazi wa Pamoja**
#
# ```mermaid
# graph TD
#     A[Anza Kazi] --> B[Utekelezaji Sambamba]
#     B --> C[Kikundi cha Wakala 1]
#     B --> D[Kikundi cha Wakala 2]
#     B --> E[Kikundi cha Wakala 3]
#     C --> F[Muhtasari wa Matokeo]
#     D --> F
#     E --> F
#     F --> G[Matokeo ya Mwisho]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Faida Muhimu:**
# - **⚡ Utendaji**: Ongezeko kubwa la kasi kutokana na utekelezaji sambamba
# - **📈 Ukuaji Rahisi**: Himili kazi zilizoongezeka bila kuongeza muda kwa kiwango sawa
# - **🔄 Ufanisi**: Matumizi bora ya rasilimali za kompyuta zinazopatikana
# - **🎯 Uzalishaji**: Fanyia kazi nyingi zaidi kwa muda uleule
#
# ## 🎨 **Mifumo ya Ubunifu wa Mtiririko wa Kazi wa Pamoja**
#
# ### 🔍 **Mlolongo wa Utafiti na Uchambuzi**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Mlolongo wa Usindikaji wa Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Mlolongo wa Uundaji Maudhui**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Usindikaji wa Hatua Nyingi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Faida za Utendaji kwa Biashara**
#
# ### ⚡ **Uboreshaji wa Uzalishaji**
# - **Utekelezaji wa Sambamba**: Mawakala wengi wakifanya kazi kwa wakati mmoja
# - **Matumizi ya Rasilimali**: Ufanisi mkubwa wa uwezo wa modeli ya AI unaopatikana
# - **Kupunguza Muda**: Kupungua kwa muda wa usindikaji kwa kiasi kikubwa
# - **Mimminyo Rahisi ya Kupanuliwa**: Ongeza mawakala wapya wanaofanya kazi kwa pamoja kwa urahisi unapotakiwa
#
# ### 🛡️ **Uaminifu na Ustahimilivu**
# - **Uvumilivu wa Kasoro**: Kushindwa kwa wakala mmoja hakusimamishi mtiririko mzima wa kazi
# - **Kutengwa kwa Makosa**: Matatizo katika tawi moja la pamoja hayagusi mengine
# - **Kupungua Kwa Hali Polepole**: Mfumo unaendelea kazi hata ikipungua uwezo wa mawakala
# - **Mekanizimu za Kupona**: Jaribio la moja kwa moja tena na usimamizi wa makosa kwa operesheni zilizoshindwa
#
# ### 📊 **Ufuatiliaji na Uwezekano wa Kuchunguza**
# - **Ufuatiliaji wa Utekelezaji wa Pamoja**: Angalia maendeleo ya operesheni zote sambamba
# - **Vipimo vya Utendaji**: Pima ongezeko la kasi na faida za ufanisi
# - **Uchambuzi wa Matumizi ya Rasilimali**: Boresha ugawaji wa mawakala wanaofanya kazi kwa pamoja
# - **Utambuzi wa Vikwazo**: Tafuta na tatua vikwazo vya utendaji
#
# Hebu tujenge mitiririko ya kazi ya AI yenye utendaji wa juu inayofanya kazi kwa pamoja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
