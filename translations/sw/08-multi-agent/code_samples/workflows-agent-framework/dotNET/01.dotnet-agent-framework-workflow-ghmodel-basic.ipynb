# %% [markdown]
# # 🔄 Mifumo Msingi ya Wakala na Azure OpenAI (API za Majibu) (.NET)
#
# ## 📋 Mafunzo ya Uratibu wa Mifumo
#
# Daftari hili linaonyesha jinsi ya kujenga **mifumo ngumu ya wakala** kwa kutumia Microsoft Agent Framework kwa .NET na Azure OpenAI (API za Majibu). Utajifunza kuunda michakato ya biashara yenye hatua nyingi ambapo mawakala wa AI hushirikiana kufanikisha kazi ngumu kupitia mifumo ya uratibu yenye muundo.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🏗️ **Misingi ya Mimarisha ya Mifumo**
# - **Mjenzi wa Mifumo**: Tengeneza na ratibu michakato ya AI yenye hatua nyingi na ngumu
# - **Uratibu wa Wakala**: Ratibu mawakala maalum wengi ndani ya mifumo
# - **Azure OpenAI (API za Majibu)**: Tumia Azure OpenAI API za Majibu katika mifumo
# - **Ubunifu wa Mifumo wa Kuonesha**: Tengeneza na ona miundo ya mifumo kwa ufahamu bora
#
# ### 🔄 **Mifumo ya Uratibu wa Michakato**
# - **Uendeshaji Mfululizo**: Unganisha kazi nyingi za wakala kwa mpangilio wa mantiki
# - **Usimamizi wa Hali**: Hifadhi muktadha na mtiririko wa data katika hatua za mfumo
# - **Utambuzi wa Makosa**: Tekeleza urejesho thabiti wa makosa na ustahimilivu wa mfumo
# - **Uboreshaji wa Utendaji**: Tengeneza mifumo yenye ufanisi kwa shughuli za kiwango cha biashara
#
# ### 🏢 **Matumizi ya Mifumo ya Biashara**
# - **Uthibiti wa Michakato ya Biashara**: Thibitisha mifumo ngumu ya shirika
# - **Mfumo wa Uzalishaji wa Maudhui**: Mifumo ya uhariri na hatua za mapitio na idhini
# - **Uthibiti wa Huduma kwa Wateja**: Ufumbuzi wa maswali ya wateja kwa hatua nyingi
# - **Mifumo ya Usindikaji Data**: Mifumo ya ETL yenye mabadiliko yenye nguvu za AI
#
# ## ⚙️ Mahitaji & Usanidi
#
# ### 📦 **Pakiti Muhimu za NuGet**
#
# Maonyesho haya ya mfumo hutumia pakiti kadhaa kuu za .NET:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Usanidi wa Azure OpenAI**
#
# **Usanidi wa Mazingira (faili la .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Ufikiaji wa Azure OpenAI:**
# 1. Tengeneza rasilimali ya Azure OpenAI kwenye lango la Azure
# 2. Sambaza mfano (kwa mfano, `gpt-5-mini`) na kumbuka jina la usambazaji
# 3. Ingia kwa `az login` na usanidi wa vigezo vya mazingira kama ilivyoonyeshwa hapo juu
#
# ### 🏗️ **Muhtasari wa Mimarisha ya Mifumo**
#
# ```mermaid
# graph TD
#     A[Mjenzi wa Mchakato wa Kazi] --> B[Rejista ya Wakala]
#     B --> C[Kifundi cha Utekelezaji wa Mchakato wa Kazi]
#     C --> D[Agent 1: Mzalishaji wa Yaliyomo
#     C --> E[Agent 2: Mkaguzi wa Yaliyomo
#     D --> F[Matokeo ya Mchakato wa Kazi]
#     E --> F
#     G[Azure OpenAI (API za Majibu)] --> D
#     G --> E
# ```
#
# **Vipengele Muhimu:**
# - **WorkflowBuilder**: Kifaa kikuu cha uratibu wa kubuni mifumo
# - **AIAgent**: Mawakala binafsi maalum wenye uwezo maalum
# - **Azure OpenAI Client**: Uunganisho wa Azure OpenAI Responses API
# - **Execution Context**: Inasimamia hali na mtiririko wa data kati ya hatua za mfumo
#
# ## 🎨 **Mifumo ya Ubunifu wa Mifumo ya Biashara**
#
# ### 📝 **Mfumo wa Uzalishaji Maudhui**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Mfumo wa Usindikaji Hati**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Mfumo wa Akili ya Biashara**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Uthibiti wa Huduma kwa Wateja**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Manufaa ya Biashara**
#
# ### 🎯 **Uaminifu & Uwezo wa Upanuzi**
# - **Utendaji wa Hakika**: Matokeo thabiti na yanayojirudia ya mifumo
# - **Urejeshaji wa Makosa**: Ushughulikiaji mwema wa kushindwa katika hatua yoyote ya mfumo
# - **Ufuatiliaji wa Utendaji**: Fuata vipimo vya utendaji na fursa za uboreshaji
# - **Usimamizi wa Rasilimali**: Ugawaji na matumizi bora ya rasilimali za mfano wa AI
#
# ### 🔒 **Usalama & Uzingatiaji**
# - **Uthibitishaji Salama**: Uthibitishaji wa Microsoft Entra ID kupitia `az login` (AzureCliCredential)
# - **Mafuatiliaji ya Ukaguzi**: Kumbukumbu kamili za utekelezaji wa mfumo na pointi za maamuzi
# - **Udhibiti wa Ufikiaji**: Ruhusa maalum za utekelezaji na ufuatiliaji wa mfumo
# - **Faragha ya Data**: Ushughulikiaji salama wa taarifa nyeti ndani ya mifumo
#
# ### 📊 **Uchunguzi & Usimamizi**
# - **Ubunifu wa Mifumo wa Kuonesha**: Uwakilishi wazi wa mtiririko wa michakato na utegemezi
# - **Ufuatiliaji wa Utekelezaji**: Ufuatiliaji wa wakati halisi wa maendeleo na utendaji wa mfumo
# - **Ripoti za Makosa**: Uchambuzi wa kina wa makosa na uwezo wa utatuzi wa matatizo
# - **Uchanganuzi wa Utendaji**: Vipimo vya uboreshaji na mipango ya uwezo
#
# Tuzitangaze mfumo wako wa kwanza wa AI wa kiwango cha biashara! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
