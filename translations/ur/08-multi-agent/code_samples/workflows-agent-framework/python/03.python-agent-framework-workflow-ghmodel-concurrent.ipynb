# %% [markdown]
# # ⚡ GitHub ماڈلز (Python) کے ساتھ متوازی ایجنٹ ورک فلو
#
# ## 📋 اعلیٰ درجے کی متوازی پروسیسنگ کی تربیت
#
# یہ نوٹ بک مائیکروسافٹ ایجنٹ فریم ورک کا استعمال کرتے ہوئے **متوازی ورک فلو پیٹرنز** کی مثال پیش کرتی ہے۔ آپ سیکھیں گے کہ کس طرح اعلیٰ کارکردگی والے، متوازی پروسیسنگ ورک فلو تیار کیے جائیں جہاں متعدد AI ایجنٹس بیک وقت کام کرتے ہیں، جس سے کام کی رفتار میں نمایاں اضافہ ہوتا ہے اور پیچیدہ ملٹی تھریڈڈ کاروباری عمل ممکن ہوتے ہیں۔
#
# ## 🎯 تعلیمی مقاصد
#
# ### 🚀 **متوازی پروسیسنگ کے اصول**
# - **متوازی ایجنٹ کا نفاذ**: زیادہ سے زیادہ کارکردگی کے لیے کئی ایجنٹس کو بیک وقت چلائیں
# - **ورک فلو کی ترتیب**: ڈیٹا کی مستقل مزاجی کو برقرار رکھتے ہوئے متوازی آپریشنز کی ہم آہنگی کریں
# - **کارکردگی کی بہتری**: متوازی پروسیسنگ کے ذریعے نمایاں تیز رفتاری حاصل کریں
# - **وسائل کا انتظام**: متوازی آپریشنز میں AI ماڈل کے وسائل کو مؤثر طریقے سے استعمال کریں
#
# ### 🏗️ **اعلیٰ درجے کے متوازی نمونے**
# - **فورک-جوائن پروسیسنگ**: کام کو متعدد ایجنٹس میں تقسیم کریں اور نتائج کو یکجا کریں
# - **پائپ لائن متوازی کاری**: لگاتار تھرو پٹ کے لیے عملدرآمد کے اسٹیجز کو اوورلیپ کریں
# - **لوڈ بیلنسنگ**: دستیاب ایجنٹ وسائل میں کام کو برابر تقسیم کریں
# - **ہم آہنگی کے پوائنٹس**: اہم ورک فلو مراحل پر متوازی ایجنٹس کی ہم آہنگی
#
# ### 🏢 **انٹرپرائز متوازی ایپلیکیشنز**
# - **اعلی حجم دستاویزات کی پروسیسنگ**: متعدد دستاویزات کو بیک وقت پروسیس کریں
# - **ریئل ٹائم مواد کا تجزیہ**: آنے والے ڈیٹا سٹریمز کا متوازی تجزیہ
# - **بیچ پروسیسنگ کی بہتری**: بڑے پیمانے پر کام کی رفتار زیادہ سے زیادہ کریں
# - **کثیر وضعی تجزیہ**: مختلف مواد کی اقسام (متن، تصاویر، ڈیٹا) کی متوازی پروسیسنگ
#
# ## ⚙️ ضروریات اور ترتیب
#
# ### 📦 **ضروری انحصار**
#
# ایجنٹ فریم ورک کو متوازی ورک فلو صلاحیتوں کے ساتھ انسٹال کریں:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub ماڈلز کی ترتیب**
#
# **ماحول کی ترتیب (.env فائل):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **متوازی پروسیسنگ کے امور:**
# - **ریٹ لیمیٹس**: متوازی درخواستوں کے لیے GitHub ماڈلز API کی حد بندی مانیٹر کریں
# - **وسائل کا استعمال**: متعدد متوازی ایجنٹس کے ساتھ میموری اور CPU کے استعمال پر غور کریں
# - **خرابیوں کا انتظام**: متوازی آپریشنز کے لیے پختہ ایرر ریکوری نافذ کریں
#
# ### 🏗️ **متوازی ورک فلو آرکیٹیکچر**
#
# ```mermaid
# graph TD
#     A[ورک فلو شروع] --> B[ہم وقت عمل درآمد]
#     B --> C[ایجنٹ پول 1]
#     B --> D[ایجنٹ پول 2]
#     B --> E[ایجنٹ پول 3]
#     C --> F[نتیجہ اجتماع]
#     D --> F
#     E --> F
#     F --> G[حتمی پیداوار]
#
#     H[گیٹ ہب ماڈلز API] --> C
#     H --> D
#     H --> E
# ```
#
# **اہم فوائد:**
# - **⚡ کارکردگی**: متوازی نفاذ کے ذریعے نمایاں تیز روی
# - **📈 توسیع پذیری**: بوجھ میں اضافے کو ناطق وقت میں بڑھائے بغیر سنبھالنا
# - **🔄 کفایت شعاری**: دستیاب کمپیوٹیشنل وسائل کا بہتر استعمال
# - **🎯 تھرو پٹ**: ایک ہی وقت میں زیادہ کام کی پروسیسنگ
#
# ## 🎨 **متوازی ورک فلو ڈیزائن کے نمونے**
#
# ### 🔍 **تحقیقی و تجزیاتی پائپ لائن**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ڈیٹا پروسیسنگ ورک فلو**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **مواد تخلیق کی پائپ لائن**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **کئی مراحل کی پروسیسنگ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **انٹرپرائز کارکردگی کے فوائد**
#
# ### ⚡ **تھرو پٹ میں بہتری**
# - **متوازی نفاذ**: کئی ایجنٹس بیک وقت کام کر رہے ہیں
# - **وسائل کا استعمال**: دستیاب AI ماڈل کی صلاحیت کا زیادہ سے زیادہ استعمال
# - **وقت کی کمی**: مجموعی پروسیسنگ کے وقت میں نمایاں کمی
# - **توسیع پذیر آرکیٹیکچر**: ضرورت پڑنے پر آسانی سے مزید متوازی ایجنٹس شامل کریں
#
# ### 🛡️ **اعتماد اور مزاحمت**
# - **خرابی کا برداشت**: انفرادی ایجنٹ کی ناکامیاں پورے ورک فلو کو متاثر نہیں کرتیں
# - **خرابی کی علیحدگی**: ایک متوازی شاخ کی مشکلات دوسرے کو متاثر نہیں کرتیں
# - **حساس تنزل**: محدود ایجنٹ صلاحیت کے باوجود نظام چلتا رہتا ہے
# - **بازیابی کے طریقے**: ناکام آپریشنز کے لیے خودکار دوبارہ کوشش اور خرابی کی ہینڈلنگ
#
# ### 📊 **مانیٹرنگ اور دیکھ بھال**
# - **متوازی نفاذ کی نگرانی**: تمام متوازی آپریشنز کی پیش رفت کا مشاہدہ کریں
# - **کارکردگی کے میٹرکس**: تیزرفتاری اور کفایت شعاری کی پیمائش کریں
# - **وسائل کے استعمال کا تجزیہ**: متوازی ایجنٹ کی تقسیم کو بہتر بنائیں
# - **رکاوٹ کی شناخت**: کارکردگی کی رکاوٹوں کو تلاش کریں اور حل کریں
#
# آئیے اعلیٰ کارکردگی والے متوازی AI ورک فلو بنائیں! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ڈس کلیمر**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ جبکہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم اس بات سے آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا عدم درستیاں ہو سکتی ہیں۔ اصل دستاویز اپنے مادری زبان میں مستند ماخذ سمجھی جائے گی۔ حساس معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم قبول نہیں کرتے۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
