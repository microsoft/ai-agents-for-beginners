# %% [markdown]
# # 🔄 ایزور اوپن اے آئی (Responses API) (.NET) کے ساتھ بنیادی ایجنٹ ورک فلو
#
# ## 📋 ورک فلو آرکسٹریشن ٹیوٹوریل
#
# یہ نوٹ بک دکھاتی ہے کہ مائیکروسافٹ ایجنٹ فریم ورک برائے .NET اور ازور اوپن اے آئی (Responses API) کا استعمال کرتے ہوئے پیچیدہ **ایجنٹ ورک فلو** کیسے بنائے جائیں۔ آپ سیکھیں گے کہ کس طرح کثیر مرحلہ کاروباری عمل بنائے جائیں جہاں AI ایجنٹس مل کر منظم آرکسٹریشن پیٹرنز کے ذریعے پیچیدہ کام انجام دیں۔
#
# ## 🎯 سیکھنے کے مقاصد
#
# ### 🏗️ **ورک فلو آرکیٹیکچر کی بنیادی باتیں**
# - **ورک فلو بلڈر**: پیچیدہ کثیر مرحلہ AI عملوں کو ڈیزائن اور آرکسٹریٹ کریں
# - **ایجنٹ کوآرڈینیشن**: ورک فلو میں متعدد مخصوص ایجنٹس کو مربوط کریں
# - **ایزور اوپن اے آئی (Responses API)**: ورک فلو میں Azure OpenAI Responses API کا استعمال کریں
# - **بصری ورک فلو ڈیزائن**: بہتر فہم کے لیے ورک فلو ڈھانچے بنائیں اور ظاہر کریں
#
# ### 🔄 **پروسیس آرکسٹریشن پیٹرنز**
# - **تسلسل سے عمل کاری**: متعدد ایجنٹ کے کام منطقی ترتیب میں جوڑیں
# - **اسٹیٹ مینجمنٹ**: ورک فلو مراحل کے درمیان سیاق و سباق اور ڈیٹا کے بہاؤ کو برقرار رکھیں
# - **خرابی کا حل**: مضبوط غلطی کی بازیابی اور ورک فلو کی لچکدار صلاحیت نافذ کریں
# - **کارکردگی کی اصلاح**: انٹرپرائز سطح کے آپریشنز کے لیے موثر ورک فلو ڈیزائن کریں
#
# ### 🏢 **انٹرپرائز ورک فلو ایپلیکیشنز**
# - **کاروباری عمل کی خود کاری**: پیچیدہ تنظیمی ورک فلو کو خودکار بنائیں
# - **مواد کی پیداوار پائپ لائن**: جائزہ اور منظوری کے مراحل کے ساتھ ادارتی ورک فلو
# - **کسٹمر سروس کی خود کاری**: کثیر مرحلہ صارفین کی انکوائری کا حل
# - **ڈیٹا پروسیسنگ ورک فلو**: AI سے چلنے والے تبدیلی کے ساتھ ETL ورک فلو
#
# ## ⚙️ ضروریات اور سیٹ اپ
#
# ### 📦 **ضروری NuGet پیکجز**
#
# یہ ورک فلو ڈیمونسٹیشن کئی اہم .NET پیکیجز استعمال کرتا ہے:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI کنفیگریشن**
#
# **ماحول کی ترتیب (.env فائل):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI تک رسائی:**
# 1. ازور پورٹل میں Azure OpenAI ریسورس بنائیں
# 2. ایک ماڈل تعینات کریں (مثال کے طور پر، `gpt-5-mini`) اور تعیناتی کا نام نوٹ کریں
# 3. `az login` کے ساتھ سائن ان کریں اور اوپر دکھائے گئے ماحول کی متغیرات کو ترتیب دیں
#
# ### 🏗️ **ورک فلو آرکیٹیکچر کا جائزہ**
#
# ```mermaid
# graph TD
#     A[ورک فلو بلڈر] --> B[ایجنٹ رجسٹری]
#     B --> C[ورک فلو ایگزیکیوشن انجن]
#     C --> D[Agent 1: مواد جنریٹر]
#     C --> E[Agent 2: مواد کا جائزہ لینے والا]
#     D --> F[ورک فلو کے نتائج]
#     E --> F
#     G[ایزور اوپن اے آئی (ریسپانسز API)] --> D
#     G --> E
# ```
#
# **اہم اجزاء:**
# - **WorkflowBuilder**: ورک فلو ڈیزائن کرنے کے لیے مرکزی آرکسٹریشن انجن
# - **AIAgent**: مخصوص صلاحیتوں کے حامل انفرادی مخصوص ایجنٹس
# - **Azure OpenAI کلائنٹ**: Azure OpenAI Responses API انضمام
# - **Execution Context**: ورک فلو مراحل کے درمیان اسٹیٹ اور ڈیٹا کے بہاؤ کا انتظام کرتا ہے
#
# ## 🎨 **انٹرپرائز ورک فلو ڈیزائن پیٹرنز**
#
# ### 📝 **مواد کی پیداوار کا ورک فلو**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **دستاویز پروسیسنگ پائپ لائن**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **کاروباری انٹیلی جنس ورک فلو**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **کسٹمر سروس کی خود کاری**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **انٹرپرائز کے فوائد**
#
# ### 🎯 **اعتمادیت اور توسیع پذیری**
# - **متعین کردہ عمل درآمد**: متسلسل، دہرائے جانے والے ورک فلو نتائج
# - **خرابی کی بازیابی**: ورک فلو کے کسی بھی مرحلے میں ناکامیوں کا شائستہ حل
# - **کارکردگی کی نگرانی**: عملدرآمد میٹرکس اور اصلاح کے مواقع پر نظر رکھیں
# - **وسائل کا انتظام**: AI ماڈل وسائل کی مؤثر تقسیم اور استعمال
#
# ### 🔒 **سیکیورٹی اور تعمیل**
# - **محفوظ توثیق**: `az login` (AzureCliCredential) کے ذریعے Microsoft Entra ID کی توثیق
# - **آڈٹ ٹریلز**: ورک فلو کے عمل درآمد اور فیصلہ سازی کے مکمل لاگز
# - **رسائی کنٹرول**: ورک فلو کے عمل درآمد اور نگرانی کے لیے باریک بینی پر مبنی اجازتیں
# - **ڈیٹا کی رازداری**: ورک فلو کے دوران حساس معلومات کی محفوظ ہینڈلنگ
#
# ### 📊 **مشاہداتی صلاحیت اور انتظام**
# - **بصری ورک فلو ڈیزائن**: عمل کے بہاؤ اور انحصار کا واضح مظاہرہ
# - **عمل درآمد کی نگرانی**: ورک فلو کی ترقی اور کارکردگی کا حقیقی وقت میں نظارت
# - **غلطی کی رپورٹنگ**: تفصیلی غلطی تجزیہ اور ڈیبگنگ کی صلاحیتیں
# - **کارکردگی کا تجزیہ**: اصلاح اور صلاحیت کی منصوبہ بندی کے لیے میٹرکس
#
# آئیں آپ کا پہلا انٹرپرائز تیار AI ورک فلو بنائیں! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ڈس کلیمر**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ جبکہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم اس بات سے آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا عدم درستیاں ہو سکتی ہیں۔ اصل دستاویز اپنے مادری زبان میں مستند ماخذ سمجھی جائے گی۔ حساس معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم قبول نہیں کرتے۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
