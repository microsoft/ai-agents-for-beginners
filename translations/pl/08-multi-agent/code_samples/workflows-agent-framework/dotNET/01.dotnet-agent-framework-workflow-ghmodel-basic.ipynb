# %% [markdown]
# # 🔄 Podstawowe przepływy pracy agentów z Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Samouczek orkiestracji przepływów pracy
#
# Ten notatnik demonstruje, jak zbudować zaawansowane **przepływy pracy agentów** przy użyciu Microsoft Agent Framework dla .NET oraz Azure OpenAI (Responses API). Nauczysz się tworzyć wieloetapowe procesy biznesowe, w których agenci AI współpracują, aby zrealizować złożone zadania za pomocą ustrukturyzowanych wzorców orkiestracji.
#
# ## 🎯 Cele nauki
#
# ### 🏗️ **Podstawy architektury przepływów pracy**
# - **Workflow Builder**: Projektowanie i orkiestracja złożonych wieloetapowych procesów AI
# - **Koordynacja agentów**: Koordynacja wielu wyspecjalizowanych agentów w przepływach pracy
# - **Azure OpenAI (Responses API)**: Wykorzystanie Azure OpenAI Responses API w przepływach pracy
# - **Wizualne projektowanie przepływów pracy**: Tworzenie i wizualizacja struktur przepływów pracy dla lepszego zrozumienia
#
# ### 🔄 **Wzorce orkiestracji procesów**
# - **Przetwarzanie sekwencyjne**: Łączenie wielu zadań agentów w logicznym porządku
# - **Zarządzanie stanem**: Utrzymywanie kontekstu i przepływu danych między etapami przepływu pracy
# - **Obsługa błędów**: Implementacja solidnej obsługi błędów i odporności przepływów pracy
# - **Optymalizacja wydajności**: Projektowanie efektywnych przepływów pracy na potrzeby przedsiębiorstw
#
# ### 🏢 **Zastosowania przepływów pracy w przedsiębiorstwach**
# - **Automatyzacja procesów biznesowych**: Automatyzacja złożonych przepływów organizacyjnych
# - **Linia produkcji treści**: Redakcyjne przepływy pracy z etapami przeglądu i zatwierdzania
# - **Automatyzacja obsługi klienta**: Wieloetapowe rozwiązywanie zapytań klientów
# - **Przepływy pracy przetwarzania danych**: ETL z transformacjami wspomaganymi AI
#
# ## ⚙️ Wymagania wstępne i konfiguracja
#
# ### 📦 **Wymagane pakiety NuGet**
#
# Ta demonstracja przepływu pracy wykorzystuje kilka kluczowych pakietów .NET:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Konfiguracja Azure OpenAI**
#
# **Konfiguracja środowiska (plik .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Dostęp do Azure OpenAI:**
# 1. Utwórz zasób Azure OpenAI w portalu Azure
# 2. Wdróż model (np. `gpt-5-mini`) i zanotuj nazwę wdrożenia
# 3. Zaloguj się używając `az login` i skonfiguruj zmienne środowiskowe jak pokazano powyżej
#
# ### 🏗️ **Przegląd architektury przepływów pracy**
#
# ```mermaid
# graph TD
#     A[Kreator Przepływów Pracy] --> B[Rejestr Agentów]
#     B --> C[Silnik Wykonywania Przepływów Pracy]
#     C --> D[Agent 1: Generator Treści]
#     C --> E[Agent 2: Recenzent Treści]
#     D --> F[Wyniki Przepływów Pracy]
#     E --> F
#     G[Azure OpenAI (API odpowiedzi)] --> D
#     G --> E
# ```
#
# **Kluczowe komponenty:**
# - **WorkflowBuilder**: Główny silnik orkiestracji do projektowania przepływów pracy
# - **AIAgent**: Pojedynczy wyspecjalizowany agent ze specyficznymi możliwościami
# - **Azure OpenAI Client**: Integracja z Azure OpenAI Responses API
# - **Execution Context**: Zarządza stanem i przepływem danych między etapami przepływu pracy
#
# ## 🎨 **Wzorce projektowe przepływów pracy dla przedsiębiorstw**
#
# ### 📝 **Przepływ pracy produkcji treści**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Linia przetwarzania dokumentów**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Przepływ pracy analizy biznesowej**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Automatyzacja obsługi klienta**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Korzyści dla przedsiębiorstw**
#
# ### 🎯 **Niezawodność i skalowalność**
# - **Deterministyczne wykonanie**: Spójne, powtarzalne wyniki przepływu pracy
# - **Odzyskiwanie po błędach**: Łagodne radzenie sobie z awariami na dowolnym etapie przepływu pracy
# - **Monitorowanie wydajności**: Śledzenie metryk wykonania i możliwości optymalizacji
# - **Zarządzanie zasobami**: Efektywna alokacja i wykorzystanie zasobów modeli AI
#
# ### 🔒 **Bezpieczeństwo i zgodność**
# - **Bezpieczna autoryzacja**: Uwierzytelnianie Microsoft Entra ID przez `az login` (AzureCliCredential)
# - **Ślady audytu**: Pełne logowanie wykonania przepływu pracy i punktów decyzyjnych
# - **Kontrola dostępu**: Szczegółowe uprawnienia do wykonywania i monitorowania przepływów pracy
# - **Prywatność danych**: Bezpieczne przetwarzanie wrażliwych danych w przepływach pracy
#
# ### 📊 **Obserwowalność i zarządzanie**
# - **Wizualne projektowanie przepływów pracy**: Czytelna reprezentacja procesów i zależności
# - **Monitorowanie wykonania**: Śledzenie przebiegu i wydajności przepływu pracy w czasie rzeczywistym
# - **Raportowanie błędów**: Szczegółowa analiza błędów i możliwości debugowania
# - **Analiza wydajności**: Metryki do optymalizacji i planowania zasobów
#
# Zbudujmy Twój pierwszy gotowy na przedsiębiorstwo przepływ pracy AI! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Zastrzeżenie**:
# Niniejszy dokument został przetłumaczony za pomocą usługi tłumaczenia AI [Co-op Translator](https://github.com/Azure/co-op-translator). Choć dążymy do dokładności, prosimy pamiętać, że automatyczne tłumaczenia mogą zawierać błędy lub niedokładności. Oryginalny dokument w jego języku źródłowym należy uznawać za autorytatywne źródło. W przypadku informacji krytycznych zalecane jest skorzystanie z profesjonalnego tłumaczenia wykonanego przez człowieka. Nie ponosimy odpowiedzialności za jakiekolwiek nieporozumienia lub błędne interpretacje wynikające z użycia tego tłumaczenia.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
