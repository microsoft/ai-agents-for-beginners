# %% [markdown]
# # ⚡ GitHubi mudelitega samaaegsed agendi töövood (Python)
#
# ## 📋 Täiustatud paralleeltöötluse juhend
#
# See märkmik demonstreerib **samaaegseid töövoo mustreid** kasutades Microsoft Agent Frameworki. Õpid, kuidas ehitada kõrge jõudlusega paralleeltöötluse töövooge, kus mitu tehisintellekti agenti töötavad samaaegselt, parandades oluliselt läbilaskevõimet ja võimaldades keerukaid mitmelõimelisi äriprotsesse.
#
# ## 🎯 Õpieesmärgid
#
# ### 🚀 **Samaaegse töötluse põhitõed**
# - **Paralleelne agendi käivitamine**: Käivita mitu agenti samaaegselt maksimaalse efektiivsuse saavutamiseks
# - **Töövoo orkestreerimine**: Koordineeri samaaegseid toiminguid, säilitades andmete järjepidevuse
# - **Jõudluse optimeerimine**: Saavuta märkimisväärne kiirendus paralleeltöötluse abil
# - **Ressursside haldamine**: Kasuta AI mudelite ressursse efektiivselt samaaegsete tegevuste jooksul
#
# ### 🏗️ **Täpsemad samaaegsuse mustrid**
# - **Fork-Join töötlus**: Jaga töö mitmele agendile ja koonda tulemused
# - **Torustiku paralleelsus**: Ülekattuvad täitmisetapid pideva läbilaskevõime tagamiseks
# - **Koormuse tasakaalustamine**: Jaota töö ühtlaselt saadaolevate agentide ressursside vahel
# - **Sünkroniseerimise punktid**: Koordineeri samaaegseid agente kriitilistes töövoo etappides
#
# ### 🏢 **Ettevõtte samaaegsed rakendused**
# - **Suure mahuga dokumentide töötlemine**: Töötle mitut dokumenti samaaegselt
# - **Reaalajas sisuanalüüs**: Samaegne sissetulevate andmevoogude analüüs
# - **Pakkide töötlemise optimeerimine**: Maksimeeri läbilaskevõime suuremahuliste toimingute jaoks
# - **Mitmemodaalne analüüs**: Erinevate sisutüüpide (tekst, pildid, andmed) paralleeltöötlus
#
# ## ⚙️ Eeldused ja seadistamine
#
# ### 📦 **Nõutavad sõltuvused**
#
# Paigalda Agent Framework samaaegsete töövoo võimalustega:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHubi mudelite seadistamine**
#
# **Keskkonna seadistamine (.env fail):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Samaaegse töötluse kaalutlused:**
# - **Piirangud**: Jälgi GitHubi mudelite API kiiruspiiranguid samaaegsete päringute puhul
# - **Ressursside kasutus**: Arvesta mälu ja protsessori kasutusega mitme samaaegse agendi korral
# - **Vigade käsitlemine**: Rakenda robustseid taastemehhanisme paralleelsete toimingute jaoks
#
# ### 🏗️ **Samaaegse töövoo arhitektuur**
#
# ```mermaid
# graph TD
#     A[Töövoo Algus] --> B[Kõrvaline Käivitus]
#     B --> C[Agentide Grupp 1]
#     B --> D[Agentide Grupp 2]
#     B --> E[Agentide Grupp 3]
#     C --> F[Tulemuste Kogumine]
#     D --> F
#     E --> F
#     F --> G[Lõplik Väljund]
#
#     H[GitHub Mudelid API] --> C
#     H --> D
#     H --> E
# ```
#
# **Peamised eelised:**
# - **⚡ Jõudlus**: Märkimisväärne kiirendus paralleelkäivituse kaudu
# - **📈 Skaalautuvus**: Koormuse kasv ilma proportsionaalse aja suurenemiseta
# - **🔄 Tõhusus**: Parema olemasolevate arvutusressursside kasutamine
# - **🎯 Läbilaskevõime**: Rohkem töötlust samal aja jooksul
#
# ## 🎨 **Samaaegse töövoo disainimustrid**
#
# ### 🔍 **Uuringute ja analüüsi torustik**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Andmetöötluse töövoog**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisu loomise torustik**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Mitmeastmeline töötlus**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Ettevõtte jõudluse eelised**
#
# ### ⚡ **Läbilaskevõime optimeerimine**
# - **Paralleelne täitmine**: Mitmed agentid töötavad samaaegselt
# - **Ressursside kasutuse efektiivsus**: Maksimaalne AI mudelite võimsuse kasutamine
# - **Ajavähendus**: Märkimisväärne kogutöötlusaja langus
# - **Skaalautuv arhitektuur**: Vajadusel lisa kergesti rohkem samaaegseid agente
#
# ### 🛡️ **Usaldusväärsus ja vastupidavus**
# - **Riketaluvus**: Üksikute agentide tõrked ei peata kogu töövoogu
# - **Vigade isoleerimine**: Probleemid ühes samaegses harus ei mõjuta teisi
# - **Ilmastiku kahjustumisega leppimine**: Süsteem jätkab töötamist ka vähendatud agendiressurssidega
# - **Taastemehhanismid**: Automaatne taaskäivitus ja vigade käsitlemine ebaõnnestunud toimingute korral
#
# ### 📊 **Jälgimine ja jälgitavus**
# - **Samaaegse täitmise jälgimine**: Jälgi kõigi paralleelsete toimingute edenemist
# - **Jõudluse mõõdikud**: Mõõda kiirendust ja tõhususe kasvu
# - **Ressursside kasutuse analüüs**: Optimeeri samaaegsete agentide jaotust
# - **Pudelistika tuvastamine**: Leia ja lahenda jõudluspiirangud
#
# Loome kõrge jõudlusega samaaegseid AI töövooge! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
