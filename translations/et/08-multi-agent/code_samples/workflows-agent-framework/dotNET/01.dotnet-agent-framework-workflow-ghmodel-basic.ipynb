# %% [markdown]
# # 🔄 Põhilised agendi töövood Azure OpenAI-ga (Responses API) (.NET)
#
# ## 📋 Töövoo orkestreerimise juhend
#
# See märkmik demonstreerib, kuidas luua keerukaid **agendi töövoogusid** Microsoft Agent Frameworki .NET jaoks ja Azure OpenAI (Responses API) abil. Õpid looma mitmeastmelisi äriprotsesse, kus AI agendid teevad koostööd keerukate ülesannete täitmiseks läbi struktureeritud orkestreerimismustrite.
#
# ## 🎯 Õpieesmärgid
#
# ### 🏗️ **Töövoo arhitektuuri alused**
# - **Töövoo ehitaja**: Kujunda ja orkestreeri keerukaid mitmeastmelisi AI protsesse
# - **Agendi koordineerimine**: Koordineeri mitut spetsialiseerunud agenti töövoogudes
# - **Azure OpenAI (Responses API)**: Kasuta Azure OpenAI Responses API-t töövoogudes
# - **Visuaalne töövoo kujundamine**: Loo ja visualiseeri töövoo struktuure parema arusaamise jaoks
#
# ### 🔄 **Protsessi orkestreerimise mustrid**
# - **Järjestikune töötlemine**: Keti mitut agendi ülesannet loogilises järjekorras
# - **Seisundi haldus**: Säilita konteksti ja andmevoogu töövoo etappide vahel
# - **Vigade käitlemine**: Rakenda robustne vigade taastamine ja töövoo vastupidavus
# - **Jõudluse optimeerimine**: Kujunda tõhusad töövood ettevõtte tasandi operatsioonide jaoks
#
# ### 🏢 **Ettevõtte töövoo rakendused**
# - **Äriprotsesside automatiseerimine**: Automatiseeri keerukaid organisatsioonilisi töövooge
# - **Sisu tootmise torujuhe**: Toimetuslikud töövood koos ülevaatamis- ja kinnitusetappidega
# - **Klienditeeninduse automatiseerimine**: Mitmeastmeline kliendipäringute lahendamine
# - **Andmetöötluse töövood**: ETL töövood AI-põhise teisendusega
#
# ## ⚙️ Eeldused ja seadistus
#
# ### 📦 **Nõutavad NuGet paketid**
#
# Selles töövoo demonstreerimises kasutatakse mitut olulist .NET paketti:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI seadistamine**
#
# **Keskkonna seadistamine (.env fail):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI ligipääs:**
# 1. Loo Azure OpenAI ressurss Azure portaali kaudu
# 2. Paiguta mudel (näiteks `gpt-5-mini`) ja märgi paigaldamise nimi
# 3. Logi sisse käsklusega `az login` ja seadista üleval toodud keskkonnamuutujad
#
# ### 🏗️ **Töövoo arhitektuuri ülevaade**
#
# ```mermaid
# graph TD
#     A[Töövoo koostaja] --> B[Agendi registratuur]
#     B --> C[Töövoo täitmise mootor]
#     C --> D[Agent 1: Sisu generaator
#     C --> E[Agent 2: Sisu ülevaataja
#     D --> F[Töövoo tulemused]
#     E --> F
#     G[Azure OpenAI (Vastuste API)] --> D
#     G --> E
# ```
#
# **Peamised komponendid:**
# - **WorkflowBuilder**: Peamine orkestreerimismootor töövoogude kujundamiseks
# - **AIAgent**: Individuaalsed spetsialiseerunud agendid spetsiifiliste võimetega
# - **Azure OpenAI klient**: Azure OpenAI Responses API integratsioon
# - **Täitekontekst**: Halda seisundit ja andmevoogu töövoo etappide vahel
#
# ## 🎨 **Ettevõtte töövoo disainimustrid**
#
# ### 📝 **Sisu tootmise töövoog**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Dokumendi töötlemise torujuhe**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Ärianalüüsi töövoog**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Klienditeeninduse automatiseerimine**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Ettevõtte eelised**
#
# ### 🎯 **Usaldusväärsus ja skaleeritavus**
# - **Deterministlik täitmine**: Järjepidevad ja korduvad töövoo tulemused
# - **Vigade taastamine**: Sujuv ebaõnnestumiste käsitlemine mis tahes töövoo etapil
# - **Jõudluse jälgimine**: Täitmise mõõdikute ja optimeerimise võimaluste jälgimine
# - **Ressursside haldus**: AI mudeli ressursside tõhus jaotamine ja kasutamine
#
# ### 🔒 **Turvalisus ja nõuetele vastavus**
# - **Turvaline autentimine**: Microsoft Entra ID autentimine läbi `az login` (AzureCliCredential)
# - **Auditijäljed**: Töövoo täitmise ja otsustuspunktide täielik logimine
# - **Ligipääsu kontroll**: Piisavalt täpsed õigused töövoo täitmiseks ja jälgimiseks
# - **Andmete privaatsus**: Sensitiivsete andmete turvaline käsitlemine kogu töövoo vältel
#
# ### 📊 **Jälgitavus ja haldus**
# - **Visuaalne töövoo kujundamine**: Selge protsessivoogude ja sõltuvuste kujutamine
# - **Täitmise jälgimine**: Töövoo edenemise ja jõudluse reaalajas jälgimine
# - **Vigade aruandlus**: Detailne vigade analüüs ja silumisvõimalused
# - **Jõudluse analüütika**: Mõõdikud optimeerimiseks ja mahukuse planeerimiseks
#
# Loome sinu esimese ettevõttele valmis AI töövoo! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
