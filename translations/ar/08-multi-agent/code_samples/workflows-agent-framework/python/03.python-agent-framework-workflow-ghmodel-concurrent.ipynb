# %% [markdown]
# # ⚡ تدفقات عمل الوكلاء المتزامنة مع نماذج GitHub (بايثون)
#
# ## 📋 دليل المعالجة المتوازية المتقدمة
#
# يعرض دفتر الملاحظات هذا **نماذج تدفقات العمل المتزامنة** باستخدام إطار عمل Microsoft Agent. ستتعلم كيفية بناء تدفقات عمل عالية الأداء للمعالجة المتوازية حيث ينفذ عدة وكلاء ذكيين في الوقت نفسه، مما يحسن بشكل كبير الإنتاجية ويمكّن من عمليات أعمال متعددة الخيوط معقدة.
#
# ## 🎯 أهداف التعلم
#
# ### 🚀 **أساسيات المعالجة المتزامنة**
# - **تنفيذ الوكلاء المتوازي**: تشغيل عدة وكلاء في الوقت نفسه لتحقيق أقصى كفاءة
# - **تنسيق تدفقات العمل**: تنسيق العمليات المتزامنة مع الحفاظ على اتساق البيانات
# - **تحسين الأداء**: تحقيق تسريع كبير من خلال المعالجة المتوازية
# - **إدارة الموارد**: استخدام موارد نماذج الذكاء الاصطناعي بكفاءة عبر العمليات المتزامنة
#
# ### 🏗️ **نماذج التزامن المتقدمة**
# - **معالجة الانقسام والدمج**: تقسيم العمل عبر عدة وكلاء ودمج النتائج
# - **التوازي في خطوط الأنابيب**: تداخل مراحل التنفيذ لتحقيق إنتاجية مستمرة
# - **موازنة الحمل**: توزيع العمل بالتساوي عبر موارد الوكلاء المتاحة
# - **نقاط التزامن**: تنسيق الوكلاء المتزامنين في مراحل حرجة من تدفق العمل
#
# ### 🏢 **تطبيقات التزامن للمؤسسات**
# - **معالجة مستندات عالية الحجم**: معالجة مستندات متعددة في الوقت نفسه
# - **تحليل المحتوى في الوقت الحقيقي**: تحليل متزامن لتدفقات البيانات الواردة
# - **تحسين معالجة الدُفعات**: تعظيم الإنتاجية للعمليات واسعة النطاق
# - **تحليل متعدد الوسائط**: معالجة متوازية لأنواع محتوى مختلفة (نصوص، صور، بيانات)
#
# ## ⚙️ المتطلبات والإعداد
#
# ### 📦 **المكتبات المطلوبة**
#
# ثبت إطار عمل الوكيل مع قدرات تدفقات العمل المتزامنة:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **تكوين نماذج GitHub**
#
# **إعداد البيئة (ملف .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **اعتبارات المعالجة المتزامنة:**
# - **القيود على المعدل**: راقب حدود معدل API لنماذج GitHub للطلبات المتزامنة
# - **استخدام الموارد**: ضع في الاعتبار استخدام الذاكرة والمعالج مع عدة وكلاء متزامنين
# - **معالجة الأخطاء**: نفذ استعادة أخطاء قوية للعمليات المتوازية
#
# ### 🏗️ **هندسة تدفقات العمل المتزامنة**
#
# ```mermaid
# graph TD
#     A[بدء سير العمل] --> B[التنفيذ المتزامن]
#     B --> C[مجموعة الوكلاء 1]
#     B --> D[مجموعة الوكلاء 2]
#     B --> E[مجموعة الوكلاء 3]
#     C --> F[تجميع النتائج]
#     D --> F
#     E --> F
#     F --> G[المُخرج النهائي]
#
#     H[واجهة برمجة تطبيقات نماذج GitHub] --> C
#     H --> D
#     H --> E
# ```
#
# **الفوائد الرئيسية:**
# - **⚡ الأداء**: تسريع كبير من خلال التنفيذ المتوازي
# - **📈 قابلية التوسع**: التعامل مع أحمال عمل متزايدة بدون زيادة زمنية متناسبة
# - **🔄 الكفاءة**: استخدام أفضل للموارد الحاسوبية المتاحة
# - **🎯 الإنتاجية**: معالجة المزيد من الأعمال في نفس الوقت
#
# ## 🎨 **نماذج تصميم تدفقات العمل المتزامنة**
#
# ### 🔍 **خط أنابيب البحث والتحليل**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **تدفق معالجة البيانات**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **خط إنشاء المحتوى**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **المعالجة متعددة المراحل**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **فوائد أداء المؤسسات**
#
# ### ⚡ **تحسين الإنتاجية**
# - **التنفيذ المتوازي**: عدة وكلاء يعملون في الوقت نفسه
# - **استخدام الموارد**: تحقيق أقصى استفادة من طاقة نماذج الذكاء الاصطناعي المتاحة
# - **تقليل الوقت**: تقليل كبير في الوقت الإجمالي للمعالجة
# - **هندسة قابلة للتوسع**: إضافة وكلاء متزامنين بسهولة حسب الحاجة
#
# ### 🛡️ **الاعتمادية والمرونة**
# - **تحمل الأخطاء**: فشل الوكيل الفردي لا يوقف تدفق العمل الكامل
# - **عزل الأخطاء**: مشاكل فرع متزامن واحد لا تؤثر على الآخرين
# - **التدهور التدريجي**: استمرار النظام في العمل حتى مع انخفاض قدرة الوكلاء
# - **آليات الاسترداد**: إعادة المحاولة التلقائية والتعامل مع الأخطاء للعمليات الفاشلة
#
# ### 📊 **المراقبة والمراقبة**
# - **تتبع التنفيذ المتزامن**: مراقبة تقدم جميع العمليات المتوازية
# - **مقاييس الأداء**: قياس التسريع ومكاسب الكفاءة
# - **تحليلات استخدام الموارد**: تحسين تخصيص الوكلاء المتزامنين
# - **تحديد الاختناقات**: اكتشاف وحل معوقات الأداء
#
# لننشئ تدفقات عمل ذكاء اصطناعي متزامنة عالي الأداء! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **تنويه**:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة بالذكاء الاصطناعي [Co-op Translator](https://github.com/Azure/co-op-translator). بينما نسعى للدقة، يرجى العلم أن الترجمات الآلية قد تحتوي على أخطاء أو عدم دقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر الرسمي والمعتمد. للمعلومات الهامة، يُنصح بالاستعانة بترجمة بشرية محترفة. نحن غير مسؤولين عن أي سوء فهم أو تفسير ناتج عن استخدام هذه الترجمة.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
