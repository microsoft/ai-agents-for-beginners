# %% [markdown]
# # ⚡ Microsoft Foundry (Python) உடன் ஒரே நேரத்தில் செயல்படும் முகவர் பணித்திட்டங்கள்
#
# ## 📋 மேம்பட்ட 병렬 செயலாக்க பயிற்சி
#
# இந்த நோட்புக் Microsoft முகவர் அமைப்பைப் பயன்படுத்தி **ஒரே நேரத்தில் செயல்படும் பணித்திட்ட வடிவமைப்புகளை** காட்டுகிறது. பல AI முகவர்கள் ஒரே நேரத்தில் பணிபுரியும் போது தயாரிப்புத்திறனை உண்மையிலேயே மேம்படுத்தி, நுண்ணறிவு மிக்க பல்துறை வணிக செயலிகளை செயல்படுத்துகிறது என்பதைக் கற்றுக்கொள்வீர்கள்.
#
# > **இடம்பெயர்வு குறிப்பு:** இந்த மாதிரி முன்பு GitHub மாதிரிகளை குறிக்கிறது. GitHub மாதிரிகள் ஒழிக்கப்பட்டுள்ளன (ஜூலை 2026ல் ஓய்வு பெறுகிறது), எனவே இப்போது இது Azure OpenAI **Responses API**க்கு இலக்கு வைக்கும் `FoundryChatClient` வழியாக **Microsoft Foundry** ஐ பயன்படுத்துகிறது.
#
# ## 🎯 கற்றல் நோக்கியங்கள்
#
# ### 🚀 **ஒரே நேரத்தில் செயலாக்க அடித்தளம்**
# - **병렬 முகவர் செயல்பாடு**: அதிக உற்பத்தித்திறனுக்காக பல முகவர்களை ஒரே நேரத்தில் இயக்குங்கள்
# - **பணித்திட்ட ஒழுங்கமைப்பு**: தரவு படைப்பாற்றலை பராமரிக்கும் போது ஒரே நேரம் நடந்துவரும் பணிகளை ஒருங்கிணைக்க
# - **செயல்திறன் மேம்படுத்தல்**: 병렬 செயலாக்கத்தின் மூலம் குறிப்பிடத்தகுந்த வேகத்தை பெற
# - **வள மேலாண்மை**: ஒரே நேரத்தில் நடக்கும் செயல்களுக்குள் AI மாதிரி வளங்களை திறமையான முறையில் பயன்படுத்துக
#
# ### 🏗️ **மேம்பட்ட 병렬 வடிவமைப்புகள்**
# - **Fork-Join செயலாக்கம்**: பணியை பல முகவர்களின் இடையே பிரித்து முடிவுகளை இணைக்க
# - **Pipeline 병렬ism**: தொடர்ச்சியான throughputக்கு ஒருங்கிணைக்கப்பட்டபடி செயல்படும் படிகள்
# - **ஏற்றுமதி சமநிலை**: கிடைக்கும் முகவர் வளங்களில் வேலை சமமாகப் பகிர்ந்துகொள்ள
# - **ஒத்துழைப்பு புள்ளிகள்**: பல்முகவர் பணிகளை முக்கிய பணித்திட்ட கட்டங்களில் ஒருங்கிணைக்க
#
# ### 🏢 **ஊழியர்வழிச் Concurrent பயன்பாடுகள்**
# - **அதிக-அளவு ஆவண செயலாக்கம்**: பல ஆவணங்களை ஒரே நேரத்தில் செயலாக்கம்
# - **நேரடி உள்ளடக்கம் பகுப்பாய்வு**: வரும் தரவு ஓடுக்களின் ஒரே நேர பரிசீலனை
# - **ব্যাচ செயலாக்கம் மேம்படுத்தல்**: பெரிய அளவில் செயல்பாடுகளுக்கான throughput அதிகரித்தல்
# - **பல-வகை பகுப்பாய்வு**: வெவ்வேறு உள்ளடக்க வகைகளை 병렬 செயலாக்கம் (உரை, படம், தரவு)
#
# ## ⚙️ தேவைகள் & அமைப்பு
#
# ### 📦 **தேவைப்படும் சார்புகள்**
#
# ஒரே நேர பணித்திட்ட திறனுள்ள முகவர் அமைப்பை நிறுவுக:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry கட்டமைப்பு**
#
# `AzureCliCredential`-ஐ அங்கீகரிக்க Azure CLI (`az login`)யில் உள்நுழைந்து, பிறகு உங்கள் Microsoft Foundry திட்ட விவரங்களை அமைக்கவும்.
#
# **சூழல் அமைப்பு (.env கோப்பு):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **ஒரே நேர செயலாக்க கருத்துக்கள்:**
# - **நேர வரம்புகள்**: ஒரே நேர கோரிக்கைகளுக்கான Azure OpenAI நேர வரம்புகளை கண்காணிக்க
# - **வள பயன்பாடு**: பல ஒரே நேர முகவர்களுடன் நினைவகமும் CPU பயன்பாடும் பரிசீலிக்க
# - **பிழை முகாமை**: 병렬 செயல்பாடுகளுக்கு கடுமையான பிழை மீட்பு நடைமுறை
#
# ### 🏗️ **ஒரே நேர பணித்திட்ட கட்டமைப்பு**
#
# ```mermaid
# graph TD
#     A[பணிச்சூழல் தொடக்கம்] --> B[ஒருங்கிணைந்த செயற்பாடு]
#     B --> C[முகவர் தொகுதி 1]
#     B --> D[முகவர் தொகுதி 2]
#     B --> E[முகவர் தொகுதி 3]
#     C --> F[முடிவுகளின் சீர்திருத்தம்]
#     D --> F
#     E --> F
#     F --> G[இறுதி வெளியீடு]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **முக்கிய நன்மைகள்:**
# - **⚡ செயல்திறன்**: 병렬 இயக்கத்தின் மூலம் குறிப்பிடத்தக்க வேகம்
# - **📈 விருத்தி**: அதிக பணியை நேர அளவுக்கு பிணையாகாது கையாள
# - **🔄 திறமை**: கிடைக்கும் கணினி வளத்தை சிறந்த முறையில் பயன்படுத்த
# - **🎯 throughput**: அதே நேரத்தில் அதிக வேலை செய்ய
#
# ## 🎨 **ஒரே நேர பணித்திட்ட வடிவமைப்பு மாதிரிகள்**
#
# ### 🔍 **ஆராய்ச்சி & பகுப்பாய்வு குழாய்**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **தரவு செயலாக்க பணித்திட்டம்**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **உள்ளடக்கம் உருவாக்க குழாய்**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **பல கட்ட செயலாக்கம்**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ஊழியர் செயல்திறன் நன்மைகள்**
#
# ### ⚡ **throughput மேம்படுத்தல்**
# - **병렬 இயக்கம்**: ஒரே நேரம் பல முகவர்கள் பணிபுரிதல்
# - **வள பயன்பாடு**: கிடைக்கும் AI மாதிரி திறனை அதிக ஊழியம்
# - **நேரக் குறைப்பு**: மொத்த செயலாக்க நேரத்தை குறிப்பிடத்தக்க வகையில் குறைத்து
# - **விருத்தி செய்யக்கூடிய கட்டமைப்பு**: தேவையான போது மேலும் ஒரே நேரம் முகவர்களைச் சேர்க்க
#
# ### 🛡️ **நம்பகத்தன்மை & மீட்பு திறன்**
# - **தோல்வி சகிப்பு**: தனி முகவர்களின் தோல்வி முழுப் பணித்திட்டத்தை நிறுத்தாது
# - **பிழை தனிமைப்படுத்தல்**: ஒரே நேர கிளையில் பிரச்சினைகள் மற்றவற்றை பாதிக்காது
# - **மிகவும் குறைக்கப்பட்ட செயல்திறன்**: குறைக்கப்பட்ட முகவர் திறனை கொண்டிருந்தாலும் அமைப்பு தொடரும்
# - **மீட்டெடுப்பு முறைகள்**: தோல்வியடைந்த செயல்களுக்கான தானாக மீண்டும் முயற்சி மற்றும் பிழை நிர்வாகம்
#
# ### 📊 **கண்காணிப்பு & புவியியல் மதிப்பீடு**
# - **ஒரே நேர இயக்க கண்காணிப்பு**: அனைத்து 병렬 செயல்களின் முன்னேற்றத்தை கண்காணி
# - **செயல்திறன் அளவுகள்**: வேகம் மற்றும் திறன் மேம்பாடுகளை அளவு
# - **வள பயன்பாடு பகுப்பாய்வு**: 병렬 முகவர் ஒதுக்கீட்டை மேம்படுத்த
# - **போத்தென்ப் அடையாளம்**: செயல்திறன் கட்டுப்பாடுகளை கண்டுபிடித்து தீர்க்க
#
# உயர் செயல்திறன் ஒரே நேர AI பணித்திட்டங்களை உருவாக்க வாருங்கள்! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
