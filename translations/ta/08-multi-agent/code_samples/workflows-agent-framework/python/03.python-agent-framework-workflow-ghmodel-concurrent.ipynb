# %% [markdown]
# # ⚡ GitHub மாதிரிகளுடன் ஒரே நேரத்தில் நடைபெறும் முகவர் பணியாளர்கள் பணி ஓட்டங்கள் (Python)
#
# ## 📋 மேம்பட்ட சீரான செயலாக்க பாடம்
#
# இந்த நோட்புக் Microsoft முகவர் கட்டமைப்பைப் பயன்படுத்தி **ஒரே நேரில் நடைபெறும் பணி ஓட்ட மாதிரிகளை** விளக்குகிறது. பல AI முகவர்கள் ஒரே நேரத்தில் செயல்படுவதன் மூலம் அதிக செயல்திறன், சீரான செயலாக்க பணி ஓட்டங்களை உருவாக்குவதற்கான வழிகளையும், பலத் தண்டுகள் கொண்ட வணிக செயல்முறைகளை எளிதாக இயக்குவதையும் நீங்கள் கற்கப்போகிறீர்கள்.
#
# ## 🎯 கற்றல் குறிக்கோள்கள்
#
# ### 🚀 **ஒரே நேரத்தில் செயலாக்க அடிக்கடி அறிவுகள்**
# - **சீரான முகவர் செயல்பாடு**: அதிக செயல்திறனுக்காக பல முகவர்களை ஒரே நேரத்தில் இயக்குதல்
# - **பணி ஓட்ட ஒத்திசைவு**: தரவுத் துல்லியத்தை பாதுகாப்பதுடன் ஒரே நேரத்தில் செயல்பாடுகளை ஒருங்கிணைத்தல்
# - **செயல்திறன் மேம்பாடு**: சீரான செயலாக்கத்தின் மூலம் மிக்க வேகம் அடைவது
# - **சாதன மேலாண்மை**: ஒரே நேரத்தில் செயல்படும் செயல்களில் AI மாதிரி ஆதாரங்களை திறமையாக பயன்படுத்தல்
#
# ### 🏗️ **மேம்பட்ட ஒரே நேர concurrency மாதிரிகள்**
# - **Fork-Join செயலாக்கம்**: பல முகவர்களுக்குள் பணி பிரித்தல் மற்றும் முடிவுகளை ஒன்றிணைத்தல்
# - **பைப்லைன் சீரான தன்மை**: தொடர்ச்சியான உற்பத்திக்காக படிகள் ஒரே நேரத்தில் நடைபெறுதல்
# - **பணி சுமை சமன்பாடு**: கிடைக்கும் முகவர் ஆதாரங்களுக்கு சரியான பணி பகிர்வு
# - **ஒத்திசைவு புள்ளிகள்**: முக்கிய பணி ஓட்ட படிகளில் ஒரே நேரமுள்ள முகவர்களை ஒருங்கிணைத்தல்
#
# ### 🏢 **தொழில்துறை ஒரே நேர concurrency பயன்பாடுகள்**
# - **உயர் அளவிலான ஆவண செயலாக்கம்**: பல ஆவணங்களை ஒரே நேரத்தில் செயலாக்குதல்
# - **நேரடி உள்ளடக்கப் பகுப்பாய்வு**: வரும் தரவு ஓட்டங்களின் ஒரே நேர பகுப்பாய்வு
# - **தொகுப்பு செயலாக்க மேம்பாடு**: பெரிய அளவிலான பணிகளுக்கான அதிக உற்பத்தி
# - **பல விதமான உள்ளடக்க பகுப்பாய்வு**: வெவ்வேறு உள்ளடக்க வகைகளின் (உரை, படங்கள், தரவு) ஒரே நேர செயலாக்கம்
#
# ## ⚙️ தேவைகள் மற்றும் அமைப்புகள்
#
# ### 📦 **தேவையான சார்புகள்**
#
# Concurrent workflow திறன்களுடன் முகவர் கட்டமைப்பை நிறுவுக:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
#
# ### 🔑 **GitHub மாதிரிகள் நாடக அமைப்பு**
#
# **சூழல் அமைப்பு (.env கோப்பு):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
#
# **ஒரே நேர செயலாக்க கருத்துக்கள்:**
# - **ரேட் வரம்புகள்**: GitHub மாதிரிகள் API ஒரே நேர கோரிக்கைகள் வரம்புகளை கவனிக்க வேண்டும்
# - **ஆதாரம் பயன்பாடு**: பல concurrent முகவர்களுடன் நினைவு மற்றும் CPU பயன்பாட்டை பரிசீலிக்கவும்
# - **பிழை கையாளுதல்**: சீரான செயல்களில் பலமாகவும் பிழைகளை முறையாக கையாள்வது முக்கியம்
#
# ### 🏗️ **Concurrent Workflow கட்டமைப்பு**
#
# ```mermaid
# graph TD
#     A[வேலை جریانத் தொடக்கம்] --> B[ஒத்த செயல்பாடு]
#     B --> C[ஏஜெண்ட் குழு 1]
#     B --> D[ஏஜெண்ட் குழு 2]
#     B --> E[ஏஜெண்ட் குழு 3]
#     C --> F[விளைவு தொகுப்பு]
#     D --> F
#     E --> F
#     F --> G[இறுதி வெளியீடு]
#
#     H[GitHub மாதிரிகள் API] --> C
#     H --> D
#     H --> E
# ```
#
#
# **முக்கிய நன்மைகள்:**
# - **⚡ செயல்திறன்**: ஒரே நேர இயக்கத்தில் பெரும் வேகம்
# - **📈 பரிமாண அளவு உயர்வு**: அதிக பணிகளுக்கு நேரம் அதிகரிக்காமல் கையாளல்
# - **🔄 திறன்மிகு பயன்பாடு**: கிடைக்கும் கணினி வளங்களை சிறப்பாக பயன்படுத்தல்
# - **🎯 அதிக உற்பத்தி**: குறைந்த நேரத்தில் அதிக பணி முடித்து விடுதல்
#
# ## 🎨 **ஒரே நேர பணி ஓட்ட வடிவமைப்புகள்**
#
# ### 🔍 **ஆராய்ச்சி மற்றும் பகுப்பாய்வு பைப்லைன்**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
#
# ### 📊 **தரவு செயலாக்க பணி ஓட்டம்**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
#
# ### 🎭 **உள்ளடக்க உருவாக்க பைப்லைன்**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
#
# ### 🔄 **பல படி செயலாக்கம்**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
#
# ## 🏢 **தொழில்துறை செயல்திறன் நன்மைகள்**
#
# ### ⚡ **உற்பத்தி திறன் மேம்பாடு**
# - **சீரான செயல்பாடு**: பல முகவர்கள் ஒரே நேரத்தில் வேலை செய்யும்
# - **ஆதாரம் பயன்பாடு**: கிடைக்கும் AI மாதிரி திறனை முழுமையாக பயன்படுத்தல்
# - **நேர குறைப்பு**: மொத்த செயலாக்க நேரத்தை முற்றிலுமாக குறைத்தல்
# - **பரிமாணக்கூறான கட்டமைப்பு**: தேவையான வரை கூடுதல் concurrent முகவர்களை எளிதில் சேர்க்க முடியும்
#
# ### 🛡️ **நம்பகத்தன்மை மற்றும் தாங்கும் திறன்**
# - **தவறு சுமந்தல்**: ஒவ்வொரு முகவரின் தோல்வி முழு பணி ஓட்டை நிறுத்தாது
# - **பிழை தனிமைப்படுத்தல்**: ஒரே நேர கிளையில் பிழைகள் மற்ற கிளைகளுக்கு பாதிப்பாக இருக்காது
# - **மெல்லிய ஓட்டம்**: குறைந்த முகவர் திறனாலும் அமைப்பு இயங்கத் தொடரும்
# - **மீட்டெடுக்கும் இயந்திரங்கள்**: தோல்வியடைந்த செயல்கள் சுயமாக மீண்டும் முயற்சி, பிழை நிர்வாகம்
#
# ### 📊 **மேலாண்மை மற்றும் கண்காணிப்பு**
# - **ஒரே நேரம் செயல்பாடு கண்காணிப்பு**: அனைத்து சீரான செயல்பாடுகளின் முன்னேற்றத்தை கண்காணி
# - **செயல்திறன் அளவீடுகள்**: வேகம் மற்றும் திறன் முன்னேற்றங்களை அளவிடு
# - **ஆதார பயன்பாட்டு பகுப்பாய்வு**: concurrent முகவர் ஒதுக்கீட்டை மேம்படுத்து
# - **தடைவாய்ந்த இடங்களை கண்டறிதல்**: செயல்திறன் தடைகளை கண்டுபிடித்து சரி செய்
#
# உயர் செயல்திறன் கொண்ட ஒரே நேர AI பணி ஓட்டங்களை உருவாக்கலாம்! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
