# %% [markdown]
# # 🔄 Baziniai agentų darbo srautų naudojant Azure OpenAI (Atsakymai API) (.NET)
#
# ## 📋 Darbo srauto koordinavimo vadovas
#
# Ši užrašų knygelė demonstruoja, kaip sukurti sudėtingus **agentų darbo srautus** naudojant Microsoft Agent Framework .NET ir Azure OpenAI (Atsakymai API). Sužinosite, kaip kurti daug etapių verslo procesus, kur AI agentai bendradarbiauja įgyvendindami sudėtingas užduotis per struktūruotus koordinavimo modelius.
#
# ## 🎯 Mokymosi tikslai
#
# ### 🏗️ **Darbo srauto architektūros pagrindai**
# - **Darbo srauto kūrėjas**: projektuokite ir koordinuokite sudėtingus daug etapų AI procesus
# - **Agentų koordinavimas**: koordinuokite kelis specializuotus agentus darbo srautuose
# - **Azure OpenAI (Atsakymai API)**: naudokite Azure OpenAI Atsakymai API darbo srautuose
# - **Vizualus darbo srauto dizainas**: kurkite ir vizualizuokite darbo srauto struktūras geresniam supratimui
#
# ### 🔄 **Proceso koordinavimo modeliai**
# - **Sekos apdorojimas**: grandinė iš kelių agentų užduočių loginėje tvarkoje
# - **Būsena valdymas**: palaikykite kontekstą ir duomenų srautus per darbo srauto etapus
# - **Klaidų tvarkymas**: įgyvendinkite patikimą klaidų atkūrimą ir darbo srauto atsparumą
# - **Veikimo optimizavimas**: projektuokite efektyvius darbo srautus įmonių lygiui
#
# ### 🏢 **Įmonių darbo srautų taikymai**
# - **Verslo proceso automatizavimas**: automatizuokite sudėtingus organizacijų darbo srautus
# - **Turinio gamybos linija**: redakcijos darbo srautai su peržiūros ir patvirtinimo etapais
# - **Klientų aptarnavimo automatizavimas**: daug etapų klientų užklausų sprendimas
# - **Duomenų apdorojimo darbo srautai**: ETL darbo srautai su AI varoma transformacija
#
# ## ⚙️ Reikalavimai ir nustatymai
#
# ### 📦 **Būtinos NuGet paketo bibliotekos**
#
# Šiame darbo srauto pavyzdyje naudojamos kelios svarbios .NET paketo bibliotekos:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="10.*" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI konfigūracija**
#
# **Aplinkos nustatymas (.env failas):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI prieiga:**
# 1. Sukurkite Azure OpenAI resource Azure portale
# 2. Įdiekite modelį (pvz., `gpt-5-mini`) ir užsirašykite diegimo pavadinimą
# 3. Prisijunkite su `az login` ir sukonfigūruokite aplinkos kintamuosius, kaip parodyta aukščiau
#
# ### 🏗️ **Darbo srauto architektūros apžvalga**
#
# ```mermaid
# graph TD
#     A[Darbo eigos kūrėjas] --> B[Agentų registras]
#     B --> C[Darbo eigos vykdymo variklis]
#     C --> D[Agent 1: Turinys generatorius]
#     C --> E[Agent 2: Turinys peržiūrėtojas]
#     D --> F[Darbo eigos rezultatai]
#     E --> F
#     G[Azure OpenAI (Atsakymai API)] --> D
#     G --> E
# ```
#
# **Pagrindinės sudedamosios dalys:**
# - **WorkflowBuilder**: pagrindinis koordinavimo variklis darbo srautų kūrimui
# - **AIAgent**: individualūs specializuoti agentai su specifinėmis galimybėmis
# - **Azure OpenAI klientas**: Azure OpenAI Atsakymai API integracija
# - **Vykdymo kontekstas**: valdo būseną ir duomenų srautus tarp darbo srauto etapų
#
# ## 🎨 **Įmonių darbo srautų dizaino modeliai**
#
# ### 📝 **Turinio gamybos darbo srautas**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Dokumentų apdorojimo linija**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Verslo informacijos darbo srautas**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Klientų aptarnavimo automatizavimas**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Įmonių pranašumai**
#
# ### 🎯 **Patikimumas ir mastelio keitimas**
# - **Deterministinis vykdymas**: nuoseklūs, pakartojami darbo srauto rezultatai
# - **Klaidų atkūrimas**: sklandus gedimų bet kuriame darbo srauto etape valdymas
# - **Veikimo stebėsena**: vykdymo metrikų ir optimizavimo galimybių sekimas
# - **Išteklių valdymas**: efektyvus AI modelių išteklių paskirstymas ir naudojimas
#
# ### 🔒 **Sauga ir atitiktis**
# - **Saugaus autentifikavimo**: Microsoft Entra ID autentifikavimas per `az login` (AzureCliCredential)
# - **Audito pėdsakai**: pilnas darbo srauto vykdymo ir sprendimų taškų įrašymas
# - **Prieigos kontrolė**: smulkios teisės darbo srautų vykdymui ir stebėsenai
# - **Duomenų privatumas**: saugus jautrios informacijos tvarkymas per visus darbo srautus
#
# ### 📊 **Stebimumas ir valdymas**
# - **Vizualus darbo srauto dizainas**: aiškus procesų srautų ir priklausomybių atvaizdavimas
# - **Vykdymo stebėsena**: realaus laiko darbo srauto pažangos ir veikimo sekimas
# - **Klaidų ataskaitos**: detali klaidų analizė ir derinimo galimybės
# - **Veikimo analizė**: metrikos optimizavimui ir pajėgumų planavimui
#
# Sukurkime jūsų pirmąjį įmonėms parengtą AI darbo srautą! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 10.*"

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.*"

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.*-*"

# %%
#r "nuget: DotNetEnv, 3.1.1"

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 1.*-*"

# %%
using System;
using System.ComponentModel;
using System.Text;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are a hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetChatClient(deployment).AsIChatClient().AsAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.RunStreamingAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
var messageData = new StringBuilder();
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentResponseUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            if (executorComplete.Data is not null)
            {
                messageData.Append(executorComplete.Data.ToString());
            }
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData.ToString());

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
