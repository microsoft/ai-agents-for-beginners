# %% [markdown]
# # ⚡ Lygiagretūs agentų veiklos srautai su Microsoft Foundry (Python)
#
# ## 📋 Pažengusių lygiagretaus apdorojimo pamoka
#
# Šis užrašynas demonstruoja **lygiagrečių veiklos srautų modelius** naudojant Microsoft Agent Framework. Išmoksite kurti aukštos spartos, lygiagretų apdorojimą, kuriame keletas AI agentų veikia vienu metu, taip žymiai pagerindami pralaidumą ir įgalindami sudėtingus daugiasluoksnius verslo procesus.
#
# > **Migracijos pastaba:** Šis pavyzdys anksčiau naudojo GitHub Models. GitHub Models nebeveikia (bus nutrauktas 2026 m. liepos mėn.), todėl dabar naudojama **Microsoft Foundry** per `FoundryChatClient`, kuris kreipiasi į Azure OpenAI **Responses API**.
#
# ## 🎯 Mokymosi tikslai
#
# ### 🚀 **Lygiagretaus apdorojimo pagrindai**
# - **Lygiagreti agentų vykdymas**: vienu metu vykdykite kelis agentus maksimaliai efektyvumui
# - **Veiklos srauto koordinavimas**: suderinkite lygiagrečias operacijas išlaikant duomenų nuoseklumą
# - **Našumo optimizavimas**: pasiekite žymų greičio padidėjimą per lygiagretų apdorojimą
# - **Išteklių valdymas**: efektyviai naudokite AI modelių resursus per kelias lygiagrečias operacijas
#
# ### 🏗️ **Pažangūs lygiagretaus darbo modeliai**
# - **Fork-Join apdorojimas**: darbą padalinkite tarp kelių agentų ir sujunkite rezultatus
# - **Vamzdyno lygiagretumas**: vykdymo etapų persidengimas užtikrina nuolatinį pralaidumą
# - **Krovio balansavimas**: tolygiai paskirstykite darbą tarp prieinamų agentų resursų
# - **Sinchronizacijos taškai**: koordinuokite lygiagrečius agentus kritiniais veiklos etapais
#
# ### 🏢 **Įmonių lygiagretės programos**
# - **Daug dokumentų apdorojimas**: vienu metu apdorokite kelis dokumentus
# - **Realaus laiko turinio analizė**: lygiagretus gaunamų duomenų srautų analizavimas
# - **Partijos apdorojimo optimizavimas**: maksimalus pralaidumas didelio masto operacijoms
# - **Daugiarūšių duomenų analizė**: lygiagretus skirtingų turinio tipų (tekstų, vaizdų, duomenų) apdorojimas
#
# ## ⚙️ Reikalavimai ir nustatymai
#
# ### 📦 **Būtinos priklausomybės**
#
# Įdiekite Agent Framework su lygiagrečių veiklos srautų galimybėmis:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfigūracija**
#
# Prisijunkite per Azure CLI (`az login`), kad `AzureCliCredential` galėtų autentifikuoti, tada nurodykite Microsoft Foundry projekto duomenis.
#
# **Aplinkos nustatymai (.env failas):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o-mini
# ```
#
# **Lygiagretaus apdorojimo svarstymai:**
# - **Ribojimai**: stebėkite Azure OpenAI užklausų ribas dėl lygiagrečių užklausų
# - **Išteklių naudojimas**: atsižvelkite į atminties ir CPU naudojimą keliems lygiagretiems agentams
# - **Klaidų valdymas**: įgyvendinkite patikimą klaidų atkūrimą lygiagretiose operacijose
#
# ### 🏗️ **Lygiagretaus veiklos srauto architektūra**
#
# ```mermaid
# graph TD
#     A[Darbo eiga prasideda] --> B[Vienalaikis vykdymas]
#     B --> C[Agentų fondas 1]
#     B --> D[Agentų fondas 2]
#     B --> E[Agentų fondas 3]
#     C --> F[Rezultatų agregacija]
#     D --> F
#     E --> F
#     F --> G[Galutinis rezultatas]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Pagrindinės naudos:**
# - **⚡ Našumas**: žymus greičio augimas per lygiagretų vykdymą
# - **📈 Masto pritaikomumas**: didesnis darbų kiekis be proporcingo laiko padidėjimo
# - **🔄 Efektyvumas**: geresnis prieinamų skaičiavimo išteklių panaudojimas
# - **🎯 Pralaidumas**: apdorokite daugiau darbo per tą patį laiką
#
# ## 🎨 **Lygiagrečių veiklos srautų dizaino modeliai**
#
# ### 🔍 **Tyrimų ir analizės vamzdynas**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Duomenų apdorojimo veiklos srautas**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Turinio kūrimo vamzdynas**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Daugiapakopis apdorojimas**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Įmonių našumo pranašumai**
#
# ### ⚡ **Pralaidumo optimizavimas**
# - **Lygiagretus vykdymas**: keli agentai dirba vienu metu
# - **Išteklių panaudojimas**: maksimalus prieinamų AI modelių galimybių efektyvumas
# - **Laiko sutrumpinimas**: žymus bendro apdorojimo laiko sumažėjimas
# - **Mastos architektūra**: lengvai pridėkite daugiau lygiagrečių agentų pagal poreikį
#
# ### 🛡️ **Patikimumas ir atsparumas**
# - **Gedimų tolerancija**: pavieniai agentų gedimai nesustabdo viso veiklos srauto
# - **Klaidų atskyrimas**: problemos vienoje lygiagrečioje šakoje neturi įtakos kitoms
# - **Sklandi degradacija**: sistema veikia net sumažėjus agentų pajėgumams
# - **Atkūrimo mechanizmai**: automatinis bandymas iš naujo ir klaidų valdymas nesėkmingoms operacijoms
#
# ### 📊 **Stebėsena ir matomumas**
# - **Lygiagretaus vykdymo sekimas**: stebėkite visų lygiagrečių operacijų pažangą
# - **Našumo rodikliai**: matuokite greičio ir efektyvumo perdavimus
# - **Išteklių naudojimo analizė**: optimizuokite lygiagrečių agentų paskirstymą
# - **Butelio kaklelio nustatymas**: raskite ir pašalinkite našumo ribojimus
#
# Sukurkime aukštos spartos lygiagretų AI veiklos srautus! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
