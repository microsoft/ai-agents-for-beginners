# %% [markdown]
# # ⚡ Lygiagretūs agentų darbo srautai su GitHub modeliais (Python)
#
# ## 📋 Išplėstinis lygiagretaus apdorojimo pamoka
#
# Šiame užrašų knygelėje demonstruojami **lygiagrečių darbo srautų modeliai** naudojant Microsoft Agent Framework. Išmoksite kurti aukštos našumo lygiagrečius apdorojimo darbo srautus, kai keli AI agentai vykdo užduotis vienu metu, ženkliai pagerindami pralaidumą ir leidžiantys kurti sudėtingus daugiagijus verslo procesus.
#
# ## 🎯 Mokymosi tikslai
#
# ### 🚀 **Lygiagretaus apdorojimo pagrindai**
# - **Lygiagretus agentų vykdymas**: Vienu metu paleiskite kelis agentus, kad pasiektumėte maksimalų efektyvumą
# - **Darbo srauto valdymas**: Koordinuokite lygiagrečias operacijas užtikrindami duomenų nuoseklumą
# - **Veikimo optimizavimas**: Reikšmingai pagreitinkite per lygiagretų apdorojimą
# - **Išteklių valdymas**: Efektyviai naudokite AI modelių išteklius lygiagrečioms operacijoms
#
# ### 🏗️ **Išplėstiniai lygiagretaus darbo srauto modeliai**
# - **Fork-Join apdorojimas**: Darbo padalijimas tarp kelių agentų ir rezultatų sujungimas
# - **Prietakos lygiagretumas**: Pereinamųjų etapų sutapdymas nuolatiniam pralaidumui
# - **Krovos balansavimas**: Darbo tolygus paskirstymas tarp prieinamų agentų išteklių
# - **Sinchronizacijos taškai**: Lygiagrečių agentų koordinavimas svarbiais darbo srauto etapais
#
# ### 🏢 **Lygiagrečios verslo programos**
# - **Didelio masto dokumentų apdorojimas**: Vienu metu apdorokite kelis dokumentus
# - **Realaus laiko turinio analizė**: Lygiagreti įeinančių duomenų srautų analizė
# - **Partijų apdorojimo optimizavimas**: Maksimalus pralaidumas didelio masto operacijoms
# - **Daugiaprofilinė analizė**: Lygiagretus įvairių turinio tipų (teksto, vaizdų, duomenų) apdorojimas
#
# ## ⚙️ Pradiniai reikalavimai ir sąranka
#
# ### 📦 **Būtinos priklausomybės**
#
# Įdiekite Agent Framework su lygiagrečių darbo srautų galimybėmis:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub modelių konfigūracija**
#
# **Aplinkos nustatymai (.env failas):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Lygiagretaus apdorojimo aspektai:**
# - **Ribojimai**: Stebėkite GitHub modelių API ribas dėl lygiagrečių užklausų
# - **Išteklių naudojimas**: Atsižvelkite į atminties ir procesoriaus apkrovą su keliais lygiagrečiais agentais
# - **Klaidų tvarkymas**: Įgyvendinkite patikimą klaidų atkūrimą lygiagrečioms operacijoms
#
# ### 🏗️ **Lygiagretaus darbo srauto architektūra**
#
# ```mermaid
# graph TD
#     A[Darbo eiga pradžia] --> B[Lygiagretus vykdymas]
#     B --> C[Agentų surinkimas 1]
#     B --> D[Agentų surinkimas 2]
#     B --> E[Agentų surinkimas 3]
#     C --> F[Rezultatų sujungimas]
#     D --> F
#     E --> F
#     F --> G[Galutinis rezultatas]
#
#     H[GitHub modelių API] --> C
#     H --> D
#     H --> E
# ```
#
# **Pagrindinės naudos:**
# - **⚡ Veikimo greitis**: Reikšmingas pagreitis per lygiagretų vykdymą
# - **📈 Mastelio keitimas**: Tvarkykite didėjančias apkrovas neskirdami proporcingo laiko
# - **🔄 Efektyvumas**: Geresnis prieinamų skaičiavimo išteklių panaudojimas
# - **🎯 Pralaidumas**: Apdorokite daugiau darbo per tą patį laiką
#
# ## 🎨 **Lygiagrečių darbo srautų dizaino modeliai**
#
# ### 🔍 **Tyrimų ir analizės prietakos linija**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Duomenų apdorojimo darbo srautas**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Turinio kūrimo prietakos linija**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Daugiapakopis apdorojimas**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Verslo veiklos efektyvumo privalumai**
#
# ### ⚡ **Pralaidumo optimizavimas**
# - **Lygiagretus vykdymas**: Keli agentai veikia tuo pačiu metu
# - **Išteklių panaudojimas**: Maksimalus prieinamų AI modelių pajėgumo efektyvumas
# - **Laiko sumažinimas**: Reikšmingas bendro apdorojimo laiko sumažėjimas
# - **Mastelio keitimo architektūra**: Lengva pridėti daugiau lygiagrečių agentų pagal poreikį
#
# ### 🛡️ **Patikimumas ir atsparumas**
# - **Atsparumas gedimams**: Atskirų agentų klaidos netrikdo viso darbo srauto
# - **Klaidų izoliacija**: Vieno lygiagretaus šakos klaidos neveikia kitų
# - **Švelnus degradavimas**: Sistema veikia net sumažinus agentų pajėgumą
# - **Atkūrimo mechanizmai**: Automatinis bandymas iš naujo ir klaidų tvarkymas nepavykus operacijų
#
# ### 📊 **Stebėjimas ir matomumas**
# - **Lygiagretaus vykdymo sekimas**: Stebėkite visų lygiagrečių operacijų eigą
# - **Veikimo rodikliai**: Matokite pagreitį ir efektyvumo prieaugį
# - **Išteklių naudojimo analizė**: Optimizuokite lygiagrečių agentų paskirstymą
# - **Sąstingio nustatymas**: Raskite ir pašalinkite veiklos trukdžius
#
# Sukurkime aukštos našumo lygiagrečius AI darbo srautus! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = await provider.create_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = await provider.create_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
