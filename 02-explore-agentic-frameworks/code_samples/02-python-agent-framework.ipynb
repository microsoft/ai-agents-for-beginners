# %% [markdown]
# # 🔍 Exploring Agentic Frameworks - Basic Agent (Python)
#
# ## 📋 Learning Objectives
#
# This notebook explores the fundamental concepts of the Microsoft Agent Framework through a basic agent implementation. You'll learn core agentic patterns and understand how intelligent agents work under the hood.
#
# **What You'll Discover:**
# - 🏗️ **Agent Architecture**: Understanding the basic structure of AI agents
# - 🛠️ **Tool Integration**: How agents use external functions to extend capabilities
# - 💬 **Conversation Flow**: Managing multi-turn conversations and context
# - 🔧 **Configuration Patterns**: Best practices for agent setup and management
#
# ## 🎯 Key Concepts Covered
#
# ### Agentic Framework Principles
# - **Autonomy**: How agents make independent decisions
# - **Reactivity**: Responding to environmental changes and user inputs
# - **Proactivity**: Taking initiative based on goals and context
# - **Social Ability**: Interacting through natural language
#
# ### Technical Components
# - **ChatAgent**: Core agent orchestration and conversation management
# - **Tool Functions**: Extending agent capabilities with custom functions
# - **OpenAI Integration**: Leveraging language models through standardized APIs
# - **Environment Management**: Secure configuration and credential handling
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core  -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🔧 Technical Stack
#
# **Core Technologies:**
# - Microsoft Agent Framework (Python)
# - GitHub Models API integration
# - OpenAI-compatible client patterns
# - Environment-based configuration
#
# **Agent Capabilities:**
# - Natural language understanding and generation
# - Function calling and tool usage
# - Context-aware responses
# - Extensible architecture
#
# ## 📚 Framework Comparison
#
# This example demonstrates the Microsoft Agent Framework approach compared to other agentic frameworks:
#
# | Feature | Microsoft Agent Framework | Other Frameworks |
# |---------|-------------------------|------------------|
# | **Integration** | Native Microsoft ecosystem | Varied compatibility |
# | **Simplicity** | Clean, intuitive API | Often complex setup |
# | **Extensibility** | Easy tool integration | Framework-dependent |
# | **Enterprise Ready** | Built for production | Varies by framework |
#
# ## 🚀 Getting Started
#
# Follow the cells below to build your first basic agent and understand foundational agentic concepts!

# %%
! pip install agent-framework-core  -U
# Out:
# Requirement already satisfied: agent-framework-core in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (1.0.0b251204)
# Requirement already satisfied: typing-extensions in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: pydantic-settings<3,>=2 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.39.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (1.109.1)
# Requirement already satisfied: azure-identity<2,>=1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp[ws]>=1.13->agent-framework-core) (1.23.1)
# Requirement already satisfied: packaging>=24.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: requests>=2.21.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: anyio>=4.5 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.38.0)
# Requirement already satisfied: idna>=2.8 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.11)
# Requirement already satisfied: certifi in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.30.0)
# Requirement already satisfied: websockets>=15.0.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.66.2 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core) (1.39.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-proto==1.39.0->opentelemetry-exporter-otlp-proto-grpc>=1.39.0->agent-framework-core) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b0)
# Requirement already satisfied: click>=7.0 in /workspaces/ai-agents-for-beginners/venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.3.1)

# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = ChatAgent(
    chat_client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Your random day trip destination is Cape Town, South Africa! Here's a suggested itinerary for your day:
#
# ### Morning
# - **Visit Table Mountain**: Start your day with a breathtaking cable car ride up Table Mountain to enjoy panoramic views of the city and surroundings.
# - **Breakfast at the Top**: Have breakfast at the Table Mountain café while soaking in the spectacular views.
#
# ### Mid-Morning
# - **Explore the V&A Waterfront**: Head to the lively V&A Waterfront for some shopping, sightseeing, and local snacks.
#
# ### Lunch
# - **Seafood by the Beach**: Enjoy a delicious seafood lunch at one of the waterfront restaurants like Baia Seafood.
#
# ### Afternoon
# - **Visit Boulders Beach**: Travel to Simon’s Town to see the famous African penguins at Boulders Beach.
# - **Cape Point Nature Reserve**: If time allows, stop at Cape Point to enjoy scenic hikes and capture the dramatic cliffs.
#
# ### Evening
# - **Sunset at Camps Bay**: Relax on Camps Bay beach and enjoy the golden sunset with a cocktail or mocktail in hand.
# - **Dinner with a View**: Dine at a beachfront restaurant like The Bungalow.
#
# Enjoy your day in Cape Town! Let me know if you’d like help with activity bookings or further details.

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Your new destination is Sydney, Australia! Here’s a suggested day trip itinerary:
#
# ### Morning
# - **Walk Across the Sydney Harbour Bridge**: Start your day with an early morning walk across the iconic bridge, enjoying stunning views of the Sydney Opera House and the harbor.
# - **Explore Circular Quay**: Stroll around this vibrant area and grab a coffee or light breakfast from one of the cozy waterfront cafes.
#
# ### Mid-Morning
# - **Visit the Sydney Opera House**: Take a guided tour of this world-famous architectural marvel or simply enjoy the exterior views and photo opportunities.
#
# ### Lunch
# - **Dine at Darling Harbour**: Head to Darling Harbour for a delicious lunch. Many restaurants offer waterfront seating and diverse menus featuring seafood, Australian dishes, and international cuisine.
#
# ### Afternoon
# - **Relax at Bondi Beach**: Spend the afternoon at Sydney’s iconic Bondi Beach. Take a dip, sunbathe, or explore local shops and cafés along Bondi’s promenade.
# - **Bondi to Coogee Walk**: If you're up for it, enjoy the scenic coastal walk from Bondi to Coogee, offering unbelievable views of the ocean and cliffs.
#
# ### Evening
# - **Sunset Ferry Ride to Manly Beach**: Take a ferry from Circular Quay to Manly Beach. The ride itself is stunning, especially during sunset.
# - **Dinner by Manly Beach**: Enjoy a relaxing dinner at one of the oceanfront restaurants in Manly before heading back.
#
# Have an amazing day exploring Sydney! Let me know if you’d like more personalizations or additional recommendations.
