# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a basic agent.
#
# The goal of this sample is to show you the steps that we will later use in the additional code samples when implementing the different agentic patterns.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
import os 
from typing import Annotated
from openai import AsyncOpenAI

from dotenv import load_dotenv

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## Creating the Client
#
# In this sample, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) for access to the LLM.
#
# The `ai_model_id` is defined as `gpt-4o-mini`. Try changing the model to another model available on the GitHub Models marketplace to see the different results.
#
# For us to use the `Azure Inference SDK` that is used for the `base_url` for GitHub Models, we will use the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) to use Semantic Kernel for other model providers.

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
load_dotenv()
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Below we create the Agent called `TravelAgent`.
#
# For this example, we are using very simple instructions. You can change these instructions to see how the agent responds differently.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agent
#
# Now we can run the Agent by defining a thread of type `ChatHistoryAgentThread`.  Any required system messages are provided to the agent's invoke_stream `messages` keyword argument.
#
# After these are defined, we create a `user_inputs` that will be what the user is sending to the agent. In this case, we have set this message to `Plan me a sunny vacation`.
#
# Feel free to change this message to see how the agent responds differently.

# %%
async def main():
    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: ChatHistoryAgentThread | None = None

    user_inputs = [
        "Plan me a day trip to the beach."
    ]

    for user_input in user_inputs:
        print(f"# User: {user_input}\n")
        first_chunk = True
        async for response in agent.invoke_stream(
            messages=user_input, thread=thread,
        ):
            # 5. Print the response
            if first_chunk:
                print(f"# {response.name}: ", end="", flush=True)
                first_chunk = False
            print(f"{response}", end="", flush=True)
            thread = response.thread
        print()

    # Clean up the thread
    await thread.delete() if thread else None

await main()
# Out:
# # User: Plan me a gay day trip.
#
# # TravelAgent: I have planned a gay day trip for you in New York, USA! Here’s a fun and inclusive itinerary:
#
# ### Morning:
# - **Breakfast at Cafeteria**: Start your day with a delicious breakfast at Cafeteria, a popular establishment known for its vibrant atmosphere and LGBTQ+ friendly vibe.
#
# ### Mid-Morning:
# - **Visit Stonewall Inn**: Head over to the Stonewall Inn, the birthplace of the modern LGBTQ+ rights movement. Explore the historic site and appreciate its significance while enjoying a cup of coffee at nearby cafes.
#
# ### Afternoon:
# - **Lunch in the West Village**: Enjoy lunch in the West Village, where you'll find plenty of eclectic shops and eateries. Try out spots like Westville or The Cubbyhole for a casual meal.
#
# ### After Lunch:
# - **Cultural Exploration**: Visit The Leslie-Lohman Museum of Gay and Lesbian Art. It’s a great place to explore queer art and culture.
#
# ### Late Afternoon:
# - **Hudson River Park**: Take a leisurely walk or rent a bike along the scenic paths of Hudson River Park. Relax by the waterfront and soak in the views.
#
# ### Evening:
# - **Dinner at Industry Bar**: Treat yourself to dinner at Industry Bar, a lively spot with great food, cocktails, and a friendly atmosphere.
#
# ### Night:
# - **Drag Show at The Stonewall Inn**: End your day with an entertaining drag show at The Stonewall Inn. This iconic venue often features fabulous performances guaranteed to make you laugh and cheer!
#
# ### Additional Tips:
# - Check local calendars for any LGBTQ+ events happening during your visit.
# - Consider public transport or rideshares to navigate easily around NYC.
#
# Enjoy your fabulous day in New York!
# # User: I want to make sure me and my gay partner won't be arrested and will have a good time.
#
# # TravelAgent: New York City is generally a very LGBTQ+ friendly destination, and you and your partner should feel safe and welcomed throughout your day trip. However, here are a few tips to ensure you have a great time without any issues:
#
# ### Safety Tips:
# 1. **Stay in Well-Lit Areas**: Stick to well-lit and populated areas, especially at night. The West Village, Chelsea, and areas around Hudson River Park are generally safe and lively.
#
# 2. **Be Mindful of Your Surroundings**: While NYC is LGBTQ+ friendly, always be aware of your surroundings. If something feels off, trust your instincts and move to a busier area.
#
# 3. **Respectful PDA**: While New York is generally accepting, it's always a good idea to be aware of your surroundings regarding public displays of affection, especially in less touristy areas.
#
# 4. **Know Your Rights**: Familiarize yourself with local laws and rights regarding LGBTQ+ individuals. New York has supportive policies, but it's always good to be informed.
#
# 5. **Travel Smart**: Use reputable transportation options, and consider downloading rideshare apps for safe travel from one location to another.
#
# ### Having a Great Time:
# - **Engage with the Community**: Don't hesitate to talk to locals or other travelers. The LGBTQ+ community in NYC is vibrant, and you'll find plenty of friendly faces.
#
# - **Participate in Events**: If your trip coincides with LGBTQ+ events, parades, or rallies, consider joining in! It's a great way to immerse yourself in the culture.
#
# - **Explore LGBTQ+ History**: Take time to learn about the rich history of the LGBTQ+ movement in NYC. Visit places like the Stonewall Inn, as it will enrich your experience.
#
# - **Go to LGBTQ+ Friendly Venues**: Most places, including bars, restaurants, and clubs in the West Village and Chelsea, are welcoming to LGBTQ+ couples, so enjoy the inclusivity!
#
# ### Overall:
# NYC is an iconic and accepting destination where you and your partner can enjoy your time together freely. As long as you stay aware and respect yourself and others, you should have a wonderful experience. Enjoy your day!
# # User: I don't like it. Pick another one.
#
# # TravelAgent: I've picked another destination for you: **Bali, Indonesia**. Here’s a fun and inclusive gay day trip itinerary for you and your partner:
#
# ### Morning:
# - **Breakfast at Cafe Organic**: Start your day with a healthy breakfast at Cafe Organic, known for its vibrant atmosphere and delicious smoothie bowls.
#
# ### Mid-Morning:
# - **Visit Ubud Monkey Forest**: Explore the Ubud Monkey Forest, a scenic sanctuary populated by playful monkeys. Just make sure to follow the guidelines for interactions to keep both you and the animals safe.
#
# ### Afternoon:
# - **Lunch at The Elephant**: Enjoy a delicious lunch at The Elephant, offering a variety of vegetarian and vegan dishes in a tranquil setting with views of rice paddies.
#
# ### After Lunch:
# - **Explore Ubud Market**: Take a stroll through the Ubud Art Market to shop for unique handicrafts, clothing, and souvenirs. This is also a great spot to support local artisans.
#
# ### Late Afternoon:
# - **Relaxing Spa Experience**: Treat yourselves to a couple's spa day at one of Bali's many luxurious spas. A Balinese massage can be a delightful way to unwind together.
#
# ### Evening:
# - **Dinner at La Baracca**: Enjoy dinner at La Baracca, an Italian restaurant with a welcoming vibe for LGBTQ+ individuals. Their wood-fired pizzas and homemade pasta are a must-try.
#
# ### Night:
# - **Visit a Gay-Friendly Bar or Club**: Head to a gay-friendly bar or club in Seminyak or Ubud. Venues like Club Égo or Bali Joe are vibrant spots with fun drag shows and a friendly atmosphere.
#
# ### Additional Tips:
# - **Respect Local Customs**: While Bali is generally accepting, it's important to respect local customs and dress modestly when visiting temples or local areas.
# - **Stay in Gay-Friendly Accommodations**: Look for hotels or resorts that are LGBTQ+ friendly to ensure a comfortable stay.
# - **Stay Safe**: Keep an eye on your belongings and be aware of your surroundings, especially when exploring nightlife.
#
# Enjoy your fabulous day in Bali! If you'd like more variations, just let me know!
